# %% [markdown]
# # Test Deterministic Short-Term Plasticity (STP)

# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import numpy as np
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
rootFolder = '/home/fernando/S1_netpyne/sim/'
rootFolder = '/home/fernando/Dropbox/SUNY/2022/S1_netpyne/sim/'

# rootFolder = os.getcwd()
os.chdir(rootFolder)
print(rootFolder)
folder = os.listdir('cell_data/')
folder = sorted(folder)

savedata = 1 # Save Netpyne and BBP soma_voltage
# Out:
# /home/fernando/Dropbox/SUNY/2022/S1_netpyne/sim/

# %%
# !nrnivmodl mod

# %%
def loadTemplateName(cellnumber):     
    f = open(outFolder+'/template.hoc', 'r')
    for line in f.readlines():
        if 'begintemplate' in line:
            templatename = str(line)     
    templatename=templatename[:-1]        
    templatename=templatename[14:]
    return templatename

# %% [markdown]
# ## Netpyne

# %%
from netpyne import specs, sim   

# Network parameters
netParams = specs.NetParams()  # object of class NetParams to store the network parameters

# %%
# %matplotlib inline

# %%
## cfg  
cfg = specs.SimConfig()					            # object of class SimConfig to store simulation configuration
cfg.duration = 4000.0 						            # Duration of the simulation, in ms
cfg.dt = 0.05								                # Internal integration timestep to use
cfg.verbose = False							                # Show detailed messages 
cfg.recordTraces = {'V_soma':{'sec':'soma','loc':0.5,'var':'v'}}  # Dict with traces to record
cfg.recordStep = 0.1 			
cfg.printRunTime = 0.1 # in sec			

cfg.seeds = {'conn': 1234, 'stim': 1234, 'loc': 1234} 
cfg.hParams = {'celsius': 34, 'v_init': -65.0}  
cfg.verbose = True
cfg.createNEURONObj = True
cfg.createPyStruct = True  
#------------------------------------------------------------------------------
# Saving
#------------------------------------------------------------------------------
cfg.filename = 'model_output'  			# Set file output name
cfg.savePickle = False         	## Save pkl file
cfg.saveJson = False	           	## Save json file
cfg.saveDataInclude = ['simData'] ## 'simData' , 'simConfig', 'netParams'
cfg.backupCfgFile = None 		##  
cfg.gatherOnlySimData = False	##  
cfg.saveCellSecs = False			
cfg.saveCellConns = True	

cfg.analysis['plotTraces'] = {'include': [i for i in range(120)], 'oneFigPer': 'trace', 'overlay': True, 'timeRange': [0,3600], 'saveFig': True, 'showFig': True, 'figSize':(12,4)} # Plot recorded traces for this list of cells
# cfg.analysis['plotShape'] = {'includePre': [0],'includePre': [0], 'saveFig': True, 'showFig': True, 'figSize':(12,12)}

# %%
for i,metype in enumerate(folder):
    print(i,metype)
# Out:
# 0 L1_DAC_bNAC219_1
# 1 L1_DAC_bNAC219_2
# 2 L1_DAC_bNAC219_3
# 3 L1_DAC_bNAC219_4
# 4 L1_DAC_bNAC219_5
# 5 L1_DAC_cNAC187_1
# 6 L1_DAC_cNAC187_2
# 7 L1_DAC_cNAC187_3
# 8 L1_DAC_cNAC187_4
# 9 L1_DAC_cNAC187_5
# 10 L1_DLAC_cNAC187_1
# 11 L1_DLAC_cNAC187_2
# 12 L1_DLAC_cNAC187_3
# 13 L1_DLAC_cNAC187_4
# 14 L1_DLAC_cNAC187_5
# 15 L1_HAC_bNAC219_1
# 16 L1_HAC_bNAC219_2
# 17 L1_HAC_bNAC219_3
# 18 L1_HAC_bNAC219_4
# 19 L1_HAC_bNAC219_5
# 20 L1_HAC_cIR216_1
# 21 L1_HAC_cIR216_2
# 22 L1_HAC_cIR216_3
# 23 L1_HAC_cIR216_4
# 24 L1_HAC_cIR216_5
# 25 L1_HAC_cNAC187_1
# 26 L1_HAC_cNAC187_2
# 27 L1_HAC_cNAC187_3
# 28 L1_HAC_cNAC187_4
# 29 L1_HAC_cNAC187_5
# 30 L1_NGC-DA_bNAC219_1
# 31 L1_NGC-DA_bNAC219_2
# 32 L1_NGC-DA_bNAC219_3
# 33 L1_NGC-DA_bNAC219_4
# 34 L1_NGC-DA_bNAC219_5
# 35 L1_NGC-DA_cACint209_1
# 36 L1_NGC-DA_cACint209_2
# 37 L1_NGC-DA_cACint209_3
# 38 L1_NGC-DA_cACint209_4
# 39 L1_NGC-DA_cACint209_5
# 40 L1_NGC-DA_cNAC187_1
# 41 L1_NGC-DA_cNAC187_2
# 42 L1_NGC-DA_cNAC187_3
# 43 L1_NGC-DA_cNAC187_4
# 44 L1_NGC-DA_cNAC187_5
# 45 L1_NGC-DA_cSTUT189_1
# 46 L1_NGC-DA_cSTUT189_2
# 47 L1_NGC-DA_cSTUT189_3
# 48 L1_NGC-DA_cSTUT189_4
# 49 L1_NGC-DA_cSTUT189_5
# 50 L1_NGC-SA_cNAC187_1
# 51 L1_NGC-SA_cNAC187_2
# 52 L1_NGC-SA_cNAC187_3
# 53 L1_NGC-SA_cNAC187_4
# 54 L1_NGC-SA_cNAC187_5
# 55 L1_SLAC_bNAC219_1
# 56 L1_SLAC_bNAC219_2
# 57 L1_SLAC_bNAC219_3
# 58 L1_SLAC_bNAC219_4
# 59 L1_SLAC_bNAC219_5
# 60 L1_SLAC_cACint209_1
# 61 L1_SLAC_cACint209_2
# 62 L1_SLAC_cACint209_3
# 63 L1_SLAC_cACint209_4
# 64 L1_SLAC_cACint209_5
# 65 L1_SLAC_cNAC187_1
# 66 L1_SLAC_cNAC187_2
# 67 L1_SLAC_cNAC187_3
# 68 L1_SLAC_cNAC187_4
# 69 L1_SLAC_cNAC187_5
# 70 L23_BP_bAC217_1
# 71 L23_BP_bAC217_2
# 72 L23_BP_bAC217_3
# 73 L23_BP_bAC217_4
# 74 L23_BP_bAC217_5
# 75 L23_BP_bIR215_1
# 76 L23_BP_bIR215_2
# 77 L23_BP_bIR215_3
# 78 L23_BP_bIR215_4
# 79 L23_BP_bIR215_5
# 80 L23_BP_bNAC219_1
# 81 L23_BP_bNAC219_2
# 82 L23_BP_bNAC219_3
# 83 L23_BP_bNAC219_4
# 84 L23_BP_bNAC219_5
# 85 L23_BP_cACint209_1
# 86 L23_BP_cACint209_2
# 87 L23_BP_cACint209_3
# 88 L23_BP_cACint209_4
# 89 L23_BP_cACint209_5
# 90 L23_BP_cNAC187_1
# 91 L23_BP_cNAC187_2
# 92 L23_BP_cNAC187_3
# 93 L23_BP_cNAC187_4
# 94 L23_BP_cNAC187_5
# 95 L23_BP_dSTUT214_1
# 96 L23_BP_dSTUT214_2
# 97 L23_BP_dSTUT214_3
# 98 L23_BP_dSTUT214_4
# 99 L23_BP_dSTUT214_5
# 100 L23_BTC_bAC217_1
# 101 L23_BTC_bAC217_2
# 102 L23_BTC_bAC217_3
# 103 L23_BTC_bAC217_4
# 104 L23_BTC_bAC217_5
# 105 L23_BTC_bIR215_1
# 106 L23_BTC_bIR215_2
# 107 L23_BTC_bIR215_3
# 108 L23_BTC_bIR215_4
# 109 L23_BTC_bIR215_5
# 110 L23_BTC_bNAC219_1
# 111 L23_BTC_bNAC219_2
# 112 L23_BTC_bNAC219_3
# 113 L23_BTC_bNAC219_4
# 114 L23_BTC_bNAC219_5
# 115 L23_BTC_cACint209_1
# 116 L23_BTC_cACint209_2
# 117 L23_BTC_cACint209_3
# 118 L23_BTC_cACint209_4
# 119 L23_BTC_cACint209_5
# 120 L23_BTC_cNAC187_1
# 121 L23_BTC_cNAC187_2
# 122 L23_BTC_cNAC187_3
# 123 L23_BTC_cNAC187_4
# 124 L23_BTC_cNAC187_5
# 125 L23_ChC_cACint209_1
# 126 L23_ChC_cACint209_2
# 127 L23_ChC_cACint209_3
# 128 L23_ChC_cACint209_4
# 129 L23_ChC_cACint209_5
# 130 L23_ChC_cNAC187_1
# 131 L23_ChC_cNAC187_2
# 132 L23_ChC_cNAC187_3
# 133 L23_ChC_cNAC187_4
# 134 L23_ChC_cNAC187_5
# 135 L23_ChC_dNAC222_1
# 136 L23_ChC_dNAC222_2
# 137 L23_ChC_dNAC222_3
# 138 L23_ChC_dNAC222_4
# 139 L23_ChC_dNAC222_5
# 140 L23_DBC_bAC217_1
# 141 L23_DBC_bAC217_2
# 142 L23_DBC_bAC217_3
# 143 L23_DBC_bAC217_4
# 144 L23_DBC_bAC217_5
# 145 L23_DBC_bIR215_1
# 146 L23_DBC_bIR215_2
# 147 L23_DBC_bIR215_3
# 148 L23_DBC_bIR215_4
# 232 L23_NBC_cIR216_3
# 233 L23_NBC_cIR216_4
# 234 L23_NBC_cIR216_5
# 235 L23_NBC_cNAC187_1
# 236 L23_NBC_cNAC187_2
# 237 L23_NBC_cNAC187_3
# 238 L23_NBC_cNAC187_4
# 239 L23_NBC_cNAC187_5
# 240 L23_NBC_dNAC222_1
# 241 L23_NBC_dNAC222_2
# 242 L23_NBC_dNAC222_3
# 243 L23_NBC_dNAC222_4
# 244 L23_NBC_dNAC222_5
# 245 L23_NGC_bNAC219_1
# 246 L23_NGC_bNAC219_2
# 247 L23_NGC_bNAC219_3
# 248 L23_NGC_bNAC219_4
# 249 L23_NGC_bNAC219_5
# 250 L23_NGC_cACint209_1
# 251 L23_NGC_cACint209_2
# 252 L23_NGC_cACint209_3
# 253 L23_NGC_cACint209_4
# 254 L23_NGC_cACint209_5
# 255 L23_NGC_cNAC187_1
# 256 L23_NGC_cNAC187_2
# 257 L23_NGC_cNAC187_3
# 258 L23_NGC_cNAC187_4
# 259 L23_NGC_cNAC187_5
# 260 L23_NGC_cSTUT189_1
# 261 L23_NGC_cSTUT189_2
# 262 L23_NGC_cSTUT189_3
# 263 L23_NGC_cSTUT189_4
# 264 L23_NGC_cSTUT189_5
# 265 L23_PC_cADpyr229_1
# 266 L23_PC_cADpyr229_2
# 267 L23_PC_cADpyr229_3
# 268 L23_PC_cADpyr229_4
# 269 L23_PC_cADpyr229_5
# 270 L23_SBC_bNAC219_1
# 271 L23_SBC_bNAC219_2
# 272 L23_SBC_bNAC219_3
# 273 L23_SBC_bNAC219_4
# 274 L23_SBC_bNAC219_5
# 275 L23_SBC_cACint209_1
# 276 L23_SBC_cACint209_2
# 277 L23_SBC_cACint209_3
# 278 L23_SBC_cACint209_4
# 279 L23_SBC_cACint209_5
# 280 L23_SBC_dNAC222_1
# 281 L23_SBC_dNAC222_2
# 282 L23_SBC_dNAC222_3
# 283 L23_SBC_dNAC222_4
# 284 L23_SBC_dNAC222_5
# 285 L4_BP_bAC217_1
# 286 L4_BP_bAC217_2
# 287 L4_BP_bAC217_3
# 288 L4_BP_bAC217_4
# 289 L4_BP_bAC217_5
# 290 L4_BP_bIR215_1
# 291 L4_BP_bIR215_2
# 292 L4_BP_bIR215_3
# 293 L4_BP_bIR215_4
# 294 L4_BP_bIR215_5
# 295 L4_BP_bNAC219_1
# 296 L4_BP_bNAC219_2
# 297 L4_BP_bNAC219_3
# 298 L4_BP_bNAC219_4
# 299 L4_BP_bNAC219_5
# 300 L4_BP_cACint209_1
# 301 L4_BP_cACint209_2
# 302 L4_BP_cACint209_3
# 303 L4_BP_cACint209_4
# 304 L4_BP_cACint209_5
# 305 L4_BP_cNAC187_1
# 306 L4_BP_cNAC187_2
# 307 L4_BP_cNAC187_3
# 308 L4_BP_cNAC187_4
# 309 L4_BP_cNAC187_5
# 310 L4_BP_dSTUT214_1
# 311 L4_BP_dSTUT214_2
# 312 L4_BP_dSTUT214_3
# 313 L4_BP_dSTUT214_4
# 314 L4_BP_dSTUT214_5
# 315 L4_BTC_bAC217_1
# 316 L4_BTC_bAC217_2
# 317 L4_BTC_bAC217_3
# 318 L4_BTC_bAC217_4
# 319 L4_BTC_bAC217_5
# 320 L4_BTC_bIR215_1
# 321 L4_BTC_bIR215_2
# 322 L4_BTC_bIR215_3
# 323 L4_BTC_bIR215_4
# 324 L4_BTC_bIR215_5
# 325 L4_BTC_bSTUT213_1
# 326 L4_BTC_bSTUT213_2
# 327 L4_BTC_bSTUT213_3
# 328 L4_BTC_bSTUT213_4
# 329 L4_BTC_bSTUT213_5
# 330 L4_BTC_cACint209_1
# 331 L4_BTC_cACint209_2
# 332 L4_BTC_cACint209_3
# 333 L4_BTC_cACint209_4
# 334 L4_BTC_cACint209_5
# 335 L4_BTC_cNAC187_1
# 336 L4_BTC_cNAC187_2
# 337 L4_BTC_cNAC187_3
# 338 L4_BTC_cNAC187_4
# 339 L4_BTC_cNAC187_5
# 340 L4_BTC_dNAC222_1
# 341 L4_BTC_dNAC222_2
# 342 L4_BTC_dNAC222_3
# 343 L4_BTC_dNAC222_4
# 344 L4_BTC_dNAC222_5
# 345 L4_ChC_cACint209_1
# 346 L4_ChC_cACint209_2
# 347 L4_ChC_cACint209_3
# 348 L4_ChC_cACint209_4
# 349 L4_ChC_cACint209_5
# 350 L4_ChC_cNAC187_1
# 351 L4_ChC_cNAC187_2
# 352 L4_ChC_cNAC187_3
# 353 L4_ChC_cNAC187_4
# 354 L4_ChC_cNAC187_5
# 355 L4_ChC_dNAC222_1
# 356 L4_ChC_dNAC222_2
# 357 L4_ChC_dNAC222_3
# 358 L4_ChC_dNAC222_4
# 359 L4_ChC_dNAC222_5
# 360 L4_DBC_bAC217_1
# 361 L4_DBC_bAC217_2
# 362 L4_DBC_bAC217_3
# 363 L4_DBC_bAC217_4
# 364 L4_DBC_bAC217_5
# 365 L4_DBC_bIR215_1
# 366 L4_DBC_bIR215_2
# 367 L4_DBC_bIR215_3
# 368 L4_DBC_bIR215_4
# 369 L4_DBC_bIR215_5
# 370 L4_DBC_bNAC219_1
# 371 L4_DBC_bNAC219_2
# 372 L4_DBC_bNAC219_3
# 373 L4_DBC_bNAC219_4
# 374 L4_DBC_bNAC219_5
# 375 L4_DBC_bSTUT213_1
# 376 L4_DBC_bSTUT213_2
# 377 L4_DBC_bSTUT213_3
# 378 L4_DBC_bSTUT213_4
# 379 L4_DBC_bSTUT213_5
# 380 L4_DBC_cACint209_1
# 381 L4_DBC_cACint209_2
# 382 L4_DBC_cACint209_3
# 383 L4_DBC_cACint209_4
# 384 L4_DBC_cACint209_5
# 385 L4_DBC_cIR216_1
# 386 L4_DBC_cIR216_2
# 387 L4_DBC_cIR216_3
# 388 L4_DBC_cIR216_4
# 389 L4_DBC_cIR216_5
# 390 L4_DBC_cNAC187_1
# 391 L4_DBC_cNAC187_2
# 392 L4_DBC_cNAC187_3
# 393 L4_DBC_cNAC187_4
# 394 L4_DBC_cNAC187_5
# 477 L4_NGC_cNAC187_3
# 478 L4_NGC_cNAC187_4
# 479 L4_NGC_cNAC187_5
# 480 L4_NGC_cSTUT189_1
# 481 L4_NGC_cSTUT189_2
# 482 L4_NGC_cSTUT189_3
# 483 L4_NGC_cSTUT189_4
# 484 L4_NGC_cSTUT189_5
# 485 L4_PC_cADpyr230_1
# 486 L4_PC_cADpyr230_2
# 487 L4_PC_cADpyr230_3
# 488 L4_PC_cADpyr230_4
# 489 L4_PC_cADpyr230_5
# 490 L4_SBC_bNAC219_1
# 491 L4_SBC_bNAC219_2
# 492 L4_SBC_bNAC219_3
# 493 L4_SBC_bNAC219_4
# 494 L4_SBC_bNAC219_5
# 495 L4_SBC_cACint209_1
# 496 L4_SBC_cACint209_2
# 497 L4_SBC_cACint209_3
# 498 L4_SBC_cACint209_4
# 499 L4_SBC_cACint209_5
# 500 L4_SBC_dNAC222_1
# 501 L4_SBC_dNAC222_2
# 502 L4_SBC_dNAC222_3
# 503 L4_SBC_dNAC222_4
# 504 L4_SBC_dNAC222_5
# 505 L4_SP_cADpyr230_1
# 506 L4_SP_cADpyr230_2
# 507 L4_SP_cADpyr230_3
# 508 L4_SP_cADpyr230_4
# 509 L4_SP_cADpyr230_5
# 510 L4_SS_cADpyr230_1
# 511 L4_SS_cADpyr230_2
# 512 L4_SS_cADpyr230_3
# 513 L4_SS_cADpyr230_4
# 514 L4_SS_cADpyr230_5
# 515 L5_BP_bAC217_1
# 516 L5_BP_bAC217_2
# 517 L5_BP_bAC217_3
# 518 L5_BP_bAC217_4
# 519 L5_BP_bAC217_5
# 520 L5_BP_bIR215_1
# 521 L5_BP_bIR215_2
# 522 L5_BP_bIR215_3
# 523 L5_BP_bIR215_4
# 524 L5_BP_bIR215_5
# 525 L5_BP_bNAC219_1
# 526 L5_BP_bNAC219_2
# 527 L5_BP_bNAC219_3
# 528 L5_BP_bNAC219_4
# 529 L5_BP_bNAC219_5
# 530 L5_BP_cACint209_1
# 531 L5_BP_cACint209_2
# 532 L5_BP_cACint209_3
# 533 L5_BP_cACint209_4
# 534 L5_BP_cACint209_5
# 535 L5_BP_cNAC187_1
# 536 L5_BP_cNAC187_2
# 537 L5_BP_cNAC187_3
# 538 L5_BP_cNAC187_4
# 539 L5_BP_cNAC187_5
# 540 L5_BP_dSTUT214_1
# 541 L5_BP_dSTUT214_2
# 542 L5_BP_dSTUT214_3
# 543 L5_BP_dSTUT214_4
# 544 L5_BP_dSTUT214_5
# 545 L5_BTC_bAC217_1
# 546 L5_BTC_bAC217_2
# 547 L5_BTC_bAC217_3
# 548 L5_BTC_bAC217_4
# 549 L5_BTC_bAC217_5
# 550 L5_BTC_cACint209_1
# 551 L5_BTC_cACint209_2
# 552 L5_BTC_cACint209_3
# 553 L5_BTC_cACint209_4
# 554 L5_BTC_cACint209_5
# 555 L5_BTC_cNAC187_1
# 556 L5_BTC_cNAC187_2
# 557 L5_BTC_cNAC187_3
# 558 L5_BTC_cNAC187_4
# 559 L5_BTC_cNAC187_5
# 560 L5_ChC_cACint209_1
# 561 L5_ChC_cACint209_2
# 562 L5_ChC_cACint209_3
# 563 L5_ChC_cACint209_4
# 564 L5_ChC_cACint209_5
# 565 L5_ChC_cNAC187_1
# 566 L5_ChC_cNAC187_2
# 567 L5_ChC_cNAC187_3
# 568 L5_ChC_cNAC187_4
# 569 L5_ChC_cNAC187_5
# 570 L5_ChC_dNAC222_1
# 571 L5_ChC_dNAC222_2
# 572 L5_ChC_dNAC222_3
# 573 L5_ChC_dNAC222_4
# 574 L5_ChC_dNAC222_5
# 575 L5_DBC_bAC217_1
# 576 L5_DBC_bAC217_2
# 577 L5_DBC_bAC217_3
# 578 L5_DBC_bAC217_4
# 579 L5_DBC_bAC217_5
# 580 L5_DBC_bIR215_1
# 581 L5_DBC_bIR215_2
# 582 L5_DBC_bIR215_3
# 583 L5_DBC_bIR215_4
# 584 L5_DBC_bIR215_5
# 585 L5_DBC_bNAC219_1
# 586 L5_DBC_bNAC219_2
# 587 L5_DBC_bNAC219_3
# 588 L5_DBC_bNAC219_4
# 589 L5_DBC_bNAC219_5
# 590 L5_DBC_bSTUT213_1
# 591 L5_DBC_bSTUT213_2
# 592 L5_DBC_bSTUT213_3
# 593 L5_DBC_bSTUT213_4
# 594 L5_DBC_bSTUT213_5
# 595 L5_DBC_cACint209_1
# 596 L5_DBC_cACint209_2
# 597 L5_DBC_cACint209_3
# 598 L5_DBC_cACint209_4
# 599 L5_DBC_cACint209_5
# 600 L5_DBC_cIR216_1
# 601 L5_DBC_cIR216_2
# 602 L5_DBC_cIR216_3
# 603 L5_DBC_cIR216_4
# 604 L5_DBC_cIR216_5
# 605 L5_DBC_cNAC187_1
# 606 L5_DBC_cNAC187_2
# 607 L5_DBC_cNAC187_3
# 608 L5_DBC_cNAC187_4
# 609 L5_DBC_cNAC187_5
# 610 L5_LBC_bAC217_1
# 611 L5_LBC_bAC217_2
# 612 L5_LBC_bAC217_3
# 613 L5_LBC_bAC217_4
# 614 L5_LBC_bAC217_5
# 615 L5_LBC_cACint209_1
# 616 L5_LBC_cACint209_2
# 617 L5_LBC_cACint209_3
# 618 L5_LBC_cACint209_4
# 619 L5_LBC_cACint209_5
# 620 L5_LBC_cIR216_1
# 621 L5_LBC_cIR216_2
# 622 L5_LBC_cIR216_3
# 623 L5_LBC_cIR216_4
# 624 L5_LBC_cIR216_5
# 625 L5_LBC_cNAC187_1
# 626 L5_LBC_cNAC187_2
# 627 L5_LBC_cNAC187_3
# 628 L5_LBC_cNAC187_4
# 629 L5_LBC_cNAC187_5
# 630 L5_LBC_cSTUT189_1
# 631 L5_LBC_cSTUT189_2
# 632 L5_LBC_cSTUT189_3
# 633 L5_LBC_cSTUT189_4
# 634 L5_LBC_cSTUT189_5
# 635 L5_LBC_dNAC222_1
# 636 L5_LBC_dNAC222_2
# 637 L5_LBC_dNAC222_3
# 638 L5_LBC_dNAC222_4
# 639 L5_LBC_dNAC222_5
# 722 L5_NGC_bNAC219_3
# 723 L5_NGC_bNAC219_4
# 724 L5_NGC_bNAC219_5
# 725 L5_NGC_cACint209_1
# 726 L5_NGC_cACint209_2
# 727 L5_NGC_cACint209_3
# 728 L5_NGC_cACint209_4
# 729 L5_NGC_cACint209_5
# 730 L5_NGC_cNAC187_1
# 731 L5_NGC_cNAC187_2
# 732 L5_NGC_cNAC187_3
# 733 L5_NGC_cNAC187_4
# 734 L5_NGC_cNAC187_5
# 735 L5_NGC_cSTUT189_1
# 736 L5_NGC_cSTUT189_2
# 737 L5_NGC_cSTUT189_3
# 738 L5_NGC_cSTUT189_4
# 739 L5_NGC_cSTUT189_5
# 740 L5_SBC_bNAC219_1
# 741 L5_SBC_bNAC219_2
# 742 L5_SBC_bNAC219_3
# 743 L5_SBC_bNAC219_4
# 744 L5_SBC_bNAC219_5
# 745 L5_SBC_cACint209_1
# 746 L5_SBC_cACint209_2
# 747 L5_SBC_cACint209_3
# 748 L5_SBC_cACint209_4
# 749 L5_SBC_cACint209_5
# 750 L5_SBC_dNAC222_1
# 751 L5_SBC_dNAC222_2
# 752 L5_SBC_dNAC222_3
# 753 L5_SBC_dNAC222_4
# 754 L5_SBC_dNAC222_5
# 755 L5_STPC_cADpyr232_1
# 756 L5_STPC_cADpyr232_2
# 757 L5_STPC_cADpyr232_3
# 758 L5_STPC_cADpyr232_4
# 759 L5_STPC_cADpyr232_5
# 760 L5_TTPC1_cADpyr232_1
# 761 L5_TTPC1_cADpyr232_2
# 762 L5_TTPC1_cADpyr232_3
# 763 L5_TTPC1_cADpyr232_4
# 764 L5_TTPC1_cADpyr232_5
# 765 L5_TTPC2_cADpyr232_1
# 766 L5_TTPC2_cADpyr232_2
# 767 L5_TTPC2_cADpyr232_3
# 768 L5_TTPC2_cADpyr232_4
# 769 L5_TTPC2_cADpyr232_5
# 770 L5_UTPC_cADpyr232_1
# 771 L5_UTPC_cADpyr232_2
# 772 L5_UTPC_cADpyr232_3
# 773 L5_UTPC_cADpyr232_4
# 774 L5_UTPC_cADpyr232_5
# 775 L6_BPC_cADpyr231_1
# 776 L6_BPC_cADpyr231_2
# 777 L6_BPC_cADpyr231_3
# 778 L6_BPC_cADpyr231_4
# 779 L6_BPC_cADpyr231_5
# 780 L6_BP_bAC217_1
# 781 L6_BP_bAC217_2
# 782 L6_BP_bAC217_3
# 783 L6_BP_bAC217_4
# 784 L6_BP_bAC217_5
# 785 L6_BP_bIR215_1
# 786 L6_BP_bIR215_2
# 787 L6_BP_bIR215_3
# 788 L6_BP_bIR215_4
# 789 L6_BP_bIR215_5
# 790 L6_BP_bNAC219_1
# 791 L6_BP_bNAC219_2
# 792 L6_BP_bNAC219_3
# 793 L6_BP_bNAC219_4
# 794 L6_BP_bNAC219_5
# 795 L6_BP_cACint209_1
# 796 L6_BP_cACint209_2
# 797 L6_BP_cACint209_3
# 798 L6_BP_cACint209_4
# 799 L6_BP_cACint209_5
# 800 L6_BP_cNAC187_1
# 801 L6_BP_cNAC187_2
# 802 L6_BP_cNAC187_3
# 803 L6_BP_cNAC187_4
# 804 L6_BP_cNAC187_5
# 805 L6_BP_dSTUT214_1
# 806 L6_BP_dSTUT214_2
# 807 L6_BP_dSTUT214_3
# 808 L6_BP_dSTUT214_4
# 809 L6_BP_dSTUT214_5
# 810 L6_BTC_bAC217_1
# 811 L6_BTC_bAC217_2
# 812 L6_BTC_bAC217_3
# 813 L6_BTC_bAC217_4
# 814 L6_BTC_bAC217_5
# 815 L6_BTC_cACint209_1
# 816 L6_BTC_cACint209_2
# 817 L6_BTC_cACint209_3
# 818 L6_BTC_cACint209_4
# 819 L6_BTC_cACint209_5
# 820 L6_BTC_cNAC187_1
# 821 L6_BTC_cNAC187_2
# 822 L6_BTC_cNAC187_3
# 823 L6_BTC_cNAC187_4
# 824 L6_BTC_cNAC187_5
# 825 L6_ChC_cACint209_1
# 826 L6_ChC_cACint209_2
# 827 L6_ChC_cACint209_3
# 828 L6_ChC_cACint209_4
# 829 L6_ChC_cACint209_5
# 830 L6_ChC_cNAC187_1
# 831 L6_ChC_cNAC187_2
# 832 L6_ChC_cNAC187_3
# 833 L6_ChC_cNAC187_4
# 834 L6_ChC_cNAC187_5
# 835 L6_ChC_dNAC222_1
# 836 L6_ChC_dNAC222_2
# 837 L6_ChC_dNAC222_3
# 838 L6_ChC_dNAC222_4
# 839 L6_ChC_dNAC222_5
# 840 L6_DBC_bAC217_1
# 841 L6_DBC_bAC217_2
# 842 L6_DBC_bAC217_3
# 843 L6_DBC_bAC217_4
# 844 L6_DBC_bAC217_5
# 845 L6_DBC_bIR215_1
# 846 L6_DBC_bIR215_2
# 847 L6_DBC_bIR215_3
# 848 L6_DBC_bIR215_4
# 849 L6_DBC_bIR215_5
# 850 L6_DBC_bNAC219_1
# 851 L6_DBC_bNAC219_2
# 852 L6_DBC_bNAC219_3
# 853 L6_DBC_bNAC219_4
# 854 L6_DBC_bNAC219_5
# 855 L6_DBC_bSTUT213_1
# 856 L6_DBC_bSTUT213_2
# 857 L6_DBC_bSTUT213_3
# 858 L6_DBC_bSTUT213_4
# 859 L6_DBC_bSTUT213_5
# 860 L6_DBC_cACint209_1
# 861 L6_DBC_cACint209_2
# 862 L6_DBC_cACint209_3
# 863 L6_DBC_cACint209_4
# 864 L6_DBC_cACint209_5
# 865 L6_DBC_cIR216_1
# 866 L6_DBC_cIR216_2
# 867 L6_DBC_cIR216_3
# 868 L6_DBC_cIR216_4
# 869 L6_DBC_cIR216_5
# 870 L6_DBC_cNAC187_1
# 871 L6_DBC_cNAC187_2
# 872 L6_DBC_cNAC187_3
# 873 L6_DBC_cNAC187_4
# 874 L6_DBC_cNAC187_5
# 875 L6_IPC_cADpyr231_1
# 876 L6_IPC_cADpyr231_2
# 877 L6_IPC_cADpyr231_3
# 878 L6_IPC_cADpyr231_4
# 879 L6_IPC_cADpyr231_5
# 880 L6_LBC_bAC217_1
# 881 L6_LBC_bAC217_2
------------------------------------------------------------------------------
# Cell parameters
#------------------------------------------------------------------------------
#StochKv_deterministic.mod
for cellnumber in cellspostE1+cellspostE2+cellspostE3+cellspostI:
    cellName = folder[cellnumber]
    outFolder = rootFolder+'/cell_data/'+folder[cellnumber]
    cellTemplateName = loadTemplateName(cellnumber)
    cellRule = netParams.importCellParams(label=cellName, somaAtOrigin=False,
        conds={'cellType': cellName, 'cellModel': 'HH_full'},
        fileName='cellwrapper.py',
        cellName='loadCell',
        cellInstance = True,
        cellArgs={'cellName': cellName, 'cellTemplateName': cellTemplateName})
# Out:
# NEURON: morphology_d5fa8128ae : a template cannot be redefined
#  in morphology.hoc near line 34
#  begintemplate morphology_d5fa8128ae
#                                    ^
#         xopen("morphology.hoc")
#       execute1("{xopen("mo...")
#     load_file("morphology.hoc")
#   xopen("template.hoc")
# NEURON: cACint209_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate cACint209_biophys
#                                ^
#         xopen("biophysics.hoc")
#       execute1("{xopen("bi...")
#     load_file("biophysics.hoc")
#   xopen("template.hoc")
# NEURON: synapses_d5fa8128ae : a template cannot be redefined
#  in synapses.hoc near line 31
#  begintemplate synapses_d5fa8128ae
#                                  ^
#         xopen("synapses.hoc")
#       execute1("{xopen("sy...")
#     load_file("synapses/s...")
#   xopen("template.hoc")
# 	0
# 	0
# 	0
# cACint209_L23_LBC_d5fa8128ae[0]
# NEURON: cACint209_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate cACint209_biophys
#                                ^
#         xopen("biophysics.hoc")
# NEURON: cACint209_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate cACint209_biophys
#                                ^
#         xopen("biophysics.hoc")
# 	1
# 	1
# 	1
# cACint209_L23_LBC_c6138544ab[0]
# 	1
# 	1
# 	1
# NEURON: cACint209_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate cACint209_biophys
#                                ^
#         xopen("biophysics.hoc")
# cACint209_L23_LBC_78b571a886[0]
# 	1
# 	1
# 	1
# NEURON: cACint209_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate cACint209_biophys
#                                ^
#         xopen("biophysics.hoc")
# cACint209_L23_LBC_fece30537a[0]
# 	1
# 	1
# 	1
# cACint209_L23_LBC_10ecac904b[0]
# 	1
# 	1
# 	1
# dNAC222_L23_LBC_df15689e81[0]
# NEURON: dNAC222_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate dNAC222_biophys
#                              ^
#         xopen("biophysics.hoc")
# NEURON: dNAC222_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate dNAC222_biophys
#                              ^
#         xopen("biophysics.hoc")
# 	1
# 	1
# 	1
# dNAC222_L23_LBC_3872d55b42[0]
# 	1
# 	1
# 	1
# dNAC222_L23_LBC_936c35a9e1[0]
# NEURON: dNAC222_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate dNAC222_biophys
#                              ^
#         xopen("biophysics.hoc")
# NEURON: dNAC222_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate dNAC222_biophys
#                              ^
#         xopen("biophysics.hoc")
# 	1
# 	1
# 	1
# dNAC222_L23_LBC_19cea46eb3[0]
# 	1
# 	1
# 	1
# dNAC222_L23_LBC_1b6313448d[0]
# 	1
# 	1
# 	1
# cADpyr231_L6_TPC_L4_3f1b0bd478[0]
# NEURON: cADpyr231_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate cADpyr231_biophys
#                                ^
#         xopen("biophysics.hoc")
# 	1
# 	1
# 	1
# cADpyr231_L6_TPC_L4_0cb1e9aa6b[0]
# NEURON: cADpyr231_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate cADpyr231_biophys
#                                ^
#         xopen("biophysics.hoc")
# 	1
# 	1
# 	1
# cADpyr231_L6_TPC_L4_184fd5677b[0]
# NEURON: cADpyr231_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate cADpyr231_biophys
#                                ^
#         xopen("biophysics.hoc")
# 	1
# 	1
# 	1
# cADpyr231_L6_TPC_L4_117b9dfb71[0]
# NEURON: cADpyr231_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate cADpyr231_biophys
#                                ^
#         xopen("biophysics.hoc")
# 	1
# 	1
# 	1
# cADpyr231_L6_TPC_L4_91b667d362[0]
# 	1
# 	1
# 	1
# cADpyr229_L23_PC_5ecbf9b163[0]
# NEURON: cADpyr229_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate cADpyr229_biophys
#                                ^
#         xopen("biophysics.hoc")
# 	1
# 	1
# 	1
# cADpyr229_L23_PC_8ef1aa6602[0]
# NEURON: cADpyr229_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate cADpyr229_biophys
#                                ^
#         xopen("biophysics.hoc")
# NEURON: cADpyr229_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate cADpyr229_biophys
#                                ^
# 	1
# 	1
# 	1
# cADpyr229_L23_PC_863902f300[0]
#     xopen("biophysics.hoc")
# NEURON: cADpyr229_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate cADpyr229_biophys
# 	1
# 	1
# 	1
# cADpyr229_L23_PC_c292d67a2e[0]
#                        ^
#         xopen("biophysics.hoc")
# 	1
# 	1
# 	1
# cADpyr229_L23_PC_c2e79db05a[0]

# %%
if cellName + '_a' in netParams.popParams.keys():
    print (cellName + '_a')

# %%
for cellnumber in cellspostE1+cellspostE2+cellspostE3:
    # ---------------------------------------------------------------------------------------------------- #
    cellName = folder[cellnumber]
    outFolder = rootFolder+'/cell_data/'+folder[cellnumber]
    cellTemplateName = loadTemplateName(cellnumber)
    
    # ---------------------------------------------------------------------------------------------------- #
    netParams.renameCellParamsSec(label=cellName, oldSec='soma_0', newSec='soma')
    
    for secname2 in netParams.cellParams[cellName]['secLists'].keys():
        if 'soma_0' in netParams.cellParams[cellName]['secLists'][secname2]:
            print(cellName,secname2,netParams.cellParams[cellName]['secLists'][secname2][0])
            netParams.cellParams[cellName]['secLists'][secname2][0] = 'soma'
    # ---------------------------------------------------------------------------------------------------- #
    
    nonSpiny = ['axon_0', 'axon_1']
    netParams.cellParams[cellName]['secLists']['spiny'] = [sec for sec in netParams.cellParams[cellName]['secLists']['all'] if sec not in nonSpiny]
    nonSpinyEE = ['axon_0', 'axon_1', 'soma']
    netParams.cellParams[cellName]['secLists']['spinyEE'] = [sec for sec in netParams.cellParams[cellName]['secLists']['all'] if sec not in nonSpinyEE]    
    
    # ---------------------------------------------------------------------------------------------------- #
    netParams.popParams[cellName + '_a'] = {'cellType': cellName, 'numCells': 1, 'cellModel': 'HH_full'}

# ----------------------------------------------------------------------------------------------------------------------------------------------------------- #
for cellnumber in cellspostI:
    # ---------------------------------------------------------------------------------------------------- #
    cellName = folder[cellnumber]
    outFolder = rootFolder+'/cell_data/'+folder[cellnumber]
    cellTemplateName = loadTemplateName(cellnumber)
    
    # ---------------------------------------------------------------------------------------------------- #
    netParams.renameCellParamsSec(label=cellName, oldSec='soma_0', newSec='soma')
    
    for secname2 in netParams.cellParams[cellName]['secLists'].keys():
        if 'soma_0' in netParams.cellParams[cellName]['secLists'][secname2]:
            print(cellName,secname2,netParams.cellParams[cellName]['secLists'][secname2][0])
            netParams.cellParams[cellName]['secLists'][secname2][0] = 'soma'
    # ---------------------------------------------------------------------------------------------------- #
    
    nonSpiny = ['axon_0', 'axon_1']
    netParams.cellParams[cellName]['secLists']['spiny'] = [sec for sec in netParams.cellParams[cellName]['secLists']['all'] if sec not in nonSpiny]
    nonSpinyEE = ['axon_0', 'axon_1', 'soma']
    netParams.cellParams[cellName]['secLists']['spinyEE'] = [sec for sec in netParams.cellParams[cellName]['secLists']['all'] if sec not in nonSpinyEE]    
    
    # ---------------------------------------------------------------------------------------------------- #
    netParams.popParams[cellName + '_I1_a'] = {'cellType': cellName, 'numCells': 1, 'cellModel': 'HH_full'}
    netParams.popParams[cellName + '_I2_a'] = {'cellType': cellName, 'numCells': 1, 'cellModel': 'HH_full'}
    netParams.popParams[cellName + '_I3_a'] = {'cellType': cellName, 'numCells': 1, 'cellModel': 'HH_full'}
# Out:
# L23_LBC_cACint209_1 all soma_0
# L23_LBC_cACint209_1 somatic soma_0
# L23_LBC_cACint209_2 all soma_0
# L23_LBC_cACint209_2 somatic soma_0
# L23_LBC_cACint209_3 all soma_0
# L23_LBC_cACint209_3 somatic soma_0
# L23_LBC_cACint209_4 all soma_0
# L23_LBC_cACint209_4 somatic soma_0
# L23_LBC_cACint209_5 all soma_0
# L23_LBC_cACint209_5 somatic soma_0
# L23_LBC_dNAC222_1 all soma_0
# L23_LBC_dNAC222_1 somatic soma_0
# L23_LBC_dNAC222_2 all soma_0
# L23_LBC_dNAC222_2 somatic soma_0
# L23_LBC_dNAC222_3 all soma_0
# L23_LBC_dNAC222_3 somatic soma_0
# L23_LBC_dNAC222_4 all soma_0
# L23_LBC_dNAC222_4 somatic soma_0
# L23_LBC_dNAC222_5 all soma_0
# L23_LBC_dNAC222_5 somatic soma_0
# L6_TPC_L4_cADpyr231_1 all soma_0
# L6_TPC_L4_cADpyr231_1 somatic soma_0
# L6_TPC_L4_cADpyr231_2 all soma_0
# L6_TPC_L4_cADpyr231_2 somatic soma_0
# L6_TPC_L4_cADpyr231_3 all soma_0
# L6_TPC_L4_cADpyr231_3 somatic soma_0
# L6_TPC_L4_cADpyr231_4 all soma_0
# L6_TPC_L4_cADpyr231_4 somatic soma_0
# L6_TPC_L4_cADpyr231_5 all soma_0
# L6_TPC_L4_cADpyr231_5 somatic soma_0
# L23_PC_cADpyr229_1 all soma_0
# L23_PC_cADpyr229_1 somatic soma_0
# L23_PC_cADpyr229_2 all soma_0
# L23_PC_cADpyr229_2 somatic soma_0
# L23_PC_cADpyr229_3 all soma_0
# L23_PC_cADpyr229_3 somatic soma_0
# L23_PC_cADpyr229_4 all soma_0
# L23_PC_cADpyr229_4 somatic soma_0
# L23_PC_cADpyr229_5 all soma_0
# L23_PC_cADpyr229_5 somatic soma_0

# %%
for cellnumber in cellspostE1+cellspostE2+cellspostE3:
    cellName = folder[cellnumber]
    netParams.popParams[cellName + '_b'] = {'cellType': cellName, 'numCells': 1, 'cellModel': 'HH_full'}    
for cellnumber in cellspostI:
    cellName = folder[cellnumber]
    netParams.popParams[cellName + '_I1_b'] = {'cellType': cellName, 'numCells': 1, 'cellModel': 'HH_full'}
    netParams.popParams[cellName + '_I2_b'] = {'cellType': cellName, 'numCells': 1, 'cellModel': 'HH_full'}
    netParams.popParams[cellName + '_I3_b'] = {'cellType': cellName, 'numCells': 1, 'cellModel': 'HH_full'}
    
    
for cellnumber in cellspostE1+cellspostE2+cellspostE3:
    cellName = folder[cellnumber]
    netParams.popParams[cellName + '_c'] = {'cellType': cellName, 'numCells': 1, 'cellModel': 'HH_full'}
for cellnumber in cellspostI:
    cellName = folder[cellnumber]
    netParams.popParams[cellName + '_I1_c'] = {'cellType': cellName, 'numCells': 1, 'cellModel': 'HH_full'}
    netParams.popParams[cellName + '_I2_c'] = {'cellType': cellName, 'numCells': 1, 'cellModel': 'HH_full'}
    netParams.popParams[cellName + '_I3_c'] = {'cellType': cellName, 'numCells': 1, 'cellModel': 'HH_full'}
    
for cellnumber in cellspostE1+cellspostE2+cellspostE3:
    cellName = folder[cellnumber]
    netParams.popParams[cellName + '_d'] = {'cellType': cellName, 'numCells': 1, 'cellModel': 'HH_full'}
for cellnumber in cellspostI:
    cellName = folder[cellnumber]
    netParams.popParams[cellName + '_I1_d'] = {'cellType': cellName, 'numCells': 1, 'cellModel': 'HH_full'}
    netParams.popParams[cellName + '_I2_d'] = {'cellType': cellName, 'numCells': 1, 'cellModel': 'HH_full'}
    netParams.popParams[cellName + '_I3_d'] = {'cellType': cellName, 'numCells': 1, 'cellModel': 'HH_full'}

# %%
# create custom list of spike times
spkTimes = [500,2500,2550,2600,2650,2700,2750,2800,2850,2900,3400]

netParams.popParams['presyn_a'] = {'cellModel': 'VecStim', 'numCells': 1, 'spkTimes': spkTimes}  # VecStim with spike times
netParams.popParams['presyn_b'] = {'cellModel': 'VecStim', 'numCells': 1, 'spkTimes': spkTimes}  # VecStim with spike times
netParams.popParams['presyn_c'] = {'cellModel': 'VecStim', 'numCells': 1, 'spkTimes': spkTimes}  # VecStim with spike times
netParams.popParams['presyn_d'] = {'cellModel': 'VecStim', 'numCells': 1, 'spkTimes': spkTimes}  # VecStim with spike times

# %%
netParams.cellParams.keys()
# Out:
# odict_keys(['L23_LBC_cACint209_1', 'L23_LBC_cACint209_2', 'L23_LBC_cACint209_3', 'L23_LBC_cACint209_4', 'L23_LBC_cACint209_5', 'L23_LBC_dNAC222_1', 'L23_LBC_dNAC222_2', 'L23_LBC_dNAC222_3', 'L23_LBC_dNAC222_4', 'L23_LBC_dNAC222_5', 'L6_TPC_L4_cADpyr231_1', 'L6_TPC_L4_cADpyr231_2', 'L6_TPC_L4_cADpyr231_3', 'L6_TPC_L4_cADpyr231_4', 'L6_TPC_L4_cADpyr231_5', 'L23_PC_cADpyr229_1', 'L23_PC_cADpyr229_2', 'L23_PC_cADpyr229_3', 'L23_PC_cADpyr229_4', 'L23_PC_cADpyr229_5'])

# %%
import pickle
#------------------------------------------------------------------------------
# load data from S1 conn pre-processing file 
#------------------------------------------------------------------------------
with open('../sim/conn/conn.pkl', 'rb') as fileObj: connData = pickle.load(fileObj)

lmat = connData['lmat']
a0mat = connData['a0mat']
d0 = connData['d0']

a0e = connData['a0mat_exp']
l0e = connData['lmat_exp']
d0e = connData['d0_exp']

a0g = connData['a0mat_gauss']
x0g = connData['x0_gauss']
l0g = connData['lmat_gauss']
d0g = connData['d0_gauss']

dfinal = connData['dfinal']
pmat = {}
pmat[12.5] = connData['pmat12um']
pmat[25] = connData['pmat25um']
pmat[50] = connData['pmat50um']
pmat[75] = connData['pmat75um']
pmat[100] = connData['pmat100um']
pmat[125] = connData['pmat125um']
pmat[150] = connData['pmat150um']
pmat[175] = connData['pmat175um']
pmat[200] = connData['pmat200um'] #max value for d0=200

synperconnNumber = connData['synperconnNumber']
connNumber = connData['connNumber']
decay = connData['decay']
gsyn = connData['gsyn']
use = connData['use']

ConnTypesNumber = connData['ConnTypesNumber'] 
ConnTypes = connData['ConnTypes']   

connIEtype = connData['connIEtype']  
connEItype = connData['connEItype']
parameters_syn = connData['parameters_syn']

# %%
import pandas as pd

physColumnNames = []
syntypes = []
for name,syntype in parameters_syn:    
    if name not in physColumnNames:
        physColumnNames.append(name) 
    if syntype not in syntypes:
        syntypes.append(syntype)
        
#     print(name,syntype,parameters_syn[name,syntype])
dfS6 = pd.DataFrame(index=syntypes, columns=physColumnNames)
for syntype in syntypes:
    for name in physColumnNames:    
        dfS6.loc[syntype][name] = parameters_syn[name,syntype]
dfS6
# Out:
#     ConnType  gsyn gsynStd  decay decayStd    use useStd     dep depStd  \
# 0          0  0.83    0.55   10.4      6.1   0.16    0.1    45.0   21.0
# 3          1  0.91    0.61   10.4      6.1   0.16    0.1    45.0   21.0
# 13         2  0.75    0.32   10.4      6.1  0.415  0.212   162.0   69.0
# 1          3  0.83    0.55    8.3      2.2   0.25   0.13   706.0  405.0
# 4          4  0.91    0.61    8.3      2.2   0.25   0.13   706.0  405.0
# 8          5  0.75    0.32    8.3      2.2   0.25   0.13   706.0  405.0
# 9          6  0.75    0.32    8.3      2.2    0.3   0.08  1250.0  520.0
# 10         7  0.91    0.61    8.3      2.2   0.14   0.05   875.0  285.0
# 12         8  2.97    0.95    8.3      2.2   0.25   0.13   706.0  405.0
# 5          9  0.91    0.61   6.44      1.7   0.32   0.14   144.0   80.0
# 11        10  0.83    0.55  36.55     0.71   0.25   0.13   706.0  405.0
# 114       11  0.43    0.28   1.74     0.18   0.02  0.001   194.0   10.0
# 115       12  0.72     0.5   1.74     0.18   0.02  0.001   194.0   10.0
# 132       13  0.72     0.5   1.74     0.18   0.01  0.001   242.0   15.0
# 133       14  0.11    0.08   1.74     0.18   0.09   0.12   138.0  211.0
# 116       15  0.72     0.5   1.74     0.18    0.5   0.02   671.0   17.0
# 117       16  0.43    0.28   1.74     0.18    0.5   0.02   671.0   17.0
# 118       17  0.72     0.5   1.74     0.18    0.5   0.02   671.0   17.0
# 119       18  0.68    0.46   1.74     0.18   0.46   0.26   671.0   17.0
# 120       19  0.68    0.46   1.74     0.18   0.86  0.049   671.0   17.0
# 121       20  0.19    0.12   1.74     0.18   0.79   0.04   671.0   17.0
# 122       21   0.8    0.53   1.74     0.18   0.39   0.03   671.0   17.0
# 123       22   1.5    1.05   1.74     0.18    0.5   0.02   671.0   17.0
# 127       23   0.8    0.53   1.74     0.18  0.391  0.134   780.0   54.0
# 131       24  0.72     0.5   1.74     0.18   0.58   0.07   240.0   43.0
# 134       25  0.72     0.5   1.74     0.18   0.72  0.065   227.0   38.0
# 126       26   0.8    0.53   1.74     0.18   0.21  0.032   460.0   53.0
# 128       27   0.8    0.53   1.74     0.18   0.27  0.033   559.0  238.0
# 129       28   0.8    0.53   1.74     0.18  0.222  0.053   535.0  134.0
#
#        fac facStd s-types type
# 0    376.0  253.0      I1   II
# 3    376.0  253.0      I1   IE
# 13   690.0    5.0      I1   IE
# 1     21.0    9.0      I2   II
# 4     21.0    9.0      I2   IE
# 8     21.0    9.0      I2   IE
# 9      2.0    4.0      I2   IE
# 10    22.0    5.0      I2   IE
# 12    21.0    9.0      I2   IE
# 5     62.0   31.0      I3   IE
# 11    21.0    9.0      I3   IE
# 114  507.0   20.0      E1   EI
# 115  507.0   20.0      E1   EI
# 132  563.0   32.0      E1   EI
# 133  670.0  830.0      E1   EI
# 116   17.0    5.0      E2   EE
# 117   17.0    5.0      E2   EI
# 118   17.0    5.0      E2   EI
# 119   17.0    5.0      E2   EE
# 120   17.0    5.0      E2   EE
# 121   17.0    5.0      E2   EE
# 122   17.0    5.0      E2   EE
# 123   17.0    5.0      E2   EE
# 127   51.0   36.0      E2   EE
# 131   71.0   47.0      E2   EI
# 134   14.0   12.0      E2   EI
# 126  230.0   69.0      E3   EE
# 128  200.0   92.0      E3   EE
# 129  116.0   81.0      E3   EE

# %%
#------------------------------------------------------------------------------
# Synaptic mechanism parameters  - mods from S1 BBP - deterministic version
#------------------------------------------------------------------------------
for syntype in syntypes:
    if syntype > 50:  # Exc
        
        netParams.synMechParams['S1_EE_STP_Det_' + str(syntype)] = {'mod': 'DetAMPANMDA',
                                         'Use': dfS6['use'][syntype], # ± dfS6['useStd'][syntype]
                                         'Dep': dfS6['dep'][syntype], # ± dfS6['depStd'][syntype] 
                                         'Fac': dfS6['fac'][syntype], # ± dfS6['facStd'][syntype]
                                         'tau_d_AMPA': 1.74, # ± 0.18 ms
                                         'tau_r_AMPA': 0.2, 
                                         'tau_r_NMDA': 0.29,
                                         'tau_d_NMDA': 43,   
                                         'NMDA_ratio': 0.8, # ± 0.1 for EE -- experimentally measured for some paths?
                                         'mg':1.0, #    0.5mM where exceptionally specified?                                                                
                                            }
        netParams.synMechParams['S1_EI_STP_Det_' + str(syntype)] = {'mod': 'DetAMPANMDA',
                                         'Use': dfS6['use'][syntype], # ± dfS6['useStd'][syntype]
                                         'Dep': dfS6['dep'][syntype], # ± dfS6['depStd'][syntype] 
                                         'Fac': dfS6['fac'][syntype], # ± dfS6['facStd'][syntype]
                                         'tau_d_AMPA': 1.74, # ± 0.18 ms
                                         'tau_r_AMPA': 0.2,
                                         'tau_r_NMDA': 0.29,
                                         'tau_d_NMDA': 43,   
                                         'NMDA_ratio': 0.4, # ± 0.1  for EI -- experimentally measured for some paths?
                                         'mg':1.0, #    0.5mM where exceptionally specified?                                                                
                                            }
    else: # Inh
        
        netParams.synMechParams['S1_II_STP_Det_' + str(syntype)] = {'mod': 'DetGABAAB',
                                         'Use': dfS6['use'][syntype], # ± dfS6['useStd'][syntype]
                                         'Dep': dfS6['dep'][syntype], # ± dfS6['depStd'][syntype]  
                                         'Fac': dfS6['fac'][syntype], # ± dfS6['facStd'][syntype]
                                         'tau_d_GABAA': dfS6['decay'][syntype], # ± dfS6['decayStd'][syntype]
                                         'tau_r_GABAA': 0.2,   #rng.lognormal(0.2, 0.1) in synapses.hoc  
                                         'tau_d_GABAB': 260.9,
                                         'tau_r_GABAB': 3.5,
#                                          'GABAB_ratio': 1.0,  #=0(1):The ratio of GABAB to GABAA  ?          
                                            }
        
        netParams.synMechParams['S1_IE_STP_Det_' + str(syntype)] = {'mod': 'DetGABAAB',
                                         'Use': dfS6['use'][syntype], # ± dfS6['useStd'][syntype]
                                         'Dep': dfS6['dep'][syntype], # ± dfS6['depStd'][syntype]  
                                         'Fac': dfS6['fac'][syntype], # ± dfS6['facStd'][syntype]
                                         'tau_d_GABAA': dfS6['decay'][syntype], # ± dfS6['decayStd'][syntype]
                                         'tau_r_GABAA': 0.2,   #rng.lognormal(0.2, 0.1) in synapses.hoc  
                                         'tau_d_GABAB': 260.9,
                                         'tau_r_GABAB': 3.5,
#                                          'GABAB_ratio': 1.0,  #=0(1):The ratio of GABAB to GABAA   ?       
                                            }

# %%
netParams.synMechParams.keys()
# Out:
# odict_keys(['S1_II_STP_Det_0', 'S1_IE_STP_Det_0', 'S1_II_STP_Det_3', 'S1_IE_STP_Det_3', 'S1_II_STP_Det_13', 'S1_IE_STP_Det_13', 'S1_II_STP_Det_1', 'S1_IE_STP_Det_1', 'S1_II_STP_Det_4', 'S1_IE_STP_Det_4', 'S1_II_STP_Det_8', 'S1_IE_STP_Det_8', 'S1_II_STP_Det_9', 'S1_IE_STP_Det_9', 'S1_II_STP_Det_10', 'S1_IE_STP_Det_10', 'S1_II_STP_Det_12', 'S1_IE_STP_Det_12', 'S1_II_STP_Det_5', 'S1_IE_STP_Det_5', 'S1_II_STP_Det_11', 'S1_IE_STP_Det_11', 'S1_EE_STP_Det_114', 'S1_EI_STP_Det_114', 'S1_EE_STP_Det_115', 'S1_EI_STP_Det_115', 'S1_EE_STP_Det_132', 'S1_EI_STP_Det_132', 'S1_EE_STP_Det_133', 'S1_EI_STP_Det_133', 'S1_EE_STP_Det_116', 'S1_EI_STP_Det_116', 'S1_EE_STP_Det_117', 'S1_EI_STP_Det_117', 'S1_EE_STP_Det_118', 'S1_EI_STP_Det_118', 'S1_EE_STP_Det_119', 'S1_EI_STP_Det_119', 'S1_EE_STP_Det_120', 'S1_EI_STP_Det_120', 'S1_EE_STP_Det_121', 'S1_EI_STP_Det_121', 'S1_EE_STP_Det_122', 'S1_EI_STP_Det_122', 'S1_EE_STP_Det_123', 'S1_EI_STP_Det_123', 'S1_EE_STP_Det_127', 'S1_EI_STP_Det_127', 'S1_EE_STP_Det_131', 'S1_EI_STP_Det_131', 'S1_EE_STP_Det_134', 'S1_EI_STP_Det_134', 'S1_EE_STP_Det_126', 'S1_EI_STP_Det_126', 'S1_EE_STP_Det_128', 'S1_EI_STP_Det_128', 'S1_EE_STP_Det_129', 'S1_EI_STP_Det_129'])

# %%
netParams.synMechParams['S1_EI_STP_Det_134']
# Out:
# {'mod': 'DetAMPANMDA',
#  'Use': 0.72,
#  'Dep': 227.0,
#  'Fac': 14.0,
#  'tau_d_AMPA': 1.74,
#  'tau_r_AMPA': 0.2,
#  'tau_r_NMDA': 0.29,
#  'tau_d_NMDA': 43,
#  'NMDA_ratio': 0.4,
#  'mg': 1.0}

# %%
netParams.synMechParams['S1_EE_STP_Det_126']
# Out:
# {'mod': 'DetAMPANMDA',
#  'Use': 0.21,
#  'Dep': 460.0,
#  'Fac': 230.0,
#  'tau_d_AMPA': 1.74,
#  'tau_r_AMPA': 0.2,
#  'tau_r_NMDA': 0.29,
#  'tau_d_NMDA': 43,
#  'NMDA_ratio': 0.8,
#  'mg': 1.0}

# %%
print((synperconnNumber['L23_PC']['L23_LBC']),(synperconnNumber['L6_TPC_L4']['L6_TPC_L4']),(synperconnNumber['L23_SBC']['L23_PC']))
# Out:
# 9.0 5.0 22.0

# %%
## Cell connectivity rules

synList = {}
synperconnList = {}

#E1 -> syn 115
synList[115] = [] # 'L23_PC:L23_LBC_cAC'
for post in list(netParams.popParams.keys()):
    if 'L23_LBC_cAC' in post:
        synList[115].append(post)
        synperconnList[115] = 9
#E2 -> syn 134
synList[134] = [] #  'L23_PC:L23_LBC_dNAC'
for post in list(netParams.popParams.keys()):
    if 'L23_LBC_dNAC' in post:
        synList[134].append(post)
        synperconnList[134] = 9
#E3 -> syn 126
synList[126] = [] # 'L6_TPC_L4:L6_TPC_L4'
for post in list(netParams.popParams.keys()):
    if 'L6_TPC_L4' in post:
        synList[126].append(post)
        synperconnList[126] = 5

#I1 -> syn 3
synList[3] = [] # ' 'L23_SBC_cAC:L23_PC'
for post in list(netParams.popParams.keys()):
    if 'I1' in post:
        synList[3].append(post)
        synperconnList[3] = 22
#I2 -> syn 4
synList[4] = [] # ' 'L23_SBC_dNAC:L23_PC'
for post in list(netParams.popParams.keys()):
    if 'I2' in post:
        synList[4].append(post)
        synperconnList[4] = 22
#I3 -> syn 5
synList[5] = [] # ' 'L23_SBC_bNAC:L23_PC'
for post in list(netParams.popParams.keys()):
    if 'I3' in post:
        synList[5].append(post)
        synperconnList[5] = 22


for syntype in [3,4,5,115,134,126]:
    
    if syntype == 126:  # Exc:Exc   
        synapseMech = 'S1_EE_STP_Det_' + str(syntype)   
    elif syntype > 50:  # Exc     
        synapseMech = 'S1_EI_STP_Det_' + str(syntype)             
    else: # Inh
        synapseMech = 'S1_IE_STP_Det_' + str(syntype)   
        
    netParams.connParams['STP_Det_a_' + str(syntype)] = { 
            'preConds': {'pop': 'presyn_a'},
            'postConds': {'pop': synList[syntype][0:5]},
            'sec': ['dend_0','dend_1','dend_2','dend_3'],                  # target postsyn section
            'synMech': synapseMech,              # target synaptic mechanism
            'weight': dfS6['gsyn'][syntype],                 # synaptic weight 
            'synsPerConn': synperconnList[syntype],
            'delay': 0.1}   
    netParams.connParams['STP_Det_b_' + str(syntype)] = { 
            'preConds': {'pop': 'presyn_b'},
            'postConds': {'pop': synList[syntype][5:10]},
            'sec': 'spinyEE', # ['dend_4','dend_5','dend_6','dend_7'],                  # target postsyn section
            'synMech': synapseMech,              # target synaptic mechanism
            'weight': dfS6['gsyn'][syntype],                 # synaptic weight 
            'synsPerConn': synperconnList[syntype],
            'delay': 0.1}   
    netParams.connParams['STP_Det_c_' + str(syntype)] = { 
            'preConds': {'pop': 'presyn_c'},
            'postConds': {'pop': synList[syntype][10:15]},
            'sec': 'basal', # ['dend_8','dend_9','dend_10','dend_11'],                  # target postsyn section
            'synMech': synapseMech,              # target synaptic mechanism
            'weight': dfS6['gsyn'][syntype],                 # synaptic weight 
            'synsPerConn': synperconnList[syntype],
            'delay': 0.1}   
    netParams.connParams['STP_Det_d_' + str(syntype)] = { 
            'preConds': {'pop': 'presyn_d'},
            'postConds': {'pop': synList[syntype][15:20]},
            'sec': ['dend_12','dend_13','dend_14','dend_15'],                  # target postsyn section
            'synMech': synapseMech,              # target synaptic mechanism
            'weight': dfS6['gsyn'][syntype],                 # synaptic weight 
            'synsPerConn': synperconnList[syntype],
            'delay': 0.1}

# %%
netParams.connParams
# Out:
# {STP_Det_a_3: {'preConds': {'pop': 'presyn_a'}, 'postConds': {'pop': ['L23_PC_cADpyr229_1_I1_a', 'L23_PC_cADpyr229_2_I1_a', 'L23_PC_cADpyr229_3_I1_a', 'L23_PC_cADpyr229_4_I1_a', 'L23_PC_cADpyr229_5_I1_a']}, 'sec': ['dend_0', 'dend_1', 'dend_2', 'dend_3'], 'synMech': 'S1_IE_STP_Det_3', 'weight': 0.91, 'synsPerConn': 22, 'delay': 0.1}, STP_Det_b_3: {'preConds': {'pop': 'presyn_b'}, 'postConds': {'pop': ['L23_PC_cADpyr229_1_I1_b', 'L23_PC_cADpyr229_2_I1_b', 'L23_PC_cADpyr229_3_I1_b', 'L23_PC_cADpyr229_4_I1_b', 'L23_PC_cADpyr229_5_I1_b']}, 'sec': 'spinyEE', 'synMech': 'S1_IE_STP_Det_3', 'weight': 0.91, 'synsPerConn': 22, 'delay': 0.1}, STP_Det_c_3: {'preConds': {'pop': 'presyn_c'}, 'postConds': {'pop': ['L23_PC_cADpyr229_1_I1_c', 'L23_PC_cADpyr229_2_I1_c', 'L23_PC_cADpyr229_3_I1_c', 'L23_PC_cADpyr229_4_I1_c', 'L23_PC_cADpyr229_5_I1_c']}, 'sec': 'basal', 'synMech': 'S1_IE_STP_Det_3', 'weight': 0.91, 'synsPerConn': 22, 'delay': 0.1}, STP_Det_d_3: {'preConds': {'pop': 'presyn_d'}, 'postConds': {'pop': ['L23_PC_cADpyr229_1_I1_d', 'L23_PC_cADpyr229_2_I1_d', 'L23_PC_cADpyr229_3_I1_d', 'L23_PC_cADpyr229_4_I1_d', 'L23_PC_cADpyr229_5_I1_d']}, 'sec': ['dend_12', 'dend_13', 'dend_14', 'dend_15'], 'synMech': 'S1_IE_STP_Det_3', 'weight': 0.91, 'synsPerConn': 22, 'delay': 0.1}, STP_Det_a_4: {'preConds': {'pop': 'presyn_a'}, 'postConds': {'pop': ['L23_PC_cADpyr229_1_I2_a', 'L23_PC_cADpyr229_2_I2_a', 'L23_PC_cADpyr229_3_I2_a', 'L23_PC_cADpyr229_4_I2_a', 'L23_PC_cADpyr229_5_I2_a']}, 'sec': ['dend_0', 'dend_1', 'dend_2', 'dend_3'], 'synMech': 'S1_IE_STP_Det_4', 'weight': 0.91, 'synsPerConn': 22, 'delay': 0.1}, STP_Det_b_4: {'preConds': {'pop': 'presyn_b'}, 'postConds': {'pop': ['L23_PC_cADpyr229_1_I2_b', 'L23_PC_cADpyr229_2_I2_b', 'L23_PC_cADpyr229_3_I2_b', 'L23_PC_cADpyr229_4_I2_b', 'L23_PC_cADpyr229_5_I2_b']}, 'sec': 'spinyEE', 'synMech': 'S1_IE_STP_Det_4', 'weight': 0.91, 'synsPerConn': 22, 'delay': 0.1}, STP_Det_c_4: {'preConds': {'pop': 'presyn_c'}, 'postConds': {'pop': ['L23_PC_cADpyr229_1_I2_c', 'L23_PC_cADpyr229_2_I2_c', 'L23_PC_cADpyr229_3_I2_c', 'L23_PC_cADpyr229_4_I2_c', 'L23_PC_cADpyr229_5_I2_c']}, 'sec': 'basal', 'synMech': 'S1_IE_STP_Det_4', 'weight': 0.91, 'synsPerConn': 22, 'delay': 0.1}, STP_Det_d_4: {'preConds': {'pop': 'presyn_d'}, 'postConds': {'pop': ['L23_PC_cADpyr229_1_I2_d', 'L23_PC_cADpyr229_2_I2_d', 'L23_PC_cADpyr229_3_I2_d', 'L23_PC_cADpyr229_4_I2_d', 'L23_PC_cADpyr229_5_I2_d']}, 'sec': ['dend_12', 'dend_13', 'dend_14', 'dend_15'], 'synMech': 'S1_IE_STP_Det_4', 'weight': 0.91, 'synsPerConn': 22, 'delay': 0.1}, STP_Det_a_5: {'preConds': {'pop': 'presyn_a'}, 'postConds': {'pop': ['L23_PC_cADpyr229_1_I3_a', 'L23_PC_cADpyr229_2_I3_a', 'L23_PC_cADpyr229_3_I3_a', 'L23_PC_cADpyr229_4_I3_a', 'L23_PC_cADpyr229_5_I3_a']}, 'sec': ['dend_0', 'dend_1', 'dend_2', 'dend_3'], 'synMech': 'S1_IE_STP_Det_5', 'weight': 0.91, 'synsPerConn': 22, 'delay': 0.1}, STP_Det_b_5: {'preConds': {'pop': 'presyn_b'}, 'postConds': {'pop': ['L23_PC_cADpyr229_1_I3_b', 'L23_PC_cADpyr229_2_I3_b', 'L23_PC_cADpyr229_3_I3_b', 'L23_PC_cADpyr229_4_I3_b', 'L23_PC_cADpyr229_5_I3_b']}, 'sec': 'spinyEE', 'synMech': 'S1_IE_STP_Det_5', 'weight': 0.91, 'synsPerConn': 22, 'delay': 0.1}, STP_Det_c_5: {'preConds': {'pop': 'presyn_c'}, 'postConds': {'pop': ['L23_PC_cADpyr229_1_I3_c', 'L23_PC_cADpyr229_2_I3_c', 'L23_PC_cADpyr229_3_I3_c', 'L23_PC_cADpyr229_4_I3_c', 'L23_PC_cADpyr229_5_I3_c']}, 'sec': 'basal', 'synMech': 'S1_IE_STP_Det_5', 'weight': 0.91, 'synsPerConn': 22, 'delay': 0.1}, STP_Det_d_5: {'preConds': {'pop': 'presyn_d'}, 'postConds': {'pop': ['L23_PC_cADpyr229_1_I3_d', 'L23_PC_cADpyr229_2_I3_d', 'L23_PC_cADpyr229_3_I3_d', 'L23_PC_cADpyr229_4_I3_d', 'L23_PC_cADpyr229_5_I3_d']}, 'sec': ['dend_12', 'dend_13', 'dend_14', 'dend_15'], 'synMech': 'S1_IE_STP_Det_5', 'weight': 0.91, 'synsPerConn': 22, 'delay': 0.1}, STP_Det_a_115: {'preConds': {'pop': 'presyn_a'}, 'postConds': {'pop': ['L23_LBC_cACint209_1_a', 'L23_LBC_cACint209_2_a', 'L23_LBC_cACint209_3_a', 'L23_LBC_cACi ...

# %%
sim.initialize(
    simConfig = cfg, 	
    netParams = netParams)  				# create network object and set cfg and net params
sim.net.createPops()               			# instantiate network populations
sim.net.createCells()              			# instantiate network cells based on defined populations
sim.net.connectCells()            			# create connections between cells based on params
sim.net.addStims() 							# add network stimulation
sim.setupRecording()              			# setup variables to record for each cell (spikes, V traces, etc)
# Out:
# Start time:  2023-04-10 17:01:35.821307
#
# Creating network of 124 cell populations on 1 hosts...
# Distributed population of 1 cells on 1 hosts: {0: [0]}, next: 0
# Cell 0/0 (gid=0) of pop L23_LBC_cACint209_1_a, on node 0,
# Instantiated 1 cells of population L23_LBC_cACint209_1_a
# Distributed population of 1 cells on 1 hosts: {0: [0]}, next: 0
# Cell 0/0 (gid=1) of pop L23_LBC_cACint209_2_a, on node 0,
# Instantiated 1 cells of population L23_LBC_cACint209_2_a
# Distributed population of 1 cells on 1 hosts: {0: [0]}, next: 0
# Cell 0/0 (gid=2) of pop L23_LBC_cACint209_3_a, on node 0,
# Instantiated 1 cells of population L23_LBC_cACint209_3_a
# Distributed population of 1 cells on 1 hosts: {0: [0]}, next: 0
# Cell 0/0 (gid=3) of pop L23_LBC_cACint209_4_a, on node 0,
# Instantiated 1 cells of population L23_LBC_cACint209_4_a
# Distributed population of 1 cells on 1 hosts: {0: [0]}, next: 0
# Cell 0/0 (gid=4) of pop L23_LBC_cACint209_5_a, on node 0,
# Instantiated 1 cells of population L23_LBC_cACint209_5_a
# Distributed population of 1 cells on 1 hosts: {0: [0]}, next: 0
# Cell 0/0 (gid=5) of pop L23_LBC_dNAC222_1_a, on node 0,
# Instantiated 1 cells of population L23_LBC_dNAC222_1_a
# Distributed population of 1 cells on 1 hosts: {0: [0]}, next: 0
# Cell 0/0 (gid=6) of pop L23_LBC_dNAC222_2_a, on node 0,
# Instantiated 1 cells of population L23_LBC_dNAC222_2_a
# Distributed population of 1 cells on 1 hosts: {0: [0]}, next: 0
# Cell 0/0 (gid=7) of pop L23_LBC_dNAC222_3_a, on node 0,
# Instantiated 1 cells of population L23_LBC_dNAC222_3_a
# Distributed population of 1 cells on 1 hosts: {0: [0]}, next: 0
# Cell 0/0 (gid=8) of pop L23_LBC_dNAC222_4_a, on node 0,
# Instantiated 1 cells of population L23_LBC_dNAC222_4_a
# Distributed population of 1 cells on 1 hosts: {0: [0]}, next: 0
# Cell 0/0 (gid=9) of pop L23_LBC_dNAC222_5_a, on node 0,
# Instantiated 1 cells of population L23_LBC_dNAC222_5_a
# Distributed population of 1 cells on 1 hosts: {0: [0]}, next: 0
# Cell 0/0 (gid=10) of pop L6_TPC_L4_cADpyr231_1_a, on node 0,
# Instantiated 1 cells of population L6_TPC_L4_cADpyr231_1_a
# Distributed population of 1 cells on 1 hosts: {0: [0]}, next: 0
# Cell 0/0 (gid=11) of pop L6_TPC_L4_cADpyr231_2_a, on node 0,
# Instantiated 1 cells of population L6_TPC_L4_cADpyr231_2_a
# Distributed population of 1 cells on 1 hosts: {0: [0]}, next: 0
# Cell 0/0 (gid=12) of pop L6_TPC_L4_cADpyr231_3_a, on node 0,
# Instantiated 1 cells of population L6_TPC_L4_cADpyr231_3_a
# Distributed population of 1 cells on 1 hosts: {0: [0]}, next: 0
# Cell 0/0 (gid=13) of pop L6_TPC_L4_cADpyr231_4_a, on node 0,
# Instantiated 1 cells of population L6_TPC_L4_cADpyr231_4_a
# Distributed population of 1 cells on 1 hosts: {0: [0]}, next: 0
# Cell 0/0 (gid=14) of pop L6_TPC_L4_cADpyr231_5_a, on node 0,
# Instantiated 1 cells of population L6_TPC_L4_cADpyr231_5_a
# Distributed population of 1 cells on 1 hosts: {0: [0]}, next: 0
# Cell 0/0 (gid
on node 0,
# Instantiated 1 cells of population L6_TPC_L4_cADpyr231_3_c
# Distributed population of 1 cells on 1 hosts: {0: [0]}, next: 0
# Cell 0/0 (gid=73) of pop L6_TPC_L4_cADpyr231_4_c, on node 0,
# Instantiated 1 cells of population L6_TPC_L4_cADpyr231_4_c
# Distributed population of 1 cells on 1 hosts: {0: [0]}, next: 0
# Cell 0/0 (gid=74) of pop L6_TPC_L4_cADpyr231_5_c, on node 0,
# Instantiated 1 cells of population L6_TPC_L4_cADpyr231_5_c
# Distributed population of 1 cells on 1 hosts: {0: [0]}, next: 0
# Cell 0/0 (gid=75) of pop L23_PC_cADpyr229_1_I1_c, on node 0,
# Instantiated 1 cells of population L23_PC_cADpyr229_1_I1_c
# Distributed population of 1 cells on 1 hosts: {0: [0]}, next: 0
# Cell 0/0 (gid=76) of pop L23_PC_cADpyr229_1_I2_c, on node 0,
# Instantiated 1 cells of population L23_PC_cADpyr229_1_I2_c
# Distributed population of 1 cells on 1 hosts: {0: [0]}, next: 0
# Cell 0/0 (gid=77) of pop L23_PC_cADpyr229_1_I3_c, on node 0,
# Instantiated 1 cells of population L23_PC_cADpyr229_1_I3_c
# Distributed population of 1 cells on 1 hosts: {0: [0]}, next: 0
# Cell 0/0 (gid=78) of pop L23_PC_cADpyr229_2_I1_c, on node 0,
# Instantiated 1 cells of population L23_PC_cADpyr229_2_I1_c
# Distributed population of 1 cells on 1 hosts: {0: [0]}, next: 0
# Cell 0/0 (gid=79) of pop L23_PC_cADpyr229_2_I2_c, on node 0,
# Instantiated 1 cells of population L23_PC_cADpyr229_2_I2_c
# Distributed population of 1 cells on 1 hosts: {0: [0]}, next: 0
# Cell 0/0 (gid=80) of pop L23_PC_cADpyr229_2_I3_c, on node 0,
# Instantiated 1 cells of population L23_PC_cADpyr229_2_I3_c
# Distributed population of 1 cells on 1 hosts: {0: [0]}, next: 0
# Cell 0/0 (gid=81) of pop L23_PC_cADpyr229_3_I1_c, on node 0,
# Instantiated 1 cells of population L23_PC_cADpyr229_3_I1_c
# Distributed population of 1 cells on 1 hosts: {0: [0]}, next: 0
# Cell 0/0 (gid=82) of pop L23_PC_cADpyr229_3_I2_c, on node 0,
# Instantiated 1 cells of population L23_PC_cADpyr229_3_I2_c
# Distributed population of 1 cells on 1 hosts: {0: [0]}, next: 0
# Cell 0/0 (gid=83) of pop L23_PC_cADpyr229_3_I3_c, on node 0,
# Instantiated 1 cells of population L23_PC_cADpyr229_3_I3_c
# Distributed population of 1 cells on 1 hosts: {0: [0]}, next: 0
# Cell 0/0 (gid=84) of pop L23_PC_cADpyr229_4_I1_c, on node 0,
# Instantiated 1 cells of population L23_PC_cADpyr229_4_I1_c
# Distributed population of 1 cells on 1 hosts: {0: [0]}, next: 0
# Cell 0/0 (gid=85) of pop L23_PC_cADpyr229_4_I2_c, on node 0,
# Instantiated 1 cells of population L23_PC_cADpyr229_4_I2_c
# Distributed population of 1 cells on 1 hosts: {0: [0]}, next: 0
# Cell 0/0 (gid=86) of pop L23_PC_cADpyr229_4_I3_c, on node 0,
# Instantiated 1 cells of population L23_PC_cADpyr229_4_I3_c
# Distributed population of 1 cells on 1 hosts: {0: [0]}, next: 0
# Cell 0/0 (gid=87) of pop L23_PC_cADpyr229_5_I1_c, on node 0,
# Instantiated 1 cells of population L23_PC_cADpyr229_5_I1_c
# Distributed population of 1 cells on 1 hosts: {0: [0]}, next: 0
# Cell 0/0 (gid=88) of pop L23_PC_cADpyr229_5_I2_c, on node 0,
# Instantiated 1 cells of population L23_PC_cADpyr229_5_I2_c
# Distributed population of 1 cells on 1 hosts: {0: [0]}, next: 0
# Cell 0/0 (gid=89) of pop L23_PC_cADpyr229_5_I3_c, on node 0,
# Instantiated 1 cells of population L23_PC_cADpyr229_5_I3_c
# Distributed population of 1 cells on 1 hosts: {0: [0]}, next: 0
# Cell 0/0 (gid=90) of pop L23_LBC_cACint209_1_d, on node 0,
# Instantiated 1 cells of population L23_LBC_cACint209_1_d
# Distributed population of 1 cells on 1 hosts: {0: [0]}, next: 0
# Cell 0/0 (gid=91) of pop L23_LBC_cACint209_2_d, on node 0,
# Instantiated 1 cells of population L23_LBC_cACint209_2_d
# Distributed population of 1 cells on 1 hosts: {0: [0]}, next: 0
# Cell 0/0 (gid=92) of pop L23_LBC_cACint209_3_d, on node 0,
# Instantiated 1 cells of population L23_LBC_cACint209_3_d
# Distributed population of 1 cells on 1 hosts: {0: [0]}, next: 0
# Cell 0/0 (gid=93) of pop L23_LBC_cACint209_4_d, on node 0,
# Instantiated 1 cells of population L23_LBC_cACint209_4_d
# Distributed population of 1 cells on 1 hosts: {0: [0]}, next: 0
# Cell 0/0 (gid=94) of pop L23_LBC_cACint209_5_d, on node 0,
# Instantiated 1 cells of population L23_LBC_cACint209_5_d
# Distributed population of 1 cells on 1 hosts: {0: [0]}, next: 0
# Cell 0/0 (gid=95) of pop L23_LBC_dNAC222_1_d, on node 0,
# Instantiated 1 cells of population L23_LBC_dNAC222_1_d
# Distributed population of 1 cells on 1 hosts: {0: [0]}, next: 0
# Cell 0/0 (gid=96) of pop L23_LBC_dNAC222_2_d, on node 0,
# Instantiated 1 cells of population L23_LBC_dNAC222_2_d
# Distributed population of 1 cells on 1 hosts: {0: [0]}, next: 0
# Cell 0/0 (gid=97) of pop L23_LBC_dNAC222_3_d, on node 0,
# Instantiated 1 cells of population L23_LBC_dNAC222_3_d
# Distributed population of 1 cells on 1 hosts: {0: [0]}, next: 0
# Cell 0/0 (gid=98) of pop L23_LBC_dNAC222_4_d, on node 0,
# Instantiated 1 cells of population L23_LBC_dNAC222_4_d
# Distributed population of 1 cells on 1 hosts: {0: [0]}, next: 0
# Cell 0/0 (gid=99) of pop L23_LBC_dNAC222_5_d, on node 0,
# Instantiated 1 cells of population L23_LBC_dNAC222_5_d
# Distributed population of 1 cells on 1 hosts: {0: [0]}, next: 0
# Cell 0/0 (gid=100) of pop L6_TPC_L4_cADpyr231_1_d, on node 0,
# Instantiated 1 cells of population L6_TPC_L4_cADpyr231_1_d
# Distributed population of 1 cells on 1 hosts: {0: [0]}, next: 0
# Cell 0/0 (gid=101) of pop L6_TPC_L4_cADpyr231_2_d, on node 0,
# Instantiated 1 cells of population L6_TPC_L4_cADpyr231_2_d
# Distributed population of 1 cells on 1 hosts: {0: [0]}, next: 0
# Cell 0/0 (gid=102) of pop L6_TPC_L4_cADpyr231_3_d, on node 0,
# Instantiated 1 cells of population L6_TPC_L4_cADpyr231_3_d
# Distributed population of 1 cells on 1 hosts: {0: [0]}, next: 0
# Cell 0/0 (gid=103) of pop L6_TPC_L4_cADpyr231_4_d, on node 0,
# Instantiated 1 cells of population L6_TPC_L4_cADpyr231_4_d
# Distributed population of 1 cells on 1 hosts: {0: [0]}, next: 0
# Cell 0/0 (gid=104) of pop L6_TPC_L4_cADpyr231_5_d, on node 0,
# Instantiated 1 cells of population L6_TPC_L4_cADpyr231_5_d
# Distributed population of 1 cells on 1 hosts: {0: [0]}, next: 0
# Cell 0/0 (gid=105) of pop L23_PC_cADpyr229_1_I1_d, on node 0,
# Instantiated 1 cells of population L23_PC_cADpyr229_1_I1_d
# Distributed population of 1 cells on 1 hosts: {0: [0]}, next: 0
# Cell 0/0 (gid=106) of pop L23_PC_cADpyr229_1_I2_d, on node 0,
# Instantiated 1 cells of population L23_PC_cADpyr229_1_I2_d
# Distributed population of 1 cells on 1 hosts: {0: [0]}, next: 0
# Cell 0/0 (gid=107) of pop L23_PC_cADpyr229_1_I3_d, on node 0,
# Instantiated 1 cells of population L23_PC_cADpyr229_1_I3_d
# Distributed population of 1 cells on 1 hosts: {0: [0]}, next: 0
# Cell 0/0 (gid=108) of pop L23_PC_cADpyr229_2_I1_d, on node 0,
# Instantiated 1 cells of population L23_PC_cADpyr229_2_I1_d
# Distributed population of 1 cells on 1 hosts: {0: [0]}, next: 0
# Cell 0/0 (gid=109) of pop L23_PC_cADpyr229_2_I2_d, on node 0,
# Instantiated 1 cells of population L23_PC_cADpyr229_2_I2_d
# Distributed population of 1 cells on 1 hosts: {0: [0]}, next: 0
# Cell 0/0 (gid=110) of pop L23_PC_cADpyr229_2_I3_d, on node 0,
# Instantiated 1 cells of population L23_PC_cADpyr229_2_I3_d
# Distributed population of 1 cells on 1 hosts: {0: [0]}, next: 0
# Cell 0/0 (gid=111) of pop L23_PC_cADpyr229_3_I1_d, on node 0,
# Instantiated 1 cells of population L23_PC_cADpyr229_3_I1_d
# Distributed population of 1 cells on 1 hosts: {0: [0]}, next: 0
# Cell 0/0 (gid=112) of pop L23_PC_cADpyr229_3_I2_d, on node 0,
# Instantiated 1 cells of population L23_PC_cADpyr229_3_I2_d
# Distributed population of 1 cells on 1 hosts: {0: [0]}, next: 0
# Cell 0/0 (gid=113) of pop L23_PC_cADpyr229_3_I3_d, on node 0,
# Instantiated 1 cells of population L23_PC_cADpyr229_3_I3_d
# Distributed population of 1 cells on 1 hosts: {0: [0]}, next: 0
# Cell 0/0 (gid=114) of pop L23_PC_cADpyr229_4_I1_d, on node 0,
# Instantiated 1 cells of population L23_PC_cADpyr229_4_I1_d
# Distributed population of 1 cells on 1 hosts: {0: [0]}, next: 0
# Cell 0/0 (gid=115) of pop L23_PC_cADpyr229_4_I2_d, on node 0,
# Instantiated 1 cells of population L23_PC_cADpyr229_4_I2_d
# Distributed population of 1 cells on 1 hosts: {0: [0]}, next: 0
# Cell 0/0 (gid=116) of pop L23_PC_cADpyr229_4_I3_d, on node 0,
# Instantiated 1 cells of population L23_PC_cADpyr229_4_I3_d
# Distributed population of 1 cells on 1 hosts: {0: [0]}, next: 0
# Cell 0/0 (gid=117) of pop L23_PC_cADpyr229_5_I1_d, on node 0,
# Instantiated 1 cells of population L23_PC_cADpyr229_5_I1_d
# Distributed population of 1 cells on 1 hosts: {0: [0]}, next: 0
# Cell 0/0 (gid=118) of pop L23_PC_cADpyr229_5_I2_d, on node 0,
# Instantiated 1 cells of population L23_PC_cADpyr229_5_I2_d
# Distributed population of 1 cells on 1 hosts: {0: [0]}, next: 0
# Cell 0/0 (gid=119) of pop L23_PC_cADpyr229_5_I3_d, on node 0,
# Instantiated 1 cells of population L23_PC_cADpyr229_5_I3_d
# Distributed population of 1 cells on 1 hosts: {0: [0]}, next: 0
#     Error while setting 'spkTimes' param to VecStim[0]
# Cell 0/0 (gid=120) of pop presyn_a, on node 0,
# Instantiated 1 cells of population presyn_a
# Distributed population of 1 cells on 1 hosts: {0: [0]}, next: 0
#     Error while setting 'spkTimes' param to VecStim[1]
# Cell 0/0 (gid=121) of pop presyn_b, on node 0,
# Instantiated 1 cells of population presyn_b
# Distributed population of 1 cells on 1 hosts: {0: [0]}, next: 0
#     Error while setting 'spkTimes' param to VecStim[2]
# Cell 0/0 (gid=122) of pop presyn_c, on node 0,
# Instantiated 1 cells of population presyn_c
# Distributed population of 1 cells on 1 hosts: {0: [0]}, next: 0
#     Error while setting 'spkTimes' param to VecStim[3]
# Cell 0/0 (gid=123) of pop presyn_d, on node 0,
# Instantiated 1 cells of population presyn_d
#   Number of cells on node 0: 124
#   Done; cell creation time = 2.71 s.
# Making connections...
# Generating set of all-to-all connections (rule: STP_Det_a_3) ...
#   Created connection preGid=120, postGid=15, sec=dend_0, loc=0.5219, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=15, sec=dend_1, loc=0.8978, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=15, sec=dend_1, loc=0.6727, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=15, sec=dend_1, loc=0.4476, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=15, sec=dend_1, loc=0.2226, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=15, sec=dend_2, loc=0.9954, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=15, sec=dend_2, loc=0.5783, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=15, sec=dend_2, loc=0.1612, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=15, sec=dend_3, loc=0.9565, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=15, sec=dend_3, loc=0.8857, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=15, sec=dend_3, loc=0.8148, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=15, sec=dend_3, loc=0.744, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=15, sec=dend_3, loc=0.6731, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=15, sec=dend_3, loc=0.6023, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=15, sec=dend_3, loc=0.5314, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=15, sec=dend_3, loc=0.4605, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=15, sec=dend_3, loc=0.3897, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=15, sec=dend_3, loc=0.3188, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=15, sec=dend_3, loc=0.248, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=15, sec=dend_3, loc=0.1771, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=15, sec=dend_3, loc=0.1063, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=15, sec=dend_3, loc=0.03543, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=18, sec=dend_0, loc=0.3993, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=18, sec=dend_1, loc=0.8312, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=18, sec=dend_1, loc=0.5783, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=18, sec=dend_1, loc=0.3254, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=18, sec=dend_1, loc=0.07249, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=18, sec=dend_2, loc=0.06141, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=18, sec=dend_3, loc=0.9421, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=18, sec=dend_3, loc=0.8813, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=18, sec=dend_3, loc=0.8205, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=18, sec=dend_3, loc=0.7597, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=18, sec=dend_3, loc=0.6989, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=18, sec=dend_3, loc=0.6382, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=18, sec=dend_3, loc=0.5774, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=18, sec=dend_3, loc=0.5166, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=18, sec=dend_3, loc=0.4558, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=18, sec=dend_3, loc=0.3951, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=18, sec=dend_3, loc=0.3343, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=18, sec=dend_3, loc=0.2735, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=18, sec=dend_3, loc=0.2127, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=18, sec=dend_3, loc=0.1519, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=18, sec=dend_3, loc=0.09117, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=18, sec=dend_3, loc=0.03039, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=21, sec=dend_1, loc=0.8771, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=21, sec=dend_1, loc=0.2812, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=21, sec=dend_2, loc=0.9504, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=21, sec=dend_2, loc=0.8564, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=21, sec=dend_2, loc=0.7624, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=21, sec=dend_2, loc=0.6683, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=21, sec=dend_2, loc=0.5743, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=21, sec=dend_2, loc=0.4803, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=21, sec=dend_2, loc=0.3863, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=21, sec=dend_2, loc=0.2923, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=21, sec=dend_2, loc=0.1983, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=21, sec=dend_2, loc=0.1043, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=21, sec=dend_2, loc=0.0103, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=21, sec=dend_3, loc=0.9052, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=21, sec=dend_3, loc=0.7987, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=21, sec=dend_3, loc=0.6922, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=21, sec=dend_3, loc=0.5857, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=21, sec=dend_3, loc=0.4792, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=21, sec=dend_3, loc=0.3727, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=21, sec=dend_3, loc=0.2662, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=21, sec=dend_3, loc=0.1597, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=21, sec=dend_3, loc=0.05325, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=24, sec=dend_1, loc=0.8848, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=24, sec=dend_1, loc=0.216, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=24, sec=dend_2, loc=0.9378, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=24, sec=dend_2, loc=0.8459, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=24, sec=dend_2, loc=0.754, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=24, sec=dend_2, loc=0.6622, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=24, sec=dend_2, loc=0.5703, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=24, sec=dend_2, loc=0.4784, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=24, sec=dend_2, loc=0.3865, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=24, sec=dend_2, loc=0.2947, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=24, sec=dend_2, loc=0.2028, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=24, sec=dend_2, loc=0.1109, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=24, sec=dend_2, loc=0.01905, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=24, sec=dend_3, loc=0.9147, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=24, sec=dend_3, loc=0.8071, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=24, sec=dend_3, loc=0.6995, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=24, sec=dend_3, loc=0.5919, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=24, sec=dend_3, loc=0.4843, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=24, sec=dend_3, loc=0.3766, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=24, sec=dend_3, loc=0.269, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=24, sec=dend_3, loc=0.1614, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=24, sec=dend_3, loc=0.05381, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=27, sec=dend_0, loc=0.6871, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=27, sec=dend_0, loc=0.06117, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=27, sec=dend_1, loc=0.3154, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=27, sec=dend_2, loc=0.9175, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=27, sec=dend_2, loc=0.7764, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=27, sec=dend_2, loc=0.6353, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=27, sec=dend_2, loc=0.4942, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=27, sec=dend_2, loc=0.3531, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=27, sec=dend_2, loc=0.212, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=27, sec=dend_2, loc=0.07095, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=27, sec=dend_3, loc=0.9586, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=27, sec=dend_3, loc=0.8752, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=27, sec=dend_3, loc=0.7919, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=27, sec=dend_3, loc=0.7085, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=27, sec=dend_3, loc=0.6251, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=27, sec=dend_3, loc=0.5418, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=27, sec=dend_3, loc=0.4584, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=27, sec=dend_3, loc=0.3751, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=27, sec=dend_3, loc=0.2917, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=27, sec=dend_3, loc=0.2084, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=27, sec=dend_3, loc=0.125, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=120, postGid=27, sec=dend_3, loc=0.04168, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
# Generating set of all-to-all connections (rule: STP_Det_b_3) ...
#   Created connection preGid=121, postGid=45, sec=dend_3, loc=0.03745, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=121, postGid=45, sec=dend_8, loc=0.7907, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=121, postGid=45, sec=dend_12, loc=0.6526, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=121, postGid=45, sec=dend_16, loc=0.03645, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=121, postGid=45, sec=dend_20, loc=0.6416, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=121, postGid=45, sec=dend_27, loc=0.94, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=121, postGid=45, sec=dend_29, loc=0.2967, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=121, postGid=45, sec=dend_35, loc=0.07036, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=121, postGid=45, sec=dend_39, loc=0.1253, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=121, postGid=45, sec=dend_44, loc=0.4847, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=121, postGid=45, sec=dend_48, loc=0.1478, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=121, postGid=45, sec=dend_54, loc=0.8196, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=121, postGid=45, sec=dend_56, loc=0.6657, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=121, postGid=45, sec=dend_63, loc=0.6531, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=121, postGid=45, sec=apic_3, loc=0.9955, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=121, postGid=45, sec=apic_5, loc=0.1627, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=121, postGid=45, sec=apic_9, loc=0.2074, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=121, postGid=45, sec=apic_12, loc=0.82, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=121, postGid=45, sec=apic_16, loc=0.8676, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=121, postGid=45, sec=apic_17, loc=0.2221, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=121, postGid=45, sec=apic_21, loc=0.8957, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=121, postGid=45, sec=apic_22, loc=0.6591, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=121, postGid=48, sec=dend_3, loc=0.3365, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=121, postGid=48, sec=dend_7, loc=0.685, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=121, postGid=48, sec=dend_9, loc=0.05861, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=121, postGid=48, sec=dend_15, loc=0.1331, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=121, postGid=48, sec=dend_19, loc=0.5084, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=121, postGid=48, sec=dend_26, loc=0.5072, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=121, postGid=48, sec=dend_29, loc=0.612, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=121, postGid=48, sec=dend_34, loc=0.8102, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=121, postGid=48, sec=dend_39, loc=0.3043, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=121, postGid=48, sec=dend_42, loc=0.1131, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=121, postGid=48, sec=dend_48, loc=0.9308, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=121, postGid=48, sec=dend_51, loc=0.8253, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=121, postGid=48, sec=dend_55, loc=0.3814, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=121, postGid=48, sec=dend_60, loc=0.8988, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=121, postGid=48, sec=dend_65, loc=0.3333, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=121, postGid=48, sec=apic_4, loc=0.3638, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=121, postGid=48, sec=apic_9, loc=0.7349, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=121, postGid=48, sec=apic_13, loc=0.8272, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=121, postGid=48, sec=apic_16, loc=0.9254, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=121, postGid=48, sec=apic_17, loc=0.66, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=121, postGid=48, sec=apic_20, loc=0.4444, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=121, postGid=48, sec=apic_22, loc=0.8792, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=121, postGid=51, sec=dend_2, loc=0.3342, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=121, postGid=51, sec=dend_6, loc=0.402, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=121, postGid=51, sec=dend_8, loc=0.2369, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=121, postGid=51, sec=dend_12, loc=0.9232, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=121, postGid=51, sec=dend_13, loc=0.06479, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=121, postGid=51, sec=dend_15, loc=0.277, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=121, postGid=51, sec=apic_4, loc=0.8247, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=121, postGid=51, sec=apic_4, loc=0.07759, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=121, postGid=51, sec=apic_8, loc=0.2281, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=121, postGid=51, sec=apic_12, loc=0.2504, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=121, postGid=51, sec=apic_17, loc=0.3622, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=121, postGid=51, sec=apic_20, loc=0.2582, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=121, postGid=51, sec=apic_24, loc=0.5787, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=121, postGid=51, sec=apic_28, loc=0.5291, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=121, postGid=51, sec=apic_30, loc=0.2778, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=121, postGid=51, sec=apic_35, loc=0.9015, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=121, postGid=51, sec=apic_39, loc=0.7361, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=121, postGid=51, sec=apic_41, loc=0.1062, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=121, postGid=51, sec=apic_50, loc=0.3683, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=121, postGid=51, sec=apic_58, loc=0.9157, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=121, postGid=51, sec=apic_59, loc=0.3477, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=121, postGid=51, sec=apic_62, loc=0.7693, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=121, postGid=54, sec=dend_2, loc=0.1463, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=121, postGid=54, sec=dend_7, loc=0.8184, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=121, postGid=54, sec=dend_10, loc=0.2911, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=121, postGid=54, sec=dend_13, loc=0.9222, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=121, postGid=54, sec=dend_14, loc=0.4592, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=121, postGid=54, sec=apic_1, loc=0.8073, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=121, postGid=54, sec=apic_4, loc=0.7507, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=121, postGid=54, sec=apic_4, loc=0.1331, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=121, postGid=54, sec=apic_8, loc=0.2134, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=121, postGid=54, sec=apic_12, loc=0.4595, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=121, postGid=54, sec=apic_17, loc=0.3861, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=121, postGid=54, sec=apic_20, loc=0.3397, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=121, postGid=54, sec=apic_25, loc=0.9621, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=121, postGid=54, sec=apic_28, loc=0.8688, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=121, postGid=54, sec=apic_30, loc=0.5245, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=121, postGid=54, sec=apic_34, loc=0.2676, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=121, postGid=54, sec=apic_39, loc=0.9604, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=121, postGid=54, sec=apic_41, loc=0.4275, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=121, postGid=54, sec=apic_49, loc=0.1934, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=121, postGid=54, sec=apic_56, loc=0.6631, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=121, postGid=54, sec=apic_59, loc=0.4886, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=121, postGid=54, sec=apic_62, loc=0.806, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=121, postGid=57, sec=dend_2, loc=0.1099, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=121, postGid=57, sec=dend_7, loc=0.708, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=121, postGid=57, sec=dend_9, loc=0.457, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=121, postGid=57, sec=dend_13, loc=0.7117, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=121, postGid=57, sec=dend_18, loc=0.1198, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=121, postGid=57, sec=dend_26, loc=0.1586, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=121, postGid=57, sec=dend_33, loc=0.84, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=121, postGid=57, sec=dend_35, loc=0.245, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=121, postGid=57, sec=dend_43, loc=0.8466, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=121, postGid=57, sec=dend_47, loc=0.07135, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=121, postGid=57, sec=dend_51, loc=0.125, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
#   Created connection preGid=121, postGid=57, sec=dend_56, loc=0.716, synMech=S1_IE_STP_Det_3, weight=0.91, delay=0.10
# ...
# Vector[252784]
#   Recording  V_soma from cell  18  with parameters:  {'sec': 'soma', 'loc': 0.5, 'var': 'v'}
# Vector[252785]
#   Recording  V_soma from cell  19  with parameters:  {'sec': 'soma', 'loc': 0.5, 'var': 'v'}
# Vector[252786]
#   Recording  V_soma from cell  20  with parameters:  {'sec': 'soma', 'loc': 0.5, 'var': 'v'}
# Vector[252787]
#   Recording  V_soma from cell  21  with parameters:  {'sec': 'soma', 'loc': 0.5, 'var': 'v'}
# Vector[252788]
#   Recording  V_soma from cell  22  with parameters:  {'sec': 'soma', 'loc': 0.5, 'var': 'v'}
# Vector[252789]
#   Recording  V_soma from cell  23  with parameters:  {'sec': 'soma', 'loc': 0.5, 'var': 'v'}
# Vector[252790]
#   Recording  V_soma from cell  24  with parameters:  {'sec': 'soma', 'loc': 0.5, 'var': 'v'}
# Vector[252791]
#   Recording  V_soma from cell  25  with parameters:  {'sec': 'soma', 'loc': 0.5, 'var': 'v'}
# Vector[252792]
#   Recording  V_soma from cell  26  with parameters:  {'sec': 'soma', 'loc': 0.5, 'var': 'v'}
# Vector[252793]
#   Recording  V_soma from cell  27  with parameters:  {'sec': 'soma', 'loc': 0.5, 'var': 'v'}
# Vector[252794]
#   Recording  V_soma from cell  28  with parameters:  {'sec': 'soma', 'loc': 0.5, 'var': 'v'}
# Vector[252795]
#   Recording  V_soma from cell  29  with parameters:  {'sec': 'soma', 'loc': 0.5, 'var': 'v'}
# Vector[252796]
#   Recording  V_soma from cell  30  with parameters:  {'sec': 'soma', 'loc': 0.5, 'var': 'v'}
# Vector[252797]
#   Recording  V_soma from cell  31  with parameters:  {'sec': 'soma', 'loc': 0.5, 'var': 'v'}
# Vector[252798]
#   Recording  V_soma from cell  32  with parameters:  {'sec': 'soma', 'loc': 0.5, 'var': 'v'}
# Vector[252799]
#   Recording  V_soma from cell  33  with parameters:  {'sec': 'soma', 'loc': 0.5, 'var': 'v'}
# Vector[252800]
#   Recording  V_soma from cell  34  with parameters:  {'sec': 'soma', 'loc': 0.5, 'var': 'v'}
# Vector[252801]
#   Recording  V_soma from cell  35  with parameters:  {'sec': 'soma', 'loc': 0.5, 'var': 'v'}
# Vector[252802]
#   Recording  V_soma from cell  36  with parameters:  {'sec': 'soma', 'loc': 0.5, 'var': 'v'}
# Vector[252803]
#   Recording  V_soma from cell  37  with parameters:  {'sec': 'soma', 'loc': 0.5, 'var': 'v'}
# Vector[252804]
#   Recording  V_soma from cell  38  with parameters:  {'sec': 'soma', 'loc': 0.5, 'var': 'v'}
# Vector[252805]
#   Recording  V_soma from cell  39  with parameters:  {'sec': 'soma', 'loc': 0.5, 'var': 'v'}
# Vector[252806]
#   Recording  V_soma from cell  40  with parameters:  {'sec': 'soma', 'loc': 0.5, 'var': 'v'}
# Vector[252807]
#   Recording  V_soma from cell  41  with parameters:  {'sec': 'soma', 'loc': 0.5, 'var': 'v'}
# Vector[252808]
#   Recording  V_soma from cell  42  with parameters:  {'sec': 'soma', 'loc': 0.5, 'var': 'v'}
# Vector[252809]
#   Recording  V_soma from cell  43  with parameters:  {'sec': 'soma', 'loc': 0.5, 'var': 'v'}
# Vector[252810]
#   Recording  V_soma from cell  44  with parameters:  {'sec': 'soma', 'loc': 0.5, 'var': 'v'}
# Vector[252811]
#   Recording  V_soma from cell  45  with parameters:  {'sec': 'soma', 'loc': 0.5, 'var': 'v'}
# Vector[252812]
#   Recording  V_soma from cell  46  with parameters:  {'sec': 'soma', 'loc': 0.5, 'var': 'v'}
# Vector[252813]
#   Recording  V_soma from cell  47  with parameters:  {'sec': 'soma', 'loc': 0.5, 'var': 'v'}
# Vector[252814]
#   Recording  V_soma from cell  48  with parameters:  {'sec': 'soma', 'loc': 0.5, 'var': 'v'}
# Vector[252815]
#   Recording  V_soma from cell  49  with parameters:  {'sec': 'soma', 'loc': 0.5, 'var': 'v'}
# Vector[252816]
#   Recording  V_soma from cell  50  with parameters:  {'sec': 'soma', 'loc': 0.5, 'var': 'v'}
# Vector[252817]
#   Recording  V_soma from cell  51  with parameters:  {'sec': 'soma', 'loc': 0.5, 'var': 'v'}
# Vector[252818]
#   Recording  V_soma from cell  52  with parameters:  {'sec': 'soma', 'loc': 0.5, 'var': 'v'}
# Vector[252819]
#   Recording  V_soma from cell  53  with parameters:  {'sec': 'soma', 'loc': 0.5, 'var': 'v'}
# Vector[252820]
#   Recording  V_soma from cell  54  with parameters:  {'sec': 'soma', 'loc': 0.5, 'var': 'v'}
# Vector[252821]
#   Recording  V_soma from cell  55  with parameters:  {'sec': 'soma', 'loc': 0.5, 'var': 'v'}
# Vector[252822]
#   Recording  V_soma from cell  56  with parameters:  {'sec': 'soma', 'loc': 0.5, 'var': 'v'}
# Vector[252823]
#   Recording  V_soma from cell  57  with parameters:  {'sec': 'soma', 'loc': 0.5, 'var': 'v'}
# Vector[252824]
#   Recording  V_soma from cell  58  with parameters:  {'sec': 'soma', 'loc': 0.5, 'var': 'v'}
# Vector[252825]
#   Recording  V_soma from cell  59  with parameters:  {'sec': 'soma', 'loc': 0.5, 'var': 'v'}
# Vector[252826]
#   Recording  V_soma from cell  60  with parameters:  {'sec': 'soma', 'loc': 0.5, 'var': 'v'}
# Vector[252827]
#   Recording  V_soma from cell  61  with parameters:  {'sec': 'soma', 'loc': 0.5, 'var': 'v'}
# Vector[252828]
#   Recording  V_soma from cell  62  with parameters:  {'sec': 'soma', 'loc': 0.5, 'var': 'v'}
# Vector[252829]
#   Recording  V_soma from cell  63  with parameters:  {'sec': 'soma', 'loc': 0.5, 'var': 'v'}
# Vector[252830]
#   Recording  V_soma from cell  64  with parameters:  {'sec': 'soma', 'loc': 0.5, 'var': 'v'}
# Vector[252831]
#   Recording  V_soma from cell  65  with parameters:  {'sec': 'soma', 'loc': 0.5, 'var': 'v'}
# Vector[252832]
#   Recording  V_soma from cell  66  with parameters:  {'sec': 'soma', 'loc': 0.5, 'var': 'v'}
# Vector[252833]
#   Recording  V_soma from cell  67  with parameters:  {'sec': 'soma', 'loc': 0.5, 'var': 'v'}
# Vector[252834]
#   Recording  V_soma from cell  68  with parameters:  {'sec': 'soma', 'loc': 0.5, 'var': 'v'}
# Vector[252835]
#   Recording  V_soma from cell  69  with parameters:  {'sec': 'soma', 'loc': 0.5, 'var': 'v'}
# Vector[252836]
#   Recording  V_soma from cell  70  with parameters:  {'sec': 'soma', 'loc': 0.5, 'var': 'v'}
# Vector[252837]
#   Recording  V_soma from cell  71  with parameters:  {'sec': 'soma', 'loc': 0.5, 'var': 'v'}
# Vector[252838]
#   Recording  V_soma from cell  72  with parameters:  {'sec': 'soma', 'loc': 0.5, 'var': 'v'}
# Vector[252839]
#   Recording  V_soma from cell  73  with parameters:  {'sec': 'soma', 'loc': 0.5, 'var': 'v'}
# Vector[252840]
#   Recording  V_soma from cell  74  with parameters:  {'sec': 'soma', 'loc': 0.5, 'var': 'v'}
# Vector[252841]
#   Recording  V_soma from cell  75  with parameters:  {'sec': 'soma', 'loc': 0.5, 'var': 'v'}
# Vector[252842]
#   Recording  V_soma from cell  76  with parameters:  {'sec': 'soma', 'loc': 0.5, 'var': 'v'}
# Vector[252843]
#   Recording  V_soma from cell  77  with parameters:  {'sec': 'soma', 'loc': 0.5, 'var': 'v'}
# Vector[252844]
#   Recording  V_soma from cell  78  with parameters:  {'sec': 'soma', 'loc': 0.5, 'var': 'v'}
# Vector[252845]
#   Recording  V_soma from cell  79  with parameters:  {'sec': 'soma', 'loc': 0.5, 'var': 'v'}
# Vector[252846]
#   Recording  V_soma from cell  80  with parameters:  {'sec': 'soma', 'loc': 0.5, 'var': 'v'}
# Vector[252847]
#   Recording  V_soma from cell  81  with parameters:  {'sec': 'soma', 'loc': 0.5, 'var': 'v'}
# Vector[252848]
#   Recording  V_soma from cell  82  with parameters:  {'sec': 'soma', 'loc': 0.5, 'var': 'v'}
# Vector[252849]
#   Recording  V_soma from cell  83  with parameters:  {'sec': 'soma', 'loc': 0.5, 'var': 'v'}
# Vector[252850]
#   Recording  V_soma from cell  84  with parameters:  {'sec': 'soma', 'loc': 0.5, 'var': 'v'}
# Vector[252851]
#   Recording  V_soma from cell  85  with parameters:  {'sec': 'soma', 'loc': 0.5, 'var': 'v'}
# Vector[252852]
#   Recording  V_soma from cell  86  with parameters:  {'sec': 'soma', 'loc': 0.5, 'var': 'v'}
# Vector[252853]
#   Recording  V_soma from cell  87  with parameters:  {'sec': 'soma', 'loc': 0.5, 'var': 'v'}
# Vector[252854]
#   Recording  V_soma from cell  88  with parameters:  {'sec': 'soma', 'loc': 0.5, 'var': 'v'}
# Vector[252855]
#   Recording  V_soma from cell  89  with parameters:  {'sec': 'soma', 'loc': 0.5, 'var': 'v'}
# Vector[252856]
#   Recording  V_soma from cell  90  with parameters:  {'sec': 'soma', 'loc': 0.5, 'var': 'v'}
# Vector[252857]
#   Recording  V_soma from cell  91  with parameters:  {'sec': 'soma', 'loc': 0.5, 'var': 'v'}
# Vector[252858]
#   Recording  V_soma from cell  92  with parameters:  {'sec': 'soma', 'loc': 0.5, 'var': 'v'}
# Vector[252859]
#   Recording  V_soma from cell  93  with parameters:  {'sec': 'soma', 'loc': 0.5, 'var': 'v'}
# Vector[252860]
#   Recording  V_soma from cell  94  with parameters:  {'sec': 'soma', 'loc': 0.5, 'var': 'v'}
# Vector[252861]
#   Recording  V_soma from cell  95  with parameters:  {'sec': 'soma', 'loc': 0.5, 'var': 'v'}
# Vector[252862]
#   Recording  V_soma from cell  96  with parameters:  {'sec': 'soma', 'loc': 0.5, 'var': 'v'}
# Vector[252863]
#   Recording  V_soma from cell  97  with parameters:  {'sec': 'soma', 'loc': 0.5, 'var': 'v'}
# Vector[252864]
#   Recording  V_soma from cell  98  with parameters:  {'sec': 'soma', 'loc': 0.5, 'var': 'v'}
# Vector[252865]
#   Recording  V_soma from cell  99  with parameters:  {'sec': 'soma', 'loc': 0.5, 'var': 'v'}
# Vector[252866]
#   Recording  V_soma from cell  100  with parameters:  {'sec': 'soma', 'loc': 0.5, 'var': 'v'}
# Vector[252867]
#   Recording  V_soma from cell  101  with parameters:  {'sec': 'soma', 'loc': 0.5, 'var': 'v'}
# Vector[252868]
#   Recording  V_soma from cell  102  with parameters:  {'sec': 'soma', 'loc': 0.5, 'var': 'v'}
# Vector[252869]
#   Recording  V_soma from cell  103  with parameters:  {'sec': 'soma', 'loc': 0.5, 'var': 'v'}
# Vector[252870]
#   Recording  V_soma from cell  104  with parameters:  {'sec': 'soma', 'loc': 0.5, 'var': 'v'}
# Vector[252871]
#   Recording  V_soma from cell  105  with parameters:  {'sec': 'soma', 'loc': 0.5, 'var': 'v'}
# Vector[252872]
#   Recording  V_soma from cell  106  with parameters:  {'sec': 'soma', 'loc': 0.5, 'var': 'v'}
# Vector[252873]
#   Recording  V_soma from cell  107  with parameters:  {'sec': 'soma', 'loc': 0.5, 'var': 'v'}
# Vector[252874]
#   Recording  V_soma from cell  108  with parameters:  {'sec': 'soma', 'loc': 0.5, 'var': 'v'}
# Vector[252875]
#   Recording  V_soma from cell  109  with parameters:  {'sec': 'soma', 'loc': 0.5, 'var': 'v'}
# Vector[252876]
#   Recording  V_soma from cell  110  with parameters:  {'sec': 'soma', 'loc': 0.5, 'var': 'v'}
# Vector[252877]
#   Recording  V_soma from cell  111  with parameters:  {'sec': 'soma', 'loc': 0.5, 'var': 'v'}
# Vector[252878]
#   Recording  V_soma from cell  112  with parameters:  {'sec': 'soma', 'loc': 0.5, 'var': 'v'}
# Vector[252879]
#   Recording  V_soma from cell  113  with parameters:  {'sec': 'soma', 'loc': 0.5, 'var': 'v'}
# Vector[252880]
#   Recording  V_soma from cell  114  with parameters:  {'sec': 'soma', 'loc': 0.5, 'var': 'v'}
# Vector[252881]
#   Recording  V_soma from cell  115  with parameters:  {'sec': 'soma', 'loc': 0.5, 'var': 'v'}
# Vector[
ell_37: Vector[252804], cell_38: Vector[252805], cell_39: Vector[252806], cell_40: Vector[252807], cell_41: Vector[252808], cell_42: Vector[252809], cell_43: Vector[252810], cell_44: Vector[252811], cell_45: Vector[252812], cell_46: Vector[252813], cell_47: Vector[252814], cell_48: Vector[252815], cell_49: Vector[252816], cell_50: Vector[252817], cell_51: Vector[252818], cell_52: Vector[252819], cell_53: Vector[252820], cell_54: Vector[252821], cell_55: Vector[252822], cell_56: Vector[252823], cell_57: Vector[252824], cell_58: Vector[252825], cell_59: Vector[252826], cell_60: Vector[252827], cell_61: Vector[252828], cell_62: Vector[252829], cell_63: Vector[252830], cell_64: Vector[252831], cell_65: Vector[252832], cell_66: Vector[252833], cell_67: Vector[252834], cell_68: Vector[252835], cell_69: Vector[252836], cell_70: Vector[252837], cell_71: Vector[252838], cell_72: Vector[252839], cell_73: Vector[252840], cell_74: Vector[252841], cell_75: Vector[252842], cell_76: Vector[252843], cell_77: Vector[252844], cell_78: Vector[252845], cell_79: Vector[252846], cell_80: Vector[252847], cell_81: Vector[252848], cell_82: Vector[252849], cell_83: Vector[252850], cell_84: Vector[252851], cell_85: Vector[252852], cell_86: Vector[252853], cell_87: Vector[252854], cell_88: Vector[252855], cell_89: Vector[252856], cell_90: Vector[252857], cell_91: Vector[252858], cell_92: Vector[252859], cell_93: Vector[252860], cell_94: Vector[252861], cell_95: Vector[252862], cell_96: Vector[252863], cell_97: Vector[252864], cell_98: Vector[252865], cell_99: Vector[252866], cell_100: Vector[252867], cell_101: Vector[252868], cell_102: Vector[252869], cell_103: Vector[252870], cell_104: Vector[252871], cell_105: Vector[252872], cell_106: Vector[252873], cell_107: Vector[252874], cell_108: Vector[252875], cell_109: Vector[252876], cell_110: Vector[252877], cell_111: Vector[252878], cell_112: Vector[252879], cell_113: Vector[252880], cell_114: Vector[252881], cell_115: Vector[252882], cell_116: Vector[252883], cell_117: Vector[252884], cell_118: Vector[252885], cell_119: Vector[252886]}, t: Vector[252887], _repr_mimebundle_: {}}

# %%
sim.runSim()                      			# run parallel Neuron simulation
# Out:
# Setting h global variables ...
#   h.celsius = 34
#   h.v_init = -65.0
#   h.tstop = 4000.0
# Minimum delay (time-step for queue exchange) is 10.00
# 0.0s
#
# Running simulation using NEURON for 4000.0 ms...
# 0.1s
# 0.2s
# 0.3s
# 0.4s
# 0.5s
# 0.6s

# %%
sim.gatherData()                  			# gather spiking data and cell info from each node
sim.saveData()                    			# save params, cell info and sim output to file (pickle,mat,txt,etc)#
sim.analysis.plotData()         			# plot spike raster etc
# Out:
# Gathering data...
#   Done; gather time = 0.18 s.
#
# Analyzing...
#   Cells: 124
#   Connections: 120 (0.97 per cell)
#   Synaptic contacts: 1780 (14.35 per cell)
#   Spikes: 44 (0.09 Hz)
#   Simulated time: 4.0 s; 1 workers
#   Run time: 1963.38 s
#   Done; saving time = 0.02 s.
# Plotting recorded cell traces ... trace
#   Done; plotting time = 1.23 s
#
# Total time = 1967.80 s
#
# End time:  2021-10-21 21:00:48.475636

# %%
Traces2 = sim.analysis.plotTraces(oneFigPer='trace', overlay=1, timeRange=[2400,4000], saveData='../info/test/syn/syn_eletrophys_all.json')
# Out:
# Plotting recorded cell traces ... trace
# Saving figure data as ../info/test/syn/syn_eletrophys_all.json ...

# %%
# import json
# Traces2 = {}
# with open('../info/test/syn/syn_eletrophys_all.json', 'r') as f:
#     Traces2[1] = json.load(f)

# %%
# alltraces = []
# for number in range(20):
#     alltraces.append(Traces2[1]['tracesData'][number]['cell_'+str(number)+'_V_soma'])

# %%
sim.net.allCells[5+6]['conns']
# Out:
# [{preGid: 120, sec: 'dend_1', loc: 0.8058838094851144, synMech: 'S1_EE_STP_Det_126', weight: 0.8, delay: 0.1, label: 'STP_Det_a_126'},
#  {preGid: 120, sec: 'dend_1', loc: 0.3578875325654556, synMech: 'S1_EE_STP_Det_126', weight: 0.8, delay: 0.1, label: 'STP_Det_a_126'},
#  {preGid: 120, sec: 'dend_2', loc: 0.4074793775397835, synMech: 'S1_EE_STP_Det_126', weight: 0.8, delay: 0.1, label: 'STP_Det_a_126'},
#  {preGid: 120, sec: 'dend_3', loc: 0.6351419182804355, synMech: 'S1_EE_STP_Det_126', weight: 0.8, delay: 0.1, label: 'STP_Det_a_126'},
#  {preGid: 120, sec: 'dend_3', loc: 0.21171397276014536, synMech: 'S1_EE_STP_Det_126', weight: 0.8, delay: 0.1, label: 'STP_Det_a_126'}]

# %%
sim.net.allCells[35+6]['conns']
# Out:
# [{preGid: 121, sec: 'dend_10', loc: 0.26560308115631714, synMech: 'S1_EE_STP_Det_126', weight: 0.8, delay: 0.1, label: 'STP_Det_b_126'},
#  {preGid: 121, sec: 'dend_36', loc: 0.284896458828752, synMech: 'S1_EE_STP_Det_126', weight: 0.8, delay: 0.1, label: 'STP_Det_b_126'},
#  {preGid: 121, sec: 'apic_17', loc: 0.8477389933768189, synMech: 'S1_EE_STP_Det_126', weight: 0.8, delay: 0.1, label: 'STP_Det_b_126'},
#  {preGid: 121, sec: 'apic_27', loc: 0.8099284606575549, synMech: 'S1_EE_STP_Det_126', weight: 0.8, delay: 0.1, label: 'STP_Det_b_126'},
#  {preGid: 121, sec: 'apic_35', loc: 0.14351014378391613, synMech: 'S1_EE_STP_Det_126', weight: 0.8, delay: 0.1, label: 'STP_Det_b_126'}]

# %%
sim.net.allCells[65+6]['conns']
# Out:
# [{preGid: 122, sec: 'dend_3', loc: 0.09082564087787404, synMech: 'S1_EE_STP_Det_126', weight: 0.8, delay: 0.1, label: 'STP_Det_c_126'},
#  {preGid: 122, sec: 'dend_10', loc: 0.16266438020830126, synMech: 'S1_EE_STP_Det_126', weight: 0.8, delay: 0.1, label: 'STP_Det_c_126'},
#  {preGid: 122, sec: 'dend_21', loc: 0.9091021032567701, synMech: 'S1_EE_STP_Det_126', weight: 0.8, delay: 0.1, label: 'STP_Det_c_126'},
#  {preGid: 122, sec: 'dend_25', loc: 0.07774049775412387, synMech: 'S1_EE_STP_Det_126', weight: 0.8, delay: 0.1, label: 'STP_Det_c_126'},
#  {preGid: 122, sec: 'dend_38', loc: 0.960445445646973, synMech: 'S1_EE_STP_Det_126', weight: 0.8, delay: 0.1, label: 'STP_Det_c_126'}]

# %%
sim.net.allCells[95+6]['conns']
# Out:
# [{preGid: 123, sec: 'dend_12', loc: 0.7636541861966151, synMech: 'S1_EE_STP_Det_126', weight: 0.8, delay: 0.1, label: 'STP_Det_d_126'},
#  {preGid: 123, sec: 'dend_12', loc: 0.2909625585898453, synMech: 'S1_EE_STP_Det_126', weight: 0.8, delay: 0.1, label: 'STP_Det_d_126'},
#  {preGid: 123, sec: 'dend_13', loc: 0.697992497594337, synMech: 'S1_EE_STP_Det_126', weight: 0.8, delay: 0.1, label: 'STP_Det_d_126'},
#  {preGid: 123, sec: 'dend_14', loc: 0.920303954582353, synMech: 'S1_EE_STP_Det_126', weight: 0.8, delay: 0.1, label: 'STP_Det_d_126'},
#  {preGid: 123, sec: 'dend_14', loc: 0.20525148548566413, synMech: 'S1_EE_STP_Det_126', weight: 0.8, delay: 0.1, label: 'STP_Det_d_126'}]

# %%
figSize = (6,20)
fig = plt.figure(figsize=figSize)  # Open a new figure
clr = ["orange","green","gray", "red", "blue"]

cellpostrules = ['L23_LBC_cAC','L23_LBC_dNAC','L6_TPC_L4','I1','I2','I3']

for i,cellpostrule in enumerate(cellpostrules):
    plt.subplot(6, 1, i+1)
    for number in range(120):     
        if cellpostrule in sim.net.allCells[number]['tags']['pop']:
            if sim.net.allCells[number]['tags']['pop'].split('_')[-2] in ['1', '2', '3', '4', '5']:
                colorNum = int(sim.net.allCells[number]['tags']['pop'].split('_')[-2])
            else:
                colorNum = int(sim.net.allCells[number]['tags']['pop'].split('_')[-3])
            plt.plot(np.array(Traces2[1]['tracesData'][number]['t'][1:]),
                     np.array(Traces2[1]['tracesData'][number]['cell_'+str(number)+'_V_soma'])-Traces2[1]['tracesData'][number]['cell_'+str(number)+'_V_soma'][999], 
                     label= sim.net.allCells[number]['tags']['pop'] + '_' + sim.net.allCells[number]['conns'][0]['sec'], color=clr[colorNum-1], linewidth=1.5) #, alpha=0.5, color=clr[i]

    plt.xlim(2400,3650)
#     plt.ylim(-15.25,12.25)
    plt.xlabel('Time (ms)', fontsize=16)
    plt.ylabel('EPSP (mV)', fontsize=16)
    plt.xticks(range(2400,3900,200), range(0,1500,200), fontsize=16);
    plt.yticks(fontsize=14);

#     plt.legend(loc='upper right', bbox_to_anchor=(1.1, 0.85), fontsize=7)
plt.savefig('../info/test/syn/syn_eletrophys_20Hz_EI.png', facecolor = 'white' , dpi=300)
