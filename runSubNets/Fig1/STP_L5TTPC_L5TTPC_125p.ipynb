# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# # Input-output properties cells

# %%
import numpy as np
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
rootFolder = '/home/fernando/Dropbox/SUNY/2022/S1_netpyne/sim/'
# rootFolder = os.getcwd()
os.chdir(rootFolder)
print(rootFolder)
folder = os.listdir('cell_data/')
folder = sorted(folder)

savedata = 1 # Save Netpyne and BBP soma_voltage
# Out:
# /home/fernando/Dropbox/SUNY/2022/S1_netpyne/sim/

# %%
# !nrnivmodl mod

# %%
def loadTemplateName(cellnumber):     
    f = open(outFolder+'/template.hoc', 'r')
    for line in f.readlines():
        if 'begintemplate' in line:
            templatename = str(line)     
    templatename=templatename[:-1]        
    templatename=templatename[14:]
    return templatename

# %% [markdown]
# ## Netpyne

# %%
from netpyne import specs, sim   

# Network parameters
netParams = specs.NetParams()  # object of class NetParams to store the network parameters

# %%
# %matplotlib inline

# %%
## cfg  
cfg = specs.SimConfig()					            # object of class SimConfig to store simulation configuration
cfg.duration = 4000.0 						            # Duration of the simulation, in ms
cfg.dt = 0.05								                # Internal integration timestep to use
cfg.verbose = False							                # Show detailed messages 
cfg.recordTraces = {'V_soma':{'sec':'soma','loc':0.5,'var':'v'}}  # Dict with traces to record
cfg.recordStep = 0.1 			
cfg.printRunTime = 0.1 # in sec			

cfg.seeds = {'conn': 1, 'stim': 1, 'loc': 1} 
cfg.hParams = {'celsius': 34, 'v_init': -71.0}  
cfg.verbose = False
cfg.createNEURONObj = True
cfg.createPyStruct = True  
#------------------------------------------------------------------------------
# Saving
#------------------------------------------------------------------------------
cfg.filename = 'model_output'  			# Set file output name
cfg.savePickle = False         	## Save pkl file
cfg.saveJson = False	           	## Save json file
cfg.saveDataInclude = ['simData'] ## 'simData' , 'simConfig', 'netParams'
cfg.backupCfgFile = None 		##  
cfg.gatherOnlySimData = False	##  
cfg.saveCellSecs = False			
cfg.saveCellConns = True	

cfg.analysis['plotTraces'] = {'include': [i for i in range(50)], 'oneFigPer': 'trace', 'overlay': True, 'timeRange': [0,4000], 'saveFig': False, 'showFig': True, 'figSize':(12,4)} # Plot recorded traces for this list of cells
# cfg.analysis['plotShape'] = {'includePre': [0],'includePre': [0], 'saveFig': True, 'showFig': True, 'figSize':(12,12)}

# %%
# for i,metype in enumerate(folder):
#     print(i,metype)
folder[760:770]
# Out:
# ['L5_TTPC1_cADpyr232_1',
#  'L5_TTPC1_cADpyr232_2',
#  'L5_TTPC1_cADpyr232_3',
#  'L5_TTPC1_cADpyr232_4',
#  'L5_TTPC1_cADpyr232_5',
#  'L5_TTPC2_cADpyr232_1',
#  'L5_TTPC2_cADpyr232_2',
#  'L5_TTPC2_cADpyr232_3',
#  'L5_TTPC2_cADpyr232_4',
#  'L5_TTPC2_cADpyr232_5']

# %%
#------------------------------------------------------------------------------
# Cell parameters
#------------------------------------------------------------------------------
#StochKv_deterministic.mod
for cellnumber in range(760,770):
    cellName = folder[cellnumber]
    outFolder = rootFolder+'/cell_data/'+folder[cellnumber]
    cellTemplateName = loadTemplateName(cellnumber)
    cellRule = netParams.importCellParams(label=cellName, somaAtOrigin=False,
        conds={'cellType': cellName, 'cellModel': 'HH_full'},
        fileName='cellwrapper.py',
        cellName='loadCell',
        cellInstance = True,
        cellArgs={'cellName': cellName, 'cellTemplateName': cellTemplateName})
# Out:
# NEURON: morphology_0fb1ca4724 : a template cannot be redefined
#  in morphology.hoc near line 34
#  begintemplate morphology_0fb1ca4724
#                                    ^
#         xopen("morphology.hoc")
#       execute1("{xopen("mo...")
#     load_file("morphology.hoc")
#   xopen("template.hoc")
# NEURON: cADpyr232_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate cADpyr232_biophys
#                                ^
#         xopen("biophysics.hoc")
#       execute1("{xopen("bi...")
#     load_file("biophysics.hoc")
#   xopen("template.hoc")
# NEURON: synapses_0fb1ca4724 : a template cannot be redefined
#  in synapses.hoc near line 31
#  begintemplate synapses_0fb1ca4724
#                                  ^
#         xopen("synapses.hoc")
#       execute1("{xopen("sy...")
#     load_file("synapses/s...")
#   xopen("template.hoc")
# 	0
# 	0
# 	0
# cADpyr232_L5_TTPC1_0fb1ca4724[0]
# NEURON: cADpyr232_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate cADpyr232_biophys
#                                ^
#         xopen("biophysics.hoc")
# 	1
# 	1
# 	1
# cADpyr232_L5_TTPC1_fc944c2cf3[0]
# NEURON: cADpyr232_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate cADpyr232_biophys
#                                ^
#         xopen("biophysics.hoc")
# 	1
# 	1
# 	1
# cADpyr232_L5_TTPC1_da1088139b[0]
# NEURON: cADpyr232_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate cADpyr232_biophys
#                                ^
#         xopen("biophysics.hoc")
# 	1
# 	1
# 	1
# cADpyr232_L5_TTPC1_ded64abc4d[0]
# NEURON: cADpyr232_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate cADpyr232_biophys
#                                ^
#         xopen("biophysics.hoc")
# 	1
# 	1
# 	1
# cADpyr232_L5_TTPC1_b6836fcf6f[0]
# NEURON: cADpyr232_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate cADpyr232_biophys
#                                ^
#         xopen("biophysics.hoc")
# 	1
# 	1
# 	1
# cADpyr232_L5_TTPC2_8052133265[0]
# NEURON: cADpyr232_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate cADpyr232_biophys
#                                ^
#         xopen("biophysics.hoc")
# 	1
# 	1
# 	1
# cADpyr232_L5_TTPC2_a28017c6c7[0]
# NEURON: cADpyr232_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate cADpyr232_biophys
#                                ^
#         xopen("biophysics.hoc")
# 	1
# 	1
# 	1
# cADpyr232_L5_TTPC2_a467781f53[0]
# NEURON: cADpyr232_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate cADpyr232_biophys
#                                ^
#         xopen("biophysics.hoc")
# 	1
# 	1
# 	1
# cADpyr232_L5_TTPC2_c46a93702c[0]
# NEURON: cADpyr232_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate cADpyr232_biophys
#                                ^
#         xopen("biophysics.hoc")
# 	1
# 	1
# 	1
# cADpyr232_L5_TTPC2_8bab918b58[0]

# %%
for cellnumber in range(760,770):
    # ---------------------------------------------------------------------------------------------------- #
    cellName = folder[cellnumber]
    outFolder = rootFolder+'/cell_data/'+folder[cellnumber]
    cellTemplateName = loadTemplateName(cellnumber)
    
    # ---------------------------------------------------------------------------------------------------- #
    netParams.renameCellParamsSec(label=cellName, oldSec='soma_0', newSec='soma')
    
    for secname2 in netParams.cellParams[cellName]['secLists'].keys():
        if 'soma_0' in netParams.cellParams[cellName]['secLists'][secname2]:
            print(cellName,secname2,netParams.cellParams[cellName]['secLists'][secname2][0])
            netParams.cellParams[cellName]['secLists'][secname2][0] = 'soma'
    # ---------------------------------------------------------------------------------------------------- #
    
    nonSpiny = ['axon_0', 'axon_1']
    netParams.cellParams[cellName]['secLists']['spiny'] = [sec for sec in netParams.cellParams[cellName]['secLists']['all'] if sec not in nonSpiny]
    nonSpinyEE = ['axon_0', 'axon_1', 'soma']
    netParams.cellParams[cellName]['secLists']['spinyEE'] = [sec for sec in netParams.cellParams[cellName]['secLists']['all'] if sec not in nonSpinyEE]    
    
    # ---------------------------------------------------------------------------------------------------- #
    for ii in range(5):
        netParams.popParams[cellName + '_' + str(ii)] = {'cellType': cellName, 'numCells': 1, 'cellModel': 'HH_full'}
# Out:
# L5_TTPC1_cADpyr232_1 all soma_0
# L5_TTPC1_cADpyr232_1 somatic soma_0
# L5_TTPC1_cADpyr232_2 all soma_0
# L5_TTPC1_cADpyr232_2 somatic soma_0
# L5_TTPC1_cADpyr232_3 all soma_0
# L5_TTPC1_cADpyr232_3 somatic soma_0
# L5_TTPC1_cADpyr232_4 all soma_0
# L5_TTPC1_cADpyr232_4 somatic soma_0
# L5_TTPC1_cADpyr232_5 all soma_0
# L5_TTPC1_cADpyr232_5 somatic soma_0
# L5_TTPC2_cADpyr232_1 all soma_0
# L5_TTPC2_cADpyr232_1 somatic soma_0
# L5_TTPC2_cADpyr232_2 all soma_0
# L5_TTPC2_cADpyr232_2 somatic soma_0
# L5_TTPC2_cADpyr232_3 all soma_0
# L5_TTPC2_cADpyr232_3 somatic soma_0
# L5_TTPC2_cADpyr232_4 all soma_0
# L5_TTPC2_cADpyr232_4 somatic soma_0
# L5_TTPC2_cADpyr232_5 all soma_0
# L5_TTPC2_cADpyr232_5 somatic soma_0

# %%
for cellnumber in range(760,770):
    cellName = folder[cellnumber]
    print(netParams.cellParams[cellName]['secLists']['basal'][-1])
# Out:
# dend_112
# dend_112
# dend_112
# dend_112
# dend_82
# dend_79
# dend_95
# dend_95
# dend_95
# dend_95

# %%
# create custom list of spike times
# spkTimes = [2000,2500,3000,3500,4000,4500]
spkTimes = [500,2500,2550,2600,2650,2700,2750,2800,2850,2900,3400]

netParams.popParams['presyn'] = {'cellModel': 'VecStim', 'numCells': 1, 'spkTimes': spkTimes}  # VecStim with spike times

# %%
netParams.cellParams.keys()
# Out:
# odict_keys(['L5_TTPC1_cADpyr232_1', 'L5_TTPC1_cADpyr232_2', 'L5_TTPC1_cADpyr232_3', 'L5_TTPC1_cADpyr232_4', 'L5_TTPC1_cADpyr232_5', 'L5_TTPC2_cADpyr232_1', 'L5_TTPC2_cADpyr232_2', 'L5_TTPC2_cADpyr232_3', 'L5_TTPC2_cADpyr232_4', 'L5_TTPC2_cADpyr232_5'])

# %%
list(netParams.popParams.keys())[0:-1]
# Out:
# ['L5_TTPC1_cADpyr232_1_0',
#  'L5_TTPC1_cADpyr232_1_1',
#  'L5_TTPC1_cADpyr232_1_2',
#  'L5_TTPC1_cADpyr232_1_3',
#  'L5_TTPC1_cADpyr232_1_4',
#  'L5_TTPC1_cADpyr232_2_0',
#  'L5_TTPC1_cADpyr232_2_1',
#  'L5_TTPC1_cADpyr232_2_2',
#  'L5_TTPC1_cADpyr232_2_3',
#  'L5_TTPC1_cADpyr232_2_4',
#  'L5_TTPC1_cADpyr232_3_0',
#  'L5_TTPC1_cADpyr232_3_1',
#  'L5_TTPC1_cADpyr232_3_2',
#  'L5_TTPC1_cADpyr232_3_3',
#  'L5_TTPC1_cADpyr232_3_4',
#  'L5_TTPC1_cADpyr232_4_0',
#  'L5_TTPC1_cADpyr232_4_1',
#  'L5_TTPC1_cADpyr232_4_2',
#  'L5_TTPC1_cADpyr232_4_3',
#  'L5_TTPC1_cADpyr232_4_4',
#  'L5_TTPC1_cADpyr232_5_0',
#  'L5_TTPC1_cADpyr232_5_1',
#  'L5_TTPC1_cADpyr232_5_2',
#  'L5_TTPC1_cADpyr232_5_3',
#  'L5_TTPC1_cADpyr232_5_4',
#  'L5_TTPC2_cADpyr232_1_0',
#  'L5_TTPC2_cADpyr232_1_1',
#  'L5_TTPC2_cADpyr232_1_2',
#  'L5_TTPC2_cADpyr232_1_3',
#  'L5_TTPC2_cADpyr232_1_4',
#  'L5_TTPC2_cADpyr232_2_0',
#  'L5_TTPC2_cADpyr232_2_1',
#  'L5_TTPC2_cADpyr232_2_2',
#  'L5_TTPC2_cADpyr232_2_3',
#  'L5_TTPC2_cADpyr232_2_4',
#  'L5_TTPC2_cADpyr232_3_0',
#  'L5_TTPC2_cADpyr232_3_1',
#  'L5_TTPC2_cADpyr232_3_2',
#  'L5_TTPC2_cADpyr232_3_3',
#  'L5_TTPC2_cADpyr232_3_4',
#  'L5_TTPC2_cADpyr232_4_0',
#  'L5_TTPC2_cADpyr232_4_1',
#  'L5_TTPC2_cADpyr232_4_2',
#  'L5_TTPC2_cADpyr232_4_3',
#  'L5_TTPC2_cADpyr232_4_4',
#  'L5_TTPC2_cADpyr232_5_0',
#  'L5_TTPC2_cADpyr232_5_1',
#  'L5_TTPC2_cADpyr232_5_2',
#  'L5_TTPC2_cADpyr232_5_3',
#  'L5_TTPC2_cADpyr232_5_4']

# %%
import scipy.stats as stats

#E2 -> syn 119 E2 EE 0.68±0.46 1.74±0.18 0.46±0.260 671±17 17±5 L23_PC:L23_PC

# lower, upper = 0.44, 0.48
# mu, sigma = 0.46, 0.26
# X = stats.truncnorm(
#     (lower - mu) / sigma, (upper - mu) / sigma, loc=mu, scale=sigma)

lower, upper = 0.48, 0.52
mu, sigma = 0.50, 0.02
X = stats.truncnorm(
    (lower - mu) / sigma, (upper - mu) / sigma, loc=mu, scale=sigma)

Use = X.rvs(50)

# for ii in range(20):
#     netParams.synMechParams['L23_PC:L23_PC_'+str(ii+1)] = {'mod': 'ProbAMPANMDA_EMS',
#                                           'Dep': 671,
#                                           'Fac': 17,
#                                           'Use': 0.46/4.0,
#                                           'tau_r_AMPA': 0.2,
#                                           'tau_d_AMPA': 1.74,
#                                           'NMDA_ratio': 0.8,
#                                           'tau_r_NMDA': 0.29,
#                                           'tau_d_NMDA': 43.0} 
    
#E2 -> syn 123 E2 EE 1.50±1.05 1.74±0.18 0.50±0.020 671±17 17±5 L5_TTPC:L5_TTPC


for ii in range(50):
    netParams.synMechParams['L5_TTPC:L5_TTPC'+str(ii+1)] = {'mod': 'DetAMPANMDA',
                                          'Dep': 671,
                                          'Fac': 17,
                                          'Use': 0.50, # Use[ii], #0.50/1.0,
                                          'tau_r_AMPA': 0.2,
                                          'tau_d_AMPA': 1.74,
                                          'NMDA_ratio': 0.8,
                                          'tau_r_NMDA': 0.29,
                                          'tau_d_NMDA': 43.0}

# %%
import random

# lower, upper = 0.2243, 1.1426
# mu, sigma = 0.68, 0.46
# X = stats.truncnorm(
#     (lower - mu) / sigma, (upper - mu) / sigma, loc=mu, scale=sigma)

lower, upper = 0.52, 2.52
mu, sigma = 1.50, 1.05
X = stats.truncnorm(
    (lower - mu) / sigma, (upper - mu) / sigma, loc=mu, scale=sigma)


weight = X.rvs(50)

## Cell connectivity rules
for ii in range(50):
    
    listsecs = random.sample(netParams.cellParams[cellName]['secLists']['spinyEE'], len(netParams.cellParams[cellName]['secLists']['spinyEE']))
    
#     netParams.connParams['pre->post'+str(ii+1)] = { 
#             'preConds': {'pop': 'presyn'},
#             'postConds': {'pop': list(netParams.popParams.keys())[ii]},
#             'sec': listsecs,                  # target postsyn section
#             'synMech': 'L23_PC:L23_PC_'+str(ii+1),              # target synaptic mechanism
#             'weight': 0.68, # 'max(0.33*0.68, normal(0.68,0.46))',                 # synaptic weight 
#             'synsPerConn': 3, # 'int(max(0.667*3.0, normal(3.0, 1.4)))',
#             'delay': 0.05}   
    
    netParams.connParams['pre->post'+str(ii+1)] = { 
            'preConds': {'pop': 'presyn'},
            'postConds': {'pop': list(netParams.popParams.keys())[ii]},
            'sec': listsecs,                  # target postsyn section
            'synMech': 'L5_TTPC:L5_TTPC'+str(ii+1),              # target synaptic mechanism
            'weight': 1.25*1.5, # weight[ii], # # synaptic weight 
            'synsPerConn': 7, 
            'delay': 0.05}

# %%
sim.initialize(
    simConfig = cfg, 	
    netParams = netParams)  				# create network object and set cfg and net params
sim.net.createPops()               			# instantiate network populations
sim.net.createCells()              			# instantiate network cells based on defined populations
sim.net.connectCells()            			# create connections between cells based on params
# Out:
# Start time:  2023-04-18 12:34:29.070614
#
# Creating network of 51 cell populations on 1 hosts...
#   Number of cells on node 0: 51
#   Done; cell creation time = 2.90 s.
# Making connections...
#   Number of connections on node 0: 50
#   Number of synaptic contacts on node 0: 350
#   Done; cell connection time = 0.04 s.
# [[{preGid: 50, sec: 'dend_27', loc: 0.7055881678970573, synMech: 'L5_TTPC:L5_TTPC1', weight: 1.875, delay: 0.05, label: 'pre->post1', preLoc: 0.5, hObj: NetCon[0]},
#   {preGid: 50, sec: 'dend_0', loc: 0.9461847865462165, synMech: 'L5_TTPC:L5_TTPC1', weight: 1.875, delay: 0.05, label: 'pre->post1', preLoc: 0.5, hObj: NetCon[1]},
#   {preGid: 50, sec: 'dend_56', loc: 0.6737478361611168, synMech: 'L5_TTPC:L5_TTPC1', weight: 1.875, delay: 0.05, label: 'pre->post1', preLoc: 0.5, hObj: NetCon[2]},
#   {preGid: 50, sec: 'dend_67', loc: 0.15782643231488075, synMech: 'L5_TTPC:L5_TTPC1', weight: 1.875, delay: 0.05, label: 'pre->post1', preLoc: 0.5, hObj: NetCon[3]},
#   {preGid: 50, sec: 'dend_14', loc: 0.07198403532761749, synMech: 'L5_TTPC:L5_TTPC1', weight: 1.875, delay: 0.05, label: 'pre->post1', preLoc: 0.5, hObj: NetCon[4]},
#   {preGid: 50, sec: 'apic_26', loc: 0.5895356310129438, synMech: 'L5_TTPC:L5_TTPC1', weight: 1.875, delay: 0.05, label: 'pre->post1', preLoc: 0.5, hObj: NetCon[5]},
#   {preGid: 50, sec: 'dend_75', loc: 0.6919800631028745, synMech: 'L5_TTPC:L5_TTPC1', weight: 1.875, delay: 0.05, label: 'pre->post1', preLoc: 0.5, hObj: NetCon[6]}],
#  [{preGid: 50, sec: 'apic_9', loc: 0.9761220286563136, synMech: 'L5_TTPC:L5_TTPC2', weight: 1.875, delay: 0.05, label: 'pre->post2', preLoc: 0.5, hObj: NetCon[7]},
#   {preGid: 50, sec: 'dend_61', loc: 0.8428542364764455, synMech: 'L5_TTPC:L5_TTPC2', weight: 1.875, delay: 0.05, label: 'pre->post2', preLoc: 0.5, hObj: NetCon[8]},
#   {preGid: 50, sec: 'dend_54', loc: 0.8537691297992301, synMech: 'L5_TTPC:L5_TTPC2', weight: 1.875, delay: 0.05, label: 'pre->post2', preLoc: 0.5, hObj: NetCon[9]},
#   {preGid: 50, sec: 'dend_20', loc: 0.01478116076430084, synMech: 'L5_TTPC:L5_TTPC2', weight: 1.875, delay: 0.05, label: 'pre->post2', preLoc: 0.5, hObj: NetCon[10]},
#   {preGid: 50, sec: 'apic_7', loc: 0.9570894350603731, synMech: 'L5_TTPC:L5_TTPC2', weight: 1.875, delay: 0.05, label: 'pre->post2', preLoc: 0.5, hObj: NetCon[11]},
#   {preGid: 50, sec: 'apic_51', loc: 0.103118008870074, synMech: 'L5_TTPC:L5_TTPC2', weight: 1.875, delay: 0.05, label: 'pre->post2', preLoc: 0.5, hObj: NetCon[12]},
#   {preGid: 50, sec: 'dend_25', loc: 0.1569856966167518, synMech: 'L5_TTPC:L5_TTPC2', weight: 1.875, delay: 0.05, label: 'pre->post2', preLoc: 0.5, hObj: NetCon[13]}],
#  [{preGid: 50, sec: 'dend_31', loc: 0.6642130727901884, synMech: 'L5_TTPC:L5_TTPC3', weight: 1.875, delay: 0.05, label: 'pre->post3', preLoc: 0.5, hObj: NetCon[14]},
#   {preGid: 50, sec: 'apic_2', loc: 0.6504341045242994, synMech: 'L5_TTPC:L5_TTPC3', weight: 1.875, delay: 0.05, label: 'pre->post3', preLoc: 0.5, hObj: NetCon[15]},
#   {preGid: 50, sec: 'dend_49', loc: 0.33298631092603564, synMech: 'L5_TTPC:L5_TTPC3', weight: 1.875, delay: 0.05, label: 'pre->post3', preLoc: 0.5, hObj: NetCon[16]},
#   {preGid: 50, sec: 'apic_50', loc: 0.85593240254686, synMech: 'L5_TTPC:L5_TTPC3', weight: 1.875, delay: 0.05, label: 'pre->post3', preLoc: 0.5, hObj: NetCon[17]},
#   {preGid: 50, sec: 'apic_92', loc: 0.776726476361618, synMech: 'L5_TTPC:L5_TTPC3', weight: 1.875, delay: 0.05, label: 'pre->post3', preLoc: 0.5, hObj: NetCon[18]},
#   {preGid: 50, sec: 'apic_56', loc: 0.14848304662754805, synMech: 'L5_TTPC:L5_TTPC3', weight: 1.875, delay: 0.05, label: 'pre->post3', preLoc: 0.5, hObj: NetCon[19]},
#   {preGid: 50, sec: 'apic_64', loc: 0.0358580445346463, synMech: 'L5_TTPC:L5_TTPC3', weight: 1.875, delay: 0.05, label: 'pre->post3', preLoc: 0.5, hObj: NetCon[20]}],
#  [{preGid: 50, sec: 'dend_9', loc: 0.5523358367437373, synMech: 'L5_TTPC:L5_TTPC4', weight: 1.875, delay: 0.05, label: 'pre->post4', preLoc: 0.5, hObj: NetCon[21]},
#   {preGid: 50, sec: 'apic_91', loc: 0.08514934172354413, synMech: 'L5_TTPC:L5_TTPC4', weight: 1.875, delay: 0.05, label: 'pre->post4', preLoc: 0.5, hObj: NetCon[22]},
#   {preGid: 50, sec: 'dend_87', loc: 0.7133836147894055, synMech: 'L5_TTPC:L5_TTPC4', weight: 1.875, delay: 0.05, label: 'pre->post4', preLoc: 0.5, hObj: NetCon[23]},
#   {preGid: 50, sec: 'dend_66', loc: 0.41826378398049857, synMech: 'L5_TTPC:L5_TTPC4', weight: 1.875, delay: 0.05, label: 'pre->post4', preLoc: 0.5, hObj: NetCon[24]},
#   {preGid: 50, sec: 'dend_45', loc: 0.11281762516807362, synMech: 'L5_TTPC:L5_TTPC4', weight: 1.875, delay: 0.05, label: 'pre->post4', preLoc: 0.5, hObj: NetCon[25]},
#   {preGid: 50, sec: 'apic_92', loc: 0.5086072487394526, synMech: 'L5_TTPC:L5_TTPC4', weight: 1.875, delay: 0.05, label: 'pre->post4', preLoc: 0.5, hObj: NetCon[26]},
#   {preGid: 50, sec: 'dend_81', loc: 0.6198881549019913, synMech: 'L5_TTPC:L5_TTPC4', weight: 1.875, delay: 0.05, label: 'pre->post4', preLoc: 0.5, hObj: NetCon[27]}],
#  [{preGid: 50, sec: 'apic_76', loc: 0.06688071113334458, synMech: 'L5_TTPC:L5_TTPC5', weight: 1.875, delay: 0.05, label: 'pre->post5', preLoc: 0.5, hObj: NetCon[28]},
#   {preGid: 50, sec: 'dend_2', loc: 0.21578129485657346, synMech: 'L5_TTPC:L5_TTPC5', weight: 1.875, delay: 0.05, label: 'pre->post5', preLoc: 0.5, hObj: NetCon[29]},
#   {preGid: 50, sec: 'apic_15', loc: 0.4287983681022669, synMech: 'L5_TTPC:L5_TTPC5', weight: 1.875, delay: 0.05, label: 'pre->post5', preLoc: 0.5, hObj: NetCon[30]},
#   {preGid: 50, sec: 'dend_71', loc: 0.5936712314831116, synMech: 'L5_TTPC:L5_TTPC5', weight: 1.875, delay: 0.05, label: 'pre->post5', preLoc: 0.5, hObj: NetCon[31]},
#   {preGid: 50, sec: 'dend_25', loc: 0.73237608824006, synMech: 'L5_TTPC:L5_TTPC5', weight: 1.875, delay: 0.05, label: 'pre->post5', preLoc: 0.5, hObj: NetCon[32]},
#   {preGid: 50, sec: 'dend_55', loc: 0.6910373417556717, synMech: 'L5_TTPC:L5_TTPC5', weight: 1.875, delay: 0.05, label: 'pre->post5', preLoc: 0.5, hObj: NetCon[33]},
#   {preGid: 50, sec: 'dend_72', loc: 0.2942362865846946, synMech: 'L5_TTPC:L5_TTPC5', weight: 1.875, delay: 0.05, label: 'pre->post5', preLoc: 0.5, hObj: NetCon[34]}],
#  [{preGid: 50, sec: 'dend_55', loc: 0.33773843950451, synMech: 'L5_TTPC:L5_TTPC6', weight: 1.875, delay: 0.05, label: 'pre->post6', preLoc: 0.5, hObj: NetCon[35]},
#   {preGid: 50, sec: 'dend_5', loc: 0.2702208038018953, synMech: 'L5_TTPC:L5_TTPC6', weight: 1.875, delay: 0.05, label: 'pre->post6', preLoc: 0.5, hObj: NetCon[36]},
#   {preGid: 50, sec: 'apic_9', loc: 0.566116237475792, synMech: 'L5_TTPC:L5_TTPC6', weight: 1.875, delay: 0.05, label: 'pre->post6', preLoc: 0.5, hObj: NetCon[37]},
#   {preGid: 50, sec: 'dend_9', loc: 0.14732771321297752, synMech: 'L5_TTPC:L5_TTPC6', weight: 1.875, delay: 0.05, label: 'pre->post6', preLoc: 0.5, hObj: NetCon[38]},
#   {preGid: 50, sec: 'apic_82', loc: 0.2196560107308806, synMech: 'L5_TTPC:L5_TTPC6', weight: 1.875, delay: 0.05, label: 'pre->post6', preLoc: 0.5, hObj: NetCon[39]},
#   {preGid: 50, sec: 'dend_58', loc: 0.14053798816108035, synMech: 'L5_TTPC:L5_TTPC6', weight: 1.875, delay: 0.05, label: 'pre->post6', preLoc: 0.5, hObj: NetCon[40]},
#   {preGid: 50, sec: 'dend_36', loc: 0.5705247328307929, synMech: 'L5_TTPC:L5_TTPC6', weight: 1.875, delay: 0.05, label: 'pre->post6', preLoc: 0.5, hObj: NetCon[41]}],
#  [{preGid: 50, sec: 'apic_83', loc: 0.7652426278375416, synMech: 'L5_TTPC:L5_TTPC7', weight: 1.875, delay: 0.05, label: 'pre->post7', preLoc: 0.5, hObj: NetCon[42]},
#   {preGid: 50, sec: 'apic_81', loc: 0.9687811124179043, synMech: 'L5_TTPC:L5_TTPC7', weight: 1.875, delay: 0.05, label: 'pre->post7', preLoc: 0.5, hObj: NetCon[43]},
#   {preGid: 50, sec: 'apic_10', loc: 0.33747418075343194, synMech: 'L5_TTPC:L5_TTPC7', weight: 1.875, delay: 0.05, label: 'pre->post7', preLoc: 0.5, hObj: NetCon[44]},
#   {preGid: 50, sec: 'apic_66', loc: 0.5439035977003038, synMech: 'L5_TTPC:L5_TTPC7', weight: 1.875, delay: 0.05, label: 'pre->post7', preLoc: 0.5, hObj: NetCon[45]},
#   {preGid: 50, sec: 'dend_94', loc: 0.49252867867760014, synMech: 'L5_TTPC:L5_TTPC7', weight: 1.875, delay: 0.05, label: 'pre->post7', preLoc: 0.5, hObj: NetCon[46]},
#   {preGid: 50, sec: 'apic_22', loc: 0.1308773001593412, synMech: 'L5_TTPC:L5_TTPC7', weight: 1.875, delay: 0.05, label: 'pre->post7', preLoc: 0.5, hObj: NetCon[47]},
#   {preGid: 50, sec: 'dend_22', loc: 0.15450363753757332, synMech: 'L5_TTPC:L5_TTPC7', weight: 1.875, delay: 0.05, label: 'pre->post7', preLoc: 0.5, hObj: NetCon[48]}],
#  [{preGid: 50, sec: 'dend_11', loc: 0.5420759689521701, synMech: 'L5_TTPC:L5_TTPC8', weight: 1.875, delay: 0.05, label: 'pre->post8', preLoc: 0.5, hObj: NetCon[49]},
#   {preGid: 50, sec: 'apic_76', loc: 0.14199377099867594, synMech: 'L5_TTPC:L5_TTPC8', weight: 1.875, delay: 0.05, label: 'pre->post8', preLoc: 0.5, hObj: NetCon[50]},
#   {preGid: 50, sec: 'apic_39', loc: 0.7336608418626421, synMech: 'L5_TTPC:L5_TTPC8', weight: 1.875, delay: 0.05, label: 'pre->post8', preLoc: 0.5, hObj: NetCon[51]},
#   {preGid: 50, sec: 'apic_29', loc: 0.13058761846293812, synMech: 'L5_TTPC:L5_TTPC8', weight: 1.875, delay: 0.05, label: 'pre->post8', preLoc: 0.5, hObj: NetCon[52]},
#   {preGid: 50, sec: 'apic_4', loc: 0.014098081986627816, synMech: 'L5_TTPC:L5_TTPC8', weight: 1.875, delay: 0.05, label: 'pre->post8', preLoc: 0.5, hObj: NetCon[53]},
#   {preGid: 50, sec: 'apic_46', loc: 0.9983496535923442, synMech: 'L5_TTPC:L5_TTPC8', weight: 1.875, delay: 0.05, label: 'pre->post8', preLoc: 0.5, hObj: NetCon[54]},
#   {preGid: 50, sec: 'apic_58', loc: 0.8125045034717431, synMech: 'L5_TTPC:L5_TTPC8', weight: 1.875, delay: 0.05, label: 'pre->post8', preLoc: 0.5, hObj: NetCon[55]}],
#  [{preGid: 50, sec: 'dend_47', loc: 0.3421255491768345, synMech: 'L5_TTPC:L5_TTPC9', weight: 1.875, delay: 0.05, label: 'pre->post9', preLoc: 0.5, hObj: NetCon[56]},
#   {preGid: 50, sec: 'apic_63', loc: 0.2625750999177392, synMech: 'L5_TTPC:L5_TTPC9', weight: 1.875, delay: 0.05, label: 'pre->post9', preLoc: 0.5, hObj: NetCon[57]},
#   {preGid: 50, sec: 'apic_86', loc: 0.2802130377398086, synMech: 'L5_TTPC:L5_TTPC9', weight: 1.875, delay: 0.05, label: 'pre->post9', preLoc: 0.5, hObj: NetCon[58]},
#   {preGid: 50, sec: 'apic_84', loc: 0.7246271060498468, synMech: 'L5_TTPC:L5_TTPC9', weight: 1.875, delay: 0.05, label: 'pre->post9', preLoc: 0.5, hObj: NetCon[59]},
#   {preGid: 50, sec: 'dend_16', loc: 0.7002869948329048, synMech: 'L5_TTPC:L5_TTPC9', weight: 1.875, delay: 0.05, label: 'pre->post9', preLoc: 0.5, hObj: NetCon[60]},
#   {preGid: 50, sec: 'apic_60', loc: 0.2053861367486761, synMech: 'L5_TTPC:L5_TTPC9', weight: 1.875, delay: 0.05, label: 'pre->post9', preLoc: 0.5, hObj: NetCon[61]},
#   {preGid: 50, sec: 'dend_65', loc: 0.22915867909585552, synMech: 'L5_TTPC:L5_TTPC9', weight: 1.875, delay: 0.05, label: 'pre->post9', preLoc: 0.5, hObj: NetCon[62]}],
#  [{preGid: 50, sec: 'apic_51', loc: 0.6031489895653752, synMech: 'L5_TTPC:L5_TTPC10', weight: 1.875, delay: 0.05, label: 'pre->post10', preLoc: 0.5, hObj: NetCon[63]},
#   {preGid: 50, sec: 'apic_15', loc: 0.39140207084045836, synMech: 'L5_TTPC:L5_TTPC10', weight: 1.875, delay: 0.05, label: 'pre->post10', preLoc: 0.5, hObj: NetCon[64]},
#   {preGid: 50, sec: 'apic_76', loc: 0.9960627782711309, synMech: 'L5_TTPC:L5_TTPC10', weight: 1.875, delay: 0.05, label: 'pre->post10', preLoc: 0.5, hObj: NetCon[65]},
#   {preGid: 50, sec: 'dend_21', loc: 0.18190708649470988, synMech: 'L5_TTPC:L5_TTPC10', weight: 1.875, delay: 0.05, label: 'pre->post10', preLoc: 0.5, hObj: NetCon[66]},
#   {preGid: 50, sec: 'apic_78', loc: 0.49237006427814156, synMech: 'L5_TTPC:L5_TTPC10', weight: 1.875, delay: 0.05, label: 'pre->post10', preLoc: 0.5, hObj: NetCon[67]},
#   {preGid: 50, sec: 'dend_47', loc: 0.228425373820693, synMech: 'L5_TTPC:L5_TTPC10', weight: 1.875, delay: 0.05, label: 'pre->post10', preLoc: 0.5, hObj: NetCon[68]},
#   {preGid: 50, sec: 'apic_39', loc: 0.9904469134270627, synMech: 'L5_TTPC:L5_TTPC10', weight: 1.875, delay: 0.05, label: 'pre->post10', preLoc: 0.5, hObj: NetCon[69]}],
#  [{preGid: 50, sec: 'dend_21', loc: 0.4549844377355502, synMech: 'L5_TTPC:L5_TTPC11', weight: 1.875, delay: 0.05, label: 'pre->post11', preLoc: 0.5, hObj: NetCon[70]},
#   {preGid: 50, sec: 'apic_81', loc: 0.5167840818088524, synMech: 'L5_TTPC:L5_TTPC11', weight: 1.875, delay: 0.05, label: 'pre->post11', preLoc: 0.5, hObj: NetCon[71]},
#   {preGid: 50, sec: 'dend_6', loc: 0.07122281755783157, synMech: 'L5_TTPC:L5_TTPC11', weight: 1.875, delay: 0.05, label: 'pre->post11', preLoc: 0.5, hObj: NetCon[72]},
#   {preGid: 50, sec: 'dend_14', loc: 0.19405404419615888, synMech: 'L5_TTPC:L5_TTPC11', weight: 1.875, delay: 0.05, label: 'pre->post11', preLoc: 0.5, hObj: NetCon[73]},
#   {preGid: 50, sec: 'dend_36', loc: 0.16566485452595603, synMech: 'L5_TTPC:L5_TTPC11', weight: 1.875, delay: 0.05, label: 'pre->post11', preLoc: 0.5, hObj: NetCon[74]},
#   {preGid: 50, sec: 'apic_75', loc: 0.39461036002309857, synMech: 'L5_TTPC:L5_TTPC11', weight: 1.875, delay: 0.05, label: 'pre->post11', preLoc: 0.5, hObj: NetCon[75]},
#   {preGid: 50, sec: 'dend_8', loc: 0.12376154079743998, synMech: 'L5_TTPC:L5_TTPC11', weight: 1.875, delay: 0.05, label: 'pre->post11', preLoc: 0.5, hObj: NetCon[76]}],
#  [{preGid: 50, sec: 'dend_94', loc: 0.018069121929947, synMech: 'L5_TTPC:L5_TTPC12', weight: 1.875, delay: 0.05, label: 'pre->post12', preLoc: 0.5, hObj: NetCon[77]},
#   {preGid: 50, sec: 'apic_23', loc: 0.6068485987395207, synMech: 'L5_TTPC:L5_TTPC12', weight: 1.875, delay: 0.05, label: 'pre->post12', preLoc: 0.5, hObj: NetCon[78]},
#   {preGid: 50, sec: 'dend_56', loc: 0.6276705444938459, synMech: 'L5_TTPC:L5_TTPC12', weight: 1.875, delay: 0.05, label: 'pre->post12', preLoc: 0.5, hObj: NetCon[79]},
#   {preGid: 50, sec: 'apic_92', loc: 0.31194767594074035, synMech: 'L5_TTPC:L5_TTPC12', weight: 1.875, delay: 0.05, label: 'pre->post12', preLoc: 0.5, hObj: NetCon[80]},
#   {preGid: 50, sec: 'apic_51', loc: 0.4724239488044604, synMech: 'L5_TTPC:L5_TTPC12', weight: 1.875, delay: 0.05, label: 'pre->post12', preLoc: 0.5, hObj: NetCon[81]},
#   {preGid: 50, sec: 'apic_68', loc: 0.5633723206697004, synMech: 'L5_TTPC:L5_TTPC12', weight: 1.875, delay: 0.05, label: 'pre->post12', preLoc: 0.5, hObj: NetCon[82]},
#   {preGid: 50, sec: 'dend_55', loc: 0.8235013576162914, synMech: 'L5_TTPC:L5_TTPC12', weight: 1.875, delay: 0.05, label: 'pre->post12', preLoc: 0.5, hObj: NetCon[83]}],
#  [{preGid: 50, sec: 'dend_65', loc: 0.5332504575203726, synMech: 'L5_TTPC:L5_TTPC13', weight: 1.875, delay: 0.05, label: 'pre->post13', preLoc: 0.5, hObj: NetCon[84]},
#   {preGid: 50, sec: 'apic_66', loc: 0.1758430483209475, synMech: 'L5_TTPC:L5_TTPC13', weight: 1.875, delay: 0.05, label: 'pre->post13', preLoc: 0.5, hObj: NetCon[85]},
#   {preGid: 50, sec: 'apic_18', loc: 0.3539933850314273, synMech: 'L5_TTPC:L5_TTPC13', weight: 1.875, delay: 0.05, label: 'pre->post13', preLoc: 0.5, hObj: NetCon[86]},
#   {preGid: 50, sec: 'apic_69', loc: 0.5698942351677989, synMech: 'L5_TTPC:L5_TTPC13', weight: 1.875, delay: 0.05, label: 'pre->post13', preLoc: 0.5, hObj: NetCon[87]},
#   {preGid: 50, sec: 'dend_9', loc: 0.671889506601372, synMech: 'L5_TTPC:L5_TTPC13', weight: 1.875, delay: 0.05, label: 'pre->post13', preLoc: 0.5, hObj: NetCon[88]},
#   {preGid: 50, sec: 'apic_22', loc: 0.6158499425687397, synMech: 'L5_TTPC:L5_TTPC13', weight: 1.875, delay: 0.05, label: 'pre->post13', preLoc: 0.5, hObj: NetCon[89]},
#   {preGid: 50, sec: 'dend_37', loc: 0.4795821355376275, synMech: 'L5_TTPC:L5_TTPC13', weight: 1.875, delay: 0.05, label: 'pre->post13', preLoc: 0.5, hObj: NetCon[90]}],
#  [{preGid: 50, sec: 'apic_38', loc: 0.5553535974477735, synMech: 'L5_TTPC:L5_TTPC14', weight: 1.875, delay: 0.05, label: 'pre->post14', preLoc: 0.5, hObj: NetCon[91]},
#   {preGid: 50, sec: 'apic_87', loc: 0.018349951637698036, synMech: 'L5_TTPC:L5_TTPC14', weight: 1.875, delay: 0.05, label: 'pre->post14', preLoc: 0.5, hObj: NetCon[92]},
#   {preGid: 50, sec: 'dend_65', loc: 0.23845772711149377, synMech: 'L5_TTPC:L5_TTPC14', weight: 1.875, delay: 0.05, label: 'pre->post14', preLoc: 0.5, hObj: NetCon[93]},
#   {preGid: 50, sec: 'apic_59', loc: 0.3427808721806318, synMech: 'L5_TTPC:L5_TTPC14', weight: 1.875, delay: 0.05, label: 'pre->post14', preLoc: 0.5, hObj: NetCon[94]},
#   {preGid: 50, sec: 'dend_70', loc: 0.16136533040134024, synMech: 'L5_TTPC:L5_TTPC14', weight: 1.875, delay: 0.05, label: 'pre->post14', preLoc: 0.5, hObj: NetCon[95]},
#   {preGid: 50, sec: 'apic_76', loc: 0.38504167144542367, synMech: 'L5_TTPC:L5_TTPC14', weight: 1.875, delay: 0.05, label: 'pre->post14', preLoc: 0.5, hObj: NetCon[96]},
#   {preGid: 50, sec: 'apic_63', loc: 0.4832549521746724, synMech: 'L5_TTPC:L5_TTPC14', weight: 1.875, delay: 0.05, label: 'pre->post14', preLoc: 0.5, hObj: NetCon[97]}],
#  [{preGid: 50, sec: 'dend_53', loc: 0.8401114135803079, synMech: 'L5_TTPC:L5_TTPC15', weight: 1.875, delay: 0.05, label: 'pre->post15', preLoc: 0.5, hObj: NetCon[98]},
#   {preGid: 50, sec: 'dend_31', loc: 0.3788450032744622, synMech: 'L5_TTPC:L5_TTPC15', weight: 1.875, delay: 0.05, label: 'pre->post15', preLoc: 0.5, hObj: NetCon[99]},
#   {preGid: 50, sec: 'apic_2', loc: 0.5882807885381259, synMech: 'L5_TTPC:L5_TTPC15', weight: 1.875, delay: 0.05, label: 'pre->post15', preLoc: 0.5, hObj: NetCon[100]},
#   {preGid: 50, sec: 'dend_72', loc: 0.7081322832154668, synMech: 'L5_TTPC:L5_TTPC15', weight: 1.875, delay: 0.05, label: 'pre->post15', preLoc: 0.5, hObj: NetCon[101]},
#   {preGid: 50, sec: 'apic_74', loc: 0.1594926227857729, synMech: 'L5_TTPC:L5_TTPC15', weight: 1.875, delay: 0.05, label: 'pre->post15', preLoc: 0.5, hObj: NetCon[102]},
#   {preGid: 50, sec: 'dend_37', loc: 0.03553614520411565, synMech: 'L5_TTPC:L5_TTPC15', weight: 1.875, delay: 0.05, label: 'pre->post15', preLoc: 0.5, hObj: NetCon[103]},
#   {preGid: 50, sec: 'apic_32', loc: 0.5876846621758682, synMech: 'L5_TTPC:L5_TTPC15', weight: 1.875, delay: 0.05, label: 'pre->post15', preLoc: 0.5, hObj: NetCon[104]}],
#  [{preGid: 50, sec: 'dend_43', loc: 0.09679966180548512, synMech: 'L5_TTPC:L5_TTPC16', weight: 1.875, delay: 0.05, label: 'pre->post16', preLoc: 0.5, hObj: NetCon[105]},
#   {preGid: 50, sec: 'apic_11', loc: 0.9585341424352517, synMech: 'L5_TTPC:L5_TTPC16', weight: 1.875, delay: 0.05, label: 'pre->post16', preLoc: 0.5, hObj: NetCon[106]},
#   {preGid: 50, sec: 'dend_28', loc: 0.8959615052087853, synMech: 'L5_TTPC:L5_TTPC16', weight: 1.875, delay: 0.05, label: 'pre->post16', preLoc: 0.5, hObj: NetCon[107]},
#   {preGid: 50, sec: 'dend_23', loc: 0.44952065345791165, synMech: 'L5_TTPC:L5_TTPC16', weight: 1.875, delay: 0.05, label: 'pre->post16', preLoc: 0.5, hObj: NetCon[108]},
#   {preGid: 50, sec: 'apic_29', loc: 0.6699049626841531, synMech: 'L5_TTPC:L5_TTPC16', weight: 1.875, delay: 0.05, label: 'pre->post16', preLoc: 0.5, hObj: NetCon[109]},
#   {preGid: 50, sec: 'dend_16', loc: 0.12339889892265592, synMech: 'L5_TTPC:L5_TTPC16', weight: 1.875, delay: 0.05, label: 'pre->post16', preLoc: 0.5, hObj: NetCon[110]},
#   {preGid: 50, sec: 'apic_68', loc: 0.3289404917187487, synMech: 'L5_TTPC:L5_TTPC16', weight: 1.875, delay: 0.05, label: 'pre->post16', preLoc: 0.5, hObj: NetCon[111]}],
#  [{preGid: 50, sec: 'dend_75', loc: 0.6597557807417779, synMech: 'L5_TTPC:L5_TTPC17', weight: 1.875, delay: 0.05, label: 'pre->post17', preLoc: 0.5, hObj: NetCon[112]},
#   {preGid: 50, sec: 'apic_91', loc: 0.08337754601329844, synMech: 'L5_TTPC:L5_TTPC17', weight: 1.875, delay: 0.05, label: 'pre->post17', preLoc: 0.5, hObj: NetCon[113]},
#   {preGid: 50, sec: 'apic_62', loc: 0.40036945381425704, synMech: 'L5_TTPC:L5_TTPC17', weight: 1.875, delay: 0.05, label: 'pre->post17', preLoc: 0.5, hObj: NetCon[114]},
#   {preGid: 50, sec: 'apic_4', loc: 0.5328003236839398, synMech: 'L5_TTPC:L5_TTPC17', weight: 1.875, delay: 0.05, label: 'pre->post17', preLoc: 0.5, hObj: NetCon[115]},
#   {preGid: 50, sec: 'apic_31', loc: 0.39019844660719477, synMech: 'L5_TTPC:L5_TTPC17', weight: 1.875, delay: 0.05, label: 'pre->post17', preLoc: 0.5, hObj: NetCon[116]},
#   {preGid: 50, sec: 'apic_66', loc: 0.9357607015026135, synMech: 'L5_TTPC:L5_TTPC17', weight: 1.875, delay: 0.05, label: 'pre->post17', preLoc: 0.5, hObj: NetCon[117]},
#   {preGid: 50, sec: 'apic_87', loc: 0.659044598872332, synMech: 'L5_TTPC:L5_TTPC17', weight: 1.875, delay: 0.05, label: 'pre->post17', preLoc: 0.5, hObj: NetCon[118]}],
#  [{preGid: 50, sec: 'dend_53', loc: 0.9062045286825001, synMech: 'L5_TTPC:L5_TTPC18', weight: 1.875, delay: 0.05, label: 'pre->post18', preLoc: 0.5, hObj: NetCon[119]},
#   {preGid: 50, sec: 'apic_74', loc: 0.39312670215598183, synMech: 'L5_TTPC:L5_TTPC18', weight: 1.875, delay: 0.05, label: 'pre->post18', preLoc: 0.5, hObj: NetCon[120]},
#   {preGid: 50, sec: 'dend_49', loc: 0.9121922069233509, synMech: 'L5_TTPC:L5_TTPC18', weight: 1.875, delay: 0.05, label: 'pre->post18', preLoc: 0.5, hObj: NetCon[121]},
#   {preGid: 50, sec: 'dend_56', loc: 0.6110306513756506, synMech: 'L5_TTPC:L5_TTPC18', weight: 1.875, delay: 0.05, label: 'pre->post18', preLoc: 0.5, hObj: NetCon[122]},
#   {preGid: 50, sec: 'apic_26', loc: 0.4744470287384986, synMech: 'L5_TTPC:L5_TTPC18', weight: 1.875, delay: 0.05, label: 'pre->post18', preLoc: 0.5, hObj: NetCon[123]},
#   {preGid: 50, sec: 'apic_82', loc: 0.1262586483851017, synMech: 'L5_TTPC:L5_TTPC18', weight: 1.875, delay: 0.05, label: 'pre->post18', preLoc: 0.5, hObj: NetCon[124]},
#   {preGid: 50, sec: 'dend_25', loc: 0.4014450365894202, synMech: 'L5_TTPC:L5_TTPC18', weight: 1.875, delay: 0.05, label: 'pre->post18', preLoc: 0.5, hObj: NetCon[125]}],
#  [{preGid: 50, sec: 'apic_12', loc: 0.5368874162661813, synMech: 'L5_TTPC:L5_TTPC19', weight: 1.875, delay: 0.05, label: 'pre->post19', preLoc: 0.5, hObj: NetCon[126]},
#   {preGid: 50, sec: 'apic_33', loc: 0.844592246448759, synMech: 'L5_TTPC:L5_TTPC19', weight: 1.875, delay: 0.05, label: 'pre->post19', preLoc: 0.5, hObj: NetCon[127]},
#   {preGid: 50, sec: 'dend_25', loc: 0.9890944767453739, synMech: 'L5_TTPC:L5_TTPC19', weight: 1.875, delay: 0.05, label: 'pre->post19', preLoc: 0.5, hObj: NetCon[128]},
#   {preGid: 50, sec: 'apic_74', loc: 0.02294629216520423, synMech: 'L5_TTPC:L5_TTPC19', weight: 1.875, delay: 0.05, label: 'pre->post19', preLoc: 0.5, hObj: NetCon[129]},
#   {preGid: 50, sec: 'apic_87', loc: 0.8927938171381165, synMech: 'L5_TTPC:L5_TTPC19', weight: 1.875, delay: 0.05, label: 'pre->post19', preLoc: 0.5, hObj: NetCon[130]},
#   {preGid: 50, sec: 'apic_17', loc: 0.9641231793961639, synMech: 'L5_TTPC:L5_TTPC19', weight: 1.875, delay: 0.05, label: 'pre->post19', preLoc: 0.5, hObj: NetCon[131]},
#   {preGid: 50, sec: 'dend_45', loc: 0.09458055519358885, synMech: 'L5_TTPC:L5_TTPC19', weight: 1.875, delay: 0.05, label: 'pre->post19', preLoc: 0.5, hObj: NetCon[132]}],
#  [{preGid: 50, sec: 'dend_53', loc: 0.7933587793937663, synMech: 'L5_TTPC:L5_TTPC20', weight: 1.875, delay: 0.05, label: 'pre->post20', preLoc: 0.5, hObj: NetCon[133]},
#   {preGid: 50, sec: 'apic_87', loc: 0.9581559309666066, synMech: 'L5_TTPC:L5_TTPC20', weight: 1.875, delay: 0.05, label: 'pre->post20', preLoc: 0.5, hObj: NetCon[134]},
#   {preGid: 50, sec: 'dend_45', loc: 0.6139905850945098, synMech: 'L5_TTPC:L5_TTPC20', weight: 1.875, delay: 0.05, label: 'pre->post20', preLoc: 0.5, hObj: NetCon[135]},
#   {preGid: 50, sec: 'apic_80', loc: 0.309888266631559, synMech: 'L5_TTPC:L5_TTPC20', weight: 1.875, delay: 0.05, label: 'pre->post20', preLoc: 0.5, hObj: NetCon[136]},
#   {preGid: 50, sec: 'apic_68', loc: 0.029959001553225083, synMech: 'L5_TTPC:L5_TTPC20', weight: 1.875, delay: 0.05, label: 'pre->post20', preLoc: 0.5, hObj: NetCon[137]},
#   {preGid: 50, sec: 'apic_39', loc: 0.4188755453380517, synMech: 'L5_TTPC:L5_TTPC20', weight: 1.875, delay: 0.05, label: 'pre->post20', preLoc: 0.5, hObj: NetCon[138]},
#   {preGid: 50, sec: 'apic_92', loc: 0.9614559687953532, synMech: 'L5_TTPC:L5_TTPC20', weight: 1.875, delay: 0.05, label: 'pre->post20', preLoc: 0.5, hObj: NetCon[139]}],
#  [{preGid: 50, sec: 'apic_32', loc: 0.87151052134498, synMech: 'L5_TTPC:L5_TTPC21', weight: 1.875, delay: 0.05, label: 'pre->post21', preLoc: 0.5, hObj: NetCon[140]},
#   {preGid: 50, sec: 'dend_35', loc: 0.12320012129966555, synMech: 'L5_TTPC:L5_TTPC21', weight: 1.875, delay: 0.05, label: 'pre->post21', preLoc: 0.5, hObj: NetCon[141]},
#   {preGid: 50, sec: 'apic_46', loc: 0.6109504548823018, synMech: 'L5_TTPC:L5_TTPC21', weight: 1.875, delay: 0.05, label: 'pre->post21', preLoc: 0.5, hObj: NetCon[142]},
#   {preGid: 50, sec: 'apic_72', loc: 0.6487952263091059, synMech: 'L5_TTPC:L5_TTPC21', weight: 1.875, delay: 0.05, label: 'pre->post21', preLoc: 0.5, hObj: NetCon[143]},
#   {preGid: 50, sec: 'dend_14', loc: 0.8110650372098652, synMech: 'L5_TTPC:L5_TTPC21', weight: 1.875, delay: 0.05, label: 'pre->post21', preLoc: 0.5, hObj: NetCon[144]},
#   {preGid: 50, sec: 'apic_23', loc: 0.25657456053945354, synMech: 'L5_TTPC:L5_TTPC21', weight: 1.875, delay: 0.05, label: 'pre->post21', preLoc: 0.5, hObj: NetCon[145]},
#   {preGid: 50, sec: 'apic_89', loc: 0.15134799873711552, synMech: 'L5_TTPC:L5_TTPC21', weight: 1.875, delay: 0.05, label: 'pre->post21', preLoc: 0.5, hObj: NetCon[146]}],
#  [{preGid: 50, sec: 'apic_46', loc: 0.22245112897744942, synMech: 'L5_TTPC:L5_TTPC22', weight: 1.875, delay: 0.05, label: 'pre->post22', preLoc: 0.5, hObj: NetCon[147]},
#   {preGid: 50, sec: 'apic_72', loc: 0.3363698393170201, synMech: 'L5_TTPC:L5_TTPC22', weight: 1.875, delay: 0.05, label: 'pre->post22', preLoc: 0.5, hObj: NetCon[148]},
#   {preGid: 50, sec: 'dend_7', loc: 0.2166593503424259, synMech: 'L5_TTPC:L5_TTPC22', weight: 1.875, delay: 0.05, label: 'pre->post22', preLoc: 0.5, hObj: NetCon[149]},
#   {preGid: 50, sec: 'apic_73', loc: 0.209922323853819, synMech: 'L5_TTPC:L5_TTPC22', weight: 1.875, delay: 0.05, label: 'pre->post22', preLoc: 0.5, hObj: NetCon[150]},
#   {preGid: 50, sec: 'apic_5', loc: 0.4762278845098723, synMech: 'L5_TTPC:L5_TTPC22', weight: 1.875, delay: 0.05, label: 'pre->post22', preLoc: 0.5, hObj: NetCon[151]},
#   {preGid: 50, sec: 'apic_92', loc: 0.8439520454774738, synMech: 'L5_TTPC:L5_TTPC22', weight: 1.875, delay: 0.05, label: 'pre->post22', preLoc: 0.5, hObj: NetCon[152]},
#   {preGid: 50, sec: 'dend_6', loc: 0.9085868227969952, synMech: 'L5_TTPC:L5_TTPC22', weight: 1.875, delay: 0.05, label: 'pre->post22', preLoc: 0.5, hObj: NetCon[153]}],
#  [{preGid: 50, sec: 'apic_89', loc: 0.5744121300994983, synMech: 'L5_TTPC:L5_TTPC23', weight: 1.875, delay: 0.05, label: 'pre->post23', preLoc: 0.5, hObj: NetCon[154]},
#   {preGid: 50, sec: 'dend_43', loc: 0.2059329158681869, synMech: 'L5_TTPC:L5_TTPC23', weight: 1.875, delay: 0.05, label: 'pre->post23', preLoc: 0.5, hObj: NetCon[155]},
#   {preGid: 50, sec: 'apic_86', loc: 0.43607067729336974, synMech: 'L5_TTPC:L5_TTPC23', weight: 1.875, delay: 0.05, label: 'pre->post23', preLoc: 0.5, hObj: NetCon[156]},
#   {preGid: 50, sec: 'dend_16', loc: 0.849765215121565, synMech: 'L5_TTPC:L5_TTPC23', weight: 1.875, delay: 0.05, label: 'pre->post23', preLoc: 0.5, hObj: NetCon[157]},
#   {preGid: 50, sec: 'apic_68', loc: 0.5971879230612896, synMech: 'L5_TTPC:L5_TTPC23', weight: 1.875, delay: 0.05, label: 'pre->post23', preLoc: 0.5, hObj: NetCon[158]},
#   {preGid: 50, sec: 'apic_13', loc: 0.27768630749710416, synMech: 'L5_TTPC:L5_TTPC23', weight: 1.875, delay: 0.05, label: 'pre->post23', preLoc: 0.5, hObj: NetCon[159]},
#   {preGid: 50, sec: 'apic_34', loc: 0.7983323321170723, synMech: 'L5_TTPC:L5_TTPC23', weight: 1.875, delay: 0.05, label: 'pre->post23', preLoc: 0.5, hObj: NetCon[160]}],
#  [{preGid: 50, sec: 'dend_5', loc: 0.24020929598178173, synMech: 'L5_TTPC:L5_TTPC24', weight: 1.875, delay: 0.05, label: 'pre->post24', preLoc: 0.5, hObj: NetCon[161]},
#   {preGid: 50, sec: 'dend_48', loc: 0.11792442320670578, synMech: 'L5_TTPC:L5_TTPC24', weight: 1.875, delay: 0.05, label: 'pre->post24', preLoc: 0.5, hObj: NetCon[162]},
#   {preGid: 50, sec: 'dend_47', loc: 0.5779882508101596, synMech: 'L5_TTPC:L5_TTPC24', weight: 1.875, delay: 0.05, label: 'pre->post24', preLoc: 0.5, hObj: NetCon[163]},
#   {preGid: 50, sec: 'apic_34', loc: 0.689223512578204, synMech: 'L5_TTPC:L5_TTPC24', weight: 1.875, delay: 0.05, label: 'pre->post24', preLoc: 0.5, hObj: NetCon[164]},
#   {preGid: 50, sec: 'apic_21', loc: 0.9181521082644177, synMech: 'L5_TTPC:L5_TTPC24', weight: 1.875, delay: 0.05, label: 'pre->post24', preLoc: 0.5, hObj: NetCon[165]},
#   {preGid: 50, sec: 'dend_82', loc: 0.39958026950333736, synMech: 'L5_TTPC:L5_TTPC24', weight: 1.875, delay: 0.05, label: 'pre->post24', preLoc: 0.5, hObj: NetCon[166]},
#   {preGid: 50, sec: 'apic_37', loc: 0.9839929868376683, synMech: 'L5_TTPC:L5_TTPC24', weight: 1.875, delay: 0.05, label: 'pre->post24', preLoc: 0.5, hObj: NetCon[167]}],
#  [{preGid: 50, sec: 'apic_18', loc: 0.2940083704773837, synMech: 'L5_TTPC:L5_TTPC25', weight: 1.875, delay: 0.05, label: 'pre->post25', preLoc: 0.5, hObj: NetCon[168]},
#   {preGid: 50, sec: 'apic_84', loc: 0.5276359958576297, synMech: 'L5_TTPC:L5_TTPC25', weight: 1.875, delay: 0.05, label: 'pre->post25', preLoc: 0.5, hObj: NetCon[169]},
#   {preGid: 50, sec: 'dend_18', loc: 0.29545578090582475, synMech: 'L5_TTPC:L5_TTPC25', weight: 1.875, delay: 0.05, label: 'pre->post25', preLoc: 0.5, hObj: NetCon[170]},
#   {preGid: 50, sec: 'apic_92', loc: 0.30128382423505157, synMech: 'L5_TTPC:L5_TTPC25', weight: 1.875, delay: 0.05, label: 'pre->post25', preLoc: 0.5, hObj: NetCon[171]},
#   {preGid: 50, sec: 'apic_89', loc: 0.5755609996519317, synMech: 'L5_TTPC:L5_TTPC25', weight: 1.875, delay: 0.05, label: 'pre->post25', preLoc: 0.5, hObj: NetCon[172]},
#   {preGid: 50, sec: 'dend_80', loc: 0.2149189951351295, synMech: 'L5_TTPC:L5_TTPC25', weight: 1.875, delay: 0.05, label: 'pre->post25', preLoc: 0.5, hObj: NetCon[173]},
#   {preGid: 50, sec: 'dend_77', loc: 0.47177573749813306, synMech: 'L5_TTPC:L5_TTPC25', weight: 1.875, delay: 0.05, label: 'pre->post25', preLoc: 0.5, hObj: NetCon[174]}],
#  [{preGid: 50, sec: 'apic_40', loc: 0.4435778532956072, synMech: 'L5_TTPC:L5_TTPC26', weight: 1.875, delay: 0.05, label: 'pre->post26', preLoc: 0.5, hObj: NetCon[175]},
#   {preGid: 50, sec: 'dend_72', loc: 0.8221662773399939, synMech: 'L5_TTPC:L5_TTPC26', weight: 1.875, delay: 0.05, label: 'pre->post26', preLoc: 0.5, hObj: NetCon[176]},
#   {preGid: 50, sec: 'dend_76', loc: 0.731759209596078, synMech: 'L5_TTPC:L5_TTPC26', weight: 1.875, delay: 0.05, label: 'pre->post26', preLoc: 0.5, hObj: NetCon[177]},
#   {preGid: 50, sec: 'dend_55', loc: 0.4659953541079955, synMech: 'L5_TTPC:L5_TTPC26', weight: 1.875, delay: 0.05, label: 'pre->post26', preLoc: 0.5, hObj: NetCon[178]},
#   {preGid: 50, sec: 'apic_32', loc: 0.6043653683964616, synMech: 'L5_TTPC:L5_TTPC26', weight: 1.875, delay: 0.05, label: 'pre->post26', preLoc: 0.5, hObj: NetCon[179]},
#   {preGid: 50, sec: 'dend_9', loc: 0.6041332109677268, synMech: 'L5_TTPC:L5_TTPC26', weight: 1.875, delay: 0.05, label: 'pre->post26', preLoc: 0.5, hObj: NetCon[180]},
#   {preGid: 50, sec: 'dend_61', loc: 0.06848745713124037, synMech: 'L5_TTPC:L5_TTPC26', weight: 1.875, delay: 0.05, label: 'pre->post26', preLoc: 0.5, hObj: NetCon[181]}],
#  [{preGid: 50, sec: 'apic_29', loc: 0.19602145735350232, synMech: 'L5_TTPC:L5_TTPC27', weight: 1.875, delay: 0.05, label: 'pre->post27', preLoc: 0.5, hObj: NetCon[182]},
#   {preGid: 50, sec: 'apic_83', loc: 0.8245288144912195, synMech: 'L5_TTPC:L5_TTPC27', weight: 1.875, delay: 0.05, label: 'pre->post27', preLoc: 0.5, hObj: NetCon[183]},
#   {preGid: 50, sec: 'apic_39', loc: 0.13681496118333542, synMech: 'L5_TTPC:L5_TTPC27', weight: 1.875, delay: 0.05, label: 'pre->post27', preLoc: 0.5, hObj: NetCon[184]},
#   {preGid: 50, sec: 'apic_72', loc: 0.060198388359458004, synMech: 'L5_TTPC:L5_TTPC27', weight: 1.875, delay: 0.05, label: 'pre->post27', preLoc: 0.5, hObj: NetCon[185]},
#   {preGid: 50, sec: 'apic_88', loc: 0.003194214945856285, synMech: 'L5_TTPC:L5_TTPC27', weight: 1.875, delay: 0.05, label: 'pre->post27', preLoc: 0.5, hObj: NetCon[186]},
#   {preGid: 50, sec: 'dend_37', loc: 0.05810450958840291, synMech: 'L5_TTPC:L5_TTPC27', weight: 1.875, delay: 0.05, label: 'pre->post27', preLoc: 0.5, hObj: NetCon[187]},
#   {preGid: 50, sec: 'dend_25', loc: 0.5199624720520006, synMech: 'L5_TTPC:L5_TTPC27', weight: 1.875, delay: 0.05, label: 'pre->post27', preLoc: 0.5, hObj: NetCon[188]}],
#  [{preGid: 50, sec: 'apic_56', loc: 0.9396496120779959, synMech: 'L5_TTPC:L5_TTPC28', weight: 1.875, delay: 0.05, label: 'pre->post28', preLoc: 0.5, hObj: NetCon[189]},
#   {preGid: 50, sec: 'dend_59', loc: 0.016974122277840654, synMech: 'L5_TTPC:L5_TTPC28', weight: 1.875, delay: 0.05, label: 'pre->post28', preLoc: 0.5, hObj: NetCon[190]},
#   {preGid: 50, sec: 'apic_20', loc: 0.013984761385535144, synMech: 'L5_TTPC:L5_TTPC28', weight: 1.875, delay: 0.05, label: 'pre->post28', preLoc: 0.5, hObj: NetCon[191]},
#   {preGid: 50, sec: 'apic_36', loc: 0.9395085783915484, synMech: 'L5_TTPC:L5_TTPC28', weight: 1.875, delay: 0.05, label: 'pre->post28', preLoc: 0.5, hObj: NetCon[192]},
#   {preGid: 50, sec: 'dend_42', loc: 0.13644624051029863, synMech: 'L5_TTPC:L5_TTPC28', weight: 1.875, delay: 0.05, label: 'pre->post28', preLoc: 0.5, hObj: NetCon[193]},
#   {preGid: 50, sec: 'apic_89', loc: 0.9305365421511359, synMech: 'L5_TTPC:L5_TTPC28', weight: 1.875, delay: 0.05, label: 'pre->post28', preLoc: 0.5, hObj: NetCon[194]},
#   {preGid: 50, sec: 'dend_31', loc: 0.37018768185077966, synMech: 'L5_TTPC:L5_TTPC28', weight: 1.875, delay: 0.05, label: 'pre->post28', preLoc: 0.5, hObj: NetCon[195]}],
#  [{preGid: 50, sec: 'apic_10', loc: 0.7148659942053592, synMech: 'L5_TTPC:L5_TTPC29', weight: 1.875, delay: 0.05, label: 'pre->post29', preLoc: 0.5, hObj: NetCon[196]},
#   {preGid: 50, sec: 'apic_87', loc: 0.6650986648976981, synMech: 'L5_TTPC:L5_TTPC29', weight: 1.875, delay: 0.05, label: 'pre->post29', preLoc: 0.5, hObj: NetCon[197]},
#   {preGid: 50, sec: 'dend_3', loc: 0.8144816674756089, synMech: 'L5_TTPC:L5_TTPC29', weight: 1.875, delay: 0.05, label: 'pre->post29', preLoc: 0.5, hObj: NetCon[198]},
#   {preGid: 50, sec: 'dend_2', loc: 0.6327079951256578, synMech: 'L5_TTPC:L5_TTPC29', weight: 1.875, delay: 0.05, label: 'pre->post29', preLoc: 0.5, hObj: NetCon[199]},
#   {preGid: 50, sec: 'apic_32', loc: 0.49791790465410485, synMech: 'L5_TTPC:L5_TTPC29', weight: 1.875, delay: 0.05, label: 'pre->post29', preLoc: 0.5, hObj: NetCon[200]},
#   {preGid: 50, sec: 'dend_33', loc: 0.36157877187128296, synMech: 'L5_TTPC:L5_TTPC29', weight: 1.875, delay: 0.05, label: 'pre->post29', preLoc: 0.5, hObj: NetCon[201]},
#   {preGid: 50, sec: 'apic_89', loc: 0.3758455230433676, synMech: 'L5_TTPC:L5_TTPC29', weight: 1.875, delay: 0.05, label: 'pre->post29', preLoc: 0.5, hObj: NetCon[202]}],
#  [{preGid: 50, sec: 'apic_48', loc: 0.539332747929448, synMech: 'L5_TTPC:L5_TTPC30', weight: 1.875, delay: 0.05, label: 'pre->post30', preLoc: 0.5, hObj: NetCon[203]},
#   {preGid: 50, sec: 'apic_22', loc: 0.42741488814842044, synMech: 'L5_TTPC:L5_TTPC30', weight: 1.875, delay: 0.05, label: 'pre->post30', preLoc: 0.5, hObj: NetCon[204]},
#   {preGid: 50, sec: 'dend_13', loc: 0.6375649411485386, synMech: 'L5_TTPC:L5_TTPC30', weight: 1.875, delay: 0.05, label: 'pre->post30', preLoc: 0.5, hObj: NetCon[205]},
#   {preGid: 50, sec: 'dend_71', loc: 0.4340682325098755, synMech: 'L5_TTPC:L5_TTPC30', weight: 1.875, delay: 0.05, label: 'pre->post30', preLoc: 0.5, hObj: NetCon[206]},
#   {preGid: 50, sec: 'dend_20', loc: 0.9554254181574597, synMech: 'L5_TTPC:L5_TTPC30', weight: 1.875, delay: 0.05, label: 'pre->post30', preLoc: 0.5, hObj: NetCon[207]},
#   {preGid: 50, sec: 'dend_46', loc: 0.8829209723027284, synMech: 'L5_TTPC:L5_TTPC30', weight: 1.875, delay: 0.05, label: 'pre->post30', preLoc: 0.5, hObj: NetCon[208]},
#   {preGid: 50, sec: 'dend_8', loc: 0.971373929238435, synMech: 'L5_TTPC:L5_TTPC30', weight: 1.875, delay: 0.05, label: 'pre->post30', preLoc: 0.5, hObj: NetCon[209]}],
#  [{preGid: 50, sec: 'dend_20', loc: 0.5643976389946631, synMech: 'L5_TTPC:L5_TTPC31', weight: 1.875, delay: 0.05, label: 'pre->post31', preLoc: 0.5, hObj: NetCon[210]},
#   {preGid: 50, sec: 'apic_30', loc: 0.6762339128522445, synMech: 'L5_TTPC:L5_TTPC31', weight: 1.875, delay: 0.05, label: 'pre->post31', preLoc: 0.5, hObj: NetCon[211]},
#   {preGid: 50, sec: 'apic_53', loc: 0.6630724671844037, synMech: 'L5_TTPC:L5_TTPC31', weight: 1.875, delay: 0.05, label: 'pre->post31', preLoc: 0.5, hObj: NetCon[212]},
#   {preGid: 50, sec: 'dend_41', loc: 0.33944858758953095, synMech: 'L5_TTPC:L5_TTPC31', weight: 1.875, delay: 0.05, label: 'pre->post31', preLoc: 0.5, hObj: NetCon[213]},
#   {preGid: 50, sec: 'dend_60', loc: 0.15448851581438017, synMech: 'L5_TTPC:L5_TTPC31', weight: 1.875, delay: 0.05, label: 'pre->post31', preLoc: 0.5, hObj: NetCon[214]},
#   {preGid: 50, sec: 'dend_95', loc: 0.09778433595225816, synMech: 'L5_TTPC:L5_TTPC31', weight: 1.875, delay: 0.05, label: 'pre->post31', preLoc: 0.5, hObj: NetCon[215]},
#   {preGid: 50, sec: 'dend_88', loc: 0.8111205179707391, synMech: 'L5_TTPC:L5_TTPC31', weight: 1.875, delay: 0.05, label: 'pre->post31', preLoc: 0.5, hObj: NetCon[216]}],
#  [{preGid: 50, sec: 'apic_73', loc: 0.6482921635467556, synMech: 'L5_TTPC:L5_TTPC32', weight: 1.875, delay: 0.05, label: 'pre->post32', preLoc: 0.5, hObj: NetCon[217]},
#   {preGid: 50, sec: 'apic_44', loc: 0.8157315907148375, synMech: 'L5_TTPC:L5_TTPC32', weight: 1.875, delay: 0.05, label: 'pre->post32', preLoc: 0.5, hObj: NetCon[218]},
#   {preGid: 50, sec: 'apic_76', loc: 0.9733185584223937, synMech: 'L5_TTPC:L5_TTPC32', weight: 1.875, delay: 0.05, label: 'pre->post32', preLoc: 0.5, hObj: NetCon[219]},
#   {preGid: 50, sec: 'dend_8', loc: 0.7524239220458024, synMech: 'L5_TTPC:L5_TTPC32', weight: 1.875, delay: 0.05, label: 'pre->post32', preLoc: 0.5, hObj: NetCon[220]},
#   {preGid: 50, sec: 'dend_93', loc: 0.2471989607846754, synMech: 'L5_TTPC:L5_TTPC32', weight: 1.875, delay: 0.05, label: 'pre->post32', preLoc: 0.5, hObj: NetCon[221]},
#   {preGid: 50, sec: 'dend_46', loc: 0.9343239325585643, synMech: 'L5_TTPC:L5_TTPC32', weight: 1.875, delay: 0.05, label: 'pre->post32', preLoc: 0.5, hObj: NetCon[222]},
#   {preGid: 50, sec: 'dend_2', loc: 0.12280945227013987, synMech: 'L5_TTPC:L5_TTPC32', weight: 1.875, delay: 0.05, label: 'pre->post32', preLoc: 0.5, hObj: NetCon[223]}],
#  [{preGid: 50, sec: 'dend_31', loc: 0.8632740291468685, synMech: 'L5_TTPC:L5_TTPC33', weight: 1.875, delay: 0.05, label: 'pre->post33', preLoc: 0.5, hObj: NetCon[224]},
#   {preGid: 50, sec: 'dend_67', loc: 0.024608724997288344, synMech: 'L5_TTPC:L5_TTPC33', weight: 1.875, delay: 0.05, label: 'pre->post33', preLoc: 0.5, hObj: NetCon[225]},
#   {preGid: 50, sec: 'apic_16', loc: 0.5846425095864174, synMech: 'L5_TTPC:L5_TTPC33', weight: 1.875, delay: 0.05, label: 'pre->post33', preLoc: 0.5, hObj: NetCon[226]},
#   {preGid: 50, sec: 'apic_35', loc: 0.22023935636296768, synMech: 'L5_TTPC:L5_TTPC33', weight: 1.875, delay: 0.05, label: 'pre->post33', preLoc: 0.5, hObj: NetCon[227]},
#   {preGid: 50, sec: 'dend_88', loc: 0.030110493056218823, synMech: 'L5_TTPC:L5_TTPC33', weight: 1.875, delay: 0.05, label: 'pre->post33', preLoc: 0.5, hObj: NetCon[228]},
#   {preGid: 50, sec: 'apic_60', loc: 0.5584248055874679, synMech: 'L5_TTPC:L5_TTPC33', weight: 1.875, delay: 0.05, label: 'pre->post33', preLoc: 0.5, hObj: NetCon[229]},
#   {preGid: 50, sec: 'apic_31', loc: 0.6635600533625604, synMech: 'L5_TTPC:L5_TTPC33', weight: 1.875, delay: 0.05, label: 'pre->post33', preLoc: 0.5, hObj: NetCon[230]}],
#  [{preGid: 50, sec: 'apic_12', loc: 0.18217661118551295, synMech: 'L5_TTPC:L5_TTPC34', weight: 1.875, delay: 0.05, label: 'pre->post34', preLoc: 0.5, hObj: NetCon[231]},
#   {preGid: 50, sec: 'dend_4', loc: 0.7998008945219873, synMech: 'L5_TTPC:L5_TTPC34', weight: 1.875, delay: 0.05, label: 'pre->post34', preLoc: 0.5, hObj: NetCon[232]},
#   {preGid: 50, sec: 'dend_82', loc: 0.3830525289422267, synMech: 'L5_TTPC:L5_TTPC34', weight: 1.875, delay: 0.05, label: 'pre->post34', preLoc: 0.5, hObj: NetCon[233]},
#   {preGid: 50, sec: 'apic_35', loc: 0.8121255629796801, synMech: 'L5_TTPC:L5_TTPC34', weight: 1.875, delay: 0.05, label: 'pre->post34', preLoc: 0.5, hObj: NetCon[234]},
#   {preGid: 50, sec: 'apic_48', loc: 0.9618619086171882, synMech: 'L5_TTPC:L5_TTPC34', weight: 1.875, delay: 0.05, label: 'pre->post34', preLoc: 0.5, hObj: NetCon[235]},
#   {preGid: 50, sec: 'apic_29', loc: 0.5114582953809234, synMech: 'L5_TTPC:L5_TTPC34', weight: 1.875, delay: 0.05, label: 'pre->post34', preLoc: 0.5, hObj: NetCon[236]},
#   {preGid: 50, sec: 'apic_27', loc: 0.018393519728470267, synMech: 'L5_TTPC:L5_TTPC34', weight: 1.875, delay: 0.05, label: 'pre->post34', preLoc: 0.5, hObj: NetCon[237]}],
#  [{preGid: 50, sec: 'apic_57', loc: 0.3355633887674691, synMech: 'L5_TTPC:L5_TTPC35', weight: 1.875, delay: 0.05, label: 'pre->post35', preLoc: 0.5, hObj: NetCon[238]},
#   {preGid: 50, sec: 'apic_12', loc: 0.6493463861805465, synMech: 'L5_TTPC:L5_TTPC35', weight: 1.875, delay: 0.05, label: 'pre->post35', preLoc: 0.5, hObj: NetCon[239]},
#   {preGid: 50, sec: 'apic_37', loc: 0.7320645703651897, synMech: 'L5_TTPC:L5_TTPC35', weight: 1.875, delay: 0.05, label: 'pre->post35', preLoc: 0.5, hObj: NetCon[240]},
#   {preGid: 50, sec: 'dend_68', loc: 0.4883756439288169, synMech: 'L5_TTPC:L5_TTPC35', weight: 1.875, delay: 0.05, label: 'pre->post35', preLoc: 0.5, hObj: NetCon[241]},
#   {preGid: 50, sec: 'dend_13', loc: 0.18534051248710295, synMech: 'L5_TTPC:L5_TTPC35', weight: 1.875, delay: 0.05, label: 'pre->post35', preLoc: 0.5, hObj: NetCon[242]},
#   {preGid: 50, sec: 'apic_89', loc: 0.6285276986289557, synMech: 'L5_TTPC:L5_TTPC35', weight: 1.875, delay: 0.05, label: 'pre->post35', preLoc: 0.5, hObj: NetCon[243]},
#   {preGid: 50, sec: 'apic_91', loc: 0.2615215735912583, synMech: 'L5_TTPC:L5_TTPC35', weight: 1.875, delay: 0.05, label: 'pre->post35', preLoc: 0.5, hObj: NetCon[244]}],
#  [{preGid: 50, sec: 'dend_28', loc: 0.06811028486730678, synMech: 'L5_TTPC:L5_TTPC36', weight: 1.875, delay: 0.05, label: 'pre->post36', preLoc: 0.5, hObj: NetCon[245]},
#   {preGid: 50, sec: 'dend_13', loc: 0.5986236946879052, synMech: 'L5_TTPC:L5_TTPC36', weight: 1.875, delay: 0.05, label: 'pre->post36', preLoc: 0.5, hObj: NetCon[246]},
#   {preGid: 50, sec: 'dend_5', loc: 0.784873897654549, synMech: 'L5_TTPC:L5_TTPC36', weight: 1.875, delay: 0.05, label: 'pre->post36', preLoc: 0.5, hObj: NetCon[247]},
#   {preGid: 50, sec: 'dend_50', loc: 0.17298807232951738, synMech: 'L5_TTPC:L5_TTPC36', weight: 1.875, delay: 0.05, label: 'pre->post36', preLoc: 0.5, hObj: NetCon[248]},
#   {preGid: 50, sec: 'apic_88', loc: 0.8356966189691504, synMech: 'L5_TTPC:L5_TTPC36', weight: 1.875, delay: 0.05, label: 'pre->post36', preLoc: 0.5, hObj: NetCon[249]},
#   {preGid: 50, sec: 'apic_80', loc: 0.40770934657272806, synMech: 'L5_TTPC:L5_TTPC36', weight: 1.875, delay: 0.05, label: 'pre->post36', preLoc: 0.5, hObj: NetCon[250]},
#   {preGid: 50, sec: 'apic_19', loc: 0.28971220754272686, synMech: 'L5_TTPC:L5_TTPC36', weight: 1.875, delay: 0.05, label: 'pre->post36', preLoc: 0.5, hObj: NetCon[251]}],
#  [{preGid: 50, sec: 'apic_66', loc: 0.9143074098198131, synMech: 'L5_TTPC:L5_TTPC37', weight: 1.875, delay: 0.05, label: 'pre->post37', preLoc: 0.5, hObj: NetCon[252]},
#   {preGid: 50, sec: 'dend_90', loc: 0.11740586774913396, synMech: 'L5_TTPC:L5_TTPC37', weight: 1.875, delay: 0.05, label: 'pre->post37', preLoc: 0.5, hObj: NetCon[253]},
#   {preGid: 50, sec: 'apic_80', loc: 0.8649613160985664, synMech: 'L5_TTPC:L5_TTPC37', weight: 1.875, delay: 0.05, label: 'pre->post37', preLoc: 0.5, hObj: NetCon[254]},
#   {preGid: 50, sec: 'dend_21', loc: 0.1896371706729586, synMech: 'L5_TTPC:L5_TTPC37', weight: 1.875, delay: 0.05, label: 'pre->post37', preLoc: 0.5, hObj: NetCon[255]},
#   {preGid: 50, sec: 'dend_46', loc: 0.512847292551137, synMech: 'L5_TTPC:L5_TTPC37', weight: 1.875, delay: 0.05, label: 'pre->post37', preLoc: 0.5, hObj: NetCon[256]},
#   {preGid: 50, sec: 'apic_28', loc: 0.8553268046079434, synMech: 'L5_TTPC:L5_TTPC37', weight: 1.875, delay: 0.05, label: 'pre->post37', preLoc: 0.5, hObj: NetCon[257]},
#   {preGid: 50, sec: 'apic_67', loc: 0.5202097703514392, synMech: 'L5_TTPC:L5_TTPC37', weight: 1.875, delay: 0.05, label: 'pre->post37', preLoc: 0.5, hObj: NetCon[258]}],
#  [{preGid: 50, sec: 'dend_59', loc: 0.8909426755785772, synMech: 'L5_TTPC:L5_TTPC38', weight: 1.875, delay: 0.05, label: 'pre->post38', preLoc: 0.5, hObj: NetCon[259]},
#   {preGid: 50, sec: 'apic_64', loc: 0.9589244461979387, synMech: 'L5_TTPC:L5_TTPC38', weight: 1.875, delay: 0.05, label: 'pre->post38', preLoc: 0.5, hObj: NetCon[260]},
#   {preGid: 50, sec: 'apic_54', loc: 0.3005362478230412, synMech: 'L5_TTPC:L5_TTPC38', weight: 1.875, delay: 0.05, label: 'pre->post38', preLoc: 0.5, hObj: NetCon[261]},
#   {preGid: 50, sec: 'dend_84', loc: 0.2815787060511207, synMech: 'L5_TTPC:L5_TTPC38', weight: 1.875, delay: 0.05, label: 'pre->post38', preLoc: 0.5, hObj: NetCon[262]},
#   {preGid: 50, sec: 'apic_12', loc: 0.9501554962927454, synMech: 'L5_TTPC:L5_TTPC38', weight: 1.875, delay: 0.05, label: 'pre->post38', preLoc: 0.5, hObj: NetCon[263]},
#   {preGid: 50, sec: 'apic_8', loc: 0.9278413641337122, synMech: 'L5_TTPC:L5_TTPC38', weight: 1.875, delay: 0.05, label: 'pre->post38', preLoc: 0.5, hObj: NetCon[264]},
#   {preGid: 50, sec: 'apic_81', loc: 0.6804484250032798, synMech: 'L5_TTPC:L5_TTPC38', weight: 1.875, delay: 0.05, label: 'pre->post38', preLoc: 0.5, hObj: NetCon[265]}],
#  [{preGid: 50, sec: 'dend_88', loc: 0.9710416109395457, synMech: 'L5_TTPC:L5_TTPC39', weight: 1.875, delay: 0.05, label: 'pre->post39', preLoc: 0.5, hObj: NetCon[266]},
#   {preGid: 50, sec: 'apic_59', loc: 0.8106020535634374, synMech: 'L5_TTPC:L5_TTPC39', weight: 1.875, delay: 0.05, label: 'pre->post39', preLoc: 0.5, hObj: NetCon[267]},
#   {preGid: 50, sec: 'apic_76', loc: 0.4571401400124771, synMech: 'L5_TTPC:L5_TTPC39', weight: 1.875, delay: 0.05, label: 'pre->post39', preLoc: 0.5, hObj: NetCon[268]},
#   {preGid: 50, sec: 'dend_64', loc: 0.931482697333039, synMech: 'L5_TTPC:L5_TTPC39', weight: 1.875, delay: 0.05, label: 'pre->post39', preLoc: 0.5, hObj: NetCon[269]},
#   {preGid: 50, sec: 'apic_58', loc: 0.6333442265349125, synMech: 'L5_TTPC:L5_TTPC39', weight: 1.875, delay: 0.05, label: 'pre->post39', preLoc: 0.5, hObj: NetCon[270]},
#   {preGid: 50, sec: 'apic_66', loc: 0.96356350212906, synMech: 'L5_TTPC:L5_TTPC39', weight: 1.875, delay: 0.05, label: 'pre->post39', preLoc: 0.5, hObj: NetCon[271]},
#   {preGid: 50, sec: 'dend_69', loc: 0.16440130523143223, synMech: 'L5_TTPC:L5_TTPC39', weight: 1.875, delay: 0.05, label: 'pre->post39', preLoc: 0.5, hObj: NetCon[272]}],
#  [{preGid: 50, sec: 'apic_14', loc: 0.4625070045959312, synMech: 'L5_TTPC:L5_TTPC40', weight: 1.875, delay: 0.05, label: 'pre->post40', preLoc: 0.5, hObj: NetCon[273]},
#   {preGid: 50, sec: 'apic_35', loc: 0.14580599472964917, synMech: 'L5_TTPC:L5_TTPC40', weight: 1.875, delay: 0.05, label: 'pre->post40', preLoc: 0.5, hObj: NetCon[274]},
#   {preGid: 50, sec: 'apic_59', loc: 0.8495056735262851, synMech: 'L5_TTPC:L5_TTPC40', weight: 1.875, delay: 0.05, label: 'pre->post40', preLoc: 0.5, hObj: NetCon[275]},
#   {preGid: 50, sec: 'apic_91', loc: 0.9031098116214055, synMech: 'L5_TTPC:L5_TTPC40', weight: 1.875, delay: 0.05, label: 'pre->post40', preLoc: 0.5, hObj: NetCon[276]},
#   {preGid: 50, sec: 'dend_21', loc: 0.5983026875963484, synMech: 'L5_TTPC:L5_TTPC40', weight: 1.875, delay: 0.05, label: 'pre->post40', preLoc: 0.5, hObj: NetCon[277]},
#   {preGid: 50, sec: 'dend_58', loc: 0.3203132539928156, synMech: 'L5_TTPC:L5_TTPC40', weight: 1.875, delay: 0.05, label: 'pre->post40', preLoc: 0.5, hObj: NetCon[278]},
#   {preGid: 50, sec: 'dend_50', loc: 0.5632593297525277, synMech: 'L5_TTPC:L5_TTPC40', weight: 1.875, delay: 0.05, label: 'pre->post40', preLoc: 0.5, hObj: NetCon[279]}],
#  [{preGid: 50, sec: 'dend_79', loc: 0.1980869859128416, synMech: 'L5_TTPC:L5_TTPC41', weight: 1.875, delay: 0.05, label: 'pre->post41', preLoc: 0.5, hObj: NetCon[280]},
#   {preGid: 50, sec: 'dend_76', loc: 0.5992404322044761, synMech: 'L5_TTPC:L5_TTPC41', weight: 1.875, delay: 0.05, label: 'pre->post41', preLoc: 0.5, hObj: NetCon[281]},
#   {preGid: 50, sec: 'apic_71', loc: 0.05184950265793699, synMech: 'L5_TTPC:L5_TTPC41', weight: 1.875, delay: 0.05, label: 'pre->post41', preLoc: 0.5, hObj: NetCon[282]},
#   {preGid: 50, sec: 'dend_58', loc: 0.7758763282199164, synMech: 'L5_TTPC:L5_TTPC41', weight: 1.875, delay: 0.05, label: 'pre->post41', preLoc: 0.5, hObj: NetCon[283]},
#   {preGid: 50, sec: 'dend_11', loc: 0.08588160671683809, synMech: 'L5_TTPC:L5_TTPC41', weight: 1.875, delay: 0.05, label: 'pre->post41', preLoc: 0.5, hObj: NetCon[284]},
#   {preGid: 50, sec: 'dend_88', loc: 0.08423685825052889, synMech: 'L5_TTPC:L5_TTPC41', weight: 1.875, delay: 0.05, label: 'pre->post41', preLoc: 0.5, hObj: NetCon[285]},
#   {preGid: 50, sec: 'apic_91', loc: 0.6915094727756947, synMech: 'L5_TTPC:L5_TTPC41', weight: 1.875, delay: 0.05, label: 'pre->post41', preLoc: 0.5, hObj: NetCon[286]}],
#  [{preGid: 50, sec: 'apic_71', loc: 0.2135706908313224, synMech: 'L5_TTPC:L5_TTPC42', weight: 1.875, delay: 0.05, label: 'pre->post42', preLoc: 0.5, hObj: NetCon[287]},
#   {preGid: 50, sec: 'dend_77', loc: 0.711421293056791, synMech: 'L5_TTPC:L5_TTPC42', weight: 1.875, delay: 0.05, label: 'pre->post42', preLoc: 0.5, hObj: NetCon[288]},
#   {preGid: 50, sec: 'dend_7', loc: 0.853755248070737, synMech: 'L5_TTPC:L5_TTPC42', weight: 1.875, delay: 0.05, label: 'pre->post42', preLoc: 0.5, hObj: NetCon[289]},
#   {preGid: 50, sec: 'apic_37', loc: 0.8480844119608257, synMech: 'L5_TTPC:L5_TTPC42', weight: 1.875, delay: 0.05, label: 'pre->post42', preLoc: 0.5, hObj: NetCon[290]},
#   {preGid: 50, sec: 'dend_14', loc: 0.3173792335746403, synMech: 'L5_TTPC:L5_TTPC42', weight: 1.875, delay: 0.05, label: 'pre->post42', preLoc: 0.5, hObj: NetCon[291]},
#   {preGid: 50, sec: 'apic_86', loc: 0.5332026528864129, synMech: 'L5_TTPC:L5_TTPC42', weight: 1.875, delay: 0.05, label: 'pre->post42', preLoc: 0.5, hObj: NetCon[292]},
#   {preGid: 50, sec: 'apic_35', loc: 0.47870868103133, synMech: 'L5_TTPC:L5_TTPC42', weight: 1.875, delay: 0.05, label: 'pre->post42', preLoc: 0.5, hObj: NetCon[293]}],
#  [{preGid: 50, sec: 'dend_5', loc: 0.027350862365487665, synMech: 'L5_TTPC:L5_TTPC43', weight: 1.875, delay: 0.05, label: 'pre->post43', preLoc: 0.5, hObj: NetCon[294]},
#   {preGid: 50, sec: 'dend_31', loc: 0.12776311748502775, synMech: 'L5_TTPC:L5_TTPC43', weight: 1.875, delay: 0.05, label: 'pre->post43', preLoc: 0.5, hObj: NetCon[295]},
#   {preGid: 50, sec: 'apic_58', loc: 0.7678720878324579, synMech: 'L5_TTPC:L5_TTPC43', weight: 1.875, delay: 0.05, label: 'pre->post43', preLoc: 0.5, hObj: NetCon[296]},
#   {preGid: 50, sec: 'apic_82', loc: 0.5123648825590889, synMech: 'L5_TTPC:L5_TTPC43', weight: 1.875, delay: 0.05, label: 'pre->post43', preLoc: 0.5, hObj: NetCon[297]},
#   {preGid: 50, sec: 'dend_13', loc: 0.038902537541157134, synMech: 'L5_TTPC:L5_TTPC43', weight: 1.875, delay: 0.05, label: 'pre->post43', preLoc: 0.5, hObj: NetCon[298]},
#   {preGid: 50, sec: 'apic_14', loc: 0.939925716229535, synMech: 'L5_TTPC:L5_TTPC43', weight: 1.875, delay: 0.05, label: 'pre->post43', preLoc: 0.5, hObj: NetCon[299]},
#   {preGid: 50, sec: 'dend_48', loc: 0.3250216052296692, synMech: 'L5_TTPC:L5_TTPC43', weight: 1.875, delay: 0.05, label: 'pre->post43', preLoc: 0.5, hObj: NetCon[300]}],
#  [{preGid: 50, sec: 'apic_49', loc: 0.3348475479215927, synMech: 'L5_TTPC:L5_TTPC44', weight: 1.875, delay: 0.05, label: 'pre->post44', preLoc: 0.5, hObj: NetCon[301]},
#   {preGid: 50, sec: 'dend_29', loc: 0.11555048101164005, synMech: 'L5_TTPC:L5_TTPC44', weight: 1.875, delay: 0.05, label: 'pre->post44', preLoc: 0.5, hObj: NetCon[302]},
#   {preGid: 50, sec: 'apic_71', loc: 0.13150153098350953, synMech: 'L5_TTPC:L5_TTPC44', weight: 1.875, delay: 0.05, label: 'pre->post44', preLoc: 0.5, hObj: NetCon[303]},
#   {preGid: 50, sec: 'apic_16', loc: 0.23153470187915526, synMech: 'L5_TTPC:L5_TTPC44', weight: 1.875, delay: 0.05, label: 'pre->post44', preLoc: 0.5, hObj: NetCon[304]},
#   {preGid: 50, sec: 'dend_30', loc: 0.2943625524068344, synMech: 'L5_TTPC:L5_TTPC44', weight: 1.875, delay: 0.05, label: 'pre->post44', preLoc: 0.5, hObj: NetCon[305]},
#   {preGid: 50, sec: 'apic_28', loc: 0.0025700017508957615, synMech: 'L5_TTPC:L5_TTPC44', weight: 1.875, delay: 0.05, label: 'pre->post44', preLoc: 0.5, hObj: NetCon[306]},
#   {preGid: 50, sec: 'dend_17', loc: 0.7018597063729753, synMech: 'L5_TTPC:L5_TTPC44', weight: 1.875, delay: 0.05, label: 'pre->post44', preLoc: 0.5, hObj: NetCon[307]}],
#  [{preGid: 50, sec: 'dend_82', loc: 0.06733873345407584, synMech: 'L5_TTPC:L5_TTPC45', weight: 1.875, delay: 0.05, label: 'pre->post45', preLoc: 0.5, hObj: NetCon[308]},
#   {preGid: 50, sec: 'dend_59', loc: 0.1720956722029258, synMech: 'L5_TTPC:L5_TTPC45', weight: 1.875, delay: 0.05, label: 'pre->post45', preLoc: 0.5, hObj: NetCon[309]},
#   {preGid: 50, sec: 'dend_68', loc: 0.27150612278424047, synMech: 'L5_TTPC:L5_TTPC45', weight: 1.875, delay: 0.05, label: 'pre->post45', preLoc: 0.5, hObj: NetCon[310]},
#   {preGid: 50, sec: 'dend_79', loc: 0.7211745362181341, synMech: 'L5_TTPC:L5_TTPC45', weight: 1.875, delay: 0.05, label: 'pre->post45', preLoc: 0.5, hObj: NetCon[311]},
#   {preGid: 50, sec: 'dend_28', loc: 0.9214447736060616, synMech: 'L5_TTPC:L5_TTPC45', weight: 1.875, delay: 0.05, label: 'pre->post45', preLoc: 0.5, hObj: NetCon[312]},
#   {preGid: 50, sec: 'apic_27', loc: 0.45962123765217194, synMech: 'L5_TTPC:L5_TTPC45', weight: 1.875, delay: 0.05, label: 'pre->post45', preLoc: 0.5, hObj: NetCon[313]},
#   {preGid: 50, sec: 'apic_43', loc: 0.7569487682480761, synMech: 'L5_TTPC:L5_TTPC45', weight: 1.875, delay: 0.05, label: 'pre->post45', preLoc: 0.5, hObj: NetCon[314]}],
#  [{preGid: 50, sec: 'dend_87', loc: 0.649461236268898, synMech: 'L5_TTPC:L5_TTPC46', weight: 1.875, delay: 0.05, label: 'pre->post46', preLoc: 0.5, hObj: NetCon[315]},
#   {preGid: 50, sec: 'dend_64', loc: 0.5558572108491238, synMech: 'L5_TTPC:L5_TTPC46', weight: 1.875, delay: 0.05, label: 'pre->post46', preLoc: 0.5, hObj: NetCon[316]},
#   {preGid: 50, sec: 'apic_36', loc: 0.30694982036463636, synMech: 'L5_TTPC:L5_TTPC46', weight: 1.875, delay: 0.05, label: 'pre->post46', preLoc: 0.5, hObj: NetCon[317]},
#   {preGid: 50, sec: 'apic_67', loc: 0.1361155678671725, synMech: 'L5_TTPC:L5_TTPC46', weight: 1.875, delay: 0.05, label: 'pre->post46', preLoc: 0.5, hObj: NetCon[318]},
#   {preGid: 50, sec: 'dend_39', loc: 0.0730408065461149, synMech: 'L5_TTPC:L5_TTPC46', weight: 1.875, delay: 0.05, label: 'pre->post46', preLoc: 0.5, hObj: NetCon[319]},
#   {preGid: 50, sec: 'apic_80', loc: 0.3034042660168614, synMech: 'L5_TTPC:L5_TTPC46', weight: 1.875, delay: 0.05, label: 'pre->post46', preLoc: 0.5, hObj: NetCon[320]},
#   {preGid: 50, sec: 'apic_92', loc: 0.44445702667469095, synMech: 'L5_TTPC:L5_TTPC46', weight: 1.875, delay: 0.05, label: 'pre->post46', preLoc: 0.5, hObj: NetCon[321]}],
#  [{preGid: 50, sec: 'dend_40', loc: 0.105272595863257, synMech: 'L5_TTPC:L5_TTPC47', weight: 1.875, delay: 0.05, label: 'pre->post47', preLoc: 0.5, hObj: NetCon[322]},
#   {preGid: 50, sec: 'apic_50', loc: 0.6162494617286274, synMech: 'L5_TTPC:L5_TTPC47', weight: 1.875, delay: 0.05, label: 'pre->post47', preLoc: 0.5, hObj: NetCon[323]},
#   {preGid: 50, sec: 'apic_47', loc: 0.28063357035620434, synMech: 'L5_TTPC:L5_TTPC47', weight: 1.875, delay: 0.05, label: 'pre->post47', preLoc: 0.5, hObj: NetCon[324]},
#   {preGid: 50, sec: 'dend_69', loc: 0.30317913561871473, synMech: 'L5_TTPC:L5_TTPC47', weight: 1.875, delay: 0.05, label: 'pre->post47', preLoc: 0.5, hObj: NetCon[325]},
#   {preGid: 50, sec: 'apic_62', loc: 0.7046434663708824, synMech: 'L5_TTPC:L5_TTPC47', weight: 1.875, delay: 0.05, label: 'pre->post47', preLoc: 0.5, hObj: NetCon[326]},
#   {preGid: 50, sec: 'apic_19', loc: 0.6835532699342578, synMech: 'L5_TTPC:L5_TTPC47', weight: 1.875, delay: 0.05, label: 'pre->post47', preLoc: 0.5, hObj: NetCon[327]},
#   {preGid: 50, sec: 'dend_52', loc: 0.021935279006244254, synMech: 'L5_TTPC:L5_TTPC47', weight: 1.875, delay: 0.05, label: 'pre->post47', preLoc: 0.5, hObj: NetCon[328]}],
#  [{preGid: 50, sec: 'apic_46', loc: 0.33790071019965096, synMech: 'L5_TTPC:L5_TTPC48', weight: 1.875, delay: 0.05, label: 'pre->post48', preLoc: 0.5, hObj: NetCon[329]},
#   {preGid: 50, sec: 'dend_85', loc: 0.8024066654187112, synMech: 'L5_TTPC:L5_TTPC48', weight: 1.875, delay: 0.05, label: 'pre->post48', preLoc: 0.5, hObj: NetCon[330]},
#   {preGid: 50, sec: 'dend_38', loc: 0.5438412292993242, synMech: 'L5_TTPC:L5_TTPC48', weight: 1.875, delay: 0.05, label: 'pre->post48', preLoc: 0.5, hObj: NetCon[331]},
#   {preGid: 50, sec: 'apic_0', loc: 0.4276374213738707, synMech: 'L5_TTPC:L5_TTPC48', weight: 1.875, delay: 0.05, label: 'pre->post48', preLoc: 0.5, hObj: NetCon[332]},
#   {preGid: 50, sec: 'dend_90', loc: 0.2958937588284989, synMech: 'L5_TTPC:L5_TTPC48', weight: 1.875, delay: 0.05, label: 'pre->post48', preLoc: 0.5, hObj: NetCon[333]},
#   {preGid: 50, sec: 'dend_41', loc: 0.3959975625655916, synMech: 'L5_TTPC:L5_TTPC48', weight: 1.875, delay: 0.05, label: 'pre->post48', preLoc: 0.5, hObj: NetCon[334]},
#   {preGid: 50, sec: 'dend_14', loc: 0.02813940175800139, synMech: 'L5_TTPC:L5_TTPC48', weight: 1.875, delay: 0.05, label: 'pre->post48', preLoc: 0.5, hObj: NetCon[335]}],
#  [{preGid: 50, sec: 'apic_66', loc: 0.6412741755321382, synMech: 'L5_TTPC:L5_TTPC49', weight: 1.875, delay: 0.05, label: 'pre->post49', preLoc: 0.5, hObj: NetCon[336]},
#   {preGid: 50, sec: 'apic_81', loc: 0.20882219622482234, synMech: 'L5_TTPC:L5_TTPC49', weight: 1.875, delay: 0.05, label: 'pre->post49', preLoc: 0.5, hObj: NetCon[337]},
#   {preGid: 50, sec: 'apic_30', loc: 0.11002224547943094, synMech: 'L5_TTPC:L5_TTPC49', weight: 1.875, delay: 0.05, label: 'pre->post49', preLoc: 0.5, hObj: NetCon[338]},
#   {preGid: 50, sec: 'apic_88', loc: 0.14426350304166904, synMech: 'L5_TTPC:L5_TTPC49', weight: 1.875, delay: 0.05, label: 'pre->post49', preLoc: 0.5, hObj: NetCon[339]},
#   {preGid: 50, sec: 'apic_12', loc: 0.8604167884038427, synMech: 'L5_TTPC:L5_TTPC49', weight: 1.875, delay: 0.05, label: 'pre->post49', preLoc: 0.5, hObj: NetCon[340]},
#   {preGid: 50, sec: 'apic_37', loc: 0.0010017760916397685, synMech: 'L5_TTPC:L5_TTPC49', weight: 1.875, delay: 0.05, label: 'pre->post49', preLoc: 0.5, hObj: NetCon[341]},
#   {preGid: 50, sec: 'dend_46', loc: 0.7350845450131763, synMech: 'L5_TTPC:L5_TTPC49', weight: 1.875, delay: 0.05, label: 'pre->post49', preLoc: 0.5, hObj: NetCon[342]}],
#  [{preGid: 50, sec: 'apic_58', loc: 0.29098554745688743, synMech: 'L5_TTPC:L5_TTPC50', weight: 1.875, delay: 0.05, label: 'pre->post50', preLoc: 0.5, hObj: NetCon[343]},
#   {preGid: 50, sec: 'apic_49', loc: 0.26899713894767824, synMech: 'L5_TTPC:L5_TTPC50', weight: 1.875, delay: 0.05, label: 'pre->post50', preLoc: 0.5, hObj: NetCon[344]},
#   {preGid: 50, sec: 'dend_17', loc: 0.00029528294707796874, synMech: 'L5_TTPC:L5_TTPC50', weight: 1.875, delay: 0.05, label: 'pre->post50', preLoc: 0.5, hObj: NetCon[345]},
#   {preGid: 50, sec: 'dend_68', loc: 0.12303849978803184, synMech: 'L5_TTPC:L5_TTPC50', weight: 1.875, delay: 0.05, label: 'pre->post50', preLoc: 0.5, hObj: NetCon[346]},
#   {preGid: 50, sec: 'dend_13', loc: 0.09866625567353224, synMech: 'L5_TTPC:L5_TTPC50', weight: 1.875, delay: 0.05, label: 'pre->post50', preLoc: 0.5, hObj: NetCon[347]},
#   {preGid: 50, sec: 'apic_29', loc: 0.46682851894053135, synMech: 'L5_TTPC:L5_TTPC50', weight: 1.875, delay: 0.05, label: 'pre->post50', preLoc: 0.5, hObj: NetCon[348]},
#   {preGid: 50, sec: 'dend_48', loc: 0.9207137526868464, synMech: 'L5_TTPC:L5_TTPC50', weight: 1.875, delay: 0.05, label: 'pre->post50', preLoc: 0.5, hObj: NetCon[349]}],
#  []]

# %%
sim.net.addStims() 							# add network stimulation
sim.setupRecording()              			# setup variables to record for each cell (spikes, V traces, etc)
# Out:
#   Number of stims on node 0: 0
#   Done; cell stims creation time = 0.00 s.
# Recording 50 traces of 1 types on node 0
# {spkt: Vector[66774], spkid: Vector[66775], V_soma: {cell_0: Vector[66776], cell_1: Vector[66777], cell_2: Vector[66778], cell_3: Vector[66779], cell_4: Vector[66780], cell_5: Vector[66781], cell_6: Vector[66782], cell_7: Vector[66783], cell_8: Vector[66784], cell_9: Vector[66785], cell_10: Vector[66786], cell_11: Vector[66787], cell_12: Vector[66788], cell_13: Vector[66789], cell_14: Vector[66790], cell_15: Vector[66791], cell_16: Vector[66792], cell_17: Vector[66793], cell_18: Vector[66794], cell_19: Vector[66795], cell_20: Vector[66796], cell_21: Vector[66797], cell_22: Vector[66798], cell_23: Vector[66799], cell_24: Vector[66800], cell_25: Vector[66801], cell_26: Vector[66802], cell_27: Vector[66803], cell_28: Vector[66804], cell_29: Vector[66805], cell_30: Vector[66806], cell_31: Vector[66807], cell_32: Vector[66808], cell_33: Vector[66809], cell_34: Vector[66810], cell_35: Vector[66811], cell_36: Vector[66812], cell_37: Vector[66813], cell_38: Vector[66814], cell_39: Vector[66815], cell_40: Vector[66816], cell_41: Vector[66817], cell_42: Vector[66818], cell_43: Vector[66819], cell_44: Vector[66820], cell_45: Vector[66821], cell_46: Vector[66822], cell_47: Vector[66823], cell_48: Vector[66824], cell_49: Vector[66825]}, t: Vector[66826], _repr_mimebundle_: {}}

# %%
sim.runSim()                      			# run Neuron simulation
# Out:
# 0.0s
#
# Running simulation using NEURON for 4000.0 ms...
# 0.1s
# 0.2s
# 0.3s
# 0.4s
# 0.5s
# 0.6s
# 0.7s
# 0.8s
# 0.9s
# 1.0s
# 1.1s
# 1.2s
# 1.3s
# 1.4s
# 1.5s
# 1.6s
# 1.7s
# 1.8s
# 1.9s
# 2.0s
# 2.1s
# 2.2s
# 2.3s
# 2.4s
# 2.5s
# 2.6s
# 2.7s
# 2.8s
# 2.9s
# 3.0s
# 3.1s
# 3.2s
# 3.3s
# 3.4s
# 3.5s
# 3.6s
# 3.7s
# 3.8s
# 3.9s
# 4.0s
#   Done; run time = 3150.17 s; real-time ratio: 0.00.

# %%
sim.gatherData()                  			# gather spiking data and cell info from each node
sim.saveData()                    			# save params, cell info and sim output to file (pickle,mat,txt,etc)#
sim.analysis.plotData()         			# plot spike raster etc
# Out:
# Gathering data...
#   Done; gather time = 0.10 s.
#
# Analyzing...
#   Cells: 51
#   Connections: 50 (0.98 per cell)
#   Synaptic contacts: 350 (6.86 per cell)
#   Spikes: 11 (0.05 Hz)
#   Simulated time: 4.0 s; 1 workers
#   Run time: 3150.17 s
# Warning: data won't be saved. No output format specified (consider sim.cfg.savePickle, sim.cfg.saveJson etc.)
# Plotting recorded cell traces ... trace
#   Done; plotting time = 0.43 s
#
# Total time = 3153.72 s

# %%
# sim.analysis.plotRaster(figSize=(10, 3))

# %%
alltraces = []
gmax1 = []

# spkTimes = [500,2500,2550,2600,2650,2700,2750,2800,2850,2900,3400]


Traces2 = sim.analysis.plotTraces(oneFigPer='trace', overlay=1, timeRange=[2400,3900],axis=False,legend=False,scaleBarLoc=1,figSize=(10, 3),fontSize=6)
for number in range(50):
    if np.max(Traces2[1]['tracesData'][number]['cell_'+str(number)+'_V_soma'])-np.min(Traces2[1]['tracesData'][number]['cell_'+str(number)+'_V_soma']) > 0.01:
        alltraces.append(Traces2[1]['tracesData'][number]['cell_'+str(number)+'_V_soma'])
        gmax1.append(np.max(Traces2[1]['tracesData'][number]['cell_'+str(number)+'_V_soma'])-np.min(Traces2[1]['tracesData'][number]['cell_'+str(number)+'_V_soma']))
#         print(number,np.max(Traces2[1]['tracesData'][number]['cell_'+str(number)+'_V_soma'])-np.min(Traces2[1]['tracesData'][number]['cell_'+str(number)+'_V_soma']))


# Traces2 = sim.analysis.plotTraces(oneFigPer='trace', overlay=1, timeRange=[3300,3900],axis=False,legend=False,scaleBarLoc=1,figSize=(10, 3),fontSize=6)
# for number in range(20):
#     if np.max(Traces2[1]['tracesData'][number]['cell_'+str(number)+'_V_soma'])-np.min(Traces2[1]['tracesData'][number]['cell_'+str(number)+'_V_soma']) > 0.01:
#         alltraces.append(Traces2[1]['tracesData'][number]['cell_'+str(number)+'_V_soma'])
#         gmax1.append(np.max(Traces2[1]['tracesData'][number]['cell_'+str(number)+'_V_soma'])-np.min(Traces2[1]['tracesData'][number]['cell_'+str(number)+'_V_soma']))
# #         print(number,np.max(Traces2[1]['tracesData'][number]['cell_'+str(number)+'_V_soma'])-np.min(Traces2[1]['tracesData'][number]['cell_'+str(number)+'_V_soma']))


# print('L23_PC:L23_PC in silico PSP amplitude (mV; mean ± SD) = %.3f±%.3f' % (np.mean(gmax1),np.std(gmax1)))
print('L5_TTPC:L5_TTPC in silico PSP amplitude (mV; mean ± SD) = %.3f±%.3f' % (np.mean(gmax1),np.std(gmax1)))
# Out:
# Plotting recorded cell traces ... trace
# L5_TTPC:L5_TTPC in silico PSP amplitude (mV; mean ± SD) = 1.068±0.206

# %%
figSize = (16,9)
fig = plt.figure(figsize=figSize)  # Open a new figure
clr = ["black", "blue","green","gray", "red","black", "blue","green","gray", "red"]
number=0
for i in range(10):
    for number2 in range(i,50,10):
        plt.plot(Traces2[1]['tracesData'][number]['t'][1:],Traces2[1]['tracesData'][number]['cell_'+str(number)+'_V_soma']-Traces2[1]['tracesData'][number]['cell_'+str(number)+'_V_soma'][999]-1.0*i, label= sim.net.allCells[number]['tags']['pop'] + '_' + sim.net.allCells[number]['conns'][0]['sec'], linewidth=1.0, color=clr[i])
        number+=1
        
plt.legend(loc='upper right', bbox_to_anchor=(1.25, 1.0), fontsize=8)
# plt.xlim(2400,4150)
plt.ylim(-9.25,2.0)
plt.xlabel('Time (ms)', fontsize=16)
plt.ylabel('EPSP (mV)', fontsize=16)
# plt.xticks(range(2400,3900,200), range(0,1500,200), fontsize=14);
plt.yticks([0,1], fontsize=14);

# %%
figSize = (8,5)
fig = plt.figure(figsize=figSize)  # Open a new figure
for number in range(np.shape(alltraces)[0]):
    plt.plot(alltraces[number]-alltraces[number][0],color = 'lightgray',linewidth=2.0)

plt.title('Vrev -80 mV and gsyn = 125p  ->  %.2f ± %.2f mV' % (np.mean(gmax1),np.std(gmax1)), fontsize=14)
plt.plot(np.mean(alltraces, axis=0)-np.mean(alltraces, axis=0)[0],color = 'black', linewidth=4.0)
# plt.legend(loc='upper right', bbox_to_anchor=(0.95, 1.0))
plt.xlim(500,12000)
plt.ylim(-0.25,1.5)
plt.xlabel('Time (ms)', fontsize=16)
plt.ylabel('PSP (mV)', fontsize=16)
plt.xticks(range(1000,12000,2000), range(0,1100,200), fontsize=14);
plt.yticks([0,1,2], fontsize=14); 

plt.savefig('../info/syn_gmax_L5TTPC_L5TTPC_125p.png', facecolor = 'white' , dpi=300)

# %%
# (0.8355167606552806, 25)

# %%
np.mean(gmax1), np.size(gmax1)
# Out:
# (1.0684623250625251, 50)

# %% [markdown]
# <!-- Connection type	s-type	in vitro PSP amplitude (mV; mean ± SD)	in silico PSP amplitude (mV; mean ± SD)	Input data sources
# L5TTPC-L5MC	E1	0.28 ± 0.3	0.28 ± 0.18	Silberberg & Markram, 2007
# L5MC-L5TTPC	I2	0.5 ± 0.3	0.57 ± 0.5	Silberberg & Markram, 2007
# L4SS-L23PC	E2	0.7 ± 0.6	0.7 ± 0.9	Feldmeyer et al. 2002
# L5STPC-L5STPC	E2	0.9 ± 0.7	0.91 ± 0.8	Le Bé et al. 2007
# L5UTPC-L5UTPC	E2	0.9 ± 0.7	0.91 ± 0.8	Le Bé et al. 2007
# L23PC-L23PC	E2	1 ± 0.7	1 ± 0.3	Feldmeyer et al. 2006
# L23LBC-L23PC	I2	1.2 ± 1.1	1.2 ± 1.02	Blatow et al. 2003
# L23NBC-L23PC	I2	1.2 ± 1.1	1.2 ± 1.02	Blatow et al. 2003
# L5TTPC-L5TTPC	E2	1.3 ± 1.1	1.2 ± 0.43	Markram et al. 1997
# L4SS-L4SS	E2	1.6 ± 1.0	1.9 ± 1.5	Feldmeyer et al. 1999
# L4SP-L4SP	E2	1.6 ± 1.0	1.9 ± 1.5	Feldmeyer et al. 1999
# L4PC-L4PC	E2	1.6 ± 1.0	1.9 ± 1.5	Feldmeyer et al. 1999
# L5TTPC-L5SBC	E2	2.1 ± 1.0	1.96 ± 0.67	Angulo et al. 1999 -->
# ![image.png](attachment:image.png)

# %%
Connectiontype = ['L5TTPC_L5MC_E1', 'L5MC_L5TTPC_I2', 'L4SS_L23PC_E2', 'L5STPC_L5STPC_E2', 'L5UTPC_L5UTPC_E2', 'L23PC_L23PC_E2', 
                  'L23LBC_L23PC_I2', 'L23NBC_L23PC_I2', 'L5TTPC_L5TTPC_E2', 'L4SS_L4SS_E2', 'L4SP_L4SP_E2', 'L4PC_L4PC_E2', 'L5TTPC_L5SBC_E2']

# %%
table13c = [0.28, 0.3, 0.28, 0.18, 0.50, 0.3, 0.57, 0.50, 0.70, 0.6, 0.70, 0.90, 0.90, 0.7, 0.91, 0.80, 0.90, 0.7, 0.91, 0.80, 
            1.00, 0.7, 1.00, 0.30, 1.20, 1.1, 1.20, 1.02, 1.20, 1.1, 1.20, 1.02, 1.30, 1.1, 1.20, 0.43, 1.60, 1.0, 1.90, 1.50, 
            1.60, 1.0, 1.90, 1.50, 1.60, 1.0, 1.90, 1.50, 2.10, 1.0, 1.96, 0.67]

# %%
x = []
sx = []
y = []
sy = []

for ii in range(13):
    print(Connectiontype[ii],table13c[4*ii],table13c[4*ii+1],table13c[4*ii+2],table13c[4*ii+3])
    x.append(table13c[4*ii])
    sx.append(table13c[4*ii+1])
    y.append(table13c[4*ii+2])
    sy.append(table13c[4*ii+3])
# Out:
# L5TTPC_L5MC_E1 0.28 0.3 0.28 0.18
# L5MC_L5TTPC_I2 0.5 0.3 0.57 0.5
# L4SS_L23PC_E2 0.7 0.6 0.7 0.9
# L5STPC_L5STPC_E2 0.9 0.7 0.91 0.8
# L5UTPC_L5UTPC_E2 0.9 0.7 0.91 0.8
# L23PC_L23PC_E2 1.0 0.7 1.0 0.3
# L23LBC_L23PC_I2 1.2 1.1 1.2 1.02
# L23NBC_L23PC_I2 1.2 1.1 1.2 1.02
# L5TTPC_L5TTPC_E2 1.3 1.1 1.2 0.43
# L4SS_L4SS_E2 1.6 1.0 1.9 1.5
# L4SP_L4SP_E2 1.6 1.0 1.9 1.5
# L4PC_L4PC_E2 1.6 1.0 1.9 1.5
# L5TTPC_L5SBC_E2 2.1 1.0 1.96 0.67

# %%
import matplotlib.pyplot as plt

# a = [1, 3, 5, 7]
# b = [11, -2, 4, 19]
# plt.scatter(a, b)


# c = [1, 3, 2, 1]
# d = [1, 3, 2, 1]

# you can use color ="r" for red or skip to default as blue
# plt.errorbar(x, y, xerr=sx, yerr=sy, fmt="o", color="r")
plt.scatter(x, y)

plt.show()
