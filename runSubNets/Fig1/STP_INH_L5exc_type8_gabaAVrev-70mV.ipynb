# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# # Input-output properties cells

# %%
import numpy as np
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
rootFolder = '/home/fernando/Dropbox/SUNY/2022/S1_netpyne/sim/'
# rootFolder = os.getcwd()
os.chdir(rootFolder)
print(rootFolder)
folder = os.listdir('cell_data/')
folder = sorted(folder)

savedata = 1 # Save Netpyne and BBP soma_voltage
# Out:
# /home/fernando/Dropbox/SUNY/2022/S1_netpyne/sim/

# %%
# !nrnivmodl mod

# %%
def loadTemplateName(cellnumber):     
    f = open(outFolder+'/template.hoc', 'r')
    for line in f.readlines():
        if 'begintemplate' in line:
            templatename = str(line)     
    templatename=templatename[:-1]        
    templatename=templatename[14:]
    return templatename

# %% [markdown]
# ## Netpyne

# %%
from netpyne import specs, sim   

# Network parameters
netParams = specs.NetParams()  # object of class NetParams to store the network parameters

# %%
# %matplotlib inline

# %%
## cfg  
cfg = specs.SimConfig()					            # object of class SimConfig to store simulation configuration
cfg.duration = 4000.0 						            # Duration of the simulation, in ms
cfg.dt = 0.05								                # Internal integration timestep to use
cfg.verbose = False							                # Show detailed messages 
cfg.recordTraces = {'V_soma':{'sec':'soma','loc':0.5,'var':'v'}}  # Dict with traces to record
cfg.recordStep = 0.1 			
cfg.printRunTime = 0.1 # in sec			

cfg.seeds = {'conn': 1, 'stim': 1, 'loc': 1} 
cfg.hParams = {'celsius': 34, 'v_init': -71.0}  
cfg.verbose = False
cfg.createNEURONObj = True
cfg.createPyStruct = True  
#------------------------------------------------------------------------------
# Saving
#------------------------------------------------------------------------------
cfg.filename = 'model_output'  			# Set file output name
cfg.savePickle = False         	## Save pkl file
cfg.saveJson = False	           	## Save json file
cfg.saveDataInclude = ['simData'] ## 'simData' , 'simConfig', 'netParams'
cfg.backupCfgFile = None 		##  
cfg.gatherOnlySimData = False	##  
cfg.saveCellSecs = False			
cfg.saveCellConns = True	

cfg.analysis['plotTraces'] = {'include': [i for i in range(100)], 'oneFigPer': 'trace', 'overlay': True, 'timeRange': [0,4000], 'saveFig': False, 'showFig': True, 'figSize':(12,4)} # Plot recorded traces for this list of cells
# cfg.analysis['plotShape'] = {'includePre': [0],'includePre': [0], 'saveFig': True, 'showFig': True, 'figSize':(12,12)}

# %%
# for i,metype in enumerate(folder):
#     print(i,metype)
folder[755:775]
# Out:
# ['L5_STPC_cADpyr232_1',
#  'L5_STPC_cADpyr232_2',
#  'L5_STPC_cADpyr232_3',
#  'L5_STPC_cADpyr232_4',
#  'L5_STPC_cADpyr232_5',
#  'L5_TTPC1_cADpyr232_1',
#  'L5_TTPC1_cADpyr232_2',
#  'L5_TTPC1_cADpyr232_3',
#  'L5_TTPC1_cADpyr232_4',
#  'L5_TTPC1_cADpyr232_5',
#  'L5_TTPC2_cADpyr232_1',
#  'L5_TTPC2_cADpyr232_2',
#  'L5_TTPC2_cADpyr232_3',
#  'L5_TTPC2_cADpyr232_4',
#  'L5_TTPC2_cADpyr232_5',
#  'L5_UTPC_cADpyr232_1',
#  'L5_UTPC_cADpyr232_2',
#  'L5_UTPC_cADpyr232_3',
#  'L5_UTPC_cADpyr232_4',
#  'L5_UTPC_cADpyr232_5']

# %%
#------------------------------------------------------------------------------
# Cell parameters
#------------------------------------------------------------------------------
#StochKv_deterministic.mod
for cellnumber in range(755,775):
    cellName = folder[cellnumber]
    outFolder = rootFolder+'/cell_data/'+folder[cellnumber]
    cellTemplateName = loadTemplateName(cellnumber)
    cellRule = netParams.importCellParams(label=cellName, somaAtOrigin=False,
        conds={'cellType': cellName, 'cellModel': 'HH_full'},
        fileName='cellwrapper.py',
        cellName='loadCell',
        cellInstance = True,
        cellArgs={'cellName': cellName, 'cellTemplateName': cellTemplateName})
# Out:
# NEURON: morphology_d16b0be14e : a template cannot be redefined
#  in morphology.hoc near line 34
#  begintemplate morphology_d16b0be14e
#                                    ^
#         xopen("morphology.hoc")
#       execute1("{xopen("mo...")
#     load_file("morphology.hoc")
#   xopen("template.hoc")
# NEURON: cADpyr232_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate cADpyr232_biophys
#                                ^
#         xopen("biophysics.hoc")
#       execute1("{xopen("bi...")
#     load_file("biophysics.hoc")
#   xopen("template.hoc")
# NEURON: synapses_d16b0be14e : a template cannot be redefined
#  in synapses.hoc near line 31
#  begintemplate synapses_d16b0be14e
#                                  ^
#         xopen("synapses.hoc")
#       execute1("{xopen("sy...")
#     load_file("synapses/s...")
#   xopen("template.hoc")
# 	0
# 	0
# 	0
# cADpyr232_L5_STPC_d16b0be14e[0]
# NEURON: cADpyr232_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate cADpyr232_biophys
#                                ^
#         xopen("biophysics.hoc")
# 	1
# 	1
# 	1
# cADpyr232_L5_STPC_d63221b7a8[0]
# NEURON: cADpyr232_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate cADpyr232_biophys
#                                ^
#         xopen("biophysics.hoc")
# 	1
# 	1
# 	1
# cADpyr232_L5_STPC_a78c3cbca8[0]
# NEURON: cADpyr232_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate cADpyr232_biophys
#                                ^
#         xopen("biophysics.hoc")
# 	1
# 	1
# 	1
# cADpyr232_L5_STPC_4ec7a36770[0]
# NEURON: cADpyr232_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate cADpyr232_biophys
#                                ^
#         xopen("biophysics.hoc")
# 	1
# 	1
# 	1
# cADpyr232_L5_STPC_6d41d50fcb[0]
# NEURON: cADpyr232_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate cADpyr232_biophys
#                                ^
#         xopen("biophysics.hoc")
# 	1
# 	1
# 	1
# cADpyr232_L5_TTPC1_0fb1ca4724[0]
# NEURON: cADpyr232_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate cADpyr232_biophys
#                                ^
#         xopen("biophysics.hoc")
# 	1
# 	1
# 	1
# cADpyr232_L5_TTPC1_fc944c2cf3[0]
# NEURON: cADpyr232_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate cADpyr232_biophys
#                                ^
#         xopen("biophysics.hoc")
# 	1
# 	1
# 	1
# cADpyr232_L5_TTPC1_da1088139b[0]
# NEURON: cADpyr232_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate cADpyr232_biophys
#                                ^
#         xopen("biophysics.hoc")
# 	1
# 	1
# 	1
# cADpyr232_L5_TTPC1_ded64abc4d[0]
# NEURON: cADpyr232_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate cADpyr232_biophys
#                                ^
#         xopen("biophysics.hoc")
# 	1
# 	1
# 	1
# cADpyr232_L5_TTPC1_b6836fcf6f[0]
# NEURON: cADpyr232_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate cADpyr232_biophys
#                                ^
#         xopen("biophysics.hoc")
# 	1
# 	1
# 	1
# cADpyr232_L5_TTPC2_8052133265[0]
# NEURON: cADpyr232_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate cADpyr232_biophys
#                                ^
#         xopen("biophysics.hoc")
# 	1
# 	1
# 	1
# cADpyr232_L5_TTPC2_a28017c6c7[0]
# NEURON: cADpyr232_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate cADpyr232_biophys
#                                ^
#         xopen("biophysics.hoc")
# 	1
# 	1
# 	1
# cADpyr232_L5_TTPC2_a467781f53[0]
# NEURON: cADpyr232_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate cADpyr232_biophys
#                                ^
#         xopen("biophysics.hoc")
# 	1
# 	1
# 	1
# cADpyr232_L5_TTPC2_c46a93702c[0]
# NEURON: cADpyr232_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate cADpyr232_biophys
#                                ^
#         xopen("biophysics.hoc")
# 	1
# 	1
# 	1
# cADpyr232_L5_TTPC2_8bab918b58[0]
# NEURON: cADpyr232_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate cADpyr232_biophys
#                                ^
#         xopen("biophysics.hoc")
# 	1
# 	1
# 	1
# cADpyr232_L5_UTPC_5e3840b51e[0]
# NEURON: cADpyr232_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate cADpyr232_biophys
#                                ^
#         xopen("biophysics.hoc")
# 	1
# 	1
# 	1
# cADpyr232_L5_UTPC_34f655e7f8[0]
# NEURON: cADpyr232_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate cADpyr232_biophys
#                                ^
#         xopen("biophysics.hoc")
# 	1
# 	1
# 	1
# cADpyr232_L5_UTPC_d736225429[0]
# NEURON: cADpyr232_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate cADpyr232_biophys
#                                ^
#         xopen("biophysics.hoc")
# 	1
# 	1
# 	1
# cADpyr232_L5_UTPC_da1143b075[0]
# NEURON: cADpyr232_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate cADpyr232_biophys
#                                ^
#         xopen("biophysics.hoc")
# 	1
# 	1
# 	1
# cADpyr232_L5_UTPC_79412a7e72[0]

# %%
for cellnumber in range(755,775):
    # ---------------------------------------------------------------------------------------------------- #
    cellName = folder[cellnumber]
    outFolder = rootFolder+'/cell_data/'+folder[cellnumber]
    cellTemplateName = loadTemplateName(cellnumber)
    
    # ---------------------------------------------------------------------------------------------------- #
    netParams.renameCellParamsSec(label=cellName, oldSec='soma_0', newSec='soma')
    
    for secname2 in netParams.cellParams[cellName]['secLists'].keys():
        if 'soma_0' in netParams.cellParams[cellName]['secLists'][secname2]:
            print(cellName,secname2,netParams.cellParams[cellName]['secLists'][secname2][0])
            netParams.cellParams[cellName]['secLists'][secname2][0] = 'soma'
    # ---------------------------------------------------------------------------------------------------- #
    
    nonSpiny = ['axon_0', 'axon_1']
    netParams.cellParams[cellName]['secLists']['spiny'] = [sec for sec in netParams.cellParams[cellName]['secLists']['all'] if sec not in nonSpiny]
    nonSpinyEE = ['axon_0', 'axon_1', 'soma']
    netParams.cellParams[cellName]['secLists']['spinyEE'] = [sec for sec in netParams.cellParams[cellName]['secLists']['all'] if sec not in nonSpinyEE]    
    
    # ---------------------------------------------------------------------------------------------------- #
    for ii in range(5):
        netParams.popParams[cellName + '_' + str(ii)] = {'cellType': cellName, 'numCells': 1, 'cellModel': 'HH_full'}
# Out:
# L5_STPC_cADpyr232_1 all soma_0
# L5_STPC_cADpyr232_1 somatic soma_0
# L5_STPC_cADpyr232_2 all soma_0
# L5_STPC_cADpyr232_2 somatic soma_0
# L5_STPC_cADpyr232_3 all soma_0
# L5_STPC_cADpyr232_3 somatic soma_0
# L5_STPC_cADpyr232_4 all soma_0
# L5_STPC_cADpyr232_4 somatic soma_0
# L5_STPC_cADpyr232_5 all soma_0
# L5_STPC_cADpyr232_5 somatic soma_0
# L5_TTPC1_cADpyr232_1 all soma_0
# L5_TTPC1_cADpyr232_1 somatic soma_0
# L5_TTPC1_cADpyr232_2 all soma_0
# L5_TTPC1_cADpyr232_2 somatic soma_0
# L5_TTPC1_cADpyr232_3 all soma_0
# L5_TTPC1_cADpyr232_3 somatic soma_0
# L5_TTPC1_cADpyr232_4 all soma_0
# L5_TTPC1_cADpyr232_4 somatic soma_0
# L5_TTPC1_cADpyr232_5 all soma_0
# L5_TTPC1_cADpyr232_5 somatic soma_0
# L5_TTPC2_cADpyr232_1 all soma_0
# L5_TTPC2_cADpyr232_1 somatic soma_0
# L5_TTPC2_cADpyr232_2 all soma_0
# L5_TTPC2_cADpyr232_2 somatic soma_0
# L5_TTPC2_cADpyr232_3 all soma_0
# L5_TTPC2_cADpyr232_3 somatic soma_0
# L5_TTPC2_cADpyr232_4 all soma_0
# L5_TTPC2_cADpyr232_4 somatic soma_0
# L5_TTPC2_cADpyr232_5 all soma_0
# L5_TTPC2_cADpyr232_5 somatic soma_0
# L5_UTPC_cADpyr232_1 all soma_0
# L5_UTPC_cADpyr232_1 somatic soma_0
# L5_UTPC_cADpyr232_2 all soma_0
# L5_UTPC_cADpyr232_2 somatic soma_0
# L5_UTPC_cADpyr232_3 all soma_0
# L5_UTPC_cADpyr232_3 somatic soma_0
# L5_UTPC_cADpyr232_4 all soma_0
# L5_UTPC_cADpyr232_4 somatic soma_0
# L5_UTPC_cADpyr232_5 all soma_0
# L5_UTPC_cADpyr232_5 somatic soma_0

# %%
for cellnumber in range(755,775):
    cellName = folder[cellnumber]
    print(netParams.cellParams[cellName]['secLists']['basal'][-1])
# Out:
# dend_41
# dend_45
# dend_59
# dend_45
# dend_59
# dend_112
# dend_112
# dend_112
# dend_112
# dend_82
# dend_79
# dend_95
# dend_95
# dend_95
# dend_95
# dend_42
# dend_42
# dend_42
# dend_60
# dend_63

# %%
# create custom list of spike times
# spkTimes = [2000,2500,3000,3500,4000,4500]
spkTimes = [500,2500,2550,2600,2650,2700,2750,2800,2850,2900,3400]

netParams.popParams['presyn'] = {'cellModel': 'VecStim', 'numCells': 1, 'spkTimes': spkTimes}  # VecStim with spike times

# %%
netParams.cellParams.keys()
# Out:
# odict_keys(['L5_STPC_cADpyr232_1', 'L5_STPC_cADpyr232_2', 'L5_STPC_cADpyr232_3', 'L5_STPC_cADpyr232_4', 'L5_STPC_cADpyr232_5', 'L5_TTPC1_cADpyr232_1', 'L5_TTPC1_cADpyr232_2', 'L5_TTPC1_cADpyr232_3', 'L5_TTPC1_cADpyr232_4', 'L5_TTPC1_cADpyr232_5', 'L5_TTPC2_cADpyr232_1', 'L5_TTPC2_cADpyr232_2', 'L5_TTPC2_cADpyr232_3', 'L5_TTPC2_cADpyr232_4', 'L5_TTPC2_cADpyr232_5', 'L5_UTPC_cADpyr232_1', 'L5_UTPC_cADpyr232_2', 'L5_UTPC_cADpyr232_3', 'L5_UTPC_cADpyr232_4', 'L5_UTPC_cADpyr232_5'])

# %%
list(netParams.popParams.keys())[0:-1]
# Out:
# ['L5_STPC_cADpyr232_1_0',
#  'L5_STPC_cADpyr232_1_1',
#  'L5_STPC_cADpyr232_1_2',
#  'L5_STPC_cADpyr232_1_3',
#  'L5_STPC_cADpyr232_1_4',
#  'L5_STPC_cADpyr232_2_0',
#  'L5_STPC_cADpyr232_2_1',
#  'L5_STPC_cADpyr232_2_2',
#  'L5_STPC_cADpyr232_2_3',
#  'L5_STPC_cADpyr232_2_4',
#  'L5_STPC_cADpyr232_3_0',
#  'L5_STPC_cADpyr232_3_1',
#  'L5_STPC_cADpyr232_3_2',
#  'L5_STPC_cADpyr232_3_3',
#  'L5_STPC_cADpyr232_3_4',
#  'L5_STPC_cADpyr232_4_0',
#  'L5_STPC_cADpyr232_4_1',
#  'L5_STPC_cADpyr232_4_2',
#  'L5_STPC_cADpyr232_4_3',
#  'L5_STPC_cADpyr232_4_4',
#  'L5_STPC_cADpyr232_5_0',
#  'L5_STPC_cADpyr232_5_1',
#  'L5_STPC_cADpyr232_5_2',
#  'L5_STPC_cADpyr232_5_3',
#  'L5_STPC_cADpyr232_5_4',
#  'L5_TTPC1_cADpyr232_1_0',
#  'L5_TTPC1_cADpyr232_1_1',
#  'L5_TTPC1_cADpyr232_1_2',
#  'L5_TTPC1_cADpyr232_1_3',
#  'L5_TTPC1_cADpyr232_1_4',
#  'L5_TTPC1_cADpyr232_2_0',
#  'L5_TTPC1_cADpyr232_2_1',
#  'L5_TTPC1_cADpyr232_2_2',
#  'L5_TTPC1_cADpyr232_2_3',
#  'L5_TTPC1_cADpyr232_2_4',
#  'L5_TTPC1_cADpyr232_3_0',
#  'L5_TTPC1_cADpyr232_3_1',
#  'L5_TTPC1_cADpyr232_3_2',
#  'L5_TTPC1_cADpyr232_3_3',
#  'L5_TTPC1_cADpyr232_3_4',
#  'L5_TTPC1_cADpyr232_4_0',
#  'L5_TTPC1_cADpyr232_4_1',
#  'L5_TTPC1_cADpyr232_4_2',
#  'L5_TTPC1_cADpyr232_4_3',
#  'L5_TTPC1_cADpyr232_4_4',
#  'L5_TTPC1_cADpyr232_5_0',
#  'L5_TTPC1_cADpyr232_5_1',
#  'L5_TTPC1_cADpyr232_5_2',
#  'L5_TTPC1_cADpyr232_5_3',
#  'L5_TTPC1_cADpyr232_5_4',
#  'L5_TTPC2_cADpyr232_1_0',
#  'L5_TTPC2_cADpyr232_1_1',
#  'L5_TTPC2_cADpyr232_1_2',
#  'L5_TTPC2_cADpyr232_1_3',
#  'L5_TTPC2_cADpyr232_1_4',
#  'L5_TTPC2_cADpyr232_2_0',
#  'L5_TTPC2_cADpyr232_2_1',
#  'L5_TTPC2_cADpyr232_2_2',
#  'L5_TTPC2_cADpyr232_2_3',
#  'L5_TTPC2_cADpyr232_2_4',
#  'L5_TTPC2_cADpyr232_3_0',
#  'L5_TTPC2_cADpyr232_3_1',
#  'L5_TTPC2_cADpyr232_3_2',
#  'L5_TTPC2_cADpyr232_3_3',
#  'L5_TTPC2_cADpyr232_3_4',
#  'L5_TTPC2_cADpyr232_4_0',
#  'L5_TTPC2_cADpyr232_4_1',
#  'L5_TTPC2_cADpyr232_4_2',
#  'L5_TTPC2_cADpyr232_4_3',
#  'L5_TTPC2_cADpyr232_4_4',
#  'L5_TTPC2_cADpyr232_5_0',
#  'L5_TTPC2_cADpyr232_5_1',
#  'L5_TTPC2_cADpyr232_5_2',
#  'L5_TTPC2_cADpyr232_5_3',
#  'L5_TTPC2_cADpyr232_5_4',
#  'L5_UTPC_cADpyr232_1_0',
#  'L5_UTPC_cADpyr232_1_1',
#  'L5_UTPC_cADpyr232_1_2',
#  'L5_UTPC_cADpyr232_1_3',
#  'L5_UTPC_cADpyr232_1_4',
#  'L5_UTPC_cADpyr232_2_0',
#  'L5_UTPC_cADpyr232_2_1',
#  'L5_UTPC_cADpyr232_2_2',
#  'L5_UTPC_cADpyr232_2_3',
#  'L5_UTPC_cADpyr232_2_4',
#  'L5_UTPC_cADpyr232_3_0',
#  'L5_UTPC_cADpyr232_3_1',
#  'L5_UTPC_cADpyr232_3_2',
#  'L5_UTPC_cADpyr232_3_3',
#  'L5_UTPC_cADpyr232_3_4',
#  'L5_UTPC_cADpyr232_4_0',
#  'L5_UTPC_cADpyr232_4_1',
#  'L5_UTPC_cADpyr232_4_2',
#  'L5_UTPC_cADpyr232_4_3',
#  'L5_UTPC_cADpyr232_4_4',
#  'L5_UTPC_cADpyr232_5_0',
#  'L5_UTPC_cADpyr232_5_1',
#  'L5_UTPC_cADpyr232_5_2',
#  'L5_UTPC_cADpyr232_5_3',
#  'L5_UTPC_cADpyr232_5_4']

# %%
# import scipy.stats as stats
# lower, upper = 0.48, 0.52
# mu, sigma = 0.50, 0.02
# X = stats.truncnorm(
#     (lower - mu) / sigma, (upper - mu) / sigma, loc=mu, scale=sigma)
# Use = X.rvs(100)

# --------------------------------------------------------------------------------------#
#BBP	gsyn	decay	       use	     dep	 fac	types	rules
#8	0.75±0.32	8.30±2.20	0.25±0.130	706±405	21±9	I2-IE	BTC-DBC-BP:Excitatory

for ii in range(100):
    netParams.synMechParams['INH:L5_PC'+str(ii+1)] = {'mod': 'DetGABAAB',
                                         'Use': 0.25,
                                         'Dep': 706.0,
                                         'Fac': 21.0,
                                         'tau_d_GABAA': 8.30,
                                         'tau_r_GABAA': 0.2,   #rng.lognormal(0.2, 0.1) in synapses.hoc  
                                         'tau_d_GABAB': 260.9,
                                         'tau_r_GABAB': 3.5,
                                         'e_GABAA': -70.0, #= -80   (mV) : GABAA reversal potential    
                                            }

# %%
import random

# lower, upper = 0.5, 1.0
# mu, sigma = 0.75, 0.32
# X = stats.truncnorm(
#     (lower - mu) / sigma, (upper - mu) / sigma, loc=mu, scale=sigma)

# weight = X.rvs(100)

## Cell connectivity rules
for ii in range(100):
    
    listsecs = random.sample(netParams.cellParams[cellName]['secLists']['spiny'], len(netParams.cellParams[cellName]['secLists']['spiny']))

    netParams.connParams['pre->post'+str(ii+1)] = { 
            'preConds': {'pop': 'presyn'},
            'postConds': {'pop': list(netParams.popParams.keys())[ii]},
            'sec': listsecs,                  # target postsyn section
            'synMech': 'INH:L5_PC'+str(ii+1),              # target synaptic mechanism
            'weight': 0.75, # weight[ii], # # synaptic weight 
            'synsPerConn': 15, 
            'delay': 0.05}

# %%
sim.initialize(
    simConfig = cfg, 	
    netParams = netParams)  				# create network object and set cfg and net params
sim.net.createPops()               			# instantiate network populations
sim.net.createCells()              			# instantiate network cells based on defined populations
sim.net.connectCells()            			# create connections between cells based on params
# Out:
# Start time:  2023-04-19 13:48:06.235751
#
# Creating network of 101 cell populations on 1 hosts...
#   Number of cells on node 0: 101
#   Done; cell creation time = 6.73 s.
# Making connections...
#   Number of connections on node 0: 100
#   Number of synaptic contacts on node 0: 1500
#   Done; cell connection time = 0.12 s.
# [[{preGid: 100, sec: 'apic_41', loc: 0.09995888142765504, synMech: 'INH:L5_PC1', weight: 0.75, delay: 0.05, label: 'pre->post1', preLoc: 0.5, hObj: NetCon[0]},
#   {preGid: 100, sec: 'dend_16', loc: 0.4478595955239664, synMech: 'INH:L5_PC1', weight: 0.75, delay: 0.05, label: 'pre->post1', preLoc: 0.5, hObj: NetCon[1]},
#   {preGid: 100, sec: 'dend_21', loc: 0.6072172902538803, synMech: 'INH:L5_PC1', weight: 0.75, delay: 0.05, label: 'pre->post1', preLoc: 0.5, hObj: NetCon[2]},
#   {preGid: 100, sec: 'dend_20', loc: 0.09595589783376426, synMech: 'INH:L5_PC1', weight: 0.75, delay: 0.05, label: 'pre->post1', preLoc: 0.5, hObj: NetCon[3]},
#   {preGid: 100, sec: 'dend_9', loc: 0.24388564680534255, synMech: 'INH:L5_PC1', weight: 0.75, delay: 0.05, label: 'pre->post1', preLoc: 0.5, hObj: NetCon[4]},
#   {preGid: 100, sec: 'apic_51', loc: 0.4282332861208504, synMech: 'INH:L5_PC1', weight: 0.75, delay: 0.05, label: 'pre->post1', preLoc: 0.5, hObj: NetCon[5]},
#   {preGid: 100, sec: 'apic_12', loc: 0.5691139588451917, synMech: 'INH:L5_PC1', weight: 0.75, delay: 0.05, label: 'pre->post1', preLoc: 0.5, hObj: NetCon[6]},
#   {preGid: 100, sec: 'apic_29', loc: 0.44951987532542587, synMech: 'INH:L5_PC1', weight: 0.75, delay: 0.05, label: 'pre->post1', preLoc: 0.5, hObj: NetCon[7]},
#   {preGid: 100, sec: 'apic_49', loc: 0.21125592979809868, synMech: 'INH:L5_PC1', weight: 0.75, delay: 0.05, label: 'pre->post1', preLoc: 0.5, hObj: NetCon[8]},
#   {preGid: 100, sec: 'apic_59', loc: 0.42437598641750396, synMech: 'INH:L5_PC1', weight: 0.75, delay: 0.05, label: 'pre->post1', preLoc: 0.5, hObj: NetCon[9]},
#   {preGid: 100, sec: 'dend_25', loc: 0.846571979892838, synMech: 'INH:L5_PC1', weight: 0.75, delay: 0.05, label: 'pre->post1', preLoc: 0.5, hObj: NetCon[10]},
#   {preGid: 100, sec: 'dend_2', loc: 0.9073483565570096, synMech: 'INH:L5_PC1', weight: 0.75, delay: 0.05, label: 'pre->post1', preLoc: 0.5, hObj: NetCon[11]},
#   {preGid: 100, sec: 'apic_35', loc: 0.7294624563517841, synMech: 'INH:L5_PC1', weight: 0.75, delay: 0.05, label: 'pre->post1', preLoc: 0.5, hObj: NetCon[12]},
#   {preGid: 100, sec: 'apic_60', loc: 0.11366161077695931, synMech: 'INH:L5_PC1', weight: 0.75, delay: 0.05, label: 'pre->post1', preLoc: 0.5, hObj: NetCon[13]},
#   {preGid: 100, sec: 'apic_63', loc: 0.8460351184092038, synMech: 'INH:L5_PC1', weight: 0.75, delay: 0.05, label: 'pre->post1', preLoc: 0.5, hObj: NetCon[14]}],
#  [{preGid: 100, sec: 'dend_20', loc: 0.4287232996099096, synMech: 'INH:L5_PC2', weight: 0.75, delay: 0.05, label: 'pre->post2', preLoc: 0.5, hObj: NetCon[15]},
#   {preGid: 100, sec: 'apic_38', loc: 0.12734680443268848, synMech: 'INH:L5_PC2', weight: 0.75, delay: 0.05, label: 'pre->post2', preLoc: 0.5, hObj: NetCon[16]},
#   {preGid: 100, sec: 'apic_20', loc: 0.1572446112908221, synMech: 'INH:L5_PC2', weight: 0.75, delay: 0.05, label: 'pre->post2', preLoc: 0.5, hObj: NetCon[17]},
#   {preGid: 100, sec: 'apic_10', loc: 0.05536119813939879, synMech: 'INH:L5_PC2', weight: 0.75, delay: 0.05, label: 'pre->post2', preLoc: 0.5, hObj: NetCon[18]},
#   {preGid: 100, sec: 'apic_34', loc: 0.5660152715230539, synMech: 'INH:L5_PC2', weight: 0.75, delay: 0.05, label: 'pre->post2', preLoc: 0.5, hObj: NetCon[19]},
#   {preGid: 100, sec: 'apic_50', loc: 0.3780892705263745, synMech: 'INH:L5_PC2', weight: 0.75, delay: 0.05, label: 'pre->post2', preLoc: 0.5, hObj: NetCon[20]},
#   {preGid: 100, sec: 'apic_59', loc: 0.12477505915012062, synMech: 'INH:L5_PC2', weight: 0.75, delay: 0.05, label: 'pre->post2', preLoc: 0.5, hObj: NetCon[21]},
#   {preGid: 100, sec: 'apic_49', loc: 0.508611790769692, synMech: 'INH:L5_PC2', weight: 0.75, delay: 0.05, label: 'pre->post2', preLoc: 0.5, hObj: NetCon[22]},
#   {preGid: 100, sec: 'dend_22', loc: 0.8507579471514605, synMech: 'INH:L5_PC2', weight: 0.75, delay: 0.05, label: 'pre->post2', preLoc: 0.5, hObj: NetCon[23]},
#   {preGid: 100, sec: 'apic_18', loc: 0.6658001306116109, synMech: 'INH:L5_PC2', weight: 0.75, delay: 0.05, label: 'pre->post2', preLoc: 0.5, hObj: NetCon[24]},
#   {preGid: 100, sec: 'dend_2', loc: 0.5678199356056219, synMech: 'INH:L5_PC2', weight: 0.75, delay: 0.05, label: 'pre->post2', preLoc: 0.5, hObj: NetCon[25]},
#   {preGid: 100, sec: 'dend_1', loc: 0.8590533136984135, synMech: 'INH:L5_PC2', weight: 0.75, delay: 0.05, label: 'pre->post2', preLoc: 0.5, hObj: NetCon[26]},
#   {preGid: 100, sec: 'apic_66', loc: 0.23713175029983366, synMech: 'INH:L5_PC2', weight: 0.75, delay: 0.05, label: 'pre->post2', preLoc: 0.5, hObj: NetCon[27]},
#   {preGid: 100, sec: 'dend_9', loc: 0.3253347826697227, synMech: 'INH:L5_PC2', weight: 0.75, delay: 0.05, label: 'pre->post2', preLoc: 0.5, hObj: NetCon[28]},
#   {preGid: 100, sec: 'apic_60', loc: 0.5286802403571234, synMech: 'INH:L5_PC2', weight: 0.75, delay: 0.05, label: 'pre->post2', preLoc: 0.5, hObj: NetCon[29]}],
#  [{preGid: 100, sec: 'dend_10', loc: 0.08554320606956921, synMech: 'INH:L5_PC3', weight: 0.75, delay: 0.05, label: 'pre->post3', preLoc: 0.5, hObj: NetCon[30]},
#   {preGid: 100, sec: 'apic_11', loc: 0.5910020233920218, synMech: 'INH:L5_PC3', weight: 0.75, delay: 0.05, label: 'pre->post3', preLoc: 0.5, hObj: NetCon[31]},
#   {preGid: 100, sec: 'dend_22', loc: 0.9984368250009895, synMech: 'INH:L5_PC3', weight: 0.75, delay: 0.05, label: 'pre->post3', preLoc: 0.5, hObj: NetCon[32]},
#   {preGid: 100, sec: 'apic_29', loc: 0.11896717761656847, synMech: 'INH:L5_PC3', weight: 0.75, delay: 0.05, label: 'pre->post3', preLoc: 0.5, hObj: NetCon[33]},
#   {preGid: 100, sec: 'apic_14', loc: 0.8072339833800102, synMech: 'INH:L5_PC3', weight: 0.75, delay: 0.05, label: 'pre->post3', preLoc: 0.5, hObj: NetCon[34]},
#   {preGid: 100, sec: 'apic_20', loc: 0.3490156017426893, synMech: 'INH:L5_PC3', weight: 0.75, delay: 0.05, label: 'pre->post3', preLoc: 0.5, hObj: NetCon[35]},
#   {preGid: 100, sec: 'dend_20', loc: 0.22539115361579173, synMech: 'INH:L5_PC3', weight: 0.75, delay: 0.05, label: 'pre->post3', preLoc: 0.5, hObj: NetCon[36]},
#   {preGid: 100, sec: 'apic_50', loc: 0.9093903234235882, synMech: 'INH:L5_PC3', weight: 0.75, delay: 0.05, label: 'pre->post3', preLoc: 0.5, hObj: NetCon[37]},
#   {preGid: 100, sec: 'apic_51', loc: 0.6977192811007119, synMech: 'INH:L5_PC3', weight: 0.75, delay: 0.05, label: 'pre->post3', preLoc: 0.5, hObj: NetCon[38]},
#   {preGid: 100, sec: 'dend_36', loc: 0.6848740248384872, synMech: 'INH:L5_PC3', weight: 0.75, delay: 0.05, label: 'pre->post3', preLoc: 0.5, hObj: NetCon[39]},
#   {preGid: 100, sec: 'dend_21', loc: 0.7072981046021993, synMech: 'INH:L5_PC3', weight: 0.75, delay: 0.05, label: 'pre->post3', preLoc: 0.5, hObj: NetCon[40]},
#   {preGid: 100, sec: 'dend_40', loc: 0.1825917849358141, synMech: 'INH:L5_PC3', weight: 0.75, delay: 0.05, label: 'pre->post3', preLoc: 0.5, hObj: NetCon[41]},
#   {preGid: 100, sec: 'dend_16', loc: 0.26679173203282414, synMech: 'INH:L5_PC3', weight: 0.75, delay: 0.05, label: 'pre->post3', preLoc: 0.5, hObj: NetCon[42]},
#   {preGid: 100, sec: 'dend_2', loc: 0.5285207456517388, synMech: 'INH:L5_PC3', weight: 0.75, delay: 0.05, label: 'pre->post3', preLoc: 0.5, hObj: NetCon[43]},
#   {preGid: 100, sec: 'apic_18', loc: 0.46192572054215253, synMech: 'INH:L5_PC3', weight: 0.75, delay: 0.05, label: 'pre->post3', preLoc: 0.5, hObj: NetCon[44]}],
#  [{preGid: 100, sec: 'apic_22', loc: 0.5370695380451795, synMech: 'INH:L5_PC4', weight: 0.75, delay: 0.05, label: 'pre->post4', preLoc: 0.5, hObj: NetCon[45]},
#   {preGid: 100, sec: 'apic_15', loc: 0.6047985003647071, synMech: 'INH:L5_PC4', weight: 0.75, delay: 0.05, label: 'pre->post4', preLoc: 0.5, hObj: NetCon[46]},
#   {preGid: 100, sec: 'dend_1', loc: 0.8668085203892776, synMech: 'INH:L5_PC4', weight: 0.75, delay: 0.05, label: 'pre->post4', preLoc: 0.5, hObj: NetCon[47]},
#   {preGid: 100, sec: 'apic_42', loc: 0.4833471642595519, synMech: 'INH:L5_PC4', weight: 0.75, delay: 0.05, label: 'pre->post4', preLoc: 0.5, hObj: NetCon[48]},
#   {preGid: 100, sec: 'apic_33', loc: 0.5748103555055456, synMech: 'INH:L5_PC4', weight: 0.75, delay: 0.05, label: 'pre->post4', preLoc: 0.5, hObj: NetCon[49]},
#   {preGid: 100, sec: 'dend_20', loc: 0.798808930223895, synMech: 'INH:L5_PC4', weight: 0.75, delay: 0.05, label: 'pre->post4', preLoc: 0.5, hObj: NetCon[50]},
#   {preGid: 100, sec: 'apic_59', loc: 0.31294951879593375, synMech: 'INH:L5_PC4', weight: 0.75, delay: 0.05, label: 'pre->post4', preLoc: 0.5, hObj: NetCon[51]},
#   {preGid: 100, sec: 'dend_38', loc: 0.38409826735148983, synMech: 'INH:L5_PC4', weight: 0.75, delay: 0.05, label: 'pre->post4', preLoc: 0.5, hObj: NetCon[52]},
#   {preGid: 100, sec: 'dend_21', loc: 0.16149926416978827, synMech: 'INH:L5_PC4', weight: 0.75, delay: 0.05, label: 'pre->post4', preLoc: 0.5, hObj: NetCon[53]},
#   {preGid: 100, sec: 'apic_12', loc: 0.9323543323401525, synMech: 'INH:L5_PC4', weight: 0.75, delay: 0.05, label: 'pre->post4', preLoc: 0.5, hObj: NetCon[54]},
#   {preGid: 100, sec: 'dend_2', loc: 0.6244013014543771, synMech: 'INH:L5_PC4', weight: 0.75, delay: 0.05, label: 'pre->post4', preLoc: 0.5, hObj: NetCon[55]},
#   {preGid: 100, sec: 'dend_40', loc: 0.28895540205985604, synMech: 'INH:L5_PC4', weight: 0.75, delay: 0.05, label: 'pre->post4', preLoc: 0.5, hObj: NetCon[56]},
#   {preGid: 100, sec: 'dend_19', loc: 0.4571162637127149, synMech: 'INH:L5_PC4', weight: 0.75, delay: 0.05, label: 'pre->post4', preLoc: 0.5, hObj: NetCon[57]},
#   {preGid: 100, sec: 'dend_16', loc: 0.108273467935155, synMech: 'INH:L5_PC4', weight: 0.75, delay: 0.05, label: 'pre->post4', preLoc: 0.5, hObj: NetCon[58]},
#   {preGid: 100, sec: 'dend_37', loc: 0.8109163714142099, synMech: 'INH:L5_PC4', weight: 0.75, delay: 0.05, label: 'pre->post4', preLoc: 0.5, hObj: NetCon[59]}],
#  [{preGid: 100, sec: 'dend_21', loc: 0.08193659091232379, synMech: 'INH:L5_PC5', weight: 0.75, delay: 0.05, label: 'pre->post5', preLoc: 0.5, hObj: NetCon[60]},
#   {preGid: 100, sec: 'dend_20', loc: 0.4780577203292425, synMech: 'INH:L5_PC5', weight: 0.75, delay: 0.05, label: 'pre->post5', preLoc: 0.5, hObj: NetCon[61]},
#   {preGid: 100, sec: 'apic_50', loc: 0.5307417018352807, synMech: 'INH:L5_PC5', weight: 0.75, delay: 0.05, label: 'pre->post5', preLoc: 0.5, hObj: NetCon[62]},
#   {preGid: 100, sec: 'apic_48', loc: 0.631371988963229, synMech: 'INH:L5_PC5', weight: 0.75, delay: 0.05, label: 'pre->post5', preLoc: 0.5, hObj: NetCon[63]},
#   {preGid: 100, sec: 'apic_18', loc: 0.5331343545754884, synMech: 'INH:L5_PC5', weight: 0.75, delay: 0.05, label: 'pre->post5', preLoc: 0.5, hObj: NetCon[64]},
#   {preGid: 100, sec: 'dend_41', loc: 0.49608404099512027, synMech: 'INH:L5_PC5', weight: 0.75, delay: 0.05, label: 'pre->post5', preLoc: 0.5, hObj: NetCon[65]},
#   {preGid: 100, sec: 'apic_33', loc: 0.3484609400489793, synMech: 'INH:L5_PC5', weight: 0.75, delay: 0.05, label: 'pre->post5', preLoc: 0.5, hObj: NetCon[66]},
#   {preGid: 100, sec: 'apic_60', loc: 0.871659694369473, synMech: 'INH:L5_PC5', weight: 0.75, delay: 0.05, label: 'pre->post5', preLoc: 0.5, hObj: NetCon[67]},
#   {preGid: 100, sec: 'apic_22', loc: 0.16821115946721052, synMech: 'INH:L5_PC5', weight: 0.75, delay: 0.05, label: 'pre->post5', preLoc: 0.5, hObj: NetCon[68]},
#   {preGid: 100, sec: 'apic_34', loc: 0.2798443217204141, synMech: 'INH:L5_PC5', weight: 0.75, delay: 0.05, label: 'pre->post5', preLoc: 0.5, hObj: NetCon[69]},
#   {preGid: 100, sec: 'apic_20', loc: 0.611952408996868, synMech: 'INH:L5_PC5', weight: 0.75, delay: 0.05, label: 'pre->post5', preLoc: 0.5, hObj: NetCon[70]},
#   {preGid: 100, sec: 'apic_66', loc: 0.2485407453872262, synMech: 'INH:L5_PC5', weight: 0.75, delay: 0.05, label: 'pre->post5', preLoc: 0.5, hObj: NetCon[71]},
#   {preGid: 100, sec: 'dend_2', loc: 0.7083254824476294, synMech: 'INH:L5_PC5', weight: 0.75, delay: 0.05, label: 'pre->post5', preLoc: 0.5, hObj: NetCon[72]},
#   {preGid: 100, sec: 'dend_6', loc: 0.5265317443506888, synMech: 'INH:L5_PC5', weight: 0.75, delay: 0.05, label: 'pre->post5', preLoc: 0.5, hObj: NetCon[73]},
#   {preGid: 100, sec: 'apic_36', loc: 0.2343954569375135, synMech: 'INH:L5_PC5', weight: 0.75, delay: 0.05, label: 'pre->post5', preLoc: 0.5, hObj: NetCon[74]}],
#  [{preGid: 100, sec: 'apic_19', loc: 0.26525716418755607, synMech: 'INH:L5_PC6', weight: 0.75, delay: 0.05, label: 'pre->post6', preLoc: 0.5, hObj: NetCon[75]},
#   {preGid: 100, sec: 'dend_12', loc: 0.6460562721726206, synMech: 'INH:L5_PC6', weight: 0.75, delay: 0.05, label: 'pre->post6', preLoc: 0.5, hObj: NetCon[76]},
#   {preGid: 100, sec: 'dend_23', loc: 0.8792790626764684, synMech: 'INH:L5_PC6', weight: 0.75, delay: 0.05, label: 'pre->post6', preLoc: 0.5, hObj: NetCon[77]},
#   {preGid: 100, sec: 'dend_32', loc: 0.7402207154521806, synMech: 'INH:L5_PC6', weight: 0.75, delay: 0.05, label: 'pre->post6', preLoc: 0.5, hObj: NetCon[78]},
#   {preGid: 100, sec: 'apic_50', loc: 0.6632038811785222, synMech: 'INH:L5_PC6', weight: 0.75, delay: 0.05, label: 'pre->post6', preLoc: 0.5, hObj: NetCon[79]},
#   {preGid: 100, sec: 'apic_21', loc: 0.7948777571023542, synMech: 'INH:L5_PC6', weight: 0.75, delay: 0.05, label: 'pre->post6', preLoc: 0.5, hObj: NetCon[80]},
#   {preGid: 100, sec: 'dend_29', loc: 0.5869299500026894, synMech: 'INH:L5_PC6', weight: 0.75, delay: 0.05, label: 'pre->post6', preLoc: 0.5, hObj: NetCon[81]},
#   {preGid: 100, sec: 'apic_7', loc: 0.24645942966621112, synMech: 'INH:L5_PC6', weight: 0.75, delay: 0.05, label: 'pre->post6', preLoc: 0.5, hObj: NetCon[82]},
#   {preGid: 100, sec: 'apic_30', loc: 0.7105579572399774, synMech: 'INH:L5_PC6', weight: 0.75, delay: 0.05, label: 'pre->post6', preLoc: 0.5, hObj: NetCon[83]},
#   {preGid: 100, sec: 'dend_45', loc: 0.4131768519616261, synMech: 'INH:L5_PC6', weight: 0.75, delay: 0.05, label: 'pre->post6', preLoc: 0.5, hObj: NetCon[84]},
#   {preGid: 100, sec: 'dend_26', loc: 0.8482766499057829, synMech: 'INH:L5_PC6', weight: 0.75, delay: 0.05, label: 'pre->post6', preLoc: 0.5, hObj: NetCon[85]},
#   {preGid: 100, sec: 'dend_16', loc: 0.008661894824887153, synMech: 'INH:L5_PC6', weight: 0.75, delay: 0.05, label: 'pre->post6', preLoc: 0.5, hObj: NetCon[86]},
#   {preGid: 100, sec: 'dend_3', loc: 0.858437379146239, synMech: 'INH:L5_PC6', weight: 0.75, delay: 0.05, label: 'pre->post6', preLoc: 0.5, hObj: NetCon[87]},
#   {preGid: 100, sec: 'apic_31', loc: 0.1444878757742044, synMech: 'INH:L5_PC6', weight: 0.75, delay: 0.05, label: 'pre->post6', preLoc: 0.5, hObj: NetCon[88]},
#   {preGid: 100, sec: 'apic_1', loc: 0.6270987936527367, synMech: 'INH:L5_PC6', weight: 0.75, delay: 0.05, label: 'pre->post6', preLoc: 0.5, hObj: NetCon[89]}],
#  [{preGid: 100, sec: 'apic_37', loc: 0.8663697600010338, synMech: 'INH:L5_PC7', weight: 0.75, delay: 0.05, label: 'pre->post7', preLoc: 0.5, hObj: NetCon[90]},
#   {preGid: 100, sec: 'dend_23', loc: 0.8096266384874096, synMech: 'INH:L5_PC7', weight: 0.75, delay: 0.05, label: 'pre->post7', preLoc: 0.5, hObj: NetCon[91]},
#   {preGid: 100, sec: 'apic_31', loc: 0.03816992233406163, synMech: 'INH:L5_PC7', weight: 0.75, delay: 0.05, label: 'pre->post7', preLoc: 0.5, hObj: NetCon[92]},
#   {preGid: 100, sec: 'apic_19', loc: 0.5875864791179104, synMech: 'INH:L5_PC7', weight: 0.75, delay: 0.05, label: 'pre->post7', preLoc: 0.5, hObj: NetCon[93]},
#   {preGid: 100, sec: 'dend_1', loc: 0.4708815827785095, synMech: 'INH:L5_PC7', weight: 0.75, delay: 0.05, label: 'pre->post7', preLoc: 0.5, hObj: NetCon[94]},
#   {preGid: 100, sec: 'apic_23', loc: 0.8276405694303512, synMech: 'INH:L5_PC7', weight: 0.75, delay: 0.05, label: 'pre->post7', preLoc: 0.5, hObj: NetCon[95]},
#   {preGid: 100, sec: 'apic_45', loc: 0.16121935245535945, synMech: 'INH:L5_PC7', weight: 0.75, delay: 0.05, label: 'pre->post7', preLoc: 0.5, hObj: NetCon[96]},
#   {preGid: 100, sec: 'dend_12', loc: 0.6715678430521551, synMech: 'INH:L5_PC7', weight: 0.75, delay: 0.05, label: 'pre->post7', preLoc: 0.5, hObj: NetCon[97]},
#   {preGid: 100, sec: 'dend_17', loc: 0.12413187031737404, synMech: 'INH:L5_PC7', weight: 0.75, delay: 0.05, label: 'pre->post7', preLoc: 0.5, hObj: NetCon[98]},
#   {preGid: 100, sec: 'dend_26', loc: 0.12585109872815697, synMech: 'INH:L5_PC7', weight: 0.75, delay: 0.05, label: 'pre->post7', preLoc: 0.5, hObj: NetCon[99]},
#   {preGid: 100, sec: 'apic_13', loc: 0.5138361373804586, synMech: 'INH:L5_PC7', weight: 0.75, delay: 0.05, label: 'pre->post7', preLoc: 0.5, hObj: NetCon[100]},
#   {preGid: 100, sec: 'dend_45', loc: 0.03365119446767104, synMech: 'INH:L5_PC7', weight: 0.75, delay: 0.05, label: 'pre->post7', preLoc: 0.5, hObj: NetCon[101]},
#   {preGid: 100, sec: 'dend_9', loc: 0.6157671021572052, synMech: 'INH:L5_PC7', weight: 0.75, delay: 0.05, label: 'pre->post7', preLoc: 0.5, hObj: NetCon[102]},
#   {preGid: 100, sec: 'apic_7', loc: 0.3804649789805055, synMech: 'INH:L5_PC7', weight: 0.75, delay: 0.05, label: 'pre->post7', preLoc: 0.5, hObj: NetCon[103]},
#   {preGid: 100, sec: 'dend_20', loc: 0.40392631496390063, synMech: 'INH:L5_PC7', weight: 0.75, delay: 0.05, label: 'pre->post7', preLoc: 0.5, hObj: NetCon[104]}],
#  [{preGid: 100, sec: 'apic_29', loc: 0.625535496356452, synMech: 'INH:L5_PC8', weight: 0.75, delay: 0.05, label: 'pre->post8', preLoc: 0.5, hObj: NetCon[105]},
#   {preGid: 100, sec: 'dend_45', loc: 0.05712562833552022, synMech: 'INH:L5_PC8', weight: 0.75, delay: 0.05, label: 'pre->post8', preLoc: 0.5, hObj: NetCon[106]},
#   {preGid: 100, sec: 'dend_5', loc: 0.2653036315853225, synMech: 'INH:L5_PC8', weight: 0.75, delay: 0.05, label: 'pre->post8', preLoc: 0.5, hObj: NetCon[107]},
#   {preGid: 100, sec: 'apic_53', loc: 0.9633715426804387, synMech: 'INH:L5_PC8', weight: 0.75, delay: 0.05, label: 'pre->post8', preLoc: 0.5, hObj: NetCon[108]},
#   {preGid: 100, sec: 'apic_45', loc: 0.67172494278126, synMech: 'INH:L5_PC8', weight: 0.75, delay: 0.05, label: 'pre->post8', preLoc: 0.5, hObj: NetCon[109]},
#   {preGid: 100, sec: 'apic_39', loc: 0.7358003832788407, synMech: 'INH:L5_PC8', weight: 0.75, delay: 0.05, label: 'pre->post8', preLoc: 0.5, hObj: NetCon[110]},
#   {preGid: 100, sec: 'apic_23', loc: 0.18621166639521783, synMech: 'INH:L5_PC8', weight: 0.75, delay: 0.05, label: 'pre->post8', preLoc: 0.5, hObj: NetCon[111]},
#   {preGid: 100, sec: 'apic_9', loc: 0.16241333599043384, synMech: 'INH:L5_PC8', weight: 0.75, delay: 0.05, label: 'pre->post8', preLoc: 0.5, hObj: NetCon[112]},
#   {preGid: 100, sec: 'dend_26', loc: 0.49663746049586904, synMech: 'INH:L5_PC8', weight: 0.75, delay: 0.05, label: 'pre->post8', preLoc: 0.5, hObj: NetCon[113]},
#   {preGid: 100, sec: 'dend_44', loc: 0.20493546075880825, synMech: 'INH:L5_PC8', weight: 0.75, delay: 0.05, label: 'pre->post8', preLoc: 0.5, hObj: NetCon[114]},
#   {preGid: 100, sec: 'apic_44', loc: 0.8818237425111428, synMech: 'INH:L5_PC8', weight: 0.75, delay: 0.05, label: 'pre->post8', preLoc: 0.5, hObj: NetCon[115]},
#   {preGid: 100, sec: 'dend_27', loc: 0.6871917001192278, synMech: 'INH:L5_PC8', weight: 0.75, delay: 0.05, label: 'pre->post8', preLoc: 0.5, hObj: NetCon[116]},
#   {preGid: 100, sec: 'apic_36', loc: 0.761715481723143, synMech: 'INH:L5_PC8', weight: 0.75, delay: 0.05, label: 'pre->post8', preLoc: 0.5, hObj: NetCon[117]},
#   {preGid: 100, sec: 'dend_36', loc: 0.8962238599350358, synMech: 'INH:L5_PC8', weight: 0.75, delay: 0.05, label: 'pre->post8', preLoc: 0.5, hObj: NetCon[118]},
#   {preGid: 100, sec: 'dend_43', loc: 0.6945190206740304, synMech: 'INH:L5_PC8', weight: 0.75, delay: 0.05, label: 'pre->post8', preLoc: 0.5, hObj: NetCon[119]}],
#  [{preGid: 100, sec: 'apic_29', loc: 0.9087352217086035, synMech: 'INH:L5_PC9', weight: 0.75, delay: 0.05, label: 'pre->post9', preLoc: 0.5, hObj: NetCon[120]},
#   {preGid: 100, sec: 'apic_7', loc: 0.46838291078748995, synMech: 'INH:L5_PC9', weight: 0.75, delay: 0.05, label: 'pre->post9', preLoc: 0.5, hObj: NetCon[121]},
#   {preGid: 100, sec: 'apic_31', loc: 0.4097269752692079, synMech: 'INH:L5_PC9', weight: 0.75, delay: 0.05, label: 'pre->post9', preLoc: 0.5, hObj: NetCon[122]},
#   {preGid: 100, sec: 'apic_4', loc: 0.4600214922692125, synMech: 'INH:L5_PC9', weight: 0.75, delay: 0.05, label: 'pre->post9', preLoc: 0.5, hObj: NetCon[123]},
#   {preGid: 100, sec: 'dend_6', loc: 0.5032097005895736, synMech: 'INH:L5_PC9', weight: 0.75, delay: 0.05, label: 'pre->post9', preLoc: 0.5, hObj: NetCon[124]},
#   {preGid: 100, sec: 'apic_34', loc: 0.6449426049172707, synMech: 'INH:L5_PC9', weight: 0.75, delay: 0.05, label: 'pre->post9', preLoc: 0.5, hObj: NetCon[125]},
#   {preGid: 100, sec: 'apic_45', loc: 0.5481688493834559, synMech: 'INH:L5_PC9', weight: 0.75, delay: 0.05, label: 'pre->post9', preLoc: 0.5, hObj: NetCon[126]},
#   {preGid: 100, sec: 'apic_5', loc: 0.051463924616473325, synMech: 'INH:L5_PC9', weight: 0.75, delay: 0.05, label: 'pre->post9', preLoc: 0.5, hObj: NetCon[127]},
#   {preGid: 100, sec: 'apic_12', loc: 0.9100594511922716, synMech: 'INH:L5_PC9', weight: 0.75, delay: 0.05, label: 'pre->post9', preLoc: 0.5, hObj: NetCon[128]},
#   {preGid: 100, sec: 'dend_12', loc: 0.6753835004295083, synMech: 'INH:L5_PC9', weight: 0.75, delay: 0.05, label: 'pre->post9', preLoc: 0.5, hObj: NetCon[129]},
#   {preGid: 100, sec: 'apic_16', loc: 0.7694812260837504, synMech: 'INH:L5_PC9', weight: 0.75, delay: 0.05, label: 'pre->post9', preLoc: 0.5, hObj: NetCon[130]},
#   {preGid: 100, sec: 'dend_27', loc: 0.02971926220651763, synMech: 'INH:L5_PC9', weight: 0.75, delay: 0.05, label: 'pre->post9', preLoc: 0.5, hObj: NetCon[131]},
#   {preGid: 100, sec: 'dend_11', loc: 0.1554453439361268, synMech: 'INH:L5_PC9', weight: 0.75, delay: 0.05, label: 'pre->post9', preLoc: 0.5, hObj: NetCon[132]},
#   {preGid: 100, sec: 'dend_17', loc: 0.5613178421608294, synMech: 'INH:L5_PC9', weight: 0.75, delay: 0.05, label: 'pre->post9', preLoc: 0.5, hObj: NetCon[133]},
#   {preGid: 100, sec: 'apic_44', loc: 0.2191913459220555, synMech: 'INH:L5_PC9', weight: 0.75, delay: 0.05, label: 'pre->post9', preLoc: 0.5, hObj: NetCon[134]}],
#  [{preGid: 100, sec: 'apic_7', loc: 0.3198517223517407, synMech: 'INH:L5_PC10', weight: 0.75, delay: 0.05, label: 'pre->post10', preLoc: 0.5, hObj: NetCon[135]},
#   {preGid: 100, sec: 'dend_14', loc: 0.49537477599671376, synMech: 'INH:L5_PC10', weight: 0.75, delay: 0.05, label: 'pre->post10', preLoc: 0.5, hObj: NetCon[136]},
#   {preGid: 100, sec: 'apic_27', loc: 0.2636806970566747, synMech: 'INH:L5_PC10', weight: 0.75, delay: 0.05, label: 'pre->post10', preLoc: 0.5, hObj: NetCon[137]},
#   {preGid: 100, sec: 'apic_9', loc: 0.814016330149436, synMech: 'INH:L5_PC10', weight: 0.75, delay: 0.05, label: 'pre->post10', preLoc: 0.5, hObj: NetCon[138]},
#   {preGid: 100, sec: 'dend_33', loc: 0.42793381610995634, synMech: 'INH:L5_PC10', weight: 0.75, delay: 0.05, label: 'pre->post10', preLoc: 0.5, hObj: NetCon[139]},
#   {preGid: 100, sec: 'dend_30', loc: 0.47093996106000285, synMech: 'INH:L5_PC10', weight: 0.75, delay: 0.05, label: 'pre->post10', preLoc: 0.5, hObj: NetCon[140]},
#   {preGid: 100, sec: 'dend_41', loc: 0.07054213242195706, synMech: 'INH:L5_PC10', weight: 0.75, delay: 0.05, label: 'pre->post10', preLoc: 0.5, hObj: NetCon[141]},
#   {preGid: 100, sec: 'dend_17', loc: 0.9680801668518131, synMech: 'INH:L5_PC10', weight: 0.75, delay: 0.05, label: 'pre->post10', preLoc: 0.5, hObj: NetCon[142]},
#   {preGid: 100, sec: 'apic_31', loc: 0.7330698597599234, synMech: 'INH:L5_PC10', weight: 0.75, delay: 0.05, label: 'pre->post10', preLoc: 0.5, hObj: NetCon[143]},
#   {preGid: 100, sec: 'apic_43', loc: 0.7169423489127466, synMech: 'INH:L5_PC10', weight: 0.75, delay: 0.05, label: 'pre->post10', preLoc: 0.5, hObj: NetCon[144]},
#   {preGid: 100, sec: 'apic_44', loc: 0.25570604393258317, synMech: 'INH:L5_PC10', weight: 0.75, delay: 0.05, label: 'pre->post10', preLoc: 0.5, hObj: NetCon[145]},
#   {preGid: 100, sec: 'apic_40', loc: 0.7161497190793128, synMech: 'INH:L5_PC10', weight: 0.75, delay: 0.05, label: 'pre->post10', preLoc: 0.5, hObj: NetCon[146]},
#   {preGid: 100, sec: 'apic_19', loc: 0.05729248566765651, synMech: 'INH:L5_PC10', weight: 0.75, delay: 0.05, label: 'pre->post10', preLoc: 0.5, hObj: NetCon[147]},
#   {preGid: 100, sec: 'apic_49', loc: 0.6353276775163668, synMech: 'INH:L5_PC10', weight: 0.75, delay: 0.05, label: 'pre->post10', preLoc: 0.5, hObj: NetCon[148]},
#   {preGid: 100, sec: 'dend_11', loc: 0.0410981880020492, synMech: 'INH:L5_PC10', weight: 0.75, delay: 0.05, label: 'pre->post10', preLoc: 0.5, hObj: NetCon[149]}],
#  [{preGid: 100, sec: 'apic_46', loc: 0.1841727888985923, synMech: 'INH:L5_PC11', weight: 0.75, delay: 0.05, label: 'pre->post11', preLoc: 0.5, hObj: NetCon[150]},
#   {preGid: 100, sec: 'apic_9', loc: 0.4018430305565344, synMech: 'INH:L5_PC11', weight: 0.75, delay: 0.05, label: 'pre->post11', preLoc: 0.5, hObj: NetCon[151]},
#   {preGid: 100, sec: 'apic_3', loc: 0.8146178237394559, synMech: 'INH:L5_PC11', weight: 0.75, delay: 0.05, label: 'pre->post11', preLoc: 0.5, hObj: NetCon[152]},
#   {preGid: 100, sec: 'dend_48', loc: 0.013915644520600482, synMech: 'INH:L5_PC11', weight: 0.75, delay: 0.05, label: 'pre->post11', preLoc: 0.5, hObj: NetCon[153]},
#   {preGid: 100, sec: 'dend_12', loc: 0.1445579252192071, synMech: 'INH:L5_PC11', weight: 0.75, delay: 0.05, label: 'pre->post11', preLoc: 0.5, hObj: NetCon[154]},
#   {preGid: 100, sec: 'dend_52', loc: 0.631222166840516, synMech: 'INH:L5_PC11', weight: 0.75, delay: 0.05, label: 'pre->post11', preLoc: 0.5, hObj: NetCon[155]},
#   {preGid: 100, sec: 'apic_29', loc: 0.66571011276363, synMech: 'INH:L5_PC11', weight: 0.75, delay: 0.05, label: 'pre->post11', preLoc: 0.5, hObj: NetCon[156]},
#   {preGid: 100, sec: 'apic_62', loc: 0.057087847707819855, synMech: 'INH:L5_PC11', weight: 0.75, delay: 0.05, label: 'pre->post11', preLoc: 0.5, hObj: NetCon[157]},
#   {preGid: 100, sec: 'dend_32', loc: 0.28160675139519065, synMech: 'INH:L5_PC11', weight: 0.75, delay: 0.05, label: 'pre->post11', preLoc: 0.5, hObj: NetCon[158]},
#   {preGid: 100, sec: 'dend_14', loc: 0.3301521582051217, synMech: 'INH:L5_PC11', weight: 0.75, delay: 0.05, label: 'pre->post11', preLoc: 0.5, hObj: NetCon[159]},
#   {preGid: 100, sec: 'apic_8', loc: 0.5310097262092986, synMech: 'INH:L5_PC11', weight: 0.75, delay: 0.05, label: 'pre->post11', preLoc: 0.5, hObj: NetCon[160]},
#   {preGid: 100, sec: 'apic_61', loc: 0.09196252017539824, synMech: 'INH:L5_PC11', weight: 0.75, delay: 0.05, label: 'pre->post11', preLoc: 0.5, hObj: NetCon[161]},
#   {preGid: 100, sec: 'dend_7', loc: 0.603100887827008, synMech: 'INH:L5_PC11', weight: 0.75, delay: 0.05, label: 'pre->post11', preLoc: 0.5, hObj: NetCon[162]},
#   {preGid: 100, sec: 'apic_24', loc: 0.9421753048677329, synMech: 'INH:L5_PC11', weight: 0.75, delay: 0.05, label: 'pre->post11', preLoc: 0.5, hObj: NetCon[163]},
#   {preGid: 100, sec: 'apic_66', loc: 0.38567132222982886, synMech: 'INH:L5_PC11', weight: 0.75, delay: 0.05, label: 'pre->post11', preLoc: 0.5, hObj: NetCon[164]}],
#  [{preGid: 100, sec: 'apic_43', loc: 0.40746688720696994, synMech: 'INH:L5_PC12', weight: 0.75, delay: 0.05, label: 'pre->post12', preLoc: 0.5, hObj: NetCon[165]},
#   {preGid: 100, sec: 'dend_26', loc: 0.7481311646545051, synMech: 'INH:L5_PC12', weight: 0.75, delay: 0.05, label: 'pre->post12', preLoc: 0.5, hObj: NetCon[166]},
#   {preGid: 100, sec: 'dend_53', loc: 0.11708266465873249, synMech: 'INH:L5_PC12', weight: 0.75, delay: 0.05, label: 'pre->post12', preLoc: 0.5, hObj: NetCon[167]},
#   {preGid: 100, sec: 'apic_47', loc: 0.7357184828277533, synMech: 'INH:L5_PC12', weight: 0.75, delay: 0.05, label: 'pre->post12', preLoc: 0.5, hObj: NetCon[168]},
#   {preGid: 100, sec: 'apic_36', loc: 0.6823488489608855, synMech: 'INH:L5_PC12', weight: 0.75, delay: 0.05, label: 'pre->post12', preLoc: 0.5, hObj: NetCon[169]},
#   {preGid: 100, sec: 'apic_44', loc: 0.7732624167142481, synMech: 'INH:L5_PC12', weight: 0.75, delay: 0.05, label: 'pre->post12', preLoc: 0.5, hObj: NetCon[170]},
#   {preGid: 100, sec: 'apic_29', loc: 0.6430481161278934, synMech: 'INH:L5_PC12', weight: 0.75, delay: 0.05, label: 'pre->post12', preLoc: 0.5, hObj: NetCon[171]},
#   {preGid: 100, sec: 'dend_40', loc: 0.1292588309647951, synMech: 'INH:L5_PC12', weight: 0.75, delay: 0.05, label: 'pre->post12', preLoc: 0.5, hObj: NetCon[172]},
#   {preGid: 100, sec: 'apic_9', loc: 0.6919818316399355, synMech: 'INH:L5_PC12', weight: 0.75, delay: 0.05, label: 'pre->post12', preLoc: 0.5, hObj: NetCon[173]},
#   {preGid: 100, sec: 'apic_24', loc: 0.10364705630536095, synMech: 'INH:L5_PC12', weight: 0.75, delay: 0.05, label: 'pre->post12', preLoc: 0.5, hObj: NetCon[174]},
#   {preGid: 100, sec: 'apic_22', loc: 0.6290969284608957, synMech: 'INH:L5_PC12', weight: 0.75, delay: 0.05, label: 'pre->post12', preLoc: 0.5, hObj: NetCon[175]},
#   {preGid: 100, sec: 'apic_46', loc: 0.9543148664218865, synMech: 'INH:L5_PC12', weight: 0.75, delay: 0.05, label: 'pre->post12', preLoc: 0.5, hObj: NetCon[176]},
#   {preGid: 100, sec: 'dend_24', loc: 0.12072189025535278, synMech: 'INH:L5_PC12', weight: 0.75, delay: 0.05, label: 'pre->post12', preLoc: 0.5, hObj: NetCon[177]},
#   {preGid: 100, sec: 'dend_44', loc: 0.858901612948673, synMech: 'INH:L5_PC12', weight: 0.75, delay: 0.05, label: 'pre->post12', preLoc: 0.5, hObj: NetCon[178]},
#   {preGid: 100, sec: 'dend_48', loc: 0.2356079453753891, synMech: 'INH:L5_PC12', weight: 0.75, delay: 0.05, label: 'pre->post12', preLoc: 0.5, hObj: NetCon[179]}],
#  [{preGid: 100, sec: 'apic_21', loc: 0.8301855148051578, synMech: 'INH:L5_PC13', weight: 0.75, delay: 0.05, label: 'pre->post13', preLoc: 0.5, hObj: NetCon[180]},
#   {preGid: 100, sec: 'apic_22', loc: 0.35093834315479217, synMech: 'INH:L5_PC13', weight: 0.75, delay: 0.05, label: 'pre->post13', preLoc: 0.5, hObj: NetCon[181]},
#   {preGid: 100, sec: 'apic_54', loc: 0.7185496397290461, synMech: 'INH:L5_PC13', weight: 0.75, delay: 0.05, label: 'pre->post13', preLoc: 0.5, hObj: NetCon[182]},
#   {preGid: 100, sec: 'apic_48', loc: 0.16867162676835873, synMech: 'INH:L5_PC13', weight: 0.75, delay: 0.05, label: 'pre->post13', preLoc: 0.5, hObj: NetCon[183]},
#   {preGid: 100, sec: 'dend_43', loc: 0.14795541799245263, synMech: 'INH:L5_PC13', weight: 0.75, delay: 0.05, label: 'pre->post13', preLoc: 0.5, hObj: NetCon[184]},
#   {preGid: 100, sec: 'apic_19', loc: 0.10559260617128398, synMech: 'INH:L5_PC13', weight: 0.75, delay: 0.05, label: 'pre->post13', preLoc: 0.5, hObj: NetCon[185]},
#   {preGid: 100, sec: 'apic_33', loc: 0.674563851271441, synMech: 'INH:L5_PC13', weight: 0.75, delay: 0.05, label: 'pre->post13', preLoc: 0.5, hObj: NetCon[186]},
#   {preGid: 100, sec: 'dend_51', loc: 0.879562683429672, synMech: 'INH:L5_PC13', weight: 0.75, delay: 0.05, label: 'pre->post13', preLoc: 0.5, hObj: NetCon[187]},
#   {preGid: 100, sec: 'dend_52', loc: 0.1915309485028419, synMech: 'INH:L5_PC13', weight: 0.75, delay: 0.05, label: 'pre->post13', preLoc: 0.5, hObj: NetCon[188]},
#   {preGid: 100, sec: 'apic_9', loc: 0.2007200603635879, synMech: 'INH:L5_PC13', weight: 0.75, delay: 0.05, label: 'pre->post13', preLoc: 0.5, hObj: NetCon[189]},
#   {preGid: 100, sec: 'dend_11', loc: 0.41356695302267893, synMech: 'INH:L5_PC13', weight: 0.75, delay: 0.05, label: 'pre->post13', preLoc: 0.5, hObj: NetCon[190]},
#   {preGid: 100, sec: 'apic_8', loc: 0.30922561345792904, synMech: 'INH:L5_PC13', weight: 0.75, delay: 0.05, label: 'pre->post13', preLoc: 0.5, hObj: NetCon[191]},
#   {preGid: 100, sec: 'apic_45', loc: 0.4547544649722126, synMech: 'INH:L5_PC13', weight: 0.75, delay: 0.05, label: 'pre->post13', preLoc: 0.5, hObj: NetCon[192]},
#   {preGid: 100, sec: 'apic_11', loc: 0.09846706145711452, synMech: 'INH:L5_PC13', weight: 0.75, delay: 0.05, label: 'pre->post13', preLoc: 0.5, hObj: NetCon[193]},
#   {preGid: 100, sec: 'apic_44', loc: 0.4471468380906446, synMech: 'INH:L5_PC13', weight: 0.75, delay: 0.05, label: 'pre->post13', preLoc: 0.5, hObj: NetCon[194]}],
#  [{preGid: 100, sec: 'apic_37', loc: 0.49372188372197207, synMech: 'INH:L5_PC14', weight: 0.75, delay: 0.05, label: 'pre->post14', preLoc: 0.5, hObj: NetCon[195]},
#   {preGid: 100, sec: 'apic_65', loc: 0.06334705123639735, synMech: 'INH:L5_PC14', weight: 0.75, delay: 0.05, label: 'pre->post14', preLoc: 0.5, hObj: NetCon[196]},
#   {preGid: 100, sec: 'apic_22', loc: 0.6873452528865107, synMech: 'INH:L5_PC14', weight: 0.75, delay: 0.05, label: 'pre->post14', preLoc: 0.5, hObj: NetCon[197]},
#   {preGid: 100, sec: 'apic_43', loc: 0.1234934279314603, synMech: 'INH:L5_PC14', weight: 0.75, delay: 0.05, label: 'pre->post14', preLoc: 0.5, hObj: NetCon[198]},
#   {preGid: 100, sec: 'apic_63', loc: 0.023588134409176228, synMech: 'INH:L5_PC14', weight: 0.75, delay: 0.05, label: 'pre->post14', preLoc: 0.5, hObj: NetCon[199]},
#   {preGid: 100, sec: 'apic_47', loc: 0.36804230720372927, synMech: 'INH:L5_PC14', weight: 0.75, delay: 0.05, label: 'pre->post14', preLoc: 0.5, hObj: NetCon[200]},
#   {preGid: 100, sec: 'apic_50', loc: 0.8083941660451767, synMech: 'INH:L5_PC14', weight: 0.75, delay: 0.05, label: 'pre->post14', preLoc: 0.5, hObj: NetCon[201]},
#   {preGid: 100, sec: 'apic_19', loc: 0.6312902617016821, synMech: 'INH:L5_PC14', weight: 0.75, delay: 0.05, label: 'pre->post14', preLoc: 0.5, hObj: NetCon[202]},
#   {preGid: 100, sec: 'apic_28', loc: 0.09258741420036698, synMech: 'INH:L5_PC14', weight: 0.75, delay: 0.05, label: 'pre->post14', preLoc: 0.5, hObj: NetCon[203]},
#   {preGid: 100, sec: 'dend_21', loc: 0.820086855623026, synMech: 'INH:L5_PC14', weight: 0.75, delay: 0.05, label: 'pre->post14', preLoc: 0.5, hObj: NetCon[204]},
#   {preGid: 100, sec: 'dend_24', loc: 0.7411374399112817, synMech: 'INH:L5_PC14', weight: 0.75, delay: 0.05, label: 'pre->post14', preLoc: 0.5, hObj: NetCon[205]},
#   {preGid: 100, sec: 'dend_18', loc: 0.9578107432860976, synMech: 'INH:L5_PC14', weight: 0.75, delay: 0.05, label: 'pre->post14', preLoc: 0.5, hObj: NetCon[206]},
#   {preGid: 100, sec: 'apic_32', loc: 0.07094562899264258, synMech: 'INH:L5_PC14', weight: 0.75, delay: 0.05, label: 'pre->post14', preLoc: 0.5, hObj: NetCon[207]},
#   {preGid: 100, sec: 'dend_59', loc: 0.31095658093143425, synMech: 'INH:L5_PC14', weight: 0.75, delay: 0.05, label: 'pre->post14', preLoc: 0.5, hObj: NetCon[208]},
#   {preGid: 100, sec: 'apic_15', loc: 0.4644664585598072, synMech: 'INH:L5_PC14', weight: 0.75, delay: 0.05, label: 'pre->post14', preLoc: 0.5, hObj: NetCon[209]}],
#  [{preGid: 100, sec: 'dend_43', loc: 0.9693211733462141, synMech: 'INH:L5_PC15', weight: 0.75, delay: 0.05, label: 'pre->post15', preLoc: 0.5, hObj: NetCon[210]},
#   {preGid: 100, sec: 'dend_27', loc: 0.6212848226866106, synMech: 'INH:L5_PC15', weight: 0.75, delay: 0.05, label: 'pre->post15', preLoc: 0.5, hObj: NetCon[211]},
#   {preGid: 100, sec: 'dend_59', loc: 0.5277156404632016, synMech: 'INH:L5_PC15', weight: 0.75, delay: 0.05, label: 'pre->post15', preLoc: 0.5, hObj: NetCon[212]},
#   {preGid: 100, sec: 'apic_65', loc: 0.6856814326352334, synMech: 'INH:L5_PC15', weight: 0.75, delay: 0.05, label: 'pre->post15', preLoc: 0.5, hObj: NetCon[213]},
#   {preGid: 100, sec: 'dend_45', loc: 0.1447604695921183, synMech: 'INH:L5_PC15', weight: 0.75, delay: 0.05, label: 'pre->post15', preLoc: 0.5, hObj: NetCon[214]},
#   {preGid: 100, sec: 'apic_22', loc: 0.8791775633410162, synMech: 'INH:L5_PC15', weight: 0.75, delay: 0.05, label: 'pre->post15', preLoc: 0.5, hObj: NetCon[215]},
#   {preGid: 100, sec: 'dend_42', loc: 0.0373960512543023, synMech: 'INH:L5_PC15', weight: 0.75, delay: 0.05, label: 'pre->post15', preLoc: 0.5, hObj: NetCon[216]},
#   {preGid: 100, sec: 'apic_45', loc: 0.9281822047699327, synMech: 'INH:L5_PC15', weight: 0.75, delay: 0.05, label: 'pre->post15', preLoc: 0.5, hObj: NetCon[217]},
#   {preGid: 100, sec: 'dend_37', loc: 0.23337681222088333, synMech: 'INH:L5_PC15', weight: 0.75, delay: 0.05, label: 'pre->post15', preLoc: 0.5, hObj: NetCon[218]},
#   {preGid: 100, sec: 'dend_16', loc: 0.4305147991717802, synMech: 'INH:L5_PC15', weight: 0.75, delay: 0.05, label: 'pre->post15', preLoc: 0.5, hObj: NetCon[219]},
#   {preGid: 100, sec: 'apic_18', loc: 0.5914779505167367, synMech: 'INH:L5_PC15', weight: 0.75, delay: 0.05, label: 'pre->post15', preLoc: 0.5, hObj: NetCon[220]},
#   {preGid: 100, sec: 'apic_47', loc: 0.5896094912687657, synMech: 'INH:L5_PC15', weight: 0.75, delay: 0.05, label: 'pre->post15', preLoc: 0.5, hObj: NetCon[221]},
#   {preGid: 100, sec: 'apic_46', loc: 0.7540270738054571, synMech: 'INH:L5_PC15', weight: 0.75, delay: 0.05, label: 'pre->post15', preLoc: 0.5, hObj: NetCon[222]},
#   {preGid: 100, sec: 'apic_57', loc: 0.4206943514647727, synMech: 'INH:L5_PC15', weight: 0.75, delay: 0.05, label: 'pre->post15', preLoc: 0.5, hObj: NetCon[223]},
#   {preGid: 100, sec: 'dend_55', loc: 0.8661126074782093, synMech: 'INH:L5_PC15', weight: 0.75, delay: 0.05, label: 'pre->post15', preLoc: 0.5, hObj: NetCon[224]}],
#  [{preGid: 100, sec: 'apic_47', loc: 0.04644312860988404, synMech: 'INH:L5_PC16', weight: 0.75, delay: 0.05, label: 'pre->post16', preLoc: 0.5, hObj: NetCon[225]},
#   {preGid: 100, sec: 'apic_38', loc: 0.7092113359194493, synMech: 'INH:L5_PC16', weight: 0.75, delay: 0.05, label: 'pre->post16', preLoc: 0.5, hObj: NetCon[226]},
#   {preGid: 100, sec: 'apic_7', loc: 0.8249497616456045, synMech: 'INH:L5_PC16', weight: 0.75, delay: 0.05, label: 'pre->post16', preLoc: 0.5, hObj: NetCon[227]},
#   {preGid: 100, sec: 'apic_49', loc: 0.8362003759573404, synMech: 'INH:L5_PC16', weight: 0.75, delay: 0.05, label: 'pre->post16', preLoc: 0.5, hObj: NetCon[228]},
#   {preGid: 100, sec: 'dend_23', loc: 0.8053508806920614, synMech: 'INH:L5_PC16', weight: 0.75, delay: 0.05, label: 'pre->post16', preLoc: 0.5, hObj: NetCon[229]},
#   {preGid: 100, sec: 'dend_17', loc: 0.5893591291501051, synMech: 'INH:L5_PC16', weight: 0.75, delay: 0.05, label: 'pre->post16', preLoc: 0.5, hObj: NetCon[230]},
#   {preGid: 100, sec: 'dend_30', loc: 0.4923048096013912, synMech: 'INH:L5_PC16', weight: 0.75, delay: 0.05, label: 'pre->post16', preLoc: 0.5, hObj: NetCon[231]},
#   {preGid: 100, sec: 'apic_53', loc: 0.3481383511397486, synMech: 'INH:L5_PC16', weight: 0.75, delay: 0.05, label: 'pre->post16', preLoc: 0.5, hObj: NetCon[232]},
#   {preGid: 100, sec: 'apic_31', loc: 0.5663346801736984, synMech: 'INH:L5_PC16', weight: 0.75, delay: 0.05, label: 'pre->post16', preLoc: 0.5, hObj: NetCon[233]},
#   {preGid: 100, sec: 'dend_13', loc: 0.030335647089577082, synMech: 'INH:L5_PC16', weight: 0.75, delay: 0.05, label: 'pre->post16', preLoc: 0.5, hObj: NetCon[234]},
#   {preGid: 100, sec: 'apic_33', loc: 0.4085591448258622, synMech: 'INH:L5_PC16', weight: 0.75, delay: 0.05, label: 'pre->post16', preLoc: 0.5, hObj: NetCon[235]},
#   {preGid: 100, sec: 'dend_22', loc: 0.39162158403533165, synMech: 'INH:L5_PC16', weight: 0.75, delay: 0.05, label: 'pre->post16', preLoc: 0.5, hObj: NetCon[236]},
#   {preGid: 100, sec: 'dend_20', loc: 0.6400085199874592, synMech: 'INH:L5_PC16', weight: 0.75, delay: 0.05, label: 'pre->post16', preLoc: 0.5, hObj: NetCon[237]},
#   {preGid: 100, sec: 'dend_27', loc: 0.39177828361187633, synMech: 'INH:L5_PC16', weight: 0.75, delay: 0.05, label: 'pre->post16', preLoc: 0.5, hObj: NetCon[238]},
#   {preGid: 100, sec: 'apic_29', loc: 0.40255988170166945, synMech: 'INH:L5_PC16', weight: 0.75, delay: 0.05, label: 'pre->post16', preLoc: 0.5, hObj: NetCon[239]}],
#  [{preGid: 100, sec: 'dend_23', loc: 0.6487622917648193, synMech: 'INH:L5_PC17', weight: 0.75, delay: 0.05, label: 'pre->post17', preLoc: 0.5, hObj: NetCon[240]},
#   {preGid: 100, sec: 'dend_45', loc: 0.08655335220822367, synMech: 'INH:L5_PC17', weight: 0.75, delay: 0.05, label: 'pre->post17', preLoc: 0.5, hObj: NetCon[241]},
#   {preGid: 100, sec: 'apic_53', loc: 0.8905417355026513, synMech: 'INH:L5_PC17', weight: 0.75, delay: 0.05, label: 'pre->post17', preLoc: 0.5, hObj: NetCon[242]},
#   {preGid: 100, sec: 'dend_30', loc: 0.07299241192518316, synMech: 'INH:L5_PC17', weight: 0.75, delay: 0.05, label: 'pre->post17', preLoc: 0.5, hObj: NetCon[243]},
#   {preGid: 100, sec: 'dend_41', loc: 0.18478393176734004, synMech: 'INH:L5_PC17', weight: 0.75, delay: 0.05, label: 'pre->post17', preLoc: 0.5, hObj: NetCon[244]},
#   {preGid: 100, sec: 'dend_6', loc: 0.4157789067254108, synMech: 'INH:L5_PC17', weight: 0.75, delay: 0.05, label: 'pre->post17', preLoc: 0.5, hObj: NetCon[245]},
#   {preGid: 100, sec: 'dend_3', loc: 0.5456875618261448, synMech: 'INH:L5_PC17', weight: 0.75, delay: 0.05, label: 'pre->post17', preLoc: 0.5, hObj: NetCon[246]},
#   {preGid: 100, sec: 'apic_33', loc: 0.7566598456744632, synMech: 'INH:L5_PC17', weight: 0.75, delay: 0.05, label: 'pre->post17', preLoc: 0.5, hObj: NetCon[247]},
#   {preGid: 100, sec: 'apic_36', loc: 0.513906891055369, synMech: 'INH:L5_PC17', weight: 0.75, delay: 0.05, label: 'pre->post17', preLoc: 0.5, hObj: NetCon[248]},
#   {preGid: 100, sec: 'apic_52', loc: 0.15998534842988862, synMech: 'INH:L5_PC17', weight: 0.75, delay: 0.05, label: 'pre->post17', preLoc: 0.5, hObj: NetCon[249]},
#   {preGid: 100, sec: 'dend_17', loc: 0.227654885264698, synMech: 'INH:L5_PC17', weight: 0.75, delay: 0.05, label: 'pre->post17', preLoc: 0.5, hObj: NetCon[250]},
#   {preGid: 100, sec: 'dend_27', loc: 0.023261225116199453, synMech: 'INH:L5_PC17', weight: 0.75, delay: 0.05, label: 'pre->post17', preLoc: 0.5, hObj: NetCon[251]},
#   {preGid: 100, sec: 'apic_21', loc: 0.9134326883244882, synMech: 'INH:L5_PC17', weight: 0.75, delay: 0.05, label: 'pre->post17', preLoc: 0.5, hObj: NetCon[252]},
#   {preGid: 100, sec: 'dend_20', loc: 0.13002793692216813, synMech: 'INH:L5_PC17', weight: 0.75, delay: 0.05, label: 'pre->post17', preLoc: 0.5, hObj: NetCon[253]},
#   {preGid: 100, sec: 'apic_40', loc: 0.8810824995480964, synMech: 'INH:L5_PC17', weight: 0.75, delay: 0.05, label: 'pre->post17', preLoc: 0.5, hObj: NetCon[254]}],
#  [{preGid: 100, sec: 'apic_16', loc: 0.12405953871583619, synMech: 'INH:L5_PC18', weight: 0.75, delay: 0.05, label: 'pre->post18', preLoc: 0.5, hObj: NetCon[255]},
#   {preGid: 100, sec: 'apic_39', loc: 0.317395883101011, synMech: 'INH:L5_PC18', weight: 0.75, delay: 0.05, label: 'pre->post18', preLoc: 0.5, hObj: NetCon[256]},
#   {preGid: 100, sec: 'dend_17', loc: 0.3407312251174521, synMech: 'INH:L5_PC18', weight: 0.75, delay: 0.05, label: 'pre->post18', preLoc: 0.5, hObj: NetCon[257]},
#   {preGid: 100, sec: 'apic_13', loc: 0.2948315651590579, synMech: 'INH:L5_PC18', weight: 0.75, delay: 0.05, label: 'pre->post18', preLoc: 0.5, hObj: NetCon[258]},
#   {preGid: 100, sec: 'apic_5', loc: 0.8022213393348946, synMech: 'INH:L5_PC18', weight: 0.75, delay: 0.05, label: 'pre->post18', preLoc: 0.5, hObj: NetCon[259]},
#   {preGid: 100, sec: 'dend_19', loc: 0.17248294756898017, synMech: 'INH:L5_PC18', weight: 0.75, delay: 0.05, label: 'pre->post18', preLoc: 0.5, hObj: NetCon[260]},
#   {preGid: 100, sec: 'dend_45', loc: 0.6501038940005152, synMech: 'INH:L5_PC18', weight: 0.75, delay: 0.05, label: 'pre->post18', preLoc: 0.5, hObj: NetCon[261]},
#   {preGid: 100, sec: 'apic_19', loc: 0.30991708328642087, synMech: 'INH:L5_PC18', weight: 0.75, delay: 0.05, label: 'pre->post18', preLoc: 0.5, hObj: NetCon[262]},
#   {preGid: 100, sec: 'apic_33', loc: 0.014706377075678317, synMech: 'INH:L5_PC18', weight: 0.75, delay: 0.05, label: 'pre->post18', preLoc: 0.5, hObj: NetCon[263]},
#   {preGid: 100, sec: 'apic_44', loc: 0.7528982471344602, synMech: 'INH:L5_PC18', weight: 0.75, delay: 0.05, label: 'pre->post18', preLoc: 0.5, hObj: NetCon[264]},
#   {preGid: 100, sec: 'dend_36', loc: 0.0019324805414926791, synMech: 'INH:L5_PC18', weight: 0.75, delay: 0.05, label: 'pre->post18', preLoc: 0.5, hObj: NetCon[265]},
#   {preGid: 100, sec: 'dend_11', loc: 0.19631300933063192, synMech: 'INH:L5_PC18', weight: 0.75, delay: 0.05, label: 'pre->post18', preLoc: 0.5, hObj: NetCon[266]},
#   {preGid: 100, sec: 'apic_37', loc: 0.2137920043020355, synMech: 'INH:L5_PC18', weight: 0.75, delay: 0.05, label: 'pre->post18', preLoc: 0.5, hObj: NetCon[267]},
#   {preGid: 100, sec: 'dend_24', loc: 0.8573735619153681, synMech: 'INH:L5_PC18', weight: 0.75, delay: 0.05, label: 'pre->post18', preLoc: 0.5, hObj: NetCon[268]},
#   {preGid: 100, sec: 'apic_25', loc: 0.3001040854878175, synMech: 'INH:L5_PC18', weight: 0.75, delay: 0.05, label: 'pre->post18', preLoc: 0.5, hObj: NetCon[269]}],
#  [{preGid: 100, sec: 'dend_17', loc: 0.6191597602669277, synMech: 'INH:L5_PC19', weight: 0.75, delay: 0.05, label: 'pre->post19', preLoc: 0.5, hObj: NetCon[270]},
#   {preGid: 100, sec: 'dend_27', loc: 0.4968166094235808, synMech: 'INH:L5_PC19', weight: 0.75, delay: 0.05, label: 'pre->post19', preLoc: 0.5, hObj: NetCon[271]},
#   {preGid: 100, sec: 'apic_9', loc: 0.8093780405806819, synMech: 'INH:L5_PC19', weight: 0.75, delay: 0.05, label: 'pre->post19', preLoc: 0.5, hObj: NetCon[272]},
#   {preGid: 100, sec: 'dend_30', loc: 0.34575745040052797, synMech: 'INH:L5_PC19', weight: 0.75, delay: 0.05, label: 'pre->post19', preLoc: 0.5, hObj: NetCon[273]},
#   {preGid: 100, sec: 'apic_33', loc: 0.6680849724387158, synMech: 'INH:L5_PC19', weight: 0.75, delay: 0.05, label: 'pre->post19', preLoc: 0.5, hObj: NetCon[274]},
#   {preGid: 100, sec: 'dend_12', loc: 0.42856840232783416, synMech: 'INH:L5_PC19', weight: 0.75, delay: 0.05, label: 'pre->post19', preLoc: 0.5, hObj: NetCon[275]},
#   {preGid: 100, sec: 'apic_37', loc: 0.5117487659632081, synMech: 'INH:L5_PC19', weight: 0.75, delay: 0.05, label: 'pre->post19', preLoc: 0.5, hObj: NetCon[276]},
#   {preGid: 100, sec: 'apic_23', loc: 0.24976588239578454, synMech: 'INH:L5_PC19', weight: 0.75, delay: 0.05, label: 'pre->post19', preLoc: 0.5, hObj: NetCon[277]},
#   {preGid: 100, sec: 'apic_45', loc: 0.8946664283377345, synMech: 'INH:L5_PC19', weight: 0.75, delay: 0.05, label: 'pre->post19', preLoc: 0.5, hObj: NetCon[278]},
#   {preGid: 100, sec: 'apic_21', loc: 0.9753622408459705, synMech: 'INH:L5_PC19', weight: 0.75, delay: 0.05, label: 'pre->post19', preLoc: 0.5, hObj: NetCon[279]},
#   {preGid: 100, sec: 'dend_36', loc: 0.5911756807177957, synMech: 'INH:L5_PC19', weight: 0.75, delay: 0.05, label: 'pre->post19', preLoc: 0.5, hObj: NetCon[280]},
#   {preGid: 100, sec: 'apic_27', loc: 0.5925857239369692, synMech: 'INH:L5_PC19', weight: 0.75, delay: 0.05, label: 'pre->post19', preLoc: 0.5, hObj: NetCon[281]},
#   {preGid: 100, sec: 'dend_41', loc: 0.9219932130943062, synMech: 'INH:L5_PC19', weight: 0.75, delay: 0.05, label: 'pre->post19', preLoc: 0.5, hObj: NetCon[282]},
#   {preGid: 100, sec: 'dend_23', loc: 0.8376076295177337, synMech: 'INH:L5_PC19', weight: 0.75, delay: 0.05, label: 'pre->post19', preLoc: 0.5, hObj: NetCon[283]},
#   {preGid: 100, sec: 'apic_22', loc: 0.7453214513213199, synMech: 'INH:L5_PC19', weight: 0.75, delay: 0.05, label: 'pre->post19', preLoc: 0.5, hObj: NetCon[284]}],
#  [{preGid: 100, sec: 'dend_23', loc: 0.5015660275049454, synMech: 'INH:L5_PC20', weight: 0.75, delay: 0.05, label: 'pre->post20', preLoc: 0.5, hObj: NetCon[285]},
#   {preGid: 100, sec: 'dend_17', loc: 0.07546136533180213, synMech: 'INH:L5_PC20', weight: 0.75, delay: 0.05, label: 'pre->post20', preLoc: 0.5, hObj: NetCon[286]},
#   {preGid: 100, sec: 'dend_19', loc: 0.12577263860786572, synMech: 'INH:L5_PC20', weight: 0.75, delay: 0.05, label: 'pre->post20', preLoc: 0.5, hObj: NetCon[287]},
#   {preGid: 100, sec: 'dend_24', loc: 0.9730006479630802, synMech: 'INH:L5_PC20', weight: 0.75, delay: 0.05, label: 'pre->post20', preLoc: 0.5, hObj: NetCon[288]},
#   {preGid: 100, sec: 'dend_3', loc: 0.7356328865787192, synMech: 'INH:L5_PC20', weight: 0.75, delay: 0.05, label: 'pre->post20', preLoc: 0.5, hObj: NetCon[289]},
#   {preGid: 100, sec: 'dend_27', loc: 0.7407977446174864, synMech: 'INH:L5_PC20', weight: 0.75, delay: 0.05, label: 'pre->post20', preLoc: 0.5, hObj: NetCon[290]},
#   {preGid: 100, sec: 'apic_33', loc: 0.4586452481845296, synMech: 'INH:L5_PC20', weight: 0.75, delay: 0.05, label: 'pre->post20', preLoc: 0.5, hObj: NetCon[291]},
#   {preGid: 100, sec: 'apic_29', loc: 0.8517427247609088, synMech: 'INH:L5_PC20', weight: 0.75, delay: 0.05, label: 'pre->post20', preLoc: 0.5, hObj: NetCon[292]},
#   {preGid: 100, sec: 'apic_21', loc: 0.7601148149514452, synMech: 'INH:L5_PC20', weight: 0.75, delay: 0.05, label: 'pre->post20', preLoc: 0.5, hObj: NetCon[293]},
# ...
#   {preGid: 100, sec: 'dend_16', loc: 0.07016761781240155, synMech: 'INH:L5_PC94', weight: 0.75, delay: 0.05, label: 'pre->post94', preLoc: 0.5, hObj: NetCon[1403]},
#   {preGid: 100, sec: 'apic_21', loc: 0.989589902327475, synMech: 'INH:L5_PC94', weight: 0.75, delay: 0.05, label: 'pre->post94', preLoc: 0.5, hObj: NetCon[1404]},
#   {preGid: 100, sec: 'apic_32', loc: 0.09306178910040366, synMech: 'INH:L5_PC94', weight: 0.75, delay: 0.05, label: 'pre->post94', preLoc: 0.5, hObj: NetCon[1405]},
#   {preGid: 100, sec: 'apic_29', loc: 0.3231742896148724, synMech: 'INH:L5_PC94', weight: 0.75, delay: 0.05, label: 'pre->post94', preLoc: 0.5, hObj: NetCon[1406]},
#   {preGid: 100, sec: 'dend_50', loc: 0.6091299176232681, synMech: 'INH:L5_PC94', weight: 0.75, delay: 0.05, label: 'pre->post94', preLoc: 0.5, hObj: NetCon[1407]},
#   {preGid: 100, sec: 'dend_25', loc: 0.08028705715262051, synMech: 'INH:L5_PC94', weight: 0.75, delay: 0.05, label: 'pre->post94', preLoc: 0.5, hObj: NetCon[1408]},
#   {preGid: 100, sec: 'dend_57', loc: 0.9864252485423739, synMech: 'INH:L5_PC94', weight: 0.75, delay: 0.05, label: 'pre->post94', preLoc: 0.5, hObj: NetCon[1409]}],
#  [{preGid: 100, sec: 'dend_21', loc: 0.8334127537255862, synMech: 'INH:L5_PC95', weight: 0.75, delay: 0.05, label: 'pre->post95', preLoc: 0.5, hObj: NetCon[1410]},
#   {preGid: 100, sec: 'dend_51', loc: 0.7000226688574146, synMech: 'INH:L5_PC95', weight: 0.75, delay: 0.05, label: 'pre->post95', preLoc: 0.5, hObj: NetCon[1411]},
#   {preGid: 100, sec: 'apic_41', loc: 0.07379121454284596, synMech: 'INH:L5_PC95', weight: 0.75, delay: 0.05, label: 'pre->post95', preLoc: 0.5, hObj: NetCon[1412]},
#   {preGid: 100, sec: 'dend_60', loc: 0.595177520642252, synMech: 'INH:L5_PC95', weight: 0.75, delay: 0.05, label: 'pre->post95', preLoc: 0.5, hObj: NetCon[1413]},
#   {preGid: 100, sec: 'apic_28', loc: 0.4781591897128837, synMech: 'INH:L5_PC95', weight: 0.75, delay: 0.05, label: 'pre->post95', preLoc: 0.5, hObj: NetCon[1414]},
#   {preGid: 100, sec: 'dend_5', loc: 0.9998789900837687, synMech: 'INH:L5_PC95', weight: 0.75, delay: 0.05, label: 'pre->post95', preLoc: 0.5, hObj: NetCon[1415]},
#   {preGid: 100, sec: 'dend_25', loc: 0.2181838247607992, synMech: 'INH:L5_PC95', weight: 0.75, delay: 0.05, label: 'pre->post95', preLoc: 0.5, hObj: NetCon[1416]},
#   {preGid: 100, sec: 'apic_32', loc: 0.4383793024666821, synMech: 'INH:L5_PC95', weight: 0.75, delay: 0.05, label: 'pre->post95', preLoc: 0.5, hObj: NetCon[1417]},
#   {preGid: 100, sec: 'apic_36', loc: 0.7432126131853777, synMech: 'INH:L5_PC95', weight: 0.75, delay: 0.05, label: 'pre->post95', preLoc: 0.5, hObj: NetCon[1418]},
#   {preGid: 100, sec: 'apic_21', loc: 0.41597320099928453, synMech: 'INH:L5_PC95', weight: 0.75, delay: 0.05, label: 'pre->post95', preLoc: 0.5, hObj: NetCon[1419]},
#   {preGid: 100, sec: 'apic_58', loc: 0.5487525785081595, synMech: 'INH:L5_PC95', weight: 0.75, delay: 0.05, label: 'pre->post95', preLoc: 0.5, hObj: NetCon[1420]},
#   {preGid: 100, sec: 'apic_48', loc: 0.9072944599140168, synMech: 'INH:L5_PC95', weight: 0.75, delay: 0.05, label: 'pre->post95', preLoc: 0.5, hObj: NetCon[1421]},
#   {preGid: 100, sec: 'apic_26', loc: 0.2737031208887228, synMech: 'INH:L5_PC95', weight: 0.75, delay: 0.05, label: 'pre->post95', preLoc: 0.5, hObj: NetCon[1422]},
#   {preGid: 100, sec: 'apic_50', loc: 0.8436966428652436, synMech: 'INH:L5_PC95', weight: 0.75, delay: 0.05, label: 'pre->post95', preLoc: 0.5, hObj: NetCon[1423]},
#   {preGid: 100, sec: 'apic_27', loc: 0.39243503330949475, synMech: 'INH:L5_PC95', weight: 0.75, delay: 0.05, label: 'pre->post95', preLoc: 0.5, hObj: NetCon[1424]}],
#  [{preGid: 100, sec: 'apic_58', loc: 0.7981954988072587, synMech: 'INH:L5_PC96', weight: 0.75, delay: 0.05, label: 'pre->post96', preLoc: 0.5, hObj: NetCon[1425]},
#   {preGid: 100, sec: 'dend_13', loc: 0.34251117437120876, synMech: 'INH:L5_PC96', weight: 0.75, delay: 0.05, label: 'pre->post96', preLoc: 0.5, hObj: NetCon[1426]},
#   {preGid: 100, sec: 'apic_11', loc: 0.2704288961991482, synMech: 'INH:L5_PC96', weight: 0.75, delay: 0.05, label: 'pre->post96', preLoc: 0.5, hObj: NetCon[1427]},
#   {preGid: 100, sec: 'apic_22', loc: 0.3479285837155073, synMech: 'INH:L5_PC96', weight: 0.75, delay: 0.05, label: 'pre->post96', preLoc: 0.5, hObj: NetCon[1428]},
#   {preGid: 100, sec: 'dend_27', loc: 0.028537681228189487, synMech: 'INH:L5_PC96', weight: 0.75, delay: 0.05, label: 'pre->post96', preLoc: 0.5, hObj: NetCon[1429]},
#   {preGid: 100, sec: 'apic_16', loc: 0.913153172066952, synMech: 'INH:L5_PC96', weight: 0.75, delay: 0.05, label: 'pre->post96', preLoc: 0.5, hObj: NetCon[1430]},
#   {preGid: 100, sec: 'dend_48', loc: 0.4374634169082206, synMech: 'INH:L5_PC96', weight: 0.75, delay: 0.05, label: 'pre->post96', preLoc: 0.5, hObj: NetCon[1431]},
#   {preGid: 100, sec: 'dend_54', loc: 0.03151217097071393, synMech: 'INH:L5_PC96', weight: 0.75, delay: 0.05, label: 'pre->post96', preLoc: 0.5, hObj: NetCon[1432]},
#   {preGid: 100, sec: 'dend_29', loc: 0.8778355257797003, synMech: 'INH:L5_PC96', weight: 0.75, delay: 0.05, label: 'pre->post96', preLoc: 0.5, hObj: NetCon[1433]},
#   {preGid: 100, sec: 'apic_37', loc: 0.647787489714052, synMech: 'INH:L5_PC96', weight: 0.75, delay: 0.05, label: 'pre->post96', preLoc: 0.5, hObj: NetCon[1434]},
#   {preGid: 100, sec: 'apic_63', loc: 0.15264315398371955, synMech: 'INH:L5_PC96', weight: 0.75, delay: 0.05, label: 'pre->post96', preLoc: 0.5, hObj: NetCon[1435]},
#   {preGid: 100, sec: 'dend_36', loc: 0.31804128823817845, synMech: 'INH:L5_PC96', weight: 0.75, delay: 0.05, label: 'pre->post96', preLoc: 0.5, hObj: NetCon[1436]},
#   {preGid: 100, sec: 'apic_3', loc: 0.8203749749789414, synMech: 'INH:L5_PC96', weight: 0.75, delay: 0.05, label: 'pre->post96', preLoc: 0.5, hObj: NetCon[1437]},
#   {preGid: 100, sec: 'dend_22', loc: 0.4408728213781282, synMech: 'INH:L5_PC96', weight: 0.75, delay: 0.05, label: 'pre->post96', preLoc: 0.5, hObj: NetCon[1438]},
#   {preGid: 100, sec: 'dend_11', loc: 0.9897456596631883, synMech: 'INH:L5_PC96', weight: 0.75, delay: 0.05, label: 'pre->post96', preLoc: 0.5, hObj: NetCon[1439]}],
#  [{preGid: 100, sec: 'dend_10', loc: 0.544247636095187, synMech: 'INH:L5_PC97', weight: 0.75, delay: 0.05, label: 'pre->post97', preLoc: 0.5, hObj: NetCon[1440]},
#   {preGid: 100, sec: 'dend_4', loc: 0.7882311901736095, synMech: 'INH:L5_PC97', weight: 0.75, delay: 0.05, label: 'pre->post97', preLoc: 0.5, hObj: NetCon[1441]},
#   {preGid: 100, sec: 'apic_8', loc: 0.19128434572185493, synMech: 'INH:L5_PC97', weight: 0.75, delay: 0.05, label: 'pre->post97', preLoc: 0.5, hObj: NetCon[1442]},
#   {preGid: 100, sec: 'apic_45', loc: 0.8171639402503992, synMech: 'INH:L5_PC97', weight: 0.75, delay: 0.05, label: 'pre->post97', preLoc: 0.5, hObj: NetCon[1443]},
#   {preGid: 100, sec: 'apic_15', loc: 0.07628696087880309, synMech: 'INH:L5_PC97', weight: 0.75, delay: 0.05, label: 'pre->post97', preLoc: 0.5, hObj: NetCon[1444]},
#   {preGid: 100, sec: 'dend_44', loc: 0.4982705537211765, synMech: 'INH:L5_PC97', weight: 0.75, delay: 0.05, label: 'pre->post97', preLoc: 0.5, hObj: NetCon[1445]},
#   {preGid: 100, sec: 'apic_32', loc: 0.32985176223667523, synMech: 'INH:L5_PC97', weight: 0.75, delay: 0.05, label: 'pre->post97', preLoc: 0.5, hObj: NetCon[1446]},
#   {preGid: 100, sec: 'apic_24', loc: 0.25048782880600773, synMech: 'INH:L5_PC97', weight: 0.75, delay: 0.05, label: 'pre->post97', preLoc: 0.5, hObj: NetCon[1447]},
#   {preGid: 100, sec: 'dend_24', loc: 0.8039762081123187, synMech: 'INH:L5_PC97', weight: 0.75, delay: 0.05, label: 'pre->post97', preLoc: 0.5, hObj: NetCon[1448]},
#   {preGid: 100, sec: 'dend_18', loc: 0.2582418680310395, synMech: 'INH:L5_PC97', weight: 0.75, delay: 0.05, label: 'pre->post97', preLoc: 0.5, hObj: NetCon[1449]},
#   {preGid: 100, sec: 'dend_34', loc: 0.6481625191560761, synMech: 'INH:L5_PC97', weight: 0.75, delay: 0.05, label: 'pre->post97', preLoc: 0.5, hObj: NetCon[1450]},
#   {preGid: 100, sec: 'dend_11', loc: 0.8444911452214927, synMech: 'INH:L5_PC97', weight: 0.75, delay: 0.05, label: 'pre->post97', preLoc: 0.5, hObj: NetCon[1451]},
#   {preGid: 100, sec: 'dend_39', loc: 0.7959780566002838, synMech: 'INH:L5_PC97', weight: 0.75, delay: 0.05, label: 'pre->post97', preLoc: 0.5, hObj: NetCon[1452]},
#   {preGid: 100, sec: 'apic_20', loc: 0.9675456691433962, synMech: 'INH:L5_PC97', weight: 0.75, delay: 0.05, label: 'pre->post97', preLoc: 0.5, hObj: NetCon[1453]},
#   {preGid: 100, sec: 'apic_63', loc: 0.6775129438198436, synMech: 'INH:L5_PC97', weight: 0.75, delay: 0.05, label: 'pre->post97', preLoc: 0.5, hObj: NetCon[1454]}],
#  [{preGid: 100, sec: 'dend_41', loc: 0.9092158584521984, synMech: 'INH:L5_PC98', weight: 0.75, delay: 0.05, label: 'pre->post98', preLoc: 0.5, hObj: NetCon[1455]},
#   {preGid: 100, sec: 'apic_31', loc: 0.9992620544253829, synMech: 'INH:L5_PC98', weight: 0.75, delay: 0.05, label: 'pre->post98', preLoc: 0.5, hObj: NetCon[1456]},
#   {preGid: 100, sec: 'dend_55', loc: 0.8694994667178889, synMech: 'INH:L5_PC98', weight: 0.75, delay: 0.05, label: 'pre->post98', preLoc: 0.5, hObj: NetCon[1457]},
#   {preGid: 100, sec: 'dend_26', loc: 0.49838258164862176, synMech: 'INH:L5_PC98', weight: 0.75, delay: 0.05, label: 'pre->post98', preLoc: 0.5, hObj: NetCon[1458]},
#   {preGid: 100, sec: 'apic_15', loc: 0.14077989426852364, synMech: 'INH:L5_PC98', weight: 0.75, delay: 0.05, label: 'pre->post98', preLoc: 0.5, hObj: NetCon[1459]},
#   {preGid: 100, sec: 'dend_62', loc: 0.8004685606682177, synMech: 'INH:L5_PC98', weight: 0.75, delay: 0.05, label: 'pre->post98', preLoc: 0.5, hObj: NetCon[1460]},
#   {preGid: 100, sec: 'apic_32', loc: 0.18283307699225199, synMech: 'INH:L5_PC98', weight: 0.75, delay: 0.05, label: 'pre->post98', preLoc: 0.5, hObj: NetCon[1461]},
#   {preGid: 100, sec: 'dend_49', loc: 0.5354337255399468, synMech: 'INH:L5_PC98', weight: 0.75, delay: 0.05, label: 'pre->post98', preLoc: 0.5, hObj: NetCon[1462]},
#   {preGid: 100, sec: 'dend_13', loc: 0.12573895981229216, synMech: 'INH:L5_PC98', weight: 0.75, delay: 0.05, label: 'pre->post98', preLoc: 0.5, hObj: NetCon[1463]},
#   {preGid: 100, sec: 'apic_60', loc: 0.336291328351646, synMech: 'INH:L5_PC98', weight: 0.75, delay: 0.05, label: 'pre->post98', preLoc: 0.5, hObj: NetCon[1464]},
#   {preGid: 100, sec: 'dend_34', loc: 0.13777752265287055, synMech: 'INH:L5_PC98', weight: 0.75, delay: 0.05, label: 'pre->post98', preLoc: 0.5, hObj: NetCon[1465]},
#   {preGid: 100, sec: 'apic_35', loc: 0.8707956439693846, synMech: 'INH:L5_PC98', weight: 0.75, delay: 0.05, label: 'pre->post98', preLoc: 0.5, hObj: NetCon[1466]},
#   {preGid: 100, sec: 'apic_62', loc: 0.6988373686065497, synMech: 'INH:L5_PC98', weight: 0.75, delay: 0.05, label: 'pre->post98', preLoc: 0.5, hObj: NetCon[1467]},
#   {preGid: 100, sec: 'apic_13', loc: 0.28561159679565146, synMech: 'INH:L5_PC98', weight: 0.75, delay: 0.05, label: 'pre->post98', preLoc: 0.5, hObj: NetCon[1468]},
#   {preGid: 100, sec: 'apic_54', loc: 0.16555817737007192, synMech: 'INH:L5_PC98', weight: 0.75, delay: 0.05, label: 'pre->post98', preLoc: 0.5, hObj: NetCon[1469]}],
#  [{preGid: 100, sec: 'dend_61', loc: 0.5344452848334045, synMech: 'INH:L5_PC99', weight: 0.75, delay: 0.05, label: 'pre->post99', preLoc: 0.5, hObj: NetCon[1470]},
#   {preGid: 100, sec: 'dend_62', loc: 0.15336448217004017, synMech: 'INH:L5_PC99', weight: 0.75, delay: 0.05, label: 'pre->post99', preLoc: 0.5, hObj: NetCon[1471]},
#   {preGid: 100, sec: 'dend_56', loc: 0.4385570187075489, synMech: 'INH:L5_PC99', weight: 0.75, delay: 0.05, label: 'pre->post99', preLoc: 0.5, hObj: NetCon[1472]},
#   {preGid: 100, sec: 'apic_54', loc: 0.27565489634179563, synMech: 'INH:L5_PC99', weight: 0.75, delay: 0.05, label: 'pre->post99', preLoc: 0.5, hObj: NetCon[1473]},
#   {preGid: 100, sec: 'dend_17', loc: 0.48439242899344354, synMech: 'INH:L5_PC99', weight: 0.75, delay: 0.05, label: 'pre->post99', preLoc: 0.5, hObj: NetCon[1474]},
#   {preGid: 100, sec: 'apic_1', loc: 0.25376474425570655, synMech: 'INH:L5_PC99', weight: 0.75, delay: 0.05, label: 'pre->post99', preLoc: 0.5, hObj: NetCon[1475]},
#   {preGid: 100, sec: 'apic_25', loc: 0.32037453743402566, synMech: 'INH:L5_PC99', weight: 0.75, delay: 0.05, label: 'pre->post99', preLoc: 0.5, hObj: NetCon[1476]},
#   {preGid: 100, sec: 'dend_14', loc: 0.6483019885356875, synMech: 'INH:L5_PC99', weight: 0.75, delay: 0.05, label: 'pre->post99', preLoc: 0.5, hObj: NetCon[1477]},
#   {preGid: 100, sec: 'apic_58', loc: 0.027297744960260238, synMech: 'INH:L5_PC99', weight: 0.75, delay: 0.05, label: 'pre->post99', preLoc: 0.5, hObj: NetCon[1478]},
#   {preGid: 100, sec: 'dend_63', loc: 0.44107170015251695, synMech: 'INH:L5_PC99', weight: 0.75, delay: 0.05, label: 'pre->post99', preLoc: 0.5, hObj: NetCon[1479]},
#   {preGid: 100, sec: 'apic_15', loc: 0.6327656593206631, synMech: 'INH:L5_PC99', weight: 0.75, delay: 0.05, label: 'pre->post99', preLoc: 0.5, hObj: NetCon[1480]},
#   {preGid: 100, sec: 'dend_11', loc: 0.2686974052350224, synMech: 'INH:L5_PC99', weight: 0.75, delay: 0.05, label: 'pre->post99', preLoc: 0.5, hObj: NetCon[1481]},
#   {preGid: 100, sec: 'dend_33', loc: 0.5142644723609996, synMech: 'INH:L5_PC99', weight: 0.75, delay: 0.05, label: 'pre->post99', preLoc: 0.5, hObj: NetCon[1482]},
#   {preGid: 100, sec: 'apic_36', loc: 0.07812124000513786, synMech: 'INH:L5_PC99', weight: 0.75, delay: 0.05, label: 'pre->post99', preLoc: 0.5, hObj: NetCon[1483]},
#   {preGid: 100, sec: 'apic_19', loc: 0.17057695146687069, synMech: 'INH:L5_PC99', weight: 0.75, delay: 0.05, label: 'pre->post99', preLoc: 0.5, hObj: NetCon[1484]}],
#  [{preGid: 100, sec: 'apic_33', loc: 0.3705321064321729, synMech: 'INH:L5_PC100', weight: 0.75, delay: 0.05, label: 'pre->post100', preLoc: 0.5, hObj: NetCon[1485]},
#   {preGid: 100, sec: 'apic_5', loc: 0.6157853996644599, synMech: 'INH:L5_PC100', weight: 0.75, delay: 0.05, label: 'pre->post100', preLoc: 0.5, hObj: NetCon[1486]},
#   {preGid: 100, sec: 'dend_11', loc: 0.1499982804878145, synMech: 'INH:L5_PC100', weight: 0.75, delay: 0.05, label: 'pre->post100', preLoc: 0.5, hObj: NetCon[1487]},
#   {preGid: 100, sec: 'apic_45', loc: 0.7724699879232241, synMech: 'INH:L5_PC100', weight: 0.75, delay: 0.05, label: 'pre->post100', preLoc: 0.5, hObj: NetCon[1488]},
#   {preGid: 100, sec: 'dend_55', loc: 0.8176937944414931, synMech: 'INH:L5_PC100', weight: 0.75, delay: 0.05, label: 'pre->post100', preLoc: 0.5, hObj: NetCon[1489]},
#   {preGid: 100, sec: 'dend_49', loc: 0.1718032053734518, synMech: 'INH:L5_PC100', weight: 0.75, delay: 0.05, label: 'pre->post100', preLoc: 0.5, hObj: NetCon[1490]},
#   {preGid: 100, sec: 'dend_26', loc: 0.8963667100585219, synMech: 'INH:L5_PC100', weight: 0.75, delay: 0.05, label: 'pre->post100', preLoc: 0.5, hObj: NetCon[1491]},
#   {preGid: 100, sec: 'dend_5', loc: 0.43984106979977255, synMech: 'INH:L5_PC100', weight: 0.75, delay: 0.05, label: 'pre->post100', preLoc: 0.5, hObj: NetCon[1492]},
#   {preGid: 100, sec: 'dend_62', loc: 0.3069128216883489, synMech: 'INH:L5_PC100', weight: 0.75, delay: 0.05, label: 'pre->post100', preLoc: 0.5, hObj: NetCon[1493]},
#   {preGid: 100, sec: 'apic_58', loc: 0.5256447432958926, synMech: 'INH:L5_PC100', weight: 0.75, delay: 0.05, label: 'pre->post100', preLoc: 0.5, hObj: NetCon[1494]},
#   {preGid: 100, sec: 'apic_37', loc: 0.3537964531045098, synMech: 'INH:L5_PC100', weight: 0.75, delay: 0.05, label: 'pre->post100', preLoc: 0.5, hObj: NetCon[1495]},
#   {preGid: 100, sec: 'dend_24', loc: 0.3839533708763682, synMech: 'INH:L5_PC100', weight: 0.75, delay: 0.05, label: 'pre->post100', preLoc: 0.5, hObj: NetCon[1496]},
#   {preGid: 100, sec: 'dend_54', loc: 0.2226681471286233, synMech: 'INH:L5_PC100', weight: 0.75, delay: 0.05, label: 'pre->post100', preLoc: 0.5, hObj: NetCon[1497]},
#   {preGid: 100, sec: 'apic_62', loc: 0.8079319774667485, synMech: 'INH:L5_PC100', weight: 0.75, delay: 0.05, label: 'pre->post100', preLoc: 0.5, hObj: NetCon[1498]},
#   {preGid: 100, sec: 'apic_9', loc: 0.8094880851544201, synMech: 'INH:L5_PC100', weight: 0.75, delay: 0.05, label: 'pre->post100', preLoc: 0.5, hObj: NetCon[1499]}],
#  []]

# %%
sim.net.addStims() 							# add network stimulation
sim.setupRecording()              			# setup variables to record for each cell (spikes, V traces, etc)
# Out:
#   Number of stims on node 0: 0
#   Done; cell stims creation time = 0.00 s.
# Recording 100 traces of 1 types on node 0
# {spkt: Vector[104791], spkid: Vector[104792], V_soma: {cell_0: Vector[104793], cell_1: Vector[104794], cell_2: Vector[104795], cell_3: Vector[104796], cell_4: Vector[104797], cell_5: Vector[104798], cell_6: Vector[104799], cell_7: Vector[104800], cell_8: Vector[104801], cell_9: Vector[104802], cell_10: Vector[104803], cell_11: Vector[104804], cell_12: Vector[104805], cell_13: Vector[104806], cell_14: Vector[104807], cell_15: Vector[104808], cell_16: Vector[104809], cell_17: Vector[104810], cell_18: Vector[104811], cell_19: Vector[104812], cell_20: Vector[104813], cell_21: Vector[104814], cell_22: Vector[104815], cell_23: Vector[104816], cell_24: Vector[104817], cell_25: Vector[104818], cell_26: Vector[104819], cell_27: Vector[104820], cell_28: Vector[104821], cell_29: Vector[104822], cell_30: Vector[104823], cell_31: Vector[104824], cell_32: Vector[104825], cell_33: Vector[104826], cell_34: Vector[104827], cell_35: Vector[104828], cell_36: Vector[104829], cell_37: Vector[104830], cell_38: Vector[104831], cell_39: Vector[104832], cell_40: Vector[104833], cell_41: Vector[104834], cell_42: Vector[104835], cell_43: Vector[104836], cell_44: Vector[104837], cell_45: Vector[104838], cell_46: Vector[104839], cell_47: Vector[104840], cell_48: Vector[104841], cell_49: Vector[104842], cell_50: Vector[104843], cell_51: Vector[104844], cell_52: Vector[104845], cell_53: Vector[104846], cell_54: Vector[104847], cell_55: Vector[104848], cell_56: Vector[104849], cell_57: Vector[104850], cell_58: Vector[104851], cell_59: Vector[104852], cell_60: Vector[104853], cell_61: Vector[104854], cell_62: Vector[104855], cell_63: Vector[104856], cell_64: Vector[104857], cell_65: Vector[104858], cell_66: Vector[104859], cell_67: Vector[104860], cell_68: Vector[104861], cell_69: Vector[104862], cell_70: Vector[104863], cell_71: Vector[104864], cell_72: Vector[104865], cell_73: Vector[104866], cell_74: Vector[104867], cell_75: Vector[104868], cell_76: Vector[104869], cell_77: Vector[104870], cell_78: Vector[104871], cell_79: Vector[104872], cell_80: Vector[104873], cell_81: Vector[104874], cell_82: Vector[104875], cell_83: Vector[104876], cell_84: Vector[104877], cell_85: Vector[104878], cell_86: Vector[104879], cell_87: Vector[104880], cell_88: Vector[104881], cell_89: Vector[104882], cell_90: Vector[104883], cell_91: Vector[104884], cell_92: Vector[104885], cell_93: Vector[104886], cell_94: Vector[104887], cell_95: Vector[104888], cell_96: Vector[104889], cell_97: Vector[104890], cell_98: Vector[104891], cell_99: Vector[104892]}, t: Vector[104893], _repr_mimebundle_: {}}

# %%
sim.runSim()                      			# run Neuron simulation
# Out:
# 0.0s
#
# Running simulation using NEURON for 4000.0 ms...
# 0.1s
# 0.2s
# 0.3s
# 0.4s
# 0.5s
# 0.6s
# 0.7s
# 0.8s
# 0.9s
# 1.0s
# 1.1s
# 1.2s
# 1.3s
# 1.4s
# 1.5s
# 1.6s
# 1.7s
# 1.8s
# 1.9s
# 2.0s
# 2.1s
# 2.2s
# 2.3s
# 2.4s
# 2.5s
# 2.6s
# 2.7s
# 2.8s
# 2.9s
# 3.0s
# 3.1s
# 3.2s
# 3.3s
# 3.4s
# 3.5s
# 3.6s
# 3.7s
# 3.8s
# 3.9s
# 4.0s
#   Done; run time = 9560.73 s; real-time ratio: 0.00.

# %%
sim.gatherData()                  			# gather spiking data and cell info from each node
sim.saveData()                    			# save params, cell info and sim output to file (pickle,mat,txt,etc)#
sim.analysis.plotData()         			# plot spike raster etc
# Out:
# Gathering data...
#   Done; gather time = 0.23 s.
#
# Analyzing...
#   Cells: 101
#   Connections: 100 (0.99 per cell)
#   Synaptic contacts: 1500 (14.85 per cell)
#   Spikes: 11 (0.03 Hz)
#   Simulated time: 4.0 s; 1 workers
#   Run time: 9560.73 s
# Warning: data won't be saved. No output format specified (consider sim.cfg.savePickle, sim.cfg.saveJson etc.)
# Plotting recorded cell traces ... trace
#   Done; plotting time = 0.96 s
#
# Total time = 9568.94 s

# %%
# sim.analysis.plotRaster(figSize=(10, 3))

# %%
alltraces = []
gmax1 = []

# spkTimes = [500,2500,2550,2600,2650,2700,2750,2800,2850,2900,3400]


Traces2 = sim.analysis.plotTraces(oneFigPer='trace', overlay=1, timeRange=[2400,3900],axis=False,legend=False,scaleBarLoc=1,figSize=(10, 3),fontSize=6)
for number in range(100):
    if np.max(Traces2[1]['tracesData'][number]['cell_'+str(number)+'_V_soma'])-np.min(Traces2[1]['tracesData'][number]['cell_'+str(number)+'_V_soma']) > 0.01:
        alltraces.append(Traces2[1]['tracesData'][number]['cell_'+str(number)+'_V_soma'])
        gmax1.append(np.max(Traces2[1]['tracesData'][number]['cell_'+str(number)+'_V_soma'])-np.min(Traces2[1]['tracesData'][number]['cell_'+str(number)+'_V_soma']))
#         print(number,np.max(Traces2[1]['tracesData'][number]['cell_'+str(number)+'_V_soma'])-np.min(Traces2[1]['tracesData'][number]['cell_'+str(number)+'_V_soma']))


# Traces2 = sim.analysis.plotTraces(oneFigPer='trace', overlay=1, timeRange=[3300,3900],axis=False,legend=False,scaleBarLoc=1,figSize=(10, 3),fontSize=6)
# for number in range(20):
#     if np.max(Traces2[1]['tracesData'][number]['cell_'+str(number)+'_V_soma'])-np.min(Traces2[1]['tracesData'][number]['cell_'+str(number)+'_V_soma']) > 0.01:
#         alltraces.append(Traces2[1]['tracesData'][number]['cell_'+str(number)+'_V_soma'])
#         gmax1.append(np.max(Traces2[1]['tracesData'][number]['cell_'+str(number)+'_V_soma'])-np.min(Traces2[1]['tracesData'][number]['cell_'+str(number)+'_V_soma']))
# #         print(number,np.max(Traces2[1]['tracesData'][number]['cell_'+str(number)+'_V_soma'])-np.min(Traces2[1]['tracesData'][number]['cell_'+str(number)+'_V_soma']))


# print('L23_PC:L23_PC in silico PSP amplitude (mV; mean ± SD) = %.3f±%.3f' % (np.mean(gmax1),np.std(gmax1)))
print('INH:L5_PC in silico PSP amplitude (mV; mean ± SD) = %.3f±%.3f' % (np.mean(gmax1),np.std(gmax1)))
# Out:
# Plotting recorded cell traces ... trace
# INH:L5_PC in silico PSP amplitude (mV; mean ± SD) = 0.067±0.058

# %%
figSize = (16,9)
fig = plt.figure(figsize=figSize)  # Open a new figure
clr = ["black", "blue","green","gray", "red","black", "blue","green","gray", "red","black", "blue","green","gray", "red","black", "blue","green","gray", "red"]
number=0
for i in range(20):
    for number2 in range(i,100,20):
        plt.plot(Traces2[1]['tracesData'][number]['t'][1:],Traces2[1]['tracesData'][number]['cell_'+str(number)+'_V_soma']-Traces2[1]['tracesData'][number]['cell_'+str(number)+'_V_soma'][999]-0.5*i, label= sim.net.allCells[number]['tags']['pop'] + '_' + sim.net.allCells[number]['conns'][0]['sec'], linewidth=1.0, color=clr[i])
        number+=1
        
plt.legend(loc='upper right', bbox_to_anchor=(1.25, 1.0), fontsize=8)
# plt.xlim(2400,4150)
plt.ylim(-10.25,1.0)
plt.xlabel('Time (ms)', fontsize=16)
plt.ylabel('EPSP (mV)', fontsize=16)
# plt.xticks(range(2400,3900,200), range(0,1500,200), fontsize=14);
plt.yticks([0,-1], fontsize=14);

# %%
figSize = (8,5)
fig = plt.figure(figsize=figSize)  # Open a new figure
for number in range(np.shape(alltraces)[0]):
    plt.plot(alltraces[number]-alltraces[number][0],color = 'lightgray',linewidth=2.0)

plt.title('Vrev -70 mV and gsyn = 100p  ->  %.2f ± %.2f mV' % (np.mean(gmax1),np.std(gmax1)), fontsize=14)
plt.plot(np.mean(alltraces, axis=0)-np.mean(alltraces, axis=0)[0],color = 'black', linewidth=4.0)
# plt.legend(loc='upper right', bbox_to_anchor=(0.95, 1.0))
plt.xlim(500,12000)
plt.ylim(0.25,-1.0)
plt.xlabel('Time (ms)', fontsize=16)
plt.ylabel('PSP (mV)', fontsize=16)
plt.xticks(range(1000,12000,2000), range(0,1100,200), fontsize=14);
plt.yticks([0,-1], fontsize=14); 

plt.savefig('../info/syn_gmax_INH_L5PC_type8_gabaAVrev-70mV.png', facecolor = 'white' , dpi=300)

# %%
# (0.8355167606552806, 25)

# %%
np.mean(gmax1), np.size(gmax1)
# Out:
# (0.06682459858756035, 99)

# %% [markdown]
# <!-- Connection type	s-type	in vitro PSP amplitude (mV; mean ± SD)	in silico PSP amplitude (mV; mean ± SD)	Input data sources
# L5TTPC-L5MC	E1	0.28 ± 0.3	0.28 ± 0.18	Silberberg & Markram, 2007
# L5MC-L5TTPC	I2	0.5 ± 0.3	0.57 ± 0.5	Silberberg & Markram, 2007
# L4SS-L23PC	E2	0.7 ± 0.6	0.7 ± 0.9	Feldmeyer et al. 2002
# L5STPC-L5STPC	E2	0.9 ± 0.7	0.91 ± 0.8	Le Bé et al. 2007
# L5UTPC-L5UTPC	E2	0.9 ± 0.7	0.91 ± 0.8	Le Bé et al. 2007
# L23PC-L23PC	E2	1 ± 0.7	1 ± 0.3	Feldmeyer et al. 2006
# L23LBC-L23PC	I2	1.2 ± 1.1	1.2 ± 1.02	Blatow et al. 2003
# L23NBC-L23PC	I2	1.2 ± 1.1	1.2 ± 1.02	Blatow et al. 2003
# L5TTPC-L5TTPC	E2	1.3 ± 1.1	1.2 ± 0.43	Markram et al. 1997
# L4SS-L4SS	E2	1.6 ± 1.0	1.9 ± 1.5	Feldmeyer et al. 1999
# L4SP-L4SP	E2	1.6 ± 1.0	1.9 ± 1.5	Feldmeyer et al. 1999
# L4PC-L4PC	E2	1.6 ± 1.0	1.9 ± 1.5	Feldmeyer et al. 1999
# L5TTPC-L5SBC	E2	2.1 ± 1.0	1.96 ± 0.67	Angulo et al. 1999 -->
# ![image.png](attachment:image.png)

# %%
Connectiontype = ['L5TTPC_L5MC_E1', 'L5MC_L5TTPC_I2', 'L4SS_L23PC_E2', 'L5STPC_L5STPC_E2', 'L5UTPC_L5UTPC_E2', 'L23PC_L23PC_E2', 
                  'L23LBC_L23PC_I2', 'L23NBC_L23PC_I2', 'L5TTPC_L5TTPC_E2', 'L4SS_L4SS_E2', 'L4SP_L4SP_E2', 'L4PC_L4PC_E2', 'L5TTPC_L5SBC_E2']

# %%
table13c = [0.28, 0.3, 0.28, 0.18, 0.50, 0.3, 0.57, 0.50, 0.70, 0.6, 0.70, 0.90, 0.90, 0.7, 0.91, 0.80, 0.90, 0.7, 0.91, 0.80, 
            1.00, 0.7, 1.00, 0.30, 1.20, 1.1, 1.20, 1.02, 1.20, 1.1, 1.20, 1.02, 1.30, 1.1, 1.20, 0.43, 1.60, 1.0, 1.90, 1.50, 
            1.60, 1.0, 1.90, 1.50, 1.60, 1.0, 1.90, 1.50, 2.10, 1.0, 1.96, 0.67]

# %%
x = []
sx = []
y = []
sy = []

for ii in range(13):
    print(Connectiontype[ii],table13c[4*ii],table13c[4*ii+1],table13c[4*ii+2],table13c[4*ii+3])
    x.append(table13c[4*ii])
    sx.append(table13c[4*ii+1])
    y.append(table13c[4*ii+2])
    sy.append(table13c[4*ii+3])
# Out:
# L5TTPC_L5MC_E1 0.28 0.3 0.28 0.18
# L5MC_L5TTPC_I2 0.5 0.3 0.57 0.5
# L4SS_L23PC_E2 0.7 0.6 0.7 0.9
# L5STPC_L5STPC_E2 0.9 0.7 0.91 0.8
# L5UTPC_L5UTPC_E2 0.9 0.7 0.91 0.8
# L23PC_L23PC_E2 1.0 0.7 1.0 0.3
# L23LBC_L23PC_I2 1.2 1.1 1.2 1.02
# L23NBC_L23PC_I2 1.2 1.1 1.2 1.02
# L5TTPC_L5TTPC_E2 1.3 1.1 1.2 0.43
# L4SS_L4SS_E2 1.6 1.0 1.9 1.5
# L4SP_L4SP_E2 1.6 1.0 1.9 1.5
# L4PC_L4PC_E2 1.6 1.0 1.9 1.5
# L5TTPC_L5SBC_E2 2.1 1.0 1.96 0.67

# %%
import matplotlib.pyplot as plt

# a = [1, 3, 5, 7]
# b = [11, -2, 4, 19]
# plt.scatter(a, b)


# c = [1, 3, 2, 1]
# d = [1, 3, 2, 1]

# you can use color ="r" for red or skip to default as blue
# plt.errorbar(x, y, xerr=sx, yerr=sy, fmt="o", color="r")
plt.scatter(x, y)

plt.show()
