# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# # Input-output properties cells

# %%
import numpy as np
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
rootFolder = '/home/fernando/Dropbox/SUNY/2022/S1_netpyne/sim/'
# rootFolder = os.getcwd()
os.chdir(rootFolder)
print(rootFolder)
folder = os.listdir('cell_data/')
folder = sorted(folder)

savedata = 1 # Save Netpyne and BBP soma_voltage
# Out:
# /home/fernando/Dropbox/SUNY/2022/S1_netpyne/sim/

# %%
# !nrnivmodl mod

# %%
def loadTemplateName(cellnumber):     
    f = open(outFolder+'/template.hoc', 'r')
    for line in f.readlines():
        if 'begintemplate' in line:
            templatename = str(line)     
    templatename=templatename[:-1]        
    templatename=templatename[14:]
    return templatename

# %% [markdown]
# ## Netpyne

# %%
from netpyne import specs, sim   

# Network parameters
netParams = specs.NetParams()  # object of class NetParams to store the network parameters

# %%
# %matplotlib inline

# %%
## cfg  
cfg = specs.SimConfig()					            # object of class SimConfig to store simulation configuration
cfg.duration = 4000.0 						            # Duration of the simulation, in ms
cfg.dt = 0.05								                # Internal integration timestep to use
cfg.verbose = False							                # Show detailed messages 
cfg.recordTraces = {'V_soma':{'sec':'soma','loc':0.5,'var':'v'}}  # Dict with traces to record
cfg.recordStep = 0.1 			
cfg.printRunTime = 0.1 # in sec			

cfg.seeds = {'conn': 1, 'stim': 1, 'loc': 1} 
cfg.hParams = {'celsius': 34, 'v_init': -71.0}  
cfg.verbose = False
cfg.createNEURONObj = True
cfg.createPyStruct = True  
#------------------------------------------------------------------------------
# Saving
#------------------------------------------------------------------------------
cfg.filename = 'model_output'  			# Set file output name
cfg.savePickle = False         	## Save pkl file
cfg.saveJson = False	           	## Save json file
cfg.saveDataInclude = ['simData'] ## 'simData' , 'simConfig', 'netParams'
cfg.backupCfgFile = None 		##  
cfg.gatherOnlySimData = False	##  
cfg.saveCellSecs = False			
cfg.saveCellConns = True	

cfg.analysis['plotTraces'] = {'include': [i for i in range(25)], 'oneFigPer': 'trace', 'overlay': True, 'timeRange': [0,4000], 'saveFig': False, 'showFig': True, 'figSize':(12,4)} # Plot recorded traces for this list of cells
# cfg.analysis['plotShape'] = {'includePre': [0],'includePre': [0], 'saveFig': True, 'showFig': True, 'figSize':(12,12)}

# %%
# for i,metype in enumerate(folder):
#     print(i,metype)
folder[770:775]
# Out:
# ['L5_UTPC_cADpyr232_1',
#  'L5_UTPC_cADpyr232_2',
#  'L5_UTPC_cADpyr232_3',
#  'L5_UTPC_cADpyr232_4',
#  'L5_UTPC_cADpyr232_5']

# %%
#------------------------------------------------------------------------------
# Cell parameters
#------------------------------------------------------------------------------
#StochKv_deterministic.mod
for cellnumber in range(770,775):
    cellName = folder[cellnumber]
    outFolder = rootFolder+'/cell_data/'+folder[cellnumber]
    cellTemplateName = loadTemplateName(cellnumber)
    cellRule = netParams.importCellParams(label=cellName, somaAtOrigin=False,
        conds={'cellType': cellName, 'cellModel': 'HH_full'},
        fileName='cellwrapper.py',
        cellName='loadCell',
        cellInstance = True,
        cellArgs={'cellName': cellName, 'cellTemplateName': cellTemplateName})
# Out:
# NEURON: morphology_5e3840b51e : a template cannot be redefined
#  in morphology.hoc near line 34
#  begintemplate morphology_5e3840b51e
#                                    ^
#         xopen("morphology.hoc")
#       execute1("{xopen("mo...")
#     load_file("morphology.hoc")
#   xopen("template.hoc")
# NEURON: cADpyr232_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate cADpyr232_biophys
#                                ^
#         xopen("biophysics.hoc")
#       execute1("{xopen("bi...")
#     load_file("biophysics.hoc")
#   xopen("template.hoc")
# NEURON: synapses_5e3840b51e : a template cannot be redefined
#  in synapses.hoc near line 31
#  begintemplate synapses_5e3840b51e
#                                  ^
#         xopen("synapses.hoc")
#       execute1("{xopen("sy...")
#     load_file("synapses/s...")
#   xopen("template.hoc")
# 	0
# 	0
# 	0
# cADpyr232_L5_UTPC_5e3840b51e[0]
# NEURON: cADpyr232_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate cADpyr232_biophys
#                                ^
#         xopen("biophysics.hoc")
# 	1
# 	1
# 	1
# cADpyr232_L5_UTPC_34f655e7f8[0]
# NEURON: cADpyr232_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate cADpyr232_biophys
#                                ^
#         xopen("biophysics.hoc")
# 	1
# 	1
# 	1
# cADpyr232_L5_UTPC_d736225429[0]
# NEURON: cADpyr232_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate cADpyr232_biophys
#                                ^
#         xopen("biophysics.hoc")
# 	1
# 	1
# 	1
# cADpyr232_L5_UTPC_da1143b075[0]
# NEURON: cADpyr232_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate cADpyr232_biophys
#                                ^
#         xopen("biophysics.hoc")
# 	1
# 	1
# 	1
# cADpyr232_L5_UTPC_79412a7e72[0]

# %%
for cellnumber in range(770,775):
    # ---------------------------------------------------------------------------------------------------- #
    cellName = folder[cellnumber]
    outFolder = rootFolder+'/cell_data/'+folder[cellnumber]
    cellTemplateName = loadTemplateName(cellnumber)
    
    # ---------------------------------------------------------------------------------------------------- #
    netParams.renameCellParamsSec(label=cellName, oldSec='soma_0', newSec='soma')
    
    for secname2 in netParams.cellParams[cellName]['secLists'].keys():
        if 'soma_0' in netParams.cellParams[cellName]['secLists'][secname2]:
            print(cellName,secname2,netParams.cellParams[cellName]['secLists'][secname2][0])
            netParams.cellParams[cellName]['secLists'][secname2][0] = 'soma'
    # ---------------------------------------------------------------------------------------------------- #
    
    nonSpiny = ['axon_0', 'axon_1']
    netParams.cellParams[cellName]['secLists']['spiny'] = [sec for sec in netParams.cellParams[cellName]['secLists']['all'] if sec not in nonSpiny]
    nonSpinyEE = ['axon_0', 'axon_1', 'soma']
    netParams.cellParams[cellName]['secLists']['spinyEE'] = [sec for sec in netParams.cellParams[cellName]['secLists']['all'] if sec not in nonSpinyEE]    
    
    # ---------------------------------------------------------------------------------------------------- #
    for ii in range(5):
        netParams.popParams[cellName + '_' + str(ii)] = {'cellType': cellName, 'numCells': 1, 'cellModel': 'HH_full'}
# Out:
# L5_UTPC_cADpyr232_1 all soma_0
# L5_UTPC_cADpyr232_1 somatic soma_0
# L5_UTPC_cADpyr232_2 all soma_0
# L5_UTPC_cADpyr232_2 somatic soma_0
# L5_UTPC_cADpyr232_3 all soma_0
# L5_UTPC_cADpyr232_3 somatic soma_0
# L5_UTPC_cADpyr232_4 all soma_0
# L5_UTPC_cADpyr232_4 somatic soma_0
# L5_UTPC_cADpyr232_5 all soma_0
# L5_UTPC_cADpyr232_5 somatic soma_0

# %%
for cellnumber in range(770,775):
    cellName = folder[cellnumber]
    print(netParams.cellParams[cellName]['secLists']['basal'][-1])
# Out:
# dend_42
# dend_42
# dend_42
# dend_60
# dend_63

# %%
# create custom list of spike times
# spkTimes = [2000,2500,3000,3500,4000,4500]
spkTimes = [500,2500,2550,2600,2650,2700,2750,2800,2850,2900,3400]

netParams.popParams['presyn'] = {'cellModel': 'VecStim', 'numCells': 1, 'spkTimes': spkTimes}  # VecStim with spike times

# %%
netParams.cellParams.keys()
# Out:
# odict_keys(['L5_UTPC_cADpyr232_1', 'L5_UTPC_cADpyr232_2', 'L5_UTPC_cADpyr232_3', 'L5_UTPC_cADpyr232_4', 'L5_UTPC_cADpyr232_5'])

# %%
list(netParams.popParams.keys())[0:-1]
# Out:
# ['L5_UTPC_cADpyr232_1_0',
#  'L5_UTPC_cADpyr232_1_1',
#  'L5_UTPC_cADpyr232_1_2',
#  'L5_UTPC_cADpyr232_1_3',
#  'L5_UTPC_cADpyr232_1_4',
#  'L5_UTPC_cADpyr232_2_0',
#  'L5_UTPC_cADpyr232_2_1',
#  'L5_UTPC_cADpyr232_2_2',
#  'L5_UTPC_cADpyr232_2_3',
#  'L5_UTPC_cADpyr232_2_4',
#  'L5_UTPC_cADpyr232_3_0',
#  'L5_UTPC_cADpyr232_3_1',
#  'L5_UTPC_cADpyr232_3_2',
#  'L5_UTPC_cADpyr232_3_3',
#  'L5_UTPC_cADpyr232_3_4',
#  'L5_UTPC_cADpyr232_4_0',
#  'L5_UTPC_cADpyr232_4_1',
#  'L5_UTPC_cADpyr232_4_2',
#  'L5_UTPC_cADpyr232_4_3',
#  'L5_UTPC_cADpyr232_4_4',
#  'L5_UTPC_cADpyr232_5_0',
#  'L5_UTPC_cADpyr232_5_1',
#  'L5_UTPC_cADpyr232_5_2',
#  'L5_UTPC_cADpyr232_5_3',
#  'L5_UTPC_cADpyr232_5_4']

# %%
# 116	0.72±0.50	1.74±0.18	0.50±0.020	671±17	17±5	E2-EE	Excitatory:Excitatory

for ii in range(25):
    netParams.synMechParams['L5_exc:L5_UTPC'+str(ii+1)] = {'mod': 'DetAMPANMDA',
                                          'Dep': 671,
                                          'Fac': 17,
                                          'Use': 0.5, 
                                          'tau_r_AMPA': 0.2,
                                          'tau_d_AMPA': 1.74,
                                          'NMDA_ratio': 0.8,
                                          'tau_r_NMDA': 0.29,
                                          'tau_d_NMDA': 43.0}

# %%
import random

## Cell connectivity rules
for ii in range(25):
    
    listsecs = random.sample(netParams.cellParams[cellName]['secLists']['spinyEE'], len(netParams.cellParams[cellName]['secLists']['spinyEE']))
        
    netParams.connParams['pre->post'+str(ii+1)] = { 
            'preConds': {'pop': 'presyn'},
            'postConds': {'pop': list(netParams.popParams.keys())[ii]},
            'sec': listsecs,                  # target postsyn section
            'synMech': 'L5_exc:L5_UTPC'+str(ii+1),              # target synaptic mechanism
            'weight': 1.50*0.72, # synaptic weight 
            'synsPerConn': 5, 
            'delay': 0.05}

# %%
sim.initialize(
    simConfig = cfg, 	
    netParams = netParams)  				# create network object and set cfg and net params
sim.net.createPops()               			# instantiate network populations
sim.net.createCells()              			# instantiate network cells based on defined populations
sim.net.connectCells()            			# create connections between cells based on params
# Out:
# Start time:  2023-04-18 13:36:01.812105
#
# Creating network of 26 cell populations on 1 hosts...
#   Number of cells on node 0: 26
#   Done; cell creation time = 0.97 s.
# Making connections...
#   Number of connections on node 0: 25
#   Number of synaptic contacts on node 0: 125
#   Done; cell connection time = 0.01 s.
# [[{preGid: 25, sec: 'apic_16', loc: 0.6156522760880084, synMech: 'L5_exc:L5_UTPC1', weight: 1.08, delay: 0.05, label: 'pre->post1', preLoc: 0.5, hObj: NetCon[0]},
#   {preGid: 25, sec: 'apic_37', loc: 0.732579193764446, synMech: 'L5_exc:L5_UTPC1', weight: 1.08, delay: 0.05, label: 'pre->post1', preLoc: 0.5, hObj: NetCon[1]},
#   {preGid: 25, sec: 'apic_33', loc: 0.7146834931972917, synMech: 'L5_exc:L5_UTPC1', weight: 1.08, delay: 0.05, label: 'pre->post1', preLoc: 0.5, hObj: NetCon[2]},
#   {preGid: 25, sec: 'dend_2', loc: 0.9208070293994707, synMech: 'L5_exc:L5_UTPC1', weight: 1.08, delay: 0.05, label: 'pre->post1', preLoc: 0.5, hObj: NetCon[3]},
#   {preGid: 25, sec: 'apic_44', loc: 0.7208087927947867, synMech: 'L5_exc:L5_UTPC1', weight: 1.08, delay: 0.05, label: 'pre->post1', preLoc: 0.5, hObj: NetCon[4]}],
#  [{preGid: 25, sec: 'dend_12', loc: 0.4435724578925806, synMech: 'L5_exc:L5_UTPC2', weight: 1.08, delay: 0.05, label: 'pre->post2', preLoc: 0.5, hObj: NetCon[5]},
#   {preGid: 25, sec: 'dend_10', loc: 0.848828904796066, synMech: 'L5_exc:L5_UTPC2', weight: 1.08, delay: 0.05, label: 'pre->post2', preLoc: 0.5, hObj: NetCon[6]},
#   {preGid: 25, sec: 'dend_24', loc: 0.06925464706038476, synMech: 'L5_exc:L5_UTPC2', weight: 1.08, delay: 0.05, label: 'pre->post2', preLoc: 0.5, hObj: NetCon[7]},
#   {preGid: 25, sec: 'apic_14', loc: 0.5235794912612382, synMech: 'L5_exc:L5_UTPC2', weight: 1.08, delay: 0.05, label: 'pre->post2', preLoc: 0.5, hObj: NetCon[8]},
#   {preGid: 25, sec: 'dend_6', loc: 0.04991152200907137, synMech: 'L5_exc:L5_UTPC2', weight: 1.08, delay: 0.05, label: 'pre->post2', preLoc: 0.5, hObj: NetCon[9]}],
#  [{preGid: 25, sec: 'apic_43', loc: 0.12360799451424181, synMech: 'L5_exc:L5_UTPC3', weight: 1.08, delay: 0.05, label: 'pre->post3', preLoc: 0.5, hObj: NetCon[10]},
#   {preGid: 25, sec: 'dend_24', loc: 0.3950618200962455, synMech: 'L5_exc:L5_UTPC3', weight: 1.08, delay: 0.05, label: 'pre->post3', preLoc: 0.5, hObj: NetCon[11]},
#   {preGid: 25, sec: 'dend_21', loc: 0.998919378392469, synMech: 'L5_exc:L5_UTPC3', weight: 1.08, delay: 0.05, label: 'pre->post3', preLoc: 0.5, hObj: NetCon[12]},
#   {preGid: 25, sec: 'apic_13', loc: 0.1344033634001248, synMech: 'L5_exc:L5_UTPC3', weight: 1.08, delay: 0.05, label: 'pre->post3', preLoc: 0.5, hObj: NetCon[13]},
#   {preGid: 25, sec: 'dend_12', loc: 0.2059666801515066, synMech: 'L5_exc:L5_UTPC3', weight: 1.08, delay: 0.05, label: 'pre->post3', preLoc: 0.5, hObj: NetCon[14]}],
#  [{preGid: 25, sec: 'apic_37', loc: 0.5385790446289496, synMech: 'L5_exc:L5_UTPC4', weight: 1.08, delay: 0.05, label: 'pre->post4', preLoc: 0.5, hObj: NetCon[15]},
#   {preGid: 25, sec: 'apic_17', loc: 0.22206498765284394, synMech: 'L5_exc:L5_UTPC4', weight: 1.08, delay: 0.05, label: 'pre->post4', preLoc: 0.5, hObj: NetCon[16]},
#   {preGid: 25, sec: 'apic_44', loc: 0.06831494796762876, synMech: 'L5_exc:L5_UTPC4', weight: 1.08, delay: 0.05, label: 'pre->post4', preLoc: 0.5, hObj: NetCon[17]},
#   {preGid: 25, sec: 'dend_14', loc: 0.03632122622683168, synMech: 'L5_exc:L5_UTPC4', weight: 1.08, delay: 0.05, label: 'pre->post4', preLoc: 0.5, hObj: NetCon[18]},
#   {preGid: 25, sec: 'apic_35', loc: 0.7373352322583708, synMech: 'L5_exc:L5_UTPC4', weight: 1.08, delay: 0.05, label: 'pre->post4', preLoc: 0.5, hObj: NetCon[19]}],
#  [{preGid: 25, sec: 'dend_12', loc: 0.15501076651962978, synMech: 'L5_exc:L5_UTPC5', weight: 1.08, delay: 0.05, label: 'pre->post5', preLoc: 0.5, hObj: NetCon[20]},
#   {preGid: 25, sec: 'dend_6', loc: 0.5747004988582116, synMech: 'L5_exc:L5_UTPC5', weight: 1.08, delay: 0.05, label: 'pre->post5', preLoc: 0.5, hObj: NetCon[21]},
#   {preGid: 25, sec: 'dend_38', loc: 0.6262638110417779, synMech: 'L5_exc:L5_UTPC5', weight: 1.08, delay: 0.05, label: 'pre->post5', preLoc: 0.5, hObj: NetCon[22]},
#   {preGid: 25, sec: 'dend_24', loc: 0.2963038176456204, synMech: 'L5_exc:L5_UTPC5', weight: 1.08, delay: 0.05, label: 'pre->post5', preLoc: 0.5, hObj: NetCon[23]},
#   {preGid: 25, sec: 'dend_19', loc: 0.7829511485888355, synMech: 'L5_exc:L5_UTPC5', weight: 1.08, delay: 0.05, label: 'pre->post5', preLoc: 0.5, hObj: NetCon[24]}],
#  [{preGid: 25, sec: 'dend_10', loc: 0.040263390634612754, synMech: 'L5_exc:L5_UTPC6', weight: 1.08, delay: 0.05, label: 'pre->post6', preLoc: 0.5, hObj: NetCon[25]},
#   {preGid: 25, sec: 'dend_33', loc: 0.31095347286311115, synMech: 'L5_exc:L5_UTPC6', weight: 1.08, delay: 0.05, label: 'pre->post6', preLoc: 0.5, hObj: NetCon[26]},
#   {preGid: 25, sec: 'apic_23', loc: 0.3832858896167737, synMech: 'L5_exc:L5_UTPC6', weight: 1.08, delay: 0.05, label: 'pre->post6', preLoc: 0.5, hObj: NetCon[27]},
#   {preGid: 25, sec: 'apic_24', loc: 0.2380637625403355, synMech: 'L5_exc:L5_UTPC6', weight: 1.08, delay: 0.05, label: 'pre->post6', preLoc: 0.5, hObj: NetCon[28]},
#   {preGid: 25, sec: 'dend_4', loc: 0.7476813686533035, synMech: 'L5_exc:L5_UTPC6', weight: 1.08, delay: 0.05, label: 'pre->post6', preLoc: 0.5, hObj: NetCon[29]}],
#  [{preGid: 25, sec: 'dend_3', loc: 0.6153438499595525, synMech: 'L5_exc:L5_UTPC7', weight: 1.08, delay: 0.05, label: 'pre->post7', preLoc: 0.5, hObj: NetCon[30]},
#   {preGid: 25, sec: 'dend_12', loc: 0.9992619427084042, synMech: 'L5_exc:L5_UTPC7', weight: 1.08, delay: 0.05, label: 'pre->post7', preLoc: 0.5, hObj: NetCon[31]},
#   {preGid: 25, sec: 'apic_16', loc: 0.8923313349025636, synMech: 'L5_exc:L5_UTPC7', weight: 1.08, delay: 0.05, label: 'pre->post7', preLoc: 0.5, hObj: NetCon[32]},
#   {preGid: 25, sec: 'apic_40', loc: 0.8801010708817468, synMech: 'L5_exc:L5_UTPC7', weight: 1.08, delay: 0.05, label: 'pre->post7', preLoc: 0.5, hObj: NetCon[33]},
#   {preGid: 25, sec: 'dend_1', loc: 0.533043458777709, synMech: 'L5_exc:L5_UTPC7', weight: 1.08, delay: 0.05, label: 'pre->post7', preLoc: 0.5, hObj: NetCon[34]}],
#  [{preGid: 25, sec: 'dend_21', loc: 0.2592231204619252, synMech: 'L5_exc:L5_UTPC8', weight: 1.08, delay: 0.05, label: 'pre->post8', preLoc: 0.5, hObj: NetCon[35]},
#   {preGid: 25, sec: 'dend_31', loc: 0.16124064094215698, synMech: 'L5_exc:L5_UTPC8', weight: 1.08, delay: 0.05, label: 'pre->post8', preLoc: 0.5, hObj: NetCon[36]},
#   {preGid: 25, sec: 'apic_40', loc: 0.9020819543185851, synMech: 'L5_exc:L5_UTPC8', weight: 1.08, delay: 0.05, label: 'pre->post8', preLoc: 0.5, hObj: NetCon[37]},
#   {preGid: 25, sec: 'apic_35', loc: 0.7735773517949812, synMech: 'L5_exc:L5_UTPC8', weight: 1.08, delay: 0.05, label: 'pre->post8', preLoc: 0.5, hObj: NetCon[38]},
#   {preGid: 25, sec: 'apic_30', loc: 0.7031125382316542, synMech: 'L5_exc:L5_UTPC8', weight: 1.08, delay: 0.05, label: 'pre->post8', preLoc: 0.5, hObj: NetCon[39]}],
#  [{preGid: 25, sec: 'apic_42', loc: 0.20709664532045624, synMech: 'L5_exc:L5_UTPC9', weight: 1.08, delay: 0.05, label: 'pre->post9', preLoc: 0.5, hObj: NetCon[40]},
#   {preGid: 25, sec: 'dend_33', loc: 0.6692405484414412, synMech: 'L5_exc:L5_UTPC9', weight: 1.08, delay: 0.05, label: 'pre->post9', preLoc: 0.5, hObj: NetCon[41]},
#   {preGid: 25, sec: 'apic_21', loc: 0.08774366779100194, synMech: 'L5_exc:L5_UTPC9', weight: 1.08, delay: 0.05, label: 'pre->post9', preLoc: 0.5, hObj: NetCon[42]},
#   {preGid: 25, sec: 'apic_50', loc: 0.8201442146674616, synMech: 'L5_exc:L5_UTPC9', weight: 1.08, delay: 0.05, label: 'pre->post9', preLoc: 0.5, hObj: NetCon[43]},
#   {preGid: 25, sec: 'dend_13', loc: 0.9800311295974141, synMech: 'L5_exc:L5_UTPC9', weight: 1.08, delay: 0.05, label: 'pre->post9', preLoc: 0.5, hObj: NetCon[44]}],
#  [{preGid: 25, sec: 'dend_29', loc: 0.5299366585946873, synMech: 'L5_exc:L5_UTPC10', weight: 1.08, delay: 0.05, label: 'pre->post10', preLoc: 0.5, hObj: NetCon[45]},
#   {preGid: 25, sec: 'apic_16', loc: 0.6390631581503181, synMech: 'L5_exc:L5_UTPC10', weight: 1.08, delay: 0.05, label: 'pre->post10', preLoc: 0.5, hObj: NetCon[46]},
#   {preGid: 25, sec: 'apic_27', loc: 0.38378251833081506, synMech: 'L5_exc:L5_UTPC10', weight: 1.08, delay: 0.05, label: 'pre->post10', preLoc: 0.5, hObj: NetCon[47]},
#   {preGid: 25, sec: 'apic_24', loc: 0.7081227132625167, synMech: 'L5_exc:L5_UTPC10', weight: 1.08, delay: 0.05, label: 'pre->post10', preLoc: 0.5, hObj: NetCon[48]},
#   {preGid: 25, sec: 'dend_11', loc: 0.2924093695799401, synMech: 'L5_exc:L5_UTPC10', weight: 1.08, delay: 0.05, label: 'pre->post10', preLoc: 0.5, hObj: NetCon[49]}],
#  [{preGid: 25, sec: 'apic_13', loc: 0.29303755319714575, synMech: 'L5_exc:L5_UTPC11', weight: 1.08, delay: 0.05, label: 'pre->post11', preLoc: 0.5, hObj: NetCon[50]},
#   {preGid: 25, sec: 'apic_28', loc: 0.43316642424475454, synMech: 'L5_exc:L5_UTPC11', weight: 1.08, delay: 0.05, label: 'pre->post11', preLoc: 0.5, hObj: NetCon[51]},
#   {preGid: 25, sec: 'apic_23', loc: 0.3280208772453439, synMech: 'L5_exc:L5_UTPC11', weight: 1.08, delay: 0.05, label: 'pre->post11', preLoc: 0.5, hObj: NetCon[52]},
#   {preGid: 25, sec: 'apic_16', loc: 0.5272949725155595, synMech: 'L5_exc:L5_UTPC11', weight: 1.08, delay: 0.05, label: 'pre->post11', preLoc: 0.5, hObj: NetCon[53]},
#   {preGid: 25, sec: 'apic_26', loc: 0.9606752263433551, synMech: 'L5_exc:L5_UTPC11', weight: 1.08, delay: 0.05, label: 'pre->post11', preLoc: 0.5, hObj: NetCon[54]}],
#  [{preGid: 25, sec: 'apic_20', loc: 0.9123590581289808, synMech: 'L5_exc:L5_UTPC12', weight: 1.08, delay: 0.05, label: 'pre->post12', preLoc: 0.5, hObj: NetCon[55]},
#   {preGid: 25, sec: 'apic_26', loc: 0.8235717906958427, synMech: 'L5_exc:L5_UTPC12', weight: 1.08, delay: 0.05, label: 'pre->post12', preLoc: 0.5, hObj: NetCon[56]},
#   {preGid: 25, sec: 'dend_1', loc: 0.520531337411679, synMech: 'L5_exc:L5_UTPC12', weight: 1.08, delay: 0.05, label: 'pre->post12', preLoc: 0.5, hObj: NetCon[57]},
#   {preGid: 25, sec: 'apic_28', loc: 0.7143125799940672, synMech: 'L5_exc:L5_UTPC12', weight: 1.08, delay: 0.05, label: 'pre->post12', preLoc: 0.5, hObj: NetCon[58]},
#   {preGid: 25, sec: 'apic_22', loc: 0.626548073086445, synMech: 'L5_exc:L5_UTPC12', weight: 1.08, delay: 0.05, label: 'pre->post12', preLoc: 0.5, hObj: NetCon[59]}],
#  [{preGid: 25, sec: 'dend_21', loc: 0.5796313776335544, synMech: 'L5_exc:L5_UTPC13', weight: 1.08, delay: 0.05, label: 'pre->post13', preLoc: 0.5, hObj: NetCon[60]},
#   {preGid: 25, sec: 'dend_38', loc: 0.6328745094861699, synMech: 'L5_exc:L5_UTPC13', weight: 1.08, delay: 0.05, label: 'pre->post13', preLoc: 0.5, hObj: NetCon[61]},
#   {preGid: 25, sec: 'dend_29', loc: 0.4848192669702412, synMech: 'L5_exc:L5_UTPC13', weight: 1.08, delay: 0.05, label: 'pre->post13', preLoc: 0.5, hObj: NetCon[62]},
#   {preGid: 25, sec: 'apic_34', loc: 0.6580989885961407, synMech: 'L5_exc:L5_UTPC13', weight: 1.08, delay: 0.05, label: 'pre->post13', preLoc: 0.5, hObj: NetCon[63]},
#   {preGid: 25, sec: 'dend_10', loc: 0.20961196468828242, synMech: 'L5_exc:L5_UTPC13', weight: 1.08, delay: 0.05, label: 'pre->post13', preLoc: 0.5, hObj: NetCon[64]}],
#  [{preGid: 25, sec: 'apic_48', loc: 0.42187628404447775, synMech: 'L5_exc:L5_UTPC14', weight: 1.08, delay: 0.05, label: 'pre->post14', preLoc: 0.5, hObj: NetCon[65]},
#   {preGid: 25, sec: 'dend_39', loc: 0.08214422459102823, synMech: 'L5_exc:L5_UTPC14', weight: 1.08, delay: 0.05, label: 'pre->post14', preLoc: 0.5, hObj: NetCon[66]},
#   {preGid: 25, sec: 'dend_42', loc: 0.5999091120332215, synMech: 'L5_exc:L5_UTPC14', weight: 1.08, delay: 0.05, label: 'pre->post14', preLoc: 0.5, hObj: NetCon[67]},
#   {preGid: 25, sec: 'apic_41', loc: 0.4617472298887214, synMech: 'L5_exc:L5_UTPC14', weight: 1.08, delay: 0.05, label: 'pre->post14', preLoc: 0.5, hObj: NetCon[68]},
#   {preGid: 25, sec: 'dend_10', loc: 0.6946528415611486, synMech: 'L5_exc:L5_UTPC14', weight: 1.08, delay: 0.05, label: 'pre->post14', preLoc: 0.5, hObj: NetCon[69]}],
#  [{preGid: 25, sec: 'dend_13', loc: 0.16982058024738667, synMech: 'L5_exc:L5_UTPC15', weight: 1.08, delay: 0.05, label: 'pre->post15', preLoc: 0.5, hObj: NetCon[70]},
#   {preGid: 25, sec: 'dend_1', loc: 0.497498824645414, synMech: 'L5_exc:L5_UTPC15', weight: 1.08, delay: 0.05, label: 'pre->post15', preLoc: 0.5, hObj: NetCon[71]},
#   {preGid: 25, sec: 'dend_41', loc: 0.42064944016712447, synMech: 'L5_exc:L5_UTPC15', weight: 1.08, delay: 0.05, label: 'pre->post15', preLoc: 0.5, hObj: NetCon[72]},
#   {preGid: 25, sec: 'apic_16', loc: 0.06480242259224213, synMech: 'L5_exc:L5_UTPC15', weight: 1.08, delay: 0.05, label: 'pre->post15', preLoc: 0.5, hObj: NetCon[73]},
#   {preGid: 25, sec: 'dend_31', loc: 0.046418497092290026, synMech: 'L5_exc:L5_UTPC15', weight: 1.08, delay: 0.05, label: 'pre->post15', preLoc: 0.5, hObj: NetCon[74]}],
#  [{preGid: 25, sec: 'apic_9', loc: 0.7236988011256066, synMech: 'L5_exc:L5_UTPC16', weight: 1.08, delay: 0.05, label: 'pre->post16', preLoc: 0.5, hObj: NetCon[75]},
#   {preGid: 25, sec: 'dend_33', loc: 0.7538102591620623, synMech: 'L5_exc:L5_UTPC16', weight: 1.08, delay: 0.05, label: 'pre->post16', preLoc: 0.5, hObj: NetCon[76]},
#   {preGid: 25, sec: 'apic_28', loc: 0.1636375615958682, synMech: 'L5_exc:L5_UTPC16', weight: 1.08, delay: 0.05, label: 'pre->post16', preLoc: 0.5, hObj: NetCon[77]},
#   {preGid: 25, sec: 'apic_25', loc: 0.20011047613891728, synMech: 'L5_exc:L5_UTPC16', weight: 1.08, delay: 0.05, label: 'pre->post16', preLoc: 0.5, hObj: NetCon[78]},
#   {preGid: 25, sec: 'dend_28', loc: 0.9521163270402132, synMech: 'L5_exc:L5_UTPC16', weight: 1.08, delay: 0.05, label: 'pre->post16', preLoc: 0.5, hObj: NetCon[79]}],
#  [{preGid: 25, sec: 'dend_1', loc: 0.4426630970154526, synMech: 'L5_exc:L5_UTPC17', weight: 1.08, delay: 0.05, label: 'pre->post17', preLoc: 0.5, hObj: NetCon[80]},
#   {preGid: 25, sec: 'apic_23', loc: 0.22049783331960227, synMech: 'L5_exc:L5_UTPC17', weight: 1.08, delay: 0.05, label: 'pre->post17', preLoc: 0.5, hObj: NetCon[81]},
#   {preGid: 25, sec: 'dend_38', loc: 0.7800591919770687, synMech: 'L5_exc:L5_UTPC17', weight: 1.08, delay: 0.05, label: 'pre->post17', preLoc: 0.5, hObj: NetCon[82]},
#   {preGid: 25, sec: 'apic_14', loc: 0.1410522117879383, synMech: 'L5_exc:L5_UTPC17', weight: 1.08, delay: 0.05, label: 'pre->post17', preLoc: 0.5, hObj: NetCon[83]},
#   {preGid: 25, sec: 'dend_30', loc: 0.24931220596828094, synMech: 'L5_exc:L5_UTPC17', weight: 1.08, delay: 0.05, label: 'pre->post17', preLoc: 0.5, hObj: NetCon[84]}],
#  [{preGid: 25, sec: 'dend_22', loc: 0.2774726534075898, synMech: 'L5_exc:L5_UTPC18', weight: 1.08, delay: 0.05, label: 'pre->post18', preLoc: 0.5, hObj: NetCon[85]},
#   {preGid: 25, sec: 'dend_4', loc: 0.49868610268064334, synMech: 'L5_exc:L5_UTPC18', weight: 1.08, delay: 0.05, label: 'pre->post18', preLoc: 0.5, hObj: NetCon[86]},
#   {preGid: 25, sec: 'apic_7', loc: 0.9125559586979878, synMech: 'L5_exc:L5_UTPC18', weight: 1.08, delay: 0.05, label: 'pre->post18', preLoc: 0.5, hObj: NetCon[87]},
#   {preGid: 25, sec: 'apic_11', loc: 0.301674521033421, synMech: 'L5_exc:L5_UTPC18', weight: 1.08, delay: 0.05, label: 'pre->post18', preLoc: 0.5, hObj: NetCon[88]},
#   {preGid: 25, sec: 'apic_57', loc: 0.22964770589283223, synMech: 'L5_exc:L5_UTPC18', weight: 1.08, delay: 0.05, label: 'pre->post18', preLoc: 0.5, hObj: NetCon[89]}],
#  [{preGid: 25, sec: 'apic_55', loc: 0.9078916261417841, synMech: 'L5_exc:L5_UTPC19', weight: 1.08, delay: 0.05, label: 'pre->post19', preLoc: 0.5, hObj: NetCon[90]},
#   {preGid: 25, sec: 'apic_56', loc: 0.15740212226121678, synMech: 'L5_exc:L5_UTPC19', weight: 1.08, delay: 0.05, label: 'pre->post19', preLoc: 0.5, hObj: NetCon[91]},
#   {preGid: 25, sec: 'apic_26', loc: 0.6358726742956144, synMech: 'L5_exc:L5_UTPC19', weight: 1.08, delay: 0.05, label: 'pre->post19', preLoc: 0.5, hObj: NetCon[92]},
#   {preGid: 25, sec: 'dend_30', loc: 0.3745432308543455, synMech: 'L5_exc:L5_UTPC19', weight: 1.08, delay: 0.05, label: 'pre->post19', preLoc: 0.5, hObj: NetCon[93]},
#   {preGid: 25, sec: 'apic_27', loc: 0.7254055468328965, synMech: 'L5_exc:L5_UTPC19', weight: 1.08, delay: 0.05, label: 'pre->post19', preLoc: 0.5, hObj: NetCon[94]}],
#  [{preGid: 25, sec: 'apic_33', loc: 0.13763542862711467, synMech: 'L5_exc:L5_UTPC20', weight: 1.08, delay: 0.05, label: 'pre->post20', preLoc: 0.5, hObj: NetCon[95]},
#   {preGid: 25, sec: 'dend_57', loc: 0.18650948487642194, synMech: 'L5_exc:L5_UTPC20', weight: 1.08, delay: 0.05, label: 'pre->post20', preLoc: 0.5, hObj: NetCon[96]},
#   {preGid: 25, sec: 'dend_25', loc: 0.8104472670994993, synMech: 'L5_exc:L5_UTPC20', weight: 1.08, delay: 0.05, label: 'pre->post20', preLoc: 0.5, hObj: NetCon[97]},
#   {preGid: 25, sec: 'dend_35', loc: 0.08881704257118128, synMech: 'L5_exc:L5_UTPC20', weight: 1.08, delay: 0.05, label: 'pre->post20', preLoc: 0.5, hObj: NetCon[98]},
#   {preGid: 25, sec: 'dend_17', loc: 0.0842729132587869, synMech: 'L5_exc:L5_UTPC20', weight: 1.08, delay: 0.05, label: 'pre->post20', preLoc: 0.5, hObj: NetCon[99]}],
#  [{preGid: 25, sec: 'dend_50', loc: 0.26503835294063083, synMech: 'L5_exc:L5_UTPC21', weight: 1.08, delay: 0.05, label: 'pre->post21', preLoc: 0.5, hObj: NetCon[100]},
#   {preGid: 25, sec: 'dend_11', loc: 0.3027161818525901, synMech: 'L5_exc:L5_UTPC21', weight: 1.08, delay: 0.05, label: 'pre->post21', preLoc: 0.5, hObj: NetCon[101]},
#   {preGid: 25, sec: 'apic_19', loc: 0.5872722390332801, synMech: 'L5_exc:L5_UTPC21', weight: 1.08, delay: 0.05, label: 'pre->post21', preLoc: 0.5, hObj: NetCon[102]},
#   {preGid: 25, sec: 'dend_60', loc: 0.54920320233008, synMech: 'L5_exc:L5_UTPC21', weight: 1.08, delay: 0.05, label: 'pre->post21', preLoc: 0.5, hObj: NetCon[103]},
#   {preGid: 25, sec: 'dend_54', loc: 0.8304801696947512, synMech: 'L5_exc:L5_UTPC21', weight: 1.08, delay: 0.05, label: 'pre->post21', preLoc: 0.5, hObj: NetCon[104]}],
#  [{preGid: 25, sec: 'apic_19', loc: 0.9482670052126029, synMech: 'L5_exc:L5_UTPC22', weight: 1.08, delay: 0.05, label: 'pre->post22', preLoc: 0.5, hObj: NetCon[105]},
#   {preGid: 25, sec: 'apic_40', loc: 0.8394395341852972, synMech: 'L5_exc:L5_UTPC22', weight: 1.08, delay: 0.05, label: 'pre->post22', preLoc: 0.5, hObj: NetCon[106]},
#   {preGid: 25, sec: 'dend_4', loc: 0.8531204394663442, synMech: 'L5_exc:L5_UTPC22', weight: 1.08, delay: 0.05, label: 'pre->post22', preLoc: 0.5, hObj: NetCon[107]},
#   {preGid: 25, sec: 'dend_17', loc: 0.3945556472526345, synMech: 'L5_exc:L5_UTPC22', weight: 1.08, delay: 0.05, label: 'pre->post22', preLoc: 0.5, hObj: NetCon[108]},
#   {preGid: 25, sec: 'apic_5', loc: 0.5199739469196807, synMech: 'L5_exc:L5_UTPC22', weight: 1.08, delay: 0.05, label: 'pre->post22', preLoc: 0.5, hObj: NetCon[109]}],
#  [{preGid: 25, sec: 'dend_17', loc: 0.8771118664921671, synMech: 'L5_exc:L5_UTPC23', weight: 1.08, delay: 0.05, label: 'pre->post23', preLoc: 0.5, hObj: NetCon[110]},
#   {preGid: 25, sec: 'dend_15', loc: 0.5513044411684442, synMech: 'L5_exc:L5_UTPC23', weight: 1.08, delay: 0.05, label: 'pre->post23', preLoc: 0.5, hObj: NetCon[111]},
#   {preGid: 25, sec: 'dend_41', loc: 0.06585645799879264, synMech: 'L5_exc:L5_UTPC23', weight: 1.08, delay: 0.05, label: 'pre->post23', preLoc: 0.5, hObj: NetCon[112]},
#   {preGid: 25, sec: 'apic_35', loc: 0.11434754169678758, synMech: 'L5_exc:L5_UTPC23', weight: 1.08, delay: 0.05, label: 'pre->post23', preLoc: 0.5, hObj: NetCon[113]},
#   {preGid: 25, sec: 'apic_19', loc: 0.27706822969979034, synMech: 'L5_exc:L5_UTPC23', weight: 1.08, delay: 0.05, label: 'pre->post23', preLoc: 0.5, hObj: NetCon[114]}],
#  [{preGid: 25, sec: 'apic_11', loc: 0.7331137537243093, synMech: 'L5_exc:L5_UTPC24', weight: 1.08, delay: 0.05, label: 'pre->post24', preLoc: 0.5, hObj: NetCon[115]},
#   {preGid: 25, sec: 'apic_43', loc: 0.2464085326784139, synMech: 'L5_exc:L5_UTPC24', weight: 1.08, delay: 0.05, label: 'pre->post24', preLoc: 0.5, hObj: NetCon[116]},
#   {preGid: 25, sec: 'apic_31', loc: 0.9988594265430357, synMech: 'L5_exc:L5_UTPC24', weight: 1.08, delay: 0.05, label: 'pre->post24', preLoc: 0.5, hObj: NetCon[117]},
#   {preGid: 25, sec: 'dend_54', loc: 0.9799428557087778, synMech: 'L5_exc:L5_UTPC24', weight: 1.08, delay: 0.05, label: 'pre->post24', preLoc: 0.5, hObj: NetCon[118]},
#   {preGid: 25, sec: 'dend_40', loc: 0.8039862941101356, synMech: 'L5_exc:L5_UTPC24', weight: 1.08, delay: 0.05, label: 'pre->post24', preLoc: 0.5, hObj: NetCon[119]}],
#  [{preGid: 25, sec: 'apic_63', loc: 0.7670579538192316, synMech: 'L5_exc:L5_UTPC25', weight: 1.08, delay: 0.05, label: 'pre->post25', preLoc: 0.5, hObj: NetCon[120]},
#   {preGid: 25, sec: 'dend_26', loc: 0.616490420677247, synMech: 'L5_exc:L5_UTPC25', weight: 1.08, delay: 0.05, label: 'pre->post25', preLoc: 0.5, hObj: NetCon[121]},
#   {preGid: 25, sec: 'apic_66', loc: 0.7309719702903918, synMech: 'L5_exc:L5_UTPC25', weight: 1.08, delay: 0.05, label: 'pre->post25', preLoc: 0.5, hObj: NetCon[122]},
#   {preGid: 25, sec: 'dend_2', loc: 0.8305260805729502, synMech: 'L5_exc:L5_UTPC25', weight: 1.08, delay: 0.05, label: 'pre->post25', preLoc: 0.5, hObj: NetCon[123]},
#   {preGid: 25, sec: 'apic_27', loc: 0.7781290030348836, synMech: 'L5_exc:L5_UTPC25', weight: 1.08, delay: 0.05, label: 'pre->post25', preLoc: 0.5, hObj: NetCon[124]}],
#  []]

# %%
sim.net.addStims() 							# add network stimulation
sim.setupRecording()              			# setup variables to record for each cell (spikes, V traces, etc)
# Out:
#   Number of stims on node 0: 0
#   Done; cell stims creation time = 0.00 s.
# Recording 25 traces of 1 types on node 0
# {spkt: Vector[11574], spkid: Vector[11575], V_soma: {cell_0: Vector[11576], cell_1: Vector[11577], cell_2: Vector[11578], cell_3: Vector[11579], cell_4: Vector[11580], cell_5: Vector[11581], cell_6: Vector[11582], cell_7: Vector[11583], cell_8: Vector[11584], cell_9: Vector[11585], cell_10: Vector[11586], cell_11: Vector[11587], cell_12: Vector[11588], cell_13: Vector[11589], cell_14: Vector[11590], cell_15: Vector[11591], cell_16: Vector[11592], cell_17: Vector[11593], cell_18: Vector[11594], cell_19: Vector[11595], cell_20: Vector[11596], cell_21: Vector[11597], cell_22: Vector[11598], cell_23: Vector[11599], cell_24: Vector[11600]}, t: Vector[11601], _repr_mimebundle_: {}}

# %%
sim.runSim()                      			# run Neuron simulation
# Out:
# 0.0s
#
# Running simulation using NEURON for 4000.0 ms...
# 0.1s
# 0.2s
# 0.3s
# 0.4s
# 0.5s
# 0.6s
# 0.7s
# 0.8s
# 0.9s
# 1.0s
# 1.1s
# 1.2s
# 1.3s
# 1.4s
# 1.5s
# 1.6s
# 1.7s
# 1.8s
# 1.9s
# 2.0s
# 2.1s
# 2.2s
# 2.3s
# 2.4s
# 2.5s
# 2.6s
# 2.7s
# 2.8s
# 2.9s
# 3.0s
# 3.1s
# 3.2s
# 3.3s
# 3.4s
# 3.5s
# 3.6s
# 3.7s
# 3.8s
# 3.9s
# 4.0s
#   Done; run time = 512.15 s; real-time ratio: 0.01.

# %%
sim.gatherData()                  			# gather spiking data and cell info from each node
sim.saveData()                    			# save params, cell info and sim output to file (pickle,mat,txt,etc)#
sim.analysis.plotData()         			# plot spike raster etc
# Out:
# Gathering data...
#   Done; gather time = 0.05 s.
#
# Analyzing...
#   Cells: 26
#   Connections: 25 (0.96 per cell)
#   Synaptic contacts: 125 (4.81 per cell)
#   Spikes: 11 (0.11 Hz)
#   Simulated time: 4.0 s; 1 workers
#   Run time: 512.15 s
# Warning: data won't be saved. No output format specified (consider sim.cfg.savePickle, sim.cfg.saveJson etc.)
# Plotting recorded cell traces ... trace
#   Done; plotting time = 0.33 s
#
# Total time = 513.55 s

# %%
# sim.analysis.plotRaster(figSize=(10, 3))

# %%
alltraces = []
gmax1 = []

# spkTimes = [500,2500,2550,2600,2650,2700,2750,2800,2850,2900,3400]


Traces2 = sim.analysis.plotTraces(oneFigPer='trace', overlay=1, timeRange=[2400,3900],axis=False,legend=False,scaleBarLoc=1,figSize=(10, 3),fontSize=6)
for number in range(25):
    if np.max(Traces2[1]['tracesData'][number]['cell_'+str(number)+'_V_soma'])-np.min(Traces2[1]['tracesData'][number]['cell_'+str(number)+'_V_soma']) > 0.01:
        alltraces.append(Traces2[1]['tracesData'][number]['cell_'+str(number)+'_V_soma'])
        gmax1.append(np.max(Traces2[1]['tracesData'][number]['cell_'+str(number)+'_V_soma'])-np.min(Traces2[1]['tracesData'][number]['cell_'+str(number)+'_V_soma']))
#         print(number,np.max(Traces2[1]['tracesData'][number]['cell_'+str(number)+'_V_soma'])-np.min(Traces2[1]['tracesData'][number]['cell_'+str(number)+'_V_soma']))


# Traces2 = sim.analysis.plotTraces(oneFigPer='trace', overlay=1, timeRange=[3300,3900],axis=False,legend=False,scaleBarLoc=1,figSize=(10, 3),fontSize=6)
# for number in range(20):
#     if np.max(Traces2[1]['tracesData'][number]['cell_'+str(number)+'_V_soma'])-np.min(Traces2[1]['tracesData'][number]['cell_'+str(number)+'_V_soma']) > 0.01:
#         alltraces.append(Traces2[1]['tracesData'][number]['cell_'+str(number)+'_V_soma'])
#         gmax1.append(np.max(Traces2[1]['tracesData'][number]['cell_'+str(number)+'_V_soma'])-np.min(Traces2[1]['tracesData'][number]['cell_'+str(number)+'_V_soma']))
# #         print(number,np.max(Traces2[1]['tracesData'][number]['cell_'+str(number)+'_V_soma'])-np.min(Traces2[1]['tracesData'][number]['cell_'+str(number)+'_V_soma']))


# print('L23_PC:L23_PC in silico PSP amplitude (mV; mean ± SD) = %.3f±%.3f' % (np.mean(gmax1),np.std(gmax1)))
print('L5_exc:L5_UTPC in silico PSP amplitude (mV; mean ± SD) = %.3f±%.3f' % (np.mean(gmax1),np.std(gmax1)))
# Out:
# Plotting recorded cell traces ... trace
# L5_exc:L5_UTPC in silico PSP amplitude (mV; mean ± SD) = 1.479±0.291

# %%
figSize = (16,9)
fig = plt.figure(figsize=figSize)  # Open a new figure
clr = ["black", "blue","green","gray", "red"]
number=0
for i in range(5):
    for number2 in range(i,25,5):
        plt.plot(Traces2[1]['tracesData'][number]['t'][1:],Traces2[1]['tracesData'][number]['cell_'+str(number)+'_V_soma']-Traces2[1]['tracesData'][number]['cell_'+str(number)+'_V_soma'][999]-1.0*i, label= sim.net.allCells[number]['tags']['pop'] + '_' + sim.net.allCells[number]['conns'][0]['sec'], linewidth=1.0, color=clr[i])
        number+=1
        
plt.legend(loc='upper right', bbox_to_anchor=(1.2, 1.0), fontsize=14)
# plt.xlim(2400,4150)
plt.ylim(-4.25,2.0)
plt.xlabel('Time (ms)', fontsize=16)
plt.ylabel('EPSP (mV)', fontsize=16)
# plt.xticks(range(2400,3900,200), range(0,1500,200), fontsize=14);
plt.yticks([0,1], fontsize=14);

# %%
figSize = (8,5)
fig = plt.figure(figsize=figSize)  # Open a new figure
for number in range(np.shape(alltraces)[0]):
    plt.plot(alltraces[number]-alltraces[number][0],color = 'lightgray',linewidth=2.0)

plt.title('Vrev -80 mV and gsyn = 150p  ->  %.2f ± %.2f mV' % (np.mean(gmax1),np.std(gmax1)), fontsize=14)
plt.plot(np.mean(alltraces, axis=0)-np.mean(alltraces, axis=0)[0],color = 'black', linewidth=4.0)
# plt.legend(loc='upper right', bbox_to_anchor=(0.95, 1.0))
plt.xlim(500,12000)
plt.ylim(-0.25,1.5)
plt.xlabel('Time (ms)', fontsize=16)
plt.ylabel('PSP (mV)', fontsize=16)
plt.xticks(range(1000,12000,2000), range(0,1100,200), fontsize=14);
plt.yticks([0,1,2], fontsize=14); 

plt.savefig('../info/syn_gmax_L5exc_L5UTPC_150p.png', facecolor = 'white' , dpi=300)

# %%
# (0.8355167606552806, 25)

# %%
np.mean(gmax1), np.size(gmax1)
# Out:
# (1.4792487770426652, 25)

# %% [markdown]
# <!-- Connection type	s-type	in vitro PSP amplitude (mV; mean ± SD)	in silico PSP amplitude (mV; mean ± SD)	Input data sources
# L5TTPC-L5MC	E1	0.28 ± 0.3	0.28 ± 0.18	Silberberg & Markram, 2007
# L5MC-L5TTPC	I2	0.5 ± 0.3	0.57 ± 0.5	Silberberg & Markram, 2007
# L4SS-L23PC	E2	0.7 ± 0.6	0.7 ± 0.9	Feldmeyer et al. 2002
# L5STPC-L5STPC	E2	0.9 ± 0.7	0.91 ± 0.8	Le Bé et al. 2007
# L5UTPC-L5UTPC	E2	0.9 ± 0.7	0.91 ± 0.8	Le Bé et al. 2007
# L23PC-L23PC	E2	1 ± 0.7	1 ± 0.3	Feldmeyer et al. 2006
# L23LBC-L23PC	I2	1.2 ± 1.1	1.2 ± 1.02	Blatow et al. 2003
# L23NBC-L23PC	I2	1.2 ± 1.1	1.2 ± 1.02	Blatow et al. 2003
# L5TTPC-L5TTPC	E2	1.3 ± 1.1	1.2 ± 0.43	Markram et al. 1997
# L4SS-L4SS	E2	1.6 ± 1.0	1.9 ± 1.5	Feldmeyer et al. 1999
# L4SP-L4SP	E2	1.6 ± 1.0	1.9 ± 1.5	Feldmeyer et al. 1999
# L4PC-L4PC	E2	1.6 ± 1.0	1.9 ± 1.5	Feldmeyer et al. 1999
# L5TTPC-L5SBC	E2	2.1 ± 1.0	1.96 ± 0.67	Angulo et al. 1999 -->
# ![image.png](attachment:image.png)

# %%
Connectiontype = ['L5TTPC_L5MC_E1', 'L5MC_L5TTPC_I2', 'L4SS_L23PC_E2', 'L5STPC_L5STPC_E2', 'L5UTPC_L5UTPC_E2', 'L23PC_L23PC_E2', 
                  'L23LBC_L23PC_I2', 'L23NBC_L23PC_I2', 'L5TTPC_L5TTPC_E2', 'L4SS_L4SS_E2', 'L4SP_L4SP_E2', 'L4PC_L4PC_E2', 'L5TTPC_L5SBC_E2']

# %%
table13c = [0.28, 0.3, 0.28, 0.18, 0.50, 0.3, 0.57, 0.50, 0.70, 0.6, 0.70, 0.90, 0.90, 0.7, 0.91, 0.80, 0.90, 0.7, 0.91, 0.80, 
            1.00, 0.7, 1.00, 0.30, 1.20, 1.1, 1.20, 1.02, 1.20, 1.1, 1.20, 1.02, 1.30, 1.1, 1.20, 0.43, 1.60, 1.0, 1.90, 1.50, 
            1.60, 1.0, 1.90, 1.50, 1.60, 1.0, 1.90, 1.50, 2.10, 1.0, 1.96, 0.67]

# %%
x = []
sx = []
y = []
sy = []

for ii in range(13):
    print(Connectiontype[ii],table13c[4*ii],table13c[4*ii+1],table13c[4*ii+2],table13c[4*ii+3])
    x.append(table13c[4*ii])
    sx.append(table13c[4*ii+1])
    y.append(table13c[4*ii+2])
    sy.append(table13c[4*ii+3])
# Out:
# L5TTPC_L5MC_E1 0.28 0.3 0.28 0.18
# L5MC_L5TTPC_I2 0.5 0.3 0.57 0.5
# L4SS_L23PC_E2 0.7 0.6 0.7 0.9
# L5STPC_L5STPC_E2 0.9 0.7 0.91 0.8
# L5UTPC_L5UTPC_E2 0.9 0.7 0.91 0.8
# L23PC_L23PC_E2 1.0 0.7 1.0 0.3
# L23LBC_L23PC_I2 1.2 1.1 1.2 1.02
# L23NBC_L23PC_I2 1.2 1.1 1.2 1.02
# L5TTPC_L5TTPC_E2 1.3 1.1 1.2 0.43
# L4SS_L4SS_E2 1.6 1.0 1.9 1.5
# L4SP_L4SP_E2 1.6 1.0 1.9 1.5
# L4PC_L4PC_E2 1.6 1.0 1.9 1.5
# L5TTPC_L5SBC_E2 2.1 1.0 1.96 0.67

# %%
import matplotlib.pyplot as plt

# a = [1, 3, 5, 7]
# b = [11, -2, 4, 19]
# plt.scatter(a, b)


# c = [1, 3, 2, 1]
# d = [1, 3, 2, 1]

# you can use color ="r" for red or skip to default as blue
# plt.errorbar(x, y, xerr=sx, yerr=sy, fmt="o", color="r")
plt.scatter(x, y)

plt.show()
