# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# # Input-output properties cells

# %%
import numpy as np
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
rootFolder = '/home/fernando/Dropbox/SUNY/2022/S1_netpyne/sim/'
# rootFolder = os.getcwd()
os.chdir(rootFolder)
print(rootFolder)
folder = os.listdir('cell_data/')
folder = sorted(folder)

savedata = 1 # Save Netpyne and BBP soma_voltage
# Out:
# /home/fernando/Dropbox/SUNY/2022/S1_netpyne/sim/

# %%
# !nrnivmodl mod

# %%
def loadTemplateName(cellnumber):     
    f = open(outFolder+'/template.hoc', 'r')
    for line in f.readlines():
        if 'begintemplate' in line:
            templatename = str(line)     
    templatename=templatename[:-1]        
    templatename=templatename[14:]
    return templatename

# %% [markdown]
# ## Netpyne

# %%
from netpyne import specs, sim   

# Network parameters
netParams = specs.NetParams()  # object of class NetParams to store the network parameters

# %%
# %matplotlib inline

# %%
## cfg  
cfg = specs.SimConfig()					            # object of class SimConfig to store simulation configuration
cfg.duration = 4000.0 						            # Duration of the simulation, in ms
cfg.dt = 0.05								                # Internal integration timestep to use
cfg.verbose = False							                # Show detailed messages 
cfg.recordTraces = {'V_soma':{'sec':'soma','loc':0.5,'var':'v'}}  # Dict with traces to record
cfg.recordStep = 0.1 			
cfg.printRunTime = 0.1 # in sec			

cfg.seeds = {'conn': 1, 'stim': 1, 'loc': 1} 
cfg.hParams = {'celsius': 34, 'v_init': -71.0}  
cfg.verbose = False
cfg.createNEURONObj = True
cfg.createPyStruct = True  
#------------------------------------------------------------------------------
# Saving
#------------------------------------------------------------------------------
cfg.filename = 'model_output'  			# Set file output name
cfg.savePickle = False         	## Save pkl file
cfg.saveJson = False	           	## Save json file
cfg.saveDataInclude = ['simData'] ## 'simData' , 'simConfig', 'netParams'
cfg.backupCfgFile = None 		##  
cfg.gatherOnlySimData = False	##  
cfg.saveCellSecs = False			
cfg.saveCellConns = True	

cfg.analysis['plotTraces'] = {'include': [i for i in range(100)], 'oneFigPer': 'trace', 'overlay': True, 'timeRange': [0,4000], 'saveFig': False, 'showFig': True, 'figSize':(12,4)} # Plot recorded traces for this list of cells
# cfg.analysis['plotShape'] = {'includePre': [0],'includePre': [0], 'saveFig': True, 'showFig': True, 'figSize':(12,12)}

# %%
# for i,metype in enumerate(folder):
#     print(i,metype)
folder[755:775]
# Out:
# ['L5_STPC_cADpyr232_1',
#  'L5_STPC_cADpyr232_2',
#  'L5_STPC_cADpyr232_3',
#  'L5_STPC_cADpyr232_4',
#  'L5_STPC_cADpyr232_5',
#  'L5_TTPC1_cADpyr232_1',
#  'L5_TTPC1_cADpyr232_2',
#  'L5_TTPC1_cADpyr232_3',
#  'L5_TTPC1_cADpyr232_4',
#  'L5_TTPC1_cADpyr232_5',
#  'L5_TTPC2_cADpyr232_1',
#  'L5_TTPC2_cADpyr232_2',
#  'L5_TTPC2_cADpyr232_3',
#  'L5_TTPC2_cADpyr232_4',
#  'L5_TTPC2_cADpyr232_5',
#  'L5_UTPC_cADpyr232_1',
#  'L5_UTPC_cADpyr232_2',
#  'L5_UTPC_cADpyr232_3',
#  'L5_UTPC_cADpyr232_4',
#  'L5_UTPC_cADpyr232_5']

# %%
#------------------------------------------------------------------------------
# Cell parameters
#------------------------------------------------------------------------------
#StochKv_deterministic.mod
for cellnumber in range(755,775):
    cellName = folder[cellnumber]
    outFolder = rootFolder+'/cell_data/'+folder[cellnumber]
    cellTemplateName = loadTemplateName(cellnumber)
    cellRule = netParams.importCellParams(label=cellName, somaAtOrigin=False,
        conds={'cellType': cellName, 'cellModel': 'HH_full'},
        fileName='cellwrapper.py',
        cellName='loadCell',
        cellInstance = True,
        cellArgs={'cellName': cellName, 'cellTemplateName': cellTemplateName})
# Out:
# NEURON: morphology_d16b0be14e : a template cannot be redefined
#  in morphology.hoc near line 34
#  begintemplate morphology_d16b0be14e
#                                    ^
#         xopen("morphology.hoc")
#       execute1("{xopen("mo...")
#     load_file("morphology.hoc")
#   xopen("template.hoc")
# NEURON: cADpyr232_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate cADpyr232_biophys
#                                ^
#         xopen("biophysics.hoc")
#       execute1("{xopen("bi...")
#     load_file("biophysics.hoc")
#   xopen("template.hoc")
# NEURON: synapses_d16b0be14e : a template cannot be redefined
#  in synapses.hoc near line 31
#  begintemplate synapses_d16b0be14e
#                                  ^
#         xopen("synapses.hoc")
#       execute1("{xopen("sy...")
#     load_file("synapses/s...")
#   xopen("template.hoc")
# 	0
# 	0
# 	0
# cADpyr232_L5_STPC_d16b0be14e[0]
# NEURON: cADpyr232_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate cADpyr232_biophys
#                                ^
#         xopen("biophysics.hoc")
# 	1
# 	1
# 	1
# cADpyr232_L5_STPC_d63221b7a8[0]
# NEURON: cADpyr232_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate cADpyr232_biophys
#                                ^
#         xopen("biophysics.hoc")
# 	1
# 	1
# 	1
# cADpyr232_L5_STPC_a78c3cbca8[0]
# NEURON: cADpyr232_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate cADpyr232_biophys
#                                ^
#         xopen("biophysics.hoc")
# 	1
# 	1
# 	1
# cADpyr232_L5_STPC_4ec7a36770[0]
# NEURON: cADpyr232_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate cADpyr232_biophys
#                                ^
#         xopen("biophysics.hoc")
# 	1
# 	1
# 	1
# cADpyr232_L5_STPC_6d41d50fcb[0]
# NEURON: cADpyr232_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate cADpyr232_biophys
#                                ^
#         xopen("biophysics.hoc")
# 	1
# 	1
# 	1
# cADpyr232_L5_TTPC1_0fb1ca4724[0]
# NEURON: cADpyr232_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate cADpyr232_biophys
#                                ^
#         xopen("biophysics.hoc")
# 	1
# 	1
# 	1
# cADpyr232_L5_TTPC1_fc944c2cf3[0]
# NEURON: cADpyr232_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate cADpyr232_biophys
#                                ^
#         xopen("biophysics.hoc")
# 	1
# 	1
# 	1
# cADpyr232_L5_TTPC1_da1088139b[0]
# NEURON: cADpyr232_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate cADpyr232_biophys
#                                ^
#         xopen("biophysics.hoc")
# 	1
# 	1
# 	1
# cADpyr232_L5_TTPC1_ded64abc4d[0]
# NEURON: cADpyr232_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate cADpyr232_biophys
#                                ^
#         xopen("biophysics.hoc")
# 	1
# 	1
# 	1
# cADpyr232_L5_TTPC1_b6836fcf6f[0]
# NEURON: cADpyr232_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate cADpyr232_biophys
#                                ^
#         xopen("biophysics.hoc")
# 	1
# 	1
# 	1
# cADpyr232_L5_TTPC2_8052133265[0]
# NEURON: cADpyr232_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate cADpyr232_biophys
#                                ^
#         xopen("biophysics.hoc")
# 	1
# 	1
# 	1
# cADpyr232_L5_TTPC2_a28017c6c7[0]
# NEURON: cADpyr232_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate cADpyr232_biophys
#                                ^
#         xopen("biophysics.hoc")
# 	1
# 	1
# 	1
# cADpyr232_L5_TTPC2_a467781f53[0]
# NEURON: cADpyr232_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate cADpyr232_biophys
#                                ^
#         xopen("biophysics.hoc")
# 	1
# 	1
# 	1
# cADpyr232_L5_TTPC2_c46a93702c[0]
# NEURON: cADpyr232_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate cADpyr232_biophys
#                                ^
#         xopen("biophysics.hoc")
# 	1
# 	1
# 	1
# cADpyr232_L5_TTPC2_8bab918b58[0]
# NEURON: cADpyr232_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate cADpyr232_biophys
#                                ^
#         xopen("biophysics.hoc")
# 	1
# 	1
# 	1
# cADpyr232_L5_UTPC_5e3840b51e[0]
# NEURON: cADpyr232_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate cADpyr232_biophys
#                                ^
#         xopen("biophysics.hoc")
# 	1
# 	1
# 	1
# cADpyr232_L5_UTPC_34f655e7f8[0]
# NEURON: cADpyr232_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate cADpyr232_biophys
#                                ^
#         xopen("biophysics.hoc")
# 	1
# 	1
# 	1
# cADpyr232_L5_UTPC_d736225429[0]
# NEURON: cADpyr232_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate cADpyr232_biophys
#                                ^
#         xopen("biophysics.hoc")
# 	1
# 	1
# 	1
# cADpyr232_L5_UTPC_da1143b075[0]
# NEURON: cADpyr232_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate cADpyr232_biophys
#                                ^
#         xopen("biophysics.hoc")
# 	1
# 	1
# 	1
# cADpyr232_L5_UTPC_79412a7e72[0]

# %%
for cellnumber in range(755,775):
    # ---------------------------------------------------------------------------------------------------- #
    cellName = folder[cellnumber]
    outFolder = rootFolder+'/cell_data/'+folder[cellnumber]
    cellTemplateName = loadTemplateName(cellnumber)
    
    # ---------------------------------------------------------------------------------------------------- #
    netParams.renameCellParamsSec(label=cellName, oldSec='soma_0', newSec='soma')
    
    for secname2 in netParams.cellParams[cellName]['secLists'].keys():
        if 'soma_0' in netParams.cellParams[cellName]['secLists'][secname2]:
            print(cellName,secname2,netParams.cellParams[cellName]['secLists'][secname2][0])
            netParams.cellParams[cellName]['secLists'][secname2][0] = 'soma'
    # ---------------------------------------------------------------------------------------------------- #
    
    nonSpiny = ['axon_0', 'axon_1']
    netParams.cellParams[cellName]['secLists']['spiny'] = [sec for sec in netParams.cellParams[cellName]['secLists']['all'] if sec not in nonSpiny]
    nonSpinyEE = ['axon_0', 'axon_1', 'soma']
    netParams.cellParams[cellName]['secLists']['spinyEE'] = [sec for sec in netParams.cellParams[cellName]['secLists']['all'] if sec not in nonSpinyEE]    
    
    # ---------------------------------------------------------------------------------------------------- #
    for ii in range(5):
        netParams.popParams[cellName + '_' + str(ii)] = {'cellType': cellName, 'numCells': 1, 'cellModel': 'HH_full'}
# Out:
# L5_STPC_cADpyr232_1 all soma_0
# L5_STPC_cADpyr232_1 somatic soma_0
# L5_STPC_cADpyr232_2 all soma_0
# L5_STPC_cADpyr232_2 somatic soma_0
# L5_STPC_cADpyr232_3 all soma_0
# L5_STPC_cADpyr232_3 somatic soma_0
# L5_STPC_cADpyr232_4 all soma_0
# L5_STPC_cADpyr232_4 somatic soma_0
# L5_STPC_cADpyr232_5 all soma_0
# L5_STPC_cADpyr232_5 somatic soma_0
# L5_TTPC1_cADpyr232_1 all soma_0
# L5_TTPC1_cADpyr232_1 somatic soma_0
# L5_TTPC1_cADpyr232_2 all soma_0
# L5_TTPC1_cADpyr232_2 somatic soma_0
# L5_TTPC1_cADpyr232_3 all soma_0
# L5_TTPC1_cADpyr232_3 somatic soma_0
# L5_TTPC1_cADpyr232_4 all soma_0
# L5_TTPC1_cADpyr232_4 somatic soma_0
# L5_TTPC1_cADpyr232_5 all soma_0
# L5_TTPC1_cADpyr232_5 somatic soma_0
# L5_TTPC2_cADpyr232_1 all soma_0
# L5_TTPC2_cADpyr232_1 somatic soma_0
# L5_TTPC2_cADpyr232_2 all soma_0
# L5_TTPC2_cADpyr232_2 somatic soma_0
# L5_TTPC2_cADpyr232_3 all soma_0
# L5_TTPC2_cADpyr232_3 somatic soma_0
# L5_TTPC2_cADpyr232_4 all soma_0
# L5_TTPC2_cADpyr232_4 somatic soma_0
# L5_TTPC2_cADpyr232_5 all soma_0
# L5_TTPC2_cADpyr232_5 somatic soma_0
# L5_UTPC_cADpyr232_1 all soma_0
# L5_UTPC_cADpyr232_1 somatic soma_0
# L5_UTPC_cADpyr232_2 all soma_0
# L5_UTPC_cADpyr232_2 somatic soma_0
# L5_UTPC_cADpyr232_3 all soma_0
# L5_UTPC_cADpyr232_3 somatic soma_0
# L5_UTPC_cADpyr232_4 all soma_0
# L5_UTPC_cADpyr232_4 somatic soma_0
# L5_UTPC_cADpyr232_5 all soma_0
# L5_UTPC_cADpyr232_5 somatic soma_0

# %%
for cellnumber in range(755,775):
    cellName = folder[cellnumber]
    print(netParams.cellParams[cellName]['secLists']['basal'][-1])
# Out:
# dend_41
# dend_45
# dend_59
# dend_45
# dend_59
# dend_112
# dend_112
# dend_112
# dend_112
# dend_82
# dend_79
# dend_95
# dend_95
# dend_95
# dend_95
# dend_42
# dend_42
# dend_42
# dend_60
# dend_63

# %%
# create custom list of spike times
# spkTimes = [2000,2500,3000,3500,4000,4500]
spkTimes = [500,2500,2550,2600,2650,2700,2750,2800,2850,2900,3400]

netParams.popParams['presyn'] = {'cellModel': 'VecStim', 'numCells': 1, 'spkTimes': spkTimes}  # VecStim with spike times

# %%
netParams.cellParams.keys()
# Out:
# odict_keys(['L5_STPC_cADpyr232_1', 'L5_STPC_cADpyr232_2', 'L5_STPC_cADpyr232_3', 'L5_STPC_cADpyr232_4', 'L5_STPC_cADpyr232_5', 'L5_TTPC1_cADpyr232_1', 'L5_TTPC1_cADpyr232_2', 'L5_TTPC1_cADpyr232_3', 'L5_TTPC1_cADpyr232_4', 'L5_TTPC1_cADpyr232_5', 'L5_TTPC2_cADpyr232_1', 'L5_TTPC2_cADpyr232_2', 'L5_TTPC2_cADpyr232_3', 'L5_TTPC2_cADpyr232_4', 'L5_TTPC2_cADpyr232_5', 'L5_UTPC_cADpyr232_1', 'L5_UTPC_cADpyr232_2', 'L5_UTPC_cADpyr232_3', 'L5_UTPC_cADpyr232_4', 'L5_UTPC_cADpyr232_5'])

# %%
list(netParams.popParams.keys())[0:-1]
# Out:
# ['L5_STPC_cADpyr232_1_0',
#  'L5_STPC_cADpyr232_1_1',
#  'L5_STPC_cADpyr232_1_2',
#  'L5_STPC_cADpyr232_1_3',
#  'L5_STPC_cADpyr232_1_4',
#  'L5_STPC_cADpyr232_2_0',
#  'L5_STPC_cADpyr232_2_1',
#  'L5_STPC_cADpyr232_2_2',
#  'L5_STPC_cADpyr232_2_3',
#  'L5_STPC_cADpyr232_2_4',
#  'L5_STPC_cADpyr232_3_0',
#  'L5_STPC_cADpyr232_3_1',
#  'L5_STPC_cADpyr232_3_2',
#  'L5_STPC_cADpyr232_3_3',
#  'L5_STPC_cADpyr232_3_4',
#  'L5_STPC_cADpyr232_4_0',
#  'L5_STPC_cADpyr232_4_1',
#  'L5_STPC_cADpyr232_4_2',
#  'L5_STPC_cADpyr232_4_3',
#  'L5_STPC_cADpyr232_4_4',
#  'L5_STPC_cADpyr232_5_0',
#  'L5_STPC_cADpyr232_5_1',
#  'L5_STPC_cADpyr232_5_2',
#  'L5_STPC_cADpyr232_5_3',
#  'L5_STPC_cADpyr232_5_4',
#  'L5_TTPC1_cADpyr232_1_0',
#  'L5_TTPC1_cADpyr232_1_1',
#  'L5_TTPC1_cADpyr232_1_2',
#  'L5_TTPC1_cADpyr232_1_3',
#  'L5_TTPC1_cADpyr232_1_4',
#  'L5_TTPC1_cADpyr232_2_0',
#  'L5_TTPC1_cADpyr232_2_1',
#  'L5_TTPC1_cADpyr232_2_2',
#  'L5_TTPC1_cADpyr232_2_3',
#  'L5_TTPC1_cADpyr232_2_4',
#  'L5_TTPC1_cADpyr232_3_0',
#  'L5_TTPC1_cADpyr232_3_1',
#  'L5_TTPC1_cADpyr232_3_2',
#  'L5_TTPC1_cADpyr232_3_3',
#  'L5_TTPC1_cADpyr232_3_4',
#  'L5_TTPC1_cADpyr232_4_0',
#  'L5_TTPC1_cADpyr232_4_1',
#  'L5_TTPC1_cADpyr232_4_2',
#  'L5_TTPC1_cADpyr232_4_3',
#  'L5_TTPC1_cADpyr232_4_4',
#  'L5_TTPC1_cADpyr232_5_0',
#  'L5_TTPC1_cADpyr232_5_1',
#  'L5_TTPC1_cADpyr232_5_2',
#  'L5_TTPC1_cADpyr232_5_3',
#  'L5_TTPC1_cADpyr232_5_4',
#  'L5_TTPC2_cADpyr232_1_0',
#  'L5_TTPC2_cADpyr232_1_1',
#  'L5_TTPC2_cADpyr232_1_2',
#  'L5_TTPC2_cADpyr232_1_3',
#  'L5_TTPC2_cADpyr232_1_4',
#  'L5_TTPC2_cADpyr232_2_0',
#  'L5_TTPC2_cADpyr232_2_1',
#  'L5_TTPC2_cADpyr232_2_2',
#  'L5_TTPC2_cADpyr232_2_3',
#  'L5_TTPC2_cADpyr232_2_4',
#  'L5_TTPC2_cADpyr232_3_0',
#  'L5_TTPC2_cADpyr232_3_1',
#  'L5_TTPC2_cADpyr232_3_2',
#  'L5_TTPC2_cADpyr232_3_3',
#  'L5_TTPC2_cADpyr232_3_4',
#  'L5_TTPC2_cADpyr232_4_0',
#  'L5_TTPC2_cADpyr232_4_1',
#  'L5_TTPC2_cADpyr232_4_2',
#  'L5_TTPC2_cADpyr232_4_3',
#  'L5_TTPC2_cADpyr232_4_4',
#  'L5_TTPC2_cADpyr232_5_0',
#  'L5_TTPC2_cADpyr232_5_1',
#  'L5_TTPC2_cADpyr232_5_2',
#  'L5_TTPC2_cADpyr232_5_3',
#  'L5_TTPC2_cADpyr232_5_4',
#  'L5_UTPC_cADpyr232_1_0',
#  'L5_UTPC_cADpyr232_1_1',
#  'L5_UTPC_cADpyr232_1_2',
#  'L5_UTPC_cADpyr232_1_3',
#  'L5_UTPC_cADpyr232_1_4',
#  'L5_UTPC_cADpyr232_2_0',
#  'L5_UTPC_cADpyr232_2_1',
#  'L5_UTPC_cADpyr232_2_2',
#  'L5_UTPC_cADpyr232_2_3',
#  'L5_UTPC_cADpyr232_2_4',
#  'L5_UTPC_cADpyr232_3_0',
#  'L5_UTPC_cADpyr232_3_1',
#  'L5_UTPC_cADpyr232_3_2',
#  'L5_UTPC_cADpyr232_3_3',
#  'L5_UTPC_cADpyr232_3_4',
#  'L5_UTPC_cADpyr232_4_0',
#  'L5_UTPC_cADpyr232_4_1',
#  'L5_UTPC_cADpyr232_4_2',
#  'L5_UTPC_cADpyr232_4_3',
#  'L5_UTPC_cADpyr232_4_4',
#  'L5_UTPC_cADpyr232_5_0',
#  'L5_UTPC_cADpyr232_5_1',
#  'L5_UTPC_cADpyr232_5_2',
#  'L5_UTPC_cADpyr232_5_3',
#  'L5_UTPC_cADpyr232_5_4']

# %%
# import scipy.stats as stats
# lower, upper = 0.48, 0.52
# mu, sigma = 0.50, 0.02
# X = stats.truncnorm(
#     (lower - mu) / sigma, (upper - mu) / sigma, loc=mu, scale=sigma)
# Use = X.rvs(100)

# --------------------------------------------------------------------------------------#
#BBP	gsyn	decay	       use	     dep	 fac	types	rules
# 5	0.91±0.61	6.44±1.70	0.32±0.140	144±80	62±31	I3-IE	SBC_bNAC or LBC-NBC_(cNAC dSTUT cSTUT bSTUT):Excitatory
for ii in range(100):
    netParams.synMechParams['INH:L5_PC'+str(ii+1)] = {'mod': 'DetGABAAB',
                                         'Use': 0.32,
                                         'Dep': 144.0,
                                         'Fac': 62.0,
                                         'tau_d_GABAA': 6.44,
                                         'tau_r_GABAA': 0.2,   #rng.lognormal(0.2, 0.1) in synapses.hoc  
                                         'tau_d_GABAB': 260.9,
                                         'tau_r_GABAB': 3.5,
                                         'e_GABAA': -70.0, #= -80   (mV) : GABAA reversal potential    
                                            }

# %%
import random

# lower, upper = 0.5, 1.0
# mu, sigma = 0.75, 0.32
# X = stats.truncnorm(
#     (lower - mu) / sigma, (upper - mu) / sigma, loc=mu, scale=sigma)

# weight = X.rvs(100)

## Cell connectivity rules
for ii in range(100):
    
    listsecs = random.sample(netParams.cellParams[cellName]['secLists']['spiny'], len(netParams.cellParams[cellName]['secLists']['spiny']))

    netParams.connParams['pre->post'+str(ii+1)] = { 
            'preConds': {'pop': 'presyn'},
            'postConds': {'pop': list(netParams.popParams.keys())[ii]},
            'sec': listsecs,                  # target postsyn section
            'synMech': 'INH:L5_PC'+str(ii+1),              # target synaptic mechanism
            'weight': 0.91, # weight[ii], # # synaptic weight 
            'synsPerConn': 15, 
            'delay': 0.05}

# %%
sim.initialize(
    simConfig = cfg, 	
    netParams = netParams)  				# create network object and set cfg and net params
sim.net.createPops()               			# instantiate network populations
sim.net.createCells()              			# instantiate network cells based on defined populations
sim.net.connectCells()            			# create connections between cells based on params
# Out:
# Start time:  2023-04-19 14:28:05.286790
#
# Creating network of 101 cell populations on 1 hosts...
#   Number of cells on node 0: 101
#   Done; cell creation time = 7.98 s.
# Making connections...
#   Number of connections on node 0: 100
#   Number of synaptic contacts on node 0: 1500
#   Done; cell connection time = 0.21 s.
# [[{preGid: 100, sec: 'apic_20', loc: 0.7339727344400158, synMech: 'INH:L5_PC1', weight: 0.91, delay: 0.05, label: 'pre->post1', preLoc: 0.5, hObj: NetCon[0]},
#   {preGid: 100, sec: 'dend_2', loc: 0.6320311290778949, synMech: 'INH:L5_PC1', weight: 0.91, delay: 0.05, label: 'pre->post1', preLoc: 0.5, hObj: NetCon[1]},
#   {preGid: 100, sec: 'apic_12', loc: 0.7717116137843649, synMech: 'INH:L5_PC1', weight: 0.91, delay: 0.05, label: 'pre->post1', preLoc: 0.5, hObj: NetCon[2]},
#   {preGid: 100, sec: 'apic_14', loc: 0.3436206794926572, synMech: 'INH:L5_PC1', weight: 0.91, delay: 0.05, label: 'pre->post1', preLoc: 0.5, hObj: NetCon[3]},
#   {preGid: 100, sec: 'dend_16', loc: 0.009113632297332702, synMech: 'INH:L5_PC1', weight: 0.91, delay: 0.05, label: 'pre->post1', preLoc: 0.5, hObj: NetCon[4]},
#   {preGid: 100, sec: 'apic_11', loc: 0.5243368899688544, synMech: 'INH:L5_PC1', weight: 0.91, delay: 0.05, label: 'pre->post1', preLoc: 0.5, hObj: NetCon[5]},
#   {preGid: 100, sec: 'apic_22', loc: 0.6568532514193761, synMech: 'INH:L5_PC1', weight: 0.91, delay: 0.05, label: 'pre->post1', preLoc: 0.5, hObj: NetCon[6]},
#   {preGid: 100, sec: 'apic_8', loc: 0.43615992249137275, synMech: 'INH:L5_PC1', weight: 0.91, delay: 0.05, label: 'pre->post1', preLoc: 0.5, hObj: NetCon[7]},
#   {preGid: 100, sec: 'apic_18', loc: 0.792137427668539, synMech: 'INH:L5_PC1', weight: 0.91, delay: 0.05, label: 'pre->post1', preLoc: 0.5, hObj: NetCon[8]},
#   {preGid: 100, sec: 'dend_35', loc: 0.06048690268397769, synMech: 'INH:L5_PC1', weight: 0.91, delay: 0.05, label: 'pre->post1', preLoc: 0.5, hObj: NetCon[9]},
#   {preGid: 100, sec: 'apic_60', loc: 0.7334836766653923, synMech: 'INH:L5_PC1', weight: 0.91, delay: 0.05, label: 'pre->post1', preLoc: 0.5, hObj: NetCon[10]},
#   {preGid: 100, sec: 'dend_21', loc: 0.3850954049159672, synMech: 'INH:L5_PC1', weight: 0.91, delay: 0.05, label: 'pre->post1', preLoc: 0.5, hObj: NetCon[11]},
#   {preGid: 100, sec: 'dend_14', loc: 0.2408839377307241, synMech: 'INH:L5_PC1', weight: 0.91, delay: 0.05, label: 'pre->post1', preLoc: 0.5, hObj: NetCon[12]},
#   {preGid: 100, sec: 'apic_35', loc: 0.9446072814385646, synMech: 'INH:L5_PC1', weight: 0.91, delay: 0.05, label: 'pre->post1', preLoc: 0.5, hObj: NetCon[13]},
#   {preGid: 100, sec: 'apic_29', loc: 0.15403618924397897, synMech: 'INH:L5_PC1', weight: 0.91, delay: 0.05, label: 'pre->post1', preLoc: 0.5, hObj: NetCon[14]}],
#  [{preGid: 100, sec: 'apic_48', loc: 0.6936150992933274, synMech: 'INH:L5_PC2', weight: 0.91, delay: 0.05, label: 'pre->post2', preLoc: 0.5, hObj: NetCon[15]},
#   {preGid: 100, sec: 'dend_21', loc: 0.4773838085937774, synMech: 'INH:L5_PC2', weight: 0.91, delay: 0.05, label: 'pre->post2', preLoc: 0.5, hObj: NetCon[16]},
#   {preGid: 100, sec: 'dend_3', loc: 0.3372744053354113, synMech: 'INH:L5_PC2', weight: 0.91, delay: 0.05, label: 'pre->post2', preLoc: 0.5, hObj: NetCon[17]},
#   {preGid: 100, sec: 'dend_2', loc: 0.5227067049369506, synMech: 'INH:L5_PC2', weight: 0.91, delay: 0.05, label: 'pre->post2', preLoc: 0.5, hObj: NetCon[18]},
#   {preGid: 100, sec: 'apic_29', loc: 0.22733804038458244, synMech: 'INH:L5_PC2', weight: 0.91, delay: 0.05, label: 'pre->post2', preLoc: 0.5, hObj: NetCon[19]},
#   {preGid: 100, sec: 'dend_25', loc: 0.5492967387256059, synMech: 'INH:L5_PC2', weight: 0.91, delay: 0.05, label: 'pre->post2', preLoc: 0.5, hObj: NetCon[20]},
#   {preGid: 100, sec: 'apic_38', loc: 0.33522611612541214, synMech: 'INH:L5_PC2', weight: 0.91, delay: 0.05, label: 'pre->post2', preLoc: 0.5, hObj: NetCon[21]},
#   {preGid: 100, sec: 'dend_10', loc: 0.9898952313195113, synMech: 'INH:L5_PC2', weight: 0.91, delay: 0.05, label: 'pre->post2', preLoc: 0.5, hObj: NetCon[22]},
#   {preGid: 100, sec: 'apic_33', loc: 0.44011143810205017, synMech: 'INH:L5_PC2', weight: 0.91, delay: 0.05, label: 'pre->post2', preLoc: 0.5, hObj: NetCon[23]},
#   {preGid: 100, sec: 'apic_14', loc: 0.12011884873580869, synMech: 'INH:L5_PC2', weight: 0.91, delay: 0.05, label: 'pre->post2', preLoc: 0.5, hObj: NetCon[24]},
#   {preGid: 100, sec: 'apic_4', loc: 0.43240706108720245, synMech: 'INH:L5_PC2', weight: 0.91, delay: 0.05, label: 'pre->post2', preLoc: 0.5, hObj: NetCon[25]},
#   {preGid: 100, sec: 'apic_41', loc: 0.5509659017351792, synMech: 'INH:L5_PC2', weight: 0.91, delay: 0.05, label: 'pre->post2', preLoc: 0.5, hObj: NetCon[26]},
#   {preGid: 100, sec: 'apic_51', loc: 0.2876630299977102, synMech: 'INH:L5_PC2', weight: 0.91, delay: 0.05, label: 'pre->post2', preLoc: 0.5, hObj: NetCon[27]},
#   {preGid: 100, sec: 'apic_22', loc: 0.46368541960268955, synMech: 'INH:L5_PC2', weight: 0.91, delay: 0.05, label: 'pre->post2', preLoc: 0.5, hObj: NetCon[28]},
#   {preGid: 100, sec: 'soma', loc: 0.9502345501235122, synMech: 'INH:L5_PC2', weight: 0.91, delay: 0.05, label: 'pre->post2', preLoc: 0.5, hObj: NetCon[29]}],
#  [{preGid: 100, sec: 'dend_20', loc: 0.48975063712724004, synMech: 'INH:L5_PC3', weight: 0.91, delay: 0.05, label: 'pre->post3', preLoc: 0.5, hObj: NetCon[30]},
#   {preGid: 100, sec: 'dend_22', loc: 0.2790000185290454, synMech: 'INH:L5_PC3', weight: 0.91, delay: 0.05, label: 'pre->post3', preLoc: 0.5, hObj: NetCon[31]},
#   {preGid: 100, sec: 'apic_15', loc: 0.7162987341667006, synMech: 'INH:L5_PC3', weight: 0.91, delay: 0.05, label: 'pre->post3', preLoc: 0.5, hObj: NetCon[32]},
#   {preGid: 100, sec: 'dend_16', loc: 0.7347907935553574, synMech: 'INH:L5_PC3', weight: 0.91, delay: 0.05, label: 'pre->post3', preLoc: 0.5, hObj: NetCon[33]},
#   {preGid: 100, sec: 'dend_21', loc: 0.2371926896843338, synMech: 'INH:L5_PC3', weight: 0.91, delay: 0.05, label: 'pre->post3', preLoc: 0.5, hObj: NetCon[34]},
#   {preGid: 100, sec: 'apic_48', loc: 0.4510052566941692, synMech: 'INH:L5_PC3', weight: 0.91, delay: 0.05, label: 'pre->post3', preLoc: 0.5, hObj: NetCon[35]},
#   {preGid: 100, sec: 'dend_29', loc: 0.5955334954077904, synMech: 'INH:L5_PC3', weight: 0.91, delay: 0.05, label: 'pre->post3', preLoc: 0.5, hObj: NetCon[36]},
#   {preGid: 100, sec: 'apic_49', loc: 0.2487819938340072, synMech: 'INH:L5_PC3', weight: 0.91, delay: 0.05, label: 'pre->post3', preLoc: 0.5, hObj: NetCon[37]},
#   {preGid: 100, sec: 'apic_12', loc: 0.18749121609296227, synMech: 'INH:L5_PC3', weight: 0.91, delay: 0.05, label: 'pre->post3', preLoc: 0.5, hObj: NetCon[38]},
#   {preGid: 100, sec: 'apic_59', loc: 0.9211375926361851, synMech: 'INH:L5_PC3', weight: 0.91, delay: 0.05, label: 'pre->post3', preLoc: 0.5, hObj: NetCon[39]},
#   {preGid: 100, sec: 'apic_62', loc: 0.6014969972774462, synMech: 'INH:L5_PC3', weight: 0.91, delay: 0.05, label: 'pre->post3', preLoc: 0.5, hObj: NetCon[40]},
#   {preGid: 100, sec: 'dend_2', loc: 0.008453047198546873, synMech: 'INH:L5_PC3', weight: 0.91, delay: 0.05, label: 'pre->post3', preLoc: 0.5, hObj: NetCon[41]},
#   {preGid: 100, sec: 'dend_40', loc: 0.2967795734977792, synMech: 'INH:L5_PC3', weight: 0.91, delay: 0.05, label: 'pre->post3', preLoc: 0.5, hObj: NetCon[42]},
#   {preGid: 100, sec: 'dend_17', loc: 0.8056096571339101, synMech: 'INH:L5_PC3', weight: 0.91, delay: 0.05, label: 'pre->post3', preLoc: 0.5, hObj: NetCon[43]},
#   {preGid: 100, sec: 'dend_18', loc: 0.005390899890093298, synMech: 'INH:L5_PC3', weight: 0.91, delay: 0.05, label: 'pre->post3', preLoc: 0.5, hObj: NetCon[44]}],
#  [{preGid: 100, sec: 'dend_16', loc: 0.5416590767522055, synMech: 'INH:L5_PC4', weight: 0.91, delay: 0.05, label: 'pre->post4', preLoc: 0.5, hObj: NetCon[45]},
#   {preGid: 100, sec: 'dend_20', loc: 0.8231775938841198, synMech: 'INH:L5_PC4', weight: 0.91, delay: 0.05, label: 'pre->post4', preLoc: 0.5, hObj: NetCon[46]},
#   {preGid: 100, sec: 'dend_2', loc: 0.7095652077852703, synMech: 'INH:L5_PC4', weight: 0.91, delay: 0.05, label: 'pre->post4', preLoc: 0.5, hObj: NetCon[47]},
#   {preGid: 100, sec: 'apic_42', loc: 0.13681989786965282, synMech: 'INH:L5_PC4', weight: 0.91, delay: 0.05, label: 'pre->post4', preLoc: 0.5, hObj: NetCon[48]},
#   {preGid: 100, sec: 'apic_14', loc: 0.5534106024763791, synMech: 'INH:L5_PC4', weight: 0.91, delay: 0.05, label: 'pre->post4', preLoc: 0.5, hObj: NetCon[49]},
#   {preGid: 100, sec: 'apic_22', loc: 0.14273180429351434, synMech: 'INH:L5_PC4', weight: 0.91, delay: 0.05, label: 'pre->post4', preLoc: 0.5, hObj: NetCon[50]},
#   {preGid: 100, sec: 'apic_20', loc: 0.8036613866441058, synMech: 'INH:L5_PC4', weight: 0.91, delay: 0.05, label: 'pre->post4', preLoc: 0.5, hObj: NetCon[51]},
#   {preGid: 100, sec: 'apic_18', loc: 0.19149718024516005, synMech: 'INH:L5_PC4', weight: 0.91, delay: 0.05, label: 'pre->post4', preLoc: 0.5, hObj: NetCon[52]},
#   {preGid: 100, sec: 'apic_59', loc: 0.5662518573806564, synMech: 'INH:L5_PC4', weight: 0.91, delay: 0.05, label: 'pre->post4', preLoc: 0.5, hObj: NetCon[53]},
#   {preGid: 100, sec: 'dend_41', loc: 0.29583725654778825, synMech: 'INH:L5_PC4', weight: 0.91, delay: 0.05, label: 'pre->post4', preLoc: 0.5, hObj: NetCon[54]},
#   {preGid: 100, sec: 'apic_50', loc: 0.0800393860426593, synMech: 'INH:L5_PC4', weight: 0.91, delay: 0.05, label: 'pre->post4', preLoc: 0.5, hObj: NetCon[55]},
#   {preGid: 100, sec: 'dend_17', loc: 0.5572734653091499, synMech: 'INH:L5_PC4', weight: 0.91, delay: 0.05, label: 'pre->post4', preLoc: 0.5, hObj: NetCon[56]},
#   {preGid: 100, sec: 'dend_25', loc: 0.29764635406700596, synMech: 'INH:L5_PC4', weight: 0.91, delay: 0.05, label: 'pre->post4', preLoc: 0.5, hObj: NetCon[57]},
#   {preGid: 100, sec: 'apic_60', loc: 0.518619774443525, synMech: 'INH:L5_PC4', weight: 0.91, delay: 0.05, label: 'pre->post4', preLoc: 0.5, hObj: NetCon[58]},
#   {preGid: 100, sec: 'dend_35', loc: 0.8909307447553055, synMech: 'INH:L5_PC4', weight: 0.91, delay: 0.05, label: 'pre->post4', preLoc: 0.5, hObj: NetCon[59]}],
#  [{preGid: 100, sec: 'apic_38', loc: 0.710413493707948, synMech: 'INH:L5_PC5', weight: 0.91, delay: 0.05, label: 'pre->post5', preLoc: 0.5, hObj: NetCon[60]},
#   {preGid: 100, sec: 'dend_41', loc: 0.5976650523812962, synMech: 'INH:L5_PC5', weight: 0.91, delay: 0.05, label: 'pre->post5', preLoc: 0.5, hObj: NetCon[61]},
#   {preGid: 100, sec: 'dend_5', loc: 0.5927406380380512, synMech: 'INH:L5_PC5', weight: 0.91, delay: 0.05, label: 'pre->post5', preLoc: 0.5, hObj: NetCon[62]},
#   {preGid: 100, sec: 'apic_45', loc: 0.5913728111058429, synMech: 'INH:L5_PC5', weight: 0.91, delay: 0.05, label: 'pre->post5', preLoc: 0.5, hObj: NetCon[63]},
#   {preGid: 100, sec: 'apic_33', loc: 0.11043754601631596, synMech: 'INH:L5_PC5', weight: 0.91, delay: 0.05, label: 'pre->post5', preLoc: 0.5, hObj: NetCon[64]},
#   {preGid: 100, sec: 'apic_12', loc: 0.14977500844713793, synMech: 'INH:L5_PC5', weight: 0.91, delay: 0.05, label: 'pre->post5', preLoc: 0.5, hObj: NetCon[65]},
#   {preGid: 100, sec: 'apic_22', loc: 0.3527003920858132, synMech: 'INH:L5_PC5', weight: 0.91, delay: 0.05, label: 'pre->post5', preLoc: 0.5, hObj: NetCon[66]},
#   {preGid: 100, sec: 'dend_40', loc: 0.3335332759727233, synMech: 'INH:L5_PC5', weight: 0.91, delay: 0.05, label: 'pre->post5', preLoc: 0.5, hObj: NetCon[67]},
#   {preGid: 100, sec: 'dend_20', loc: 0.3383990317722422, synMech: 'INH:L5_PC5', weight: 0.91, delay: 0.05, label: 'pre->post5', preLoc: 0.5, hObj: NetCon[68]},
#   {preGid: 100, sec: 'dend_10', loc: 0.9789288913843068, synMech: 'INH:L5_PC5', weight: 0.91, delay: 0.05, label: 'pre->post5', preLoc: 0.5, hObj: NetCon[69]},
#   {preGid: 100, sec: 'dend_8', loc: 0.158244572140018, synMech: 'INH:L5_PC5', weight: 0.91, delay: 0.05, label: 'pre->post5', preLoc: 0.5, hObj: NetCon[70]},
#   {preGid: 100, sec: 'dend_4', loc: 0.958232885916487, synMech: 'INH:L5_PC5', weight: 0.91, delay: 0.05, label: 'pre->post5', preLoc: 0.5, hObj: NetCon[71]},
#   {preGid: 100, sec: 'dend_2', loc: 0.09591703982679982, synMech: 'INH:L5_PC5', weight: 0.91, delay: 0.05, label: 'pre->post5', preLoc: 0.5, hObj: NetCon[72]},
#   {preGid: 100, sec: 'apic_20', loc: 0.10420805679663339, synMech: 'INH:L5_PC5', weight: 0.91, delay: 0.05, label: 'pre->post5', preLoc: 0.5, hObj: NetCon[73]},
#   {preGid: 100, sec: 'apic_18', loc: 0.82098513280344, synMech: 'INH:L5_PC5', weight: 0.91, delay: 0.05, label: 'pre->post5', preLoc: 0.5, hObj: NetCon[74]}],
#  [{preGid: 100, sec: 'apic_37', loc: 0.8314040386338919, synMech: 'INH:L5_PC6', weight: 0.91, delay: 0.05, label: 'pre->post6', preLoc: 0.5, hObj: NetCon[75]},
#   {preGid: 100, sec: 'apic_25', loc: 0.1169288908558609, synMech: 'INH:L5_PC6', weight: 0.91, delay: 0.05, label: 'pre->post6', preLoc: 0.5, hObj: NetCon[76]},
#   {preGid: 100, sec: 'dend_12', loc: 0.3834400743675271, synMech: 'INH:L5_PC6', weight: 0.91, delay: 0.05, label: 'pre->post6', preLoc: 0.5, hObj: NetCon[77]},
#   {preGid: 100, sec: 'apic_19', loc: 0.4273679020549547, synMech: 'INH:L5_PC6', weight: 0.91, delay: 0.05, label: 'pre->post6', preLoc: 0.5, hObj: NetCon[78]},
#   {preGid: 100, sec: 'dend_26', loc: 0.7064775176129892, synMech: 'INH:L5_PC6', weight: 0.91, delay: 0.05, label: 'pre->post6', preLoc: 0.5, hObj: NetCon[79]},
#   {preGid: 100, sec: 'apic_36', loc: 0.020140548040290997, synMech: 'INH:L5_PC6', weight: 0.91, delay: 0.05, label: 'pre->post6', preLoc: 0.5, hObj: NetCon[80]},
#   {preGid: 100, sec: 'apic_47', loc: 0.36657699961411244, synMech: 'INH:L5_PC6', weight: 0.91, delay: 0.05, label: 'pre->post6', preLoc: 0.5, hObj: NetCon[81]},
#   {preGid: 100, sec: 'apic_45', loc: 0.983066395670055, synMech: 'INH:L5_PC6', weight: 0.91, delay: 0.05, label: 'pre->post6', preLoc: 0.5, hObj: NetCon[82]},
#   {preGid: 100, sec: 'apic_27', loc: 0.1298904467110135, synMech: 'INH:L5_PC6', weight: 0.91, delay: 0.05, label: 'pre->post6', preLoc: 0.5, hObj: NetCon[83]},
#   {preGid: 100, sec: 'apic_7', loc: 0.12850569975399256, synMech: 'INH:L5_PC6', weight: 0.91, delay: 0.05, label: 'pre->post6', preLoc: 0.5, hObj: NetCon[84]},
#   {preGid: 100, sec: 'dend_13', loc: 0.7678084083345503, synMech: 'INH:L5_PC6', weight: 0.91, delay: 0.05, label: 'pre->post6', preLoc: 0.5, hObj: NetCon[85]},
#   {preGid: 100, sec: 'dend_11', loc: 0.9322111935263857, synMech: 'INH:L5_PC6', weight: 0.91, delay: 0.05, label: 'pre->post6', preLoc: 0.5, hObj: NetCon[86]},
#   {preGid: 100, sec: 'dend_6', loc: 0.7536479021642404, synMech: 'INH:L5_PC6', weight: 0.91, delay: 0.05, label: 'pre->post6', preLoc: 0.5, hObj: NetCon[87]},
#   {preGid: 100, sec: 'apic_29', loc: 0.9380100793816201, synMech: 'INH:L5_PC6', weight: 0.91, delay: 0.05, label: 'pre->post6', preLoc: 0.5, hObj: NetCon[88]},
#   {preGid: 100, sec: 'dend_16', loc: 0.10480756195611737, synMech: 'INH:L5_PC6', weight: 0.91, delay: 0.05, label: 'pre->post6', preLoc: 0.5, hObj: NetCon[89]}],
#  [{preGid: 100, sec: 'apic_5', loc: 0.8829050153874627, synMech: 'INH:L5_PC7', weight: 0.91, delay: 0.05, label: 'pre->post7', preLoc: 0.5, hObj: NetCon[90]},
#   {preGid: 100, sec: 'apic_22', loc: 0.7076778976016768, synMech: 'INH:L5_PC7', weight: 0.91, delay: 0.05, label: 'pre->post7', preLoc: 0.5, hObj: NetCon[91]},
#   {preGid: 100, sec: 'apic_1', loc: 0.995816370009702, synMech: 'INH:L5_PC7', weight: 0.91, delay: 0.05, label: 'pre->post7', preLoc: 0.5, hObj: NetCon[92]},
#   {preGid: 100, sec: 'dend_2', loc: 0.24945062843047264, synMech: 'INH:L5_PC7', weight: 0.91, delay: 0.05, label: 'pre->post7', preLoc: 0.5, hObj: NetCon[93]},
#   {preGid: 100, sec: 'dend_37', loc: 0.4309740959368124, synMech: 'INH:L5_PC7', weight: 0.91, delay: 0.05, label: 'pre->post7', preLoc: 0.5, hObj: NetCon[94]},
#   {preGid: 100, sec: 'dend_45', loc: 0.1958412041505802, synMech: 'INH:L5_PC7', weight: 0.91, delay: 0.05, label: 'pre->post7', preLoc: 0.5, hObj: NetCon[95]},
#   {preGid: 100, sec: 'apic_36', loc: 0.8167914451081254, synMech: 'INH:L5_PC7', weight: 0.91, delay: 0.05, label: 'pre->post7', preLoc: 0.5, hObj: NetCon[96]},
#   {preGid: 100, sec: 'dend_8', loc: 0.9125149859809384, synMech: 'INH:L5_PC7', weight: 0.91, delay: 0.05, label: 'pre->post7', preLoc: 0.5, hObj: NetCon[97]},
#   {preGid: 100, sec: 'dend_34', loc: 0.9433586454481313, synMech: 'INH:L5_PC7', weight: 0.91, delay: 0.05, label: 'pre->post7', preLoc: 0.5, hObj: NetCon[98]},
#   {preGid: 100, sec: 'dend_39', loc: 0.9469310542937618, synMech: 'INH:L5_PC7', weight: 0.91, delay: 0.05, label: 'pre->post7', preLoc: 0.5, hObj: NetCon[99]},
#   {preGid: 100, sec: 'apic_38', loc: 0.8879345665687741, synMech: 'INH:L5_PC7', weight: 0.91, delay: 0.05, label: 'pre->post7', preLoc: 0.5, hObj: NetCon[100]},
#   {preGid: 100, sec: 'apic_17', loc: 0.27699114083098225, synMech: 'INH:L5_PC7', weight: 0.91, delay: 0.05, label: 'pre->post7', preLoc: 0.5, hObj: NetCon[101]},
#   {preGid: 100, sec: 'apic_51', loc: 0.4766752779730028, synMech: 'INH:L5_PC7', weight: 0.91, delay: 0.05, label: 'pre->post7', preLoc: 0.5, hObj: NetCon[102]},
#   {preGid: 100, sec: 'dend_1', loc: 0.7609083087217362, synMech: 'INH:L5_PC7', weight: 0.91, delay: 0.05, label: 'pre->post7', preLoc: 0.5, hObj: NetCon[103]},
#   {preGid: 100, sec: 'apic_25', loc: 0.1866607326483096, synMech: 'INH:L5_PC7', weight: 0.91, delay: 0.05, label: 'pre->post7', preLoc: 0.5, hObj: NetCon[104]}],
#  [{preGid: 100, sec: 'dend_19', loc: 0.6268994234840309, synMech: 'INH:L5_PC8', weight: 0.91, delay: 0.05, label: 'pre->post8', preLoc: 0.5, hObj: NetCon[105]},
#   {preGid: 100, sec: 'apic_16', loc: 0.40501987444902554, synMech: 'INH:L5_PC8', weight: 0.91, delay: 0.05, label: 'pre->post8', preLoc: 0.5, hObj: NetCon[106]},
#   {preGid: 100, sec: 'dend_24', loc: 0.6562444884737119, synMech: 'INH:L5_PC8', weight: 0.91, delay: 0.05, label: 'pre->post8', preLoc: 0.5, hObj: NetCon[107]},
#   {preGid: 100, sec: 'apic_23', loc: 0.6858141953581216, synMech: 'INH:L5_PC8', weight: 0.91, delay: 0.05, label: 'pre->post8', preLoc: 0.5, hObj: NetCon[108]},
#   {preGid: 100, sec: 'dend_36', loc: 0.09137280528576303, synMech: 'INH:L5_PC8', weight: 0.91, delay: 0.05, label: 'pre->post8', preLoc: 0.5, hObj: NetCon[109]},
#   {preGid: 100, sec: 'dend_6', loc: 0.5485276332847486, synMech: 'INH:L5_PC8', weight: 0.91, delay: 0.05, label: 'pre->post8', preLoc: 0.5, hObj: NetCon[110]},
#   {preGid: 100, sec: 'apic_9', loc: 0.534036875168756, synMech: 'INH:L5_PC8', weight: 0.91, delay: 0.05, label: 'pre->post8', preLoc: 0.5, hObj: NetCon[111]},
#   {preGid: 100, sec: 'apic_25', loc: 0.9592867303832225, synMech: 'INH:L5_PC8', weight: 0.91, delay: 0.05, label: 'pre->post8', preLoc: 0.5, hObj: NetCon[112]},
#   {preGid: 100, sec: 'dend_11', loc: 0.3033799190256573, synMech: 'INH:L5_PC8', weight: 0.91, delay: 0.05, label: 'pre->post8', preLoc: 0.5, hObj: NetCon[113]},
#   {preGid: 100, sec: 'dend_8', loc: 0.5805952124487311, synMech: 'INH:L5_PC8', weight: 0.91, delay: 0.05, label: 'pre->post8', preLoc: 0.5, hObj: NetCon[114]},
#   {preGid: 100, sec: 'apic_21', loc: 0.048163629283932724, synMech: 'INH:L5_PC8', weight: 0.91, delay: 0.05, label: 'pre->post8', preLoc: 0.5, hObj: NetCon[115]},
#   {preGid: 100, sec: 'dend_34', loc: 0.17047476671273062, synMech: 'INH:L5_PC8', weight: 0.91, delay: 0.05, label: 'pre->post8', preLoc: 0.5, hObj: NetCon[116]},
#   {preGid: 100, sec: 'dend_30', loc: 0.5534402165754881, synMech: 'INH:L5_PC8', weight: 0.91, delay: 0.05, label: 'pre->post8', preLoc: 0.5, hObj: NetCon[117]},
#   {preGid: 100, sec: 'apic_47', loc: 0.4072252145965399, synMech: 'INH:L5_PC8', weight: 0.91, delay: 0.05, label: 'pre->post8', preLoc: 0.5, hObj: NetCon[118]},
#   {preGid: 100, sec: 'apic_5', loc: 0.14675107129653195, synMech: 'INH:L5_PC8', weight: 0.91, delay: 0.05, label: 'pre->post8', preLoc: 0.5, hObj: NetCon[119]}],
#  [{preGid: 100, sec: 'dend_23', loc: 0.33179560116167434, synMech: 'INH:L5_PC9', weight: 0.91, delay: 0.05, label: 'pre->post9', preLoc: 0.5, hObj: NetCon[120]},
#   {preGid: 100, sec: 'dend_26', loc: 0.17552192526910046, synMech: 'INH:L5_PC9', weight: 0.91, delay: 0.05, label: 'pre->post9', preLoc: 0.5, hObj: NetCon[121]},
#   {preGid: 100, sec: 'apic_53', loc: 0.4156730778078664, synMech: 'INH:L5_PC9', weight: 0.91, delay: 0.05, label: 'pre->post9', preLoc: 0.5, hObj: NetCon[122]},
#   {preGid: 100, sec: 'apic_34', loc: 0.28056570130060965, synMech: 'INH:L5_PC9', weight: 0.91, delay: 0.05, label: 'pre->post9', preLoc: 0.5, hObj: NetCon[123]},
#   {preGid: 100, sec: 'apic_4', loc: 0.7719476098800487, synMech: 'INH:L5_PC9', weight: 0.91, delay: 0.05, label: 'pre->post9', preLoc: 0.5, hObj: NetCon[124]},
#   {preGid: 100, sec: 'dend_34', loc: 0.7251570704098643, synMech: 'INH:L5_PC9', weight: 0.91, delay: 0.05, label: 'pre->post9', preLoc: 0.5, hObj: NetCon[125]},
#   {preGid: 100, sec: 'dend_11', loc: 0.5125701308219922, synMech: 'INH:L5_PC9', weight: 0.91, delay: 0.05, label: 'pre->post9', preLoc: 0.5, hObj: NetCon[126]},
#   {preGid: 100, sec: 'apic_45', loc: 0.5915949440683675, synMech: 'INH:L5_PC9', weight: 0.91, delay: 0.05, label: 'pre->post9', preLoc: 0.5, hObj: NetCon[127]},
#   {preGid: 100, sec: 'dend_38', loc: 0.11599138444510783, synMech: 'INH:L5_PC9', weight: 0.91, delay: 0.05, label: 'pre->post9', preLoc: 0.5, hObj: NetCon[128]},
#   {preGid: 100, sec: 'apic_31', loc: 0.2075081388480133, synMech: 'INH:L5_PC9', weight: 0.91, delay: 0.05, label: 'pre->post9', preLoc: 0.5, hObj: NetCon[129]},
#   {preGid: 100, sec: 'apic_27', loc: 0.6654131872379864, synMech: 'INH:L5_PC9', weight: 0.91, delay: 0.05, label: 'pre->post9', preLoc: 0.5, hObj: NetCon[130]},
#   {preGid: 100, sec: 'apic_7', loc: 0.8944528232775171, synMech: 'INH:L5_PC9', weight: 0.91, delay: 0.05, label: 'pre->post9', preLoc: 0.5, hObj: NetCon[131]},
#   {preGid: 100, sec: 'soma', loc: 0.9551027950302261, synMech: 'INH:L5_PC9', weight: 0.91, delay: 0.05, label: 'pre->post9', preLoc: 0.5, hObj: NetCon[132]},
#   {preGid: 100, sec: 'apic_19', loc: 0.0023838124483791558, synMech: 'INH:L5_PC9', weight: 0.91, delay: 0.05, label: 'pre->post9', preLoc: 0.5, hObj: NetCon[133]},
#   {preGid: 100, sec: 'apic_40', loc: 0.3090310049388383, synMech: 'INH:L5_PC9', weight: 0.91, delay: 0.05, label: 'pre->post9', preLoc: 0.5, hObj: NetCon[134]}],
#  [{preGid: 100, sec: 'apic_29', loc: 0.999590748111169, synMech: 'INH:L5_PC10', weight: 0.91, delay: 0.05, label: 'pre->post10', preLoc: 0.5, hObj: NetCon[135]},
#   {preGid: 100, sec: 'apic_19', loc: 0.06436654373241983, synMech: 'INH:L5_PC10', weight: 0.91, delay: 0.05, label: 'pre->post10', preLoc: 0.5, hObj: NetCon[136]},
#   {preGid: 100, sec: 'apic_5', loc: 0.9562701866412419, synMech: 'INH:L5_PC10', weight: 0.91, delay: 0.05, label: 'pre->post10', preLoc: 0.5, hObj: NetCon[137]},
#   {preGid: 100, sec: 'apic_17', loc: 0.34482425892977964, synMech: 'INH:L5_PC10', weight: 0.91, delay: 0.05, label: 'pre->post10', preLoc: 0.5, hObj: NetCon[138]},
#   {preGid: 100, sec: 'apic_39', loc: 0.7716254798763545, synMech: 'INH:L5_PC10', weight: 0.91, delay: 0.05, label: 'pre->post10', preLoc: 0.5, hObj: NetCon[139]},
#   {preGid: 100, sec: 'dend_6', loc: 0.43011617116871653, synMech: 'INH:L5_PC10', weight: 0.91, delay: 0.05, label: 'pre->post10', preLoc: 0.5, hObj: NetCon[140]},
#   {preGid: 100, sec: 'dend_11', loc: 0.309153073569901, synMech: 'INH:L5_PC10', weight: 0.91, delay: 0.05, label: 'pre->post10', preLoc: 0.5, hObj: NetCon[141]},
#   {preGid: 100, sec: 'dend_3', loc: 0.8981073958341113, synMech: 'INH:L5_PC10', weight: 0.91, delay: 0.05, label: 'pre->post10', preLoc: 0.5, hObj: NetCon[142]},
#   {preGid: 100, sec: 'dend_1', loc: 0.9449694788531212, synMech: 'INH:L5_PC10', weight: 0.91, delay: 0.05, label: 'pre->post10', preLoc: 0.5, hObj: NetCon[143]},
#   {preGid: 100, sec: 'dend_38', loc: 0.7706290360475544, synMech: 'INH:L5_PC10', weight: 0.91, delay: 0.05, label: 'pre->post10', preLoc: 0.5, hObj: NetCon[144]},
#   {preGid: 100, sec: 'dend_27', loc: 0.9278564154162711, synMech: 'INH:L5_PC10', weight: 0.91, delay: 0.05, label: 'pre->post10', preLoc: 0.5, hObj: NetCon[145]},
#   {preGid: 100, sec: 'dend_41', loc: 0.736462039040703, synMech: 'INH:L5_PC10', weight: 0.91, delay: 0.05, label: 'pre->post10', preLoc: 0.5, hObj: NetCon[146]},
#   {preGid: 100, sec: 'dend_13', loc: 0.027755810344001007, synMech: 'INH:L5_PC10', weight: 0.91, delay: 0.05, label: 'pre->post10', preLoc: 0.5, hObj: NetCon[147]},
#   {preGid: 100, sec: 'dend_44', loc: 0.7918160401618466, synMech: 'INH:L5_PC10', weight: 0.91, delay: 0.05, label: 'pre->post10', preLoc: 0.5, hObj: NetCon[148]},
#   {preGid: 100, sec: 'dend_45', loc: 0.1157731068709269, synMech: 'INH:L5_PC10', weight: 0.91, delay: 0.05, label: 'pre->post10', preLoc: 0.5, hObj: NetCon[149]}],
#  [{preGid: 100, sec: 'apic_66', loc: 0.03105780603213097, synMech: 'INH:L5_PC11', weight: 0.91, delay: 0.05, label: 'pre->post11', preLoc: 0.5, hObj: NetCon[150]},
#   {preGid: 100, sec: 'dend_18', loc: 0.8428114102332628, synMech: 'INH:L5_PC11', weight: 0.91, delay: 0.05, label: 'pre->post11', preLoc: 0.5, hObj: NetCon[151]},
#   {preGid: 100, sec: 'dend_26', loc: 0.21632657124777482, synMech: 'INH:L5_PC11', weight: 0.91, delay: 0.05, label: 'pre->post11', preLoc: 0.5, hObj: NetCon[152]},
#   {preGid: 100, sec: 'apic_22', loc: 0.8446912150355639, synMech: 'INH:L5_PC11', weight: 0.91, delay: 0.05, label: 'pre->post11', preLoc: 0.5, hObj: NetCon[153]},
#   {preGid: 100, sec: 'apic_27', loc: 0.6863565666088912, synMech: 'INH:L5_PC11', weight: 0.91, delay: 0.05, label: 'pre->post11', preLoc: 0.5, hObj: NetCon[154]},
#   {preGid: 100, sec: 'apic_45', loc: 0.8626812592697566, synMech: 'INH:L5_PC11', weight: 0.91, delay: 0.05, label: 'pre->post11', preLoc: 0.5, hObj: NetCon[155]},
#   {preGid: 100, sec: 'apic_49', loc: 0.44407340091461295, synMech: 'INH:L5_PC11', weight: 0.91, delay: 0.05, label: 'pre->post11', preLoc: 0.5, hObj: NetCon[156]},
#   {preGid: 100, sec: 'dend_42', loc: 0.8999796876571742, synMech: 'INH:L5_PC11', weight: 0.91, delay: 0.05, label: 'pre->post11', preLoc: 0.5, hObj: NetCon[157]},
#   {preGid: 100, sec: 'dend_55', loc: 0.9055111158825373, synMech: 'INH:L5_PC11', weight: 0.91, delay: 0.05, label: 'pre->post11', preLoc: 0.5, hObj: NetCon[158]},
#   {preGid: 100, sec: 'dend_49', loc: 0.8110604867635925, synMech: 'INH:L5_PC11', weight: 0.91, delay: 0.05, label: 'pre->post11', preLoc: 0.5, hObj: NetCon[159]},
#   {preGid: 100, sec: 'apic_47', loc: 0.5374701678888221, synMech: 'INH:L5_PC11', weight: 0.91, delay: 0.05, label: 'pre->post11', preLoc: 0.5, hObj: NetCon[160]},
#   {preGid: 100, sec: 'dend_51', loc: 0.7446078527141744, synMech: 'INH:L5_PC11', weight: 0.91, delay: 0.05, label: 'pre->post11', preLoc: 0.5, hObj: NetCon[161]},
#   {preGid: 100, sec: 'apic_54', loc: 0.20115939504647673, synMech: 'INH:L5_PC11', weight: 0.91, delay: 0.05, label: 'pre->post11', preLoc: 0.5, hObj: NetCon[162]},
#   {preGid: 100, sec: 'apic_9', loc: 0.09675801088212937, synMech: 'INH:L5_PC11', weight: 0.91, delay: 0.05, label: 'pre->post11', preLoc: 0.5, hObj: NetCon[163]},
#   {preGid: 100, sec: 'apic_34', loc: 0.8825543448036681, synMech: 'INH:L5_PC11', weight: 0.91, delay: 0.05, label: 'pre->post11', preLoc: 0.5, hObj: NetCon[164]}],
#  [{preGid: 100, sec: 'dend_4', loc: 0.556102727929775, synMech: 'INH:L5_PC12', weight: 0.91, delay: 0.05, label: 'pre->post12', preLoc: 0.5, hObj: NetCon[165]},
#   {preGid: 100, sec: 'apic_48', loc: 0.5138324150735954, synMech: 'INH:L5_PC12', weight: 0.91, delay: 0.05, label: 'pre->post12', preLoc: 0.5, hObj: NetCon[166]},
#   {preGid: 100, sec: 'dend_52', loc: 0.2929457287071554, synMech: 'INH:L5_PC12', weight: 0.91, delay: 0.05, label: 'pre->post12', preLoc: 0.5, hObj: NetCon[167]},
#   {preGid: 100, sec: 'dend_55', loc: 0.8919831487430386, synMech: 'INH:L5_PC12', weight: 0.91, delay: 0.05, label: 'pre->post12', preLoc: 0.5, hObj: NetCon[168]},
#   {preGid: 100, sec: 'dend_7', loc: 0.18217694977964793, synMech: 'INH:L5_PC12', weight: 0.91, delay: 0.05, label: 'pre->post12', preLoc: 0.5, hObj: NetCon[169]},
#   {preGid: 100, sec: 'apic_9', loc: 0.5278167771309675, synMech: 'INH:L5_PC12', weight: 0.91, delay: 0.05, label: 'pre->post12', preLoc: 0.5, hObj: NetCon[170]},
#   {preGid: 100, sec: 'apic_3', loc: 0.2023344136095045, synMech: 'INH:L5_PC12', weight: 0.91, delay: 0.05, label: 'pre->post12', preLoc: 0.5, hObj: NetCon[171]},
#   {preGid: 100, sec: 'dend_42', loc: 0.12980849659425703, synMech: 'INH:L5_PC12', weight: 0.91, delay: 0.05, label: 'pre->post12', preLoc: 0.5, hObj: NetCon[172]},
#   {preGid: 100, sec: 'apic_22', loc: 0.4267792571363205, synMech: 'INH:L5_PC12', weight: 0.91, delay: 0.05, label: 'pre->post12', preLoc: 0.5, hObj: NetCon[173]},
#   {preGid: 100, sec: 'dend_2', loc: 0.23429278228021516, synMech: 'INH:L5_PC12', weight: 0.91, delay: 0.05, label: 'pre->post12', preLoc: 0.5, hObj: NetCon[174]},
#   {preGid: 100, sec: 'dend_9', loc: 0.978622838232194, synMech: 'INH:L5_PC12', weight: 0.91, delay: 0.05, label: 'pre->post12', preLoc: 0.5, hObj: NetCon[175]},
#   {preGid: 100, sec: 'apic_46', loc: 0.5177491673925619, synMech: 'INH:L5_PC12', weight: 0.91, delay: 0.05, label: 'pre->post12', preLoc: 0.5, hObj: NetCon[176]},
#   {preGid: 100, sec: 'dend_45', loc: 0.23101449078467332, synMech: 'INH:L5_PC12', weight: 0.91, delay: 0.05, label: 'pre->post12', preLoc: 0.5, hObj: NetCon[177]},
#   {preGid: 100, sec: 'apic_24', loc: 0.09792757513195675, synMech: 'INH:L5_PC12', weight: 0.91, delay: 0.05, label: 'pre->post12', preLoc: 0.5, hObj: NetCon[178]},
#   {preGid: 100, sec: 'apic_61', loc: 0.03729877944037255, synMech: 'INH:L5_PC12', weight: 0.91, delay: 0.05, label: 'pre->post12', preLoc: 0.5, hObj: NetCon[179]}],
#  [{preGid: 100, sec: 'dend_25', loc: 0.15185886569667634, synMech: 'INH:L5_PC13', weight: 0.91, delay: 0.05, label: 'pre->post13', preLoc: 0.5, hObj: NetCon[180]},
#   {preGid: 100, sec: 'apic_43', loc: 0.8956972837911267, synMech: 'INH:L5_PC13', weight: 0.91, delay: 0.05, label: 'pre->post13', preLoc: 0.5, hObj: NetCon[181]},
#   {preGid: 100, sec: 'dend_7', loc: 0.29776705330032294, synMech: 'INH:L5_PC13', weight: 0.91, delay: 0.05, label: 'pre->post13', preLoc: 0.5, hObj: NetCon[182]},
#   {preGid: 100, sec: 'dend_36', loc: 0.6434652430768283, synMech: 'INH:L5_PC13', weight: 0.91, delay: 0.05, label: 'pre->post13', preLoc: 0.5, hObj: NetCon[183]},
#   {preGid: 100, sec: 'apic_23', loc: 0.477982392901777, synMech: 'INH:L5_PC13', weight: 0.91, delay: 0.05, label: 'pre->post13', preLoc: 0.5, hObj: NetCon[184]},
#   {preGid: 100, sec: 'dend_43', loc: 0.5184512835469415, synMech: 'INH:L5_PC13', weight: 0.91, delay: 0.05, label: 'pre->post13', preLoc: 0.5, hObj: NetCon[185]},
#   {preGid: 100, sec: 'dend_52', loc: 0.5923652984178062, synMech: 'INH:L5_PC13', weight: 0.91, delay: 0.05, label: 'pre->post13', preLoc: 0.5, hObj: NetCon[186]},
#   {preGid: 100, sec: 'apic_15', loc: 0.5243084804947704, synMech: 'INH:L5_PC13', weight: 0.91, delay: 0.05, label: 'pre->post13', preLoc: 0.5, hObj: NetCon[187]},
#   {preGid: 100, sec: 'apic_24', loc: 0.3114790507834832, synMech: 'INH:L5_PC13', weight: 0.91, delay: 0.05, label: 'pre->post13', preLoc: 0.5, hObj: NetCon[188]},
#   {preGid: 100, sec: 'apic_27', loc: 0.47723485612860006, synMech: 'INH:L5_PC13', weight: 0.91, delay: 0.05, label: 'pre->post13', preLoc: 0.5, hObj: NetCon[189]},
#   {preGid: 100, sec: 'apic_60', loc: 0.44629857022161656, synMech: 'INH:L5_PC13', weight: 0.91, delay: 0.05, label: 'pre->post13', preLoc: 0.5, hObj: NetCon[190]},
#   {preGid: 100, sec: 'dend_54', loc: 0.9934699959485507, synMech: 'INH:L5_PC13', weight: 0.91, delay: 0.05, label: 'pre->post13', preLoc: 0.5, hObj: NetCon[191]},
#   {preGid: 100, sec: 'apic_54', loc: 0.1772548296996179, synMech: 'INH:L5_PC13', weight: 0.91, delay: 0.05, label: 'pre->post13', preLoc: 0.5, hObj: NetCon[192]},
#   {preGid: 100, sec: 'apic_46', loc: 0.6648832921123264, synMech: 'INH:L5_PC13', weight: 0.91, delay: 0.05, label: 'pre->post13', preLoc: 0.5, hObj: NetCon[193]},
#   {preGid: 100, sec: 'apic_47', loc: 0.4123814889511414, synMech: 'INH:L5_PC13', weight: 0.91, delay: 0.05, label: 'pre->post13', preLoc: 0.5, hObj: NetCon[194]}],
#  [{preGid: 100, sec: 'dend_26', loc: 0.2973022122446753, synMech: 'INH:L5_PC14', weight: 0.91, delay: 0.05, label: 'pre->post14', preLoc: 0.5, hObj: NetCon[195]},
#   {preGid: 100, sec: 'apic_22', loc: 0.2524704231377173, synMech: 'INH:L5_PC14', weight: 0.91, delay: 0.05, label: 'pre->post14', preLoc: 0.5, hObj: NetCon[196]},
#   {preGid: 100, sec: 'dend_11', loc: 0.31085383390090526, synMech: 'INH:L5_PC14', weight: 0.91, delay: 0.05, label: 'pre->post14', preLoc: 0.5, hObj: NetCon[197]},
#   {preGid: 100, sec: 'apic_9', loc: 0.13179791206121122, synMech: 'INH:L5_PC14', weight: 0.91, delay: 0.05, label: 'pre->post14', preLoc: 0.5, hObj: NetCon[198]},
#   {preGid: 100, sec: 'apic_65', loc: 0.3774746759352904, synMech: 'INH:L5_PC14', weight: 0.91, delay: 0.05, label: 'pre->post14', preLoc: 0.5, hObj: NetCon[199]},
#   {preGid: 100, sec: 'apic_46', loc: 0.11517512035990848, synMech: 'INH:L5_PC14', weight: 0.91, delay: 0.05, label: 'pre->post14', preLoc: 0.5, hObj: NetCon[200]},
#   {preGid: 100, sec: 'apic_29', loc: 0.10092301860145668, synMech: 'INH:L5_PC14', weight: 0.91, delay: 0.05, label: 'pre->post14', preLoc: 0.5, hObj: NetCon[201]},
#   {preGid: 100, sec: 'dend_49', loc: 0.674021224615782, synMech: 'INH:L5_PC14', weight: 0.91, delay: 0.05, label: 'pre->post14', preLoc: 0.5, hObj: NetCon[202]},
#   {preGid: 100, sec: 'dend_45', loc: 0.14322978900918806, synMech: 'INH:L5_PC14', weight: 0.91, delay: 0.05, label: 'pre->post14', preLoc: 0.5, hObj: NetCon[203]},
#   {preGid: 100, sec: 'apic_15', loc: 0.429915859785886, synMech: 'INH:L5_PC14', weight: 0.91, delay: 0.05, label: 'pre->post14', preLoc: 0.5, hObj: NetCon[204]},
#   {preGid: 100, sec: 'dend_42', loc: 0.9630026971892154, synMech: 'INH:L5_PC14', weight: 0.91, delay: 0.05, label: 'pre->post14', preLoc: 0.5, hObj: NetCon[205]},
#   {preGid: 100, sec: 'dend_46', loc: 0.33556452112785834, synMech: 'INH:L5_PC14', weight: 0.91, delay: 0.05, label: 'pre->post14', preLoc: 0.5, hObj: NetCon[206]},
#   {preGid: 100, sec: 'apic_44', loc: 0.9836960278049531, synMech: 'INH:L5_PC14', weight: 0.91, delay: 0.05, label: 'pre->post14', preLoc: 0.5, hObj: NetCon[207]},
#   {preGid: 100, sec: 'apic_47', loc: 0.5118619120890535, synMech: 'INH:L5_PC14', weight: 0.91, delay: 0.05, label: 'pre->post14', preLoc: 0.5, hObj: NetCon[208]},
#   {preGid: 100, sec: 'apic_28', loc: 0.9266492283522857, synMech: 'INH:L5_PC14', weight: 0.91, delay: 0.05, label: 'pre->post14', preLoc: 0.5, hObj: NetCon[209]}],
#  [{preGid: 100, sec: 'apic_46', loc: 0.006518334456416628, synMech: 'INH:L5_PC15', weight: 0.91, delay: 0.05, label: 'pre->post15', preLoc: 0.5, hObj: NetCon[210]},
#   {preGid: 100, sec: 'apic_15', loc: 0.4951035998825311, synMech: 'INH:L5_PC15', weight: 0.91, delay: 0.05, label: 'pre->post15', preLoc: 0.5, hObj: NetCon[211]},
#   {preGid: 100, sec: 'dend_11', loc: 0.5108646989394223, synMech: 'INH:L5_PC15', weight: 0.91, delay: 0.05, label: 'pre->post15', preLoc: 0.5, hObj: NetCon[212]},
#   {preGid: 100, sec: 'dend_51', loc: 0.9282664998785347, synMech: 'INH:L5_PC15', weight: 0.91, delay: 0.05, label: 'pre->post15', preLoc: 0.5, hObj: NetCon[213]},
#   {preGid: 100, sec: 'apic_63', loc: 0.12369379979148216, synMech: 'INH:L5_PC15', weight: 0.91, delay: 0.05, label: 'pre->post15', preLoc: 0.5, hObj: NetCon[214]},
#   {preGid: 100, sec: 'apic_9', loc: 0.8270382902691846, synMech: 'INH:L5_PC15', weight: 0.91, delay: 0.05, label: 'pre->post15', preLoc: 0.5, hObj: NetCon[215]},
#   {preGid: 100, sec: 'dend_41', loc: 0.6729667845653269, synMech: 'INH:L5_PC15', weight: 0.91, delay: 0.05, label: 'pre->post15', preLoc: 0.5, hObj: NetCon[216]},
#   {preGid: 100, sec: 'dend_18', loc: 0.43038050981891784, synMech: 'INH:L5_PC15', weight: 0.91, delay: 0.05, label: 'pre->post15', preLoc: 0.5, hObj: NetCon[217]},
#   {preGid: 100, sec: 'dend_6', loc: 0.11272211047753966, synMech: 'INH:L5_PC15', weight: 0.91, delay: 0.05, label: 'pre->post15', preLoc: 0.5, hObj: NetCon[218]},
#   {preGid: 100, sec: 'apic_22', loc: 0.8136650261249151, synMech: 'INH:L5_PC15', weight: 0.91, delay: 0.05, label: 'pre->post15', preLoc: 0.5, hObj: NetCon[219]},
#   {preGid: 100, sec: 'apic_47', loc: 0.8427870111882575, synMech: 'INH:L5_PC15', weight: 0.91, delay: 0.05, label: 'pre->post15', preLoc: 0.5, hObj: NetCon[220]},
#   {preGid: 100, sec: 'dend_14', loc: 0.8162844442413801, synMech: 'INH:L5_PC15', weight: 0.91, delay: 0.05, label: 'pre->post15', preLoc: 0.5, hObj: NetCon[221]},
#   {preGid: 100, sec: 'dend_42', loc: 0.5902850211977758, synMech: 'INH:L5_PC15', weight: 0.91, delay: 0.05, label: 'pre->post15', preLoc: 0.5, hObj: NetCon[222]},
#   {preGid: 100, sec: 'apic_66', loc: 0.4888628072587554, synMech: 'INH:L5_PC15', weight: 0.91, delay: 0.05, label: 'pre->post15', preLoc: 0.5, hObj: NetCon[223]},
#   {preGid: 100, sec: 'apic_41', loc: 0.7714341952415078, synMech: 'INH:L5_PC15', weight: 0.91, delay: 0.05, label: 'pre->post15', preLoc: 0.5, hObj: NetCon[224]}],
#  [{preGid: 100, sec: 'apic_53', loc: 0.24673187436290456, synMech: 'INH:L5_PC16', weight: 0.91, delay: 0.05, label: 'pre->post16', preLoc: 0.5, hObj: NetCon[225]},
#   {preGid: 100, sec: 'dend_43', loc: 0.7347540717656657, synMech: 'INH:L5_PC16', weight: 0.91, delay: 0.05, label: 'pre->post16', preLoc: 0.5, hObj: NetCon[226]},
#   {preGid: 100, sec: 'dend_7', loc: 0.1589815583744118, synMech: 'INH:L5_PC16', weight: 0.91, delay: 0.05, label: 'pre->post16', preLoc: 0.5, hObj: NetCon[227]},
#   {preGid: 100, sec: 'dend_26', loc: 0.9097632804276916, synMech: 'INH:L5_PC16', weight: 0.91, delay: 0.05, label: 'pre->post16', preLoc: 0.5, hObj: NetCon[228]},
#   {preGid: 100, sec: 'dend_12', loc: 0.6526114713389013, synMech: 'INH:L5_PC16', weight: 0.91, delay: 0.05, label: 'pre->post16', preLoc: 0.5, hObj: NetCon[229]},
#   {preGid: 100, sec: 'apic_21', loc: 0.8262472320478149, synMech: 'INH:L5_PC16', weight: 0.91, delay: 0.05, label: 'pre->post16', preLoc: 0.5, hObj: NetCon[230]},
#   {preGid: 100, sec: 'dend_11', loc: 0.2926456909881328, synMech: 'INH:L5_PC16', weight: 0.91, delay: 0.05, label: 'pre->post16', preLoc: 0.5, hObj: NetCon[231]},
#   {preGid: 100, sec: 'dend_27', loc: 0.5411187456739414, synMech: 'INH:L5_PC16', weight: 0.91, delay: 0.05, label: 'pre->post16', preLoc: 0.5, hObj: NetCon[232]},
#   {preGid: 100, sec: 'apic_12', loc: 0.15542242401181267, synMech: 'INH:L5_PC16', weight: 0.91, delay: 0.05, label: 'pre->post16', preLoc: 0.5, hObj: NetCon[233]},
#   {preGid: 100, sec: 'apic_19', loc: 0.5994404544263428, synMech: 'INH:L5_PC16', weight: 0.91, delay: 0.05, label: 'pre->post16', preLoc: 0.5, hObj: NetCon[234]},
#   {preGid: 100, sec: 'dend_20', loc: 0.18411478032489376, synMech: 'INH:L5_PC16', weight: 0.91, delay: 0.05, label: 'pre->post16', preLoc: 0.5, hObj: NetCon[235]},
#   {preGid: 100, sec: 'apic_9', loc: 0.8738583455235439, synMech: 'INH:L5_PC16', weight: 0.91, delay: 0.05, label: 'pre->post16', preLoc: 0.5, hObj: NetCon[236]},
#   {preGid: 100, sec: 'apic_14', loc: 0.05181337064635829, synMech: 'INH:L5_PC16', weight: 0.91, delay: 0.05, label: 'pre->post16', preLoc: 0.5, hObj: NetCon[237]},
#   {preGid: 100, sec: 'dend_17', loc: 0.24788049865266776, synMech: 'INH:L5_PC16', weight: 0.91, delay: 0.05, label: 'pre->post16', preLoc: 0.5, hObj: NetCon[238]},
#   {preGid: 100, sec: 'apic_1', loc: 0.44668630962010253, synMech: 'INH:L5_PC16', weight: 0.91, delay: 0.05, label: 'pre->post16', preLoc: 0.5, hObj: NetCon[239]}],
#  [{preGid: 100, sec: 'dend_11', loc: 0.46138868012498935, synMech: 'INH:L5_PC17', weight: 0.91, delay: 0.05, label: 'pre->post17', preLoc: 0.5, hObj: NetCon[240]},
#   {preGid: 100, sec: 'apic_26', loc: 0.07847945816298016, synMech: 'INH:L5_PC17', weight: 0.91, delay: 0.05, label: 'pre->post17', preLoc: 0.5, hObj: NetCon[241]},
#   {preGid: 100, sec: 'apic_31', loc: 0.7889511874242912, synMech: 'INH:L5_PC17', weight: 0.91, delay: 0.05, label: 'pre->post17', preLoc: 0.5, hObj: NetCon[242]},
#   {preGid: 100, sec: 'apic_36', loc: 0.21942989783118344, synMech: 'INH:L5_PC17', weight: 0.91, delay: 0.05, label: 'pre->post17', preLoc: 0.5, hObj: NetCon[243]},
#   {preGid: 100, sec: 'apic_19', loc: 0.8840207263677721, synMech: 'INH:L5_PC17', weight: 0.91, delay: 0.05, label: 'pre->post17', preLoc: 0.5, hObj: NetCon[244]},
#   {preGid: 100, sec: 'dend_37', loc: 0.44936540924267154, synMech: 'INH:L5_PC17', weight: 0.91, delay: 0.05, label: 'pre->post17', preLoc: 0.5, hObj: NetCon[245]},
#   {preGid: 100, sec: 'dend_34', loc: 0.4987379494919692, synMech: 'INH:L5_PC17', weight: 0.91, delay: 0.05, label: 'pre->post17', preLoc: 0.5, hObj: NetCon[246]},
#   {preGid: 100, sec: 'dend_8', loc: 0.8801015901088244, synMech: 'INH:L5_PC17', weight: 0.91, delay: 0.05, label: 'pre->post17', preLoc: 0.5, hObj: NetCon[247]},
#   {preGid: 100, sec: 'dend_41', loc: 0.18533874940853387, synMech: 'INH:L5_PC17', weight: 0.91, delay: 0.05, label: 'pre->post17', preLoc: 0.5, hObj: NetCon[248]},
#   {preGid: 100, sec: 'apic_45', loc: 0.31320240982603575, synMech: 'INH:L5_PC17', weight: 0.91, delay: 0.05, label: 'pre->post17', preLoc: 0.5, hObj: NetCon[249]},
#   {preGid: 100, sec: 'apic_32', loc: 0.5124812430131298, synMech: 'INH:L5_PC17', weight: 0.91, delay: 0.05, label: 'pre->post17', preLoc: 0.5, hObj: NetCon[250]},
#   {preGid: 100, sec: 'apic_7', loc: 0.15045678698815096, synMech: 'INH:L5_PC17', weight: 0.91, delay: 0.05, label: 'pre->post17', preLoc: 0.5, hObj: NetCon[251]},
#   {preGid: 100, sec: 'apic_9', loc: 0.38371775646207684, synMech: 'INH:L5_PC17', weight: 0.91, delay: 0.05, label: 'pre->post17', preLoc: 0.5, hObj: NetCon[252]},
#   {preGid: 100, sec: 'dend_13', loc: 0.9934790599246528, synMech: 'INH:L5_PC17', weight: 0.91, delay: 0.05, label: 'pre->post17', preLoc: 0.5, hObj: NetCon[253]},
#   {preGid: 100, sec: 'dend_44', loc: 0.558381402850245, synMech: 'INH:L5_PC17', weight: 0.91, delay: 0.05, label: 'pre->post17', preLoc: 0.5, hObj: NetCon[254]}],
#  [{preGid: 100, sec: 'dend_7', loc: 0.5386439494639806, synMech: 'INH:L5_PC18', weight: 0.91, delay: 0.05, label: 'pre->post18', preLoc: 0.5, hObj: NetCon[255]},
#   {preGid: 100, sec: 'apic_5', loc: 0.30047141293758683, synMech: 'INH:L5_PC18', weight: 0.91, delay: 0.05, label: 'pre->post18', preLoc: 0.5, hObj: NetCon[256]},
#   {preGid: 100, sec: 'apic_25', loc: 0.7486214814048405, synMech: 'INH:L5_PC18', weight: 0.91, delay: 0.05, label: 'pre->post18', preLoc: 0.5, hObj: NetCon[257]},
#   {preGid: 100, sec: 'dend_30', loc: 0.5019727666770241, synMech: 'INH:L5_PC18', weight: 0.91, delay: 0.05, label: 'pre->post18', preLoc: 0.5, hObj: NetCon[258]},
#   {preGid: 100, sec: 'apic_17', loc: 0.11051397425993822, synMech: 'INH:L5_PC18', weight: 0.91, delay: 0.05, label: 'pre->post18', preLoc: 0.5, hObj: NetCon[259]},
#   {preGid: 100, sec: 'apic_23', loc: 0.8216939688079458, synMech: 'INH:L5_PC18', weight: 0.91, delay: 0.05, label: 'pre->post18', preLoc: 0.5, hObj: NetCon[260]},
#   {preGid: 100, sec: 'dend_8', loc: 0.9696606809289545, synMech: 'INH:L5_PC18', weight: 0.91, delay: 0.05, label: 'pre->post18', preLoc: 0.5, hObj: NetCon[261]},
#   {preGid: 100, sec: 'dend_10', loc: 0.74363563000021, synMech: 'INH:L5_PC18', weight: 0.91, delay: 0.05, label: 'pre->post18', preLoc: 0.5, hObj: NetCon[262]},
#   {preGid: 100, sec: 'apic_47', loc: 0.5065943789066002, synMech: 'INH:L5_PC18', weight: 0.91, delay: 0.05, label: 'pre->post18', preLoc: 0.5, hObj: NetCon[263]},
#   {preGid: 100, sec: 'apic_31', loc: 0.6204681943916657, synMech: 'INH:L5_PC18', weight: 0.91, delay: 0.05, label: 'pre->post18', preLoc: 0.5, hObj: NetCon[264]},
#   {preGid: 100, sec: 'dend_1', loc: 0.01922720921606776, synMech: 'INH:L5_PC18', weight: 0.91, delay: 0.05, label: 'pre->post18', preLoc: 0.5, hObj: NetCon[265]},
#   {preGid: 100, sec: 'dend_37', loc: 0.8516837149823887, synMech: 'INH:L5_PC18', weight: 0.91, delay: 0.05, label: 'pre->post18', preLoc: 0.5, hObj: NetCon[266]},
#   {preGid: 100, sec: 'dend_38', loc: 0.0686558290169519, synMech: 'INH:L5_PC18', weight: 0.91, delay: 0.05, label: 'pre->post18', preLoc: 0.5, hObj: NetCon[267]},
#   {preGid: 100, sec: 'apic_22', loc: 0.2955818116516448, synMech: 'INH:L5_PC18', weight: 0.91, delay: 0.05, label: 'pre->post18', preLoc: 0.5, hObj: NetCon[268]},
#   {preGid: 100, sec: 'dend_34', loc: 0.6322494840332571, synMech: 'INH:L5_PC18', weight: 0.91, delay: 0.05, label: 'pre->post18', preLoc: 0.5, hObj: NetCon[269]}],
#  [{preGid: 100, sec: 'apic_44', loc: 0.1456068771565426, synMech: 'INH:L5_PC19', weight: 0.91, delay: 0.05, label: 'pre->post19', preLoc: 0.5, hObj: NetCon[270]},
#   {preGid: 100, sec: 'apic_18', loc: 0.3946007140320333, synMech: 'INH:L5_PC19', weight: 0.91, delay: 0.05, label: 'pre->post19', preLoc: 0.5, hObj: NetCon[271]},
#   {preGid: 100, sec: 'apic_47', loc: 0.6209628326919527, synMech: 'INH:L5_PC19', weight: 0.91, delay: 0.05, label: 'pre->post19', preLoc: 0.5, hObj: NetCon[272]},
#   {preGid: 100, sec: 'apic_5', loc: 0.23142338495764497, synMech: 'INH:L5_PC19', weight: 0.91, delay: 0.05, label: 'pre->post19', preLoc: 0.5, hObj: NetCon[273]},
#   {preGid: 100, sec: 'apic_23', loc: 0.9538426833969194, synMech: 'INH:L5_PC19', weight: 0.91, delay: 0.05, label: 'pre->post19', preLoc: 0.5, hObj: NetCon[274]},
#   {preGid: 100, sec: 'apic_37', loc: 0.7236719426041118, synMech: 'INH:L5_PC19', weight: 0.91, delay: 0.05, label: 'pre->post19', preLoc: 0.5, hObj: NetCon[275]},
#   {preGid: 100, sec: 'dend_27', loc: 0.5709437503698767, synMech: 'INH:L5_PC19', weight: 0.91, delay: 0.05, label: 'pre->post19', preLoc: 0.5, hObj: NetCon[276]},
#   {preGid: 100, sec: 'dend_1', loc: 0.8761226421222417, synMech: 'INH:L5_PC19', weight: 0.91, delay: 0.05, label: 'pre->post19', preLoc: 0.5, hObj: NetCon[277]},
#   {preGid: 100, sec: 'apic_36', loc: 0.43889941587326925, synMech: 'INH:L5_PC19', weight: 0.91, delay: 0.05, label: 'pre->post19', preLoc: 0.5, hObj: NetCon[278]},
#   {preGid: 100, sec: 'apic_17', loc: 0.693095376375096, synMech: 'INH:L5_PC19', weight: 0.91, delay: 0.05, label: 'pre->post19', preLoc: 0.5, hObj: NetCon[279]},
#   {preGid: 100, sec: 'apic_38', loc: 0.5318594096074618, synMech: 'INH:L5_PC19', weight: 0.91, delay: 0.05, label: 'pre->post19', preLoc: 0.5, hObj: NetCon[280]},
#   {preGid: 100, sec: 'apic_40', loc: 0.6389188379298751, synMech: 'INH:L5_PC19', weight: 0.91, delay: 0.05, label: 'pre->post19', preLoc: 0.5, hObj: NetCon[281]},
#   {preGid: 100, sec: 'apic_15', loc: 0.6041977945691247, synMech: 'INH:L5_PC19', weight: 0.91, delay: 0.05, label: 'pre->post19', preLoc: 0.5, hObj: NetCon[282]},
#   {preGid: 100, sec: 'apic_39', loc: 0.16342281602991943, synMech: 'INH:L5_PC19', weight: 0.91, delay: 0.05, label: 'pre->post19', preLoc: 0.5, hObj: NetCon[283]},
#   {preGid: 100, sec: 'dend_30', loc: 0.26973640002997723, synMech: 'INH:L5_PC19', weight: 0.91, delay: 0.05, label: 'pre->post19', preLoc: 0.5, hObj: NetCon[284]}],
#  [{preGid: 100, sec: 'apic_0', loc: 0.586460608397569, synMech: 'INH:L5_PC20', weight: 0.91, delay: 0.05, label: 'pre->post20', preLoc: 0.5, hObj: NetCon[285]},
#   {preGid: 100, sec: 'apic_45', loc: 0.15076767463965884, synMech: 'INH:L5_PC20', weight: 0.91, delay: 0.05, label: 'pre->post20', preLoc: 0.5, hObj: NetCon[286]},
#   {preGid: 100, sec: 'apic_7', loc: 0.049285299001567126, synMech: 'INH:L5_PC20', weight: 0.91, delay: 0.05, label: 'pre->post20', preLoc: 0.5, hObj: NetCon[287]},
#   {preGid: 100, sec: 'apic_52', loc: 0.9648154251664961, synMech: 'INH:L5_PC20', weight: 0.91, delay: 0.05, label: 'pre->post20', preLoc: 0.5, hObj: NetCon[288]},
#   {preGid: 100, sec: 'apic_12', loc: 0.5656044340735091, synMech: 'INH:L5_PC20', weight: 0.91, delay: 0.05, label: 'pre->post20', preLoc: 0.5, hObj: NetCon[289]},
#   {preGid: 100, sec: 'dend_24', loc: 0.6768909400463635, synMech: 'INH:L5_PC20', weight: 0.91, delay: 0.05, label: 'pre->post20', preLoc: 0.5, hObj: NetCon[290]},
#   {preGid: 100, sec: 'apic_6', loc: 0.6851751041643501, synMech: 'INH:L5_PC20', weight: 0.91, delay: 0.05, label: 'pre->post20', preLoc: 0.5, hObj: NetCon[291]},
#   {preGid: 100, sec: 'apic_33', loc: 0.9592499132907192, synMech: 'INH:L5_PC20', weight: 0.91, delay: 0.05, label: 'pre->post20', preLoc: 0.5, hObj: NetCon[292]},
#   {preGid: 100, sec: 'apic_49', loc: 0.3908614965005888, synMech: 'INH:L5_PC20', weight: 0.91, delay: 0.05, label: 'pre->post20', preLoc: 0.5, hObj: NetCon[293]},
# ...
#   {preGid: 100, sec: 'dend_55', loc: 0.27115010670328077, synMech: 'INH:L5_PC94', weight: 0.91, delay: 0.05, label: 'pre->post94', preLoc: 0.5, hObj: NetCon[1403]},
#   {preGid: 100, sec: 'apic_21', loc: 0.8766074267415693, synMech: 'INH:L5_PC94', weight: 0.91, delay: 0.05, label: 'pre->post94', preLoc: 0.5, hObj: NetCon[1404]},
#   {preGid: 100, sec: 'apic_7', loc: 0.08985109479519642, synMech: 'INH:L5_PC94', weight: 0.91, delay: 0.05, label: 'pre->post94', preLoc: 0.5, hObj: NetCon[1405]},
#   {preGid: 100, sec: 'dend_1', loc: 0.5860449977101693, synMech: 'INH:L5_PC94', weight: 0.91, delay: 0.05, label: 'pre->post94', preLoc: 0.5, hObj: NetCon[1406]},
#   {preGid: 100, sec: 'apic_25', loc: 0.6251738036474036, synMech: 'INH:L5_PC94', weight: 0.91, delay: 0.05, label: 'pre->post94', preLoc: 0.5, hObj: NetCon[1407]},
#   {preGid: 100, sec: 'dend_11', loc: 0.8566522368203593, synMech: 'INH:L5_PC94', weight: 0.91, delay: 0.05, label: 'pre->post94', preLoc: 0.5, hObj: NetCon[1408]},
#   {preGid: 100, sec: 'apic_43', loc: 0.49814290270788897, synMech: 'INH:L5_PC94', weight: 0.91, delay: 0.05, label: 'pre->post94', preLoc: 0.5, hObj: NetCon[1409]}],
#  [{preGid: 100, sec: 'dend_38', loc: 0.6287692527269404, synMech: 'INH:L5_PC95', weight: 0.91, delay: 0.05, label: 'pre->post95', preLoc: 0.5, hObj: NetCon[1410]},
#   {preGid: 100, sec: 'apic_19', loc: 0.8373878748703274, synMech: 'INH:L5_PC95', weight: 0.91, delay: 0.05, label: 'pre->post95', preLoc: 0.5, hObj: NetCon[1411]},
#   {preGid: 100, sec: 'apic_26', loc: 0.95283681208628, synMech: 'INH:L5_PC95', weight: 0.91, delay: 0.05, label: 'pre->post95', preLoc: 0.5, hObj: NetCon[1412]},
#   {preGid: 100, sec: 'apic_54', loc: 0.9231966544711847, synMech: 'INH:L5_PC95', weight: 0.91, delay: 0.05, label: 'pre->post95', preLoc: 0.5, hObj: NetCon[1413]},
#   {preGid: 100, sec: 'apic_33', loc: 0.07740135215905627, synMech: 'INH:L5_PC95', weight: 0.91, delay: 0.05, label: 'pre->post95', preLoc: 0.5, hObj: NetCon[1414]},
#   {preGid: 100, sec: 'apic_21', loc: 0.6940167865304095, synMech: 'INH:L5_PC95', weight: 0.91, delay: 0.05, label: 'pre->post95', preLoc: 0.5, hObj: NetCon[1415]},
#   {preGid: 100, sec: 'dend_55', loc: 0.6777703270017992, synMech: 'INH:L5_PC95', weight: 0.91, delay: 0.05, label: 'pre->post95', preLoc: 0.5, hObj: NetCon[1416]},
#   {preGid: 100, sec: 'apic_58', loc: 0.02112497216117742, synMech: 'INH:L5_PC95', weight: 0.91, delay: 0.05, label: 'pre->post95', preLoc: 0.5, hObj: NetCon[1417]},
#   {preGid: 100, sec: 'dend_22', loc: 0.6530832743233014, synMech: 'INH:L5_PC95', weight: 0.91, delay: 0.05, label: 'pre->post95', preLoc: 0.5, hObj: NetCon[1418]},
#   {preGid: 100, sec: 'dend_1', loc: 0.9713174166893719, synMech: 'INH:L5_PC95', weight: 0.91, delay: 0.05, label: 'pre->post95', preLoc: 0.5, hObj: NetCon[1419]},
#   {preGid: 100, sec: 'apic_27', loc: 0.07778499981257939, synMech: 'INH:L5_PC95', weight: 0.91, delay: 0.05, label: 'pre->post95', preLoc: 0.5, hObj: NetCon[1420]},
#   {preGid: 100, sec: 'dend_2', loc: 0.3051711224956946, synMech: 'INH:L5_PC95', weight: 0.91, delay: 0.05, label: 'pre->post95', preLoc: 0.5, hObj: NetCon[1421]},
#   {preGid: 100, sec: 'apic_43', loc: 0.10398196694982123, synMech: 'INH:L5_PC95', weight: 0.91, delay: 0.05, label: 'pre->post95', preLoc: 0.5, hObj: NetCon[1422]},
#   {preGid: 100, sec: 'apic_50', loc: 0.16708119552506998, synMech: 'INH:L5_PC95', weight: 0.91, delay: 0.05, label: 'pre->post95', preLoc: 0.5, hObj: NetCon[1423]},
#   {preGid: 100, sec: 'dend_47', loc: 0.21937054926713273, synMech: 'INH:L5_PC95', weight: 0.91, delay: 0.05, label: 'pre->post95', preLoc: 0.5, hObj: NetCon[1424]}],
#  [{preGid: 100, sec: 'apic_1', loc: 0.3584915815360728, synMech: 'INH:L5_PC96', weight: 0.91, delay: 0.05, label: 'pre->post96', preLoc: 0.5, hObj: NetCon[1425]},
#   {preGid: 100, sec: 'dend_58', loc: 0.7137727905223212, synMech: 'INH:L5_PC96', weight: 0.91, delay: 0.05, label: 'pre->post96', preLoc: 0.5, hObj: NetCon[1426]},
#   {preGid: 100, sec: 'dend_49', loc: 0.4687523989923179, synMech: 'INH:L5_PC96', weight: 0.91, delay: 0.05, label: 'pre->post96', preLoc: 0.5, hObj: NetCon[1427]},
#   {preGid: 100, sec: 'apic_29', loc: 0.03852299816247775, synMech: 'INH:L5_PC96', weight: 0.91, delay: 0.05, label: 'pre->post96', preLoc: 0.5, hObj: NetCon[1428]},
#   {preGid: 100, sec: 'apic_35', loc: 0.5927000488950073, synMech: 'INH:L5_PC96', weight: 0.91, delay: 0.05, label: 'pre->post96', preLoc: 0.5, hObj: NetCon[1429]},
#   {preGid: 100, sec: 'dend_35', loc: 0.9399858259226719, synMech: 'INH:L5_PC96', weight: 0.91, delay: 0.05, label: 'pre->post96', preLoc: 0.5, hObj: NetCon[1430]},
#   {preGid: 100, sec: 'dend_29', loc: 0.8616739771464491, synMech: 'INH:L5_PC96', weight: 0.91, delay: 0.05, label: 'pre->post96', preLoc: 0.5, hObj: NetCon[1431]},
#   {preGid: 100, sec: 'apic_32', loc: 0.8792697789506249, synMech: 'INH:L5_PC96', weight: 0.91, delay: 0.05, label: 'pre->post96', preLoc: 0.5, hObj: NetCon[1432]},
#   {preGid: 100, sec: 'dend_62', loc: 0.07165748315178046, synMech: 'INH:L5_PC96', weight: 0.91, delay: 0.05, label: 'pre->post96', preLoc: 0.5, hObj: NetCon[1433]},
#   {preGid: 100, sec: 'apic_21', loc: 0.14956428237423505, synMech: 'INH:L5_PC96', weight: 0.91, delay: 0.05, label: 'pre->post96', preLoc: 0.5, hObj: NetCon[1434]},
#   {preGid: 100, sec: 'dend_38', loc: 0.2749036612646218, synMech: 'INH:L5_PC96', weight: 0.91, delay: 0.05, label: 'pre->post96', preLoc: 0.5, hObj: NetCon[1435]},
#   {preGid: 100, sec: 'dend_23', loc: 0.36687017060433574, synMech: 'INH:L5_PC96', weight: 0.91, delay: 0.05, label: 'pre->post96', preLoc: 0.5, hObj: NetCon[1436]},
#   {preGid: 100, sec: 'dend_26', loc: 0.10075922014281728, synMech: 'INH:L5_PC96', weight: 0.91, delay: 0.05, label: 'pre->post96', preLoc: 0.5, hObj: NetCon[1437]},
#   {preGid: 100, sec: 'dend_11', loc: 0.613869618074516, synMech: 'INH:L5_PC96', weight: 0.91, delay: 0.05, label: 'pre->post96', preLoc: 0.5, hObj: NetCon[1438]},
#   {preGid: 100, sec: 'apic_61', loc: 0.32694897702884046, synMech: 'INH:L5_PC96', weight: 0.91, delay: 0.05, label: 'pre->post96', preLoc: 0.5, hObj: NetCon[1439]}],
#  [{preGid: 100, sec: 'apic_32', loc: 0.19155793316189096, synMech: 'INH:L5_PC97', weight: 0.91, delay: 0.05, label: 'pre->post97', preLoc: 0.5, hObj: NetCon[1440]},
#   {preGid: 100, sec: 'dend_26', loc: 0.24727507261669437, synMech: 'INH:L5_PC97', weight: 0.91, delay: 0.05, label: 'pre->post97', preLoc: 0.5, hObj: NetCon[1441]},
#   {preGid: 100, sec: 'apic_35', loc: 0.3891267119404263, synMech: 'INH:L5_PC97', weight: 0.91, delay: 0.05, label: 'pre->post97', preLoc: 0.5, hObj: NetCon[1442]},
#   {preGid: 100, sec: 'dend_22', loc: 0.7475973917699033, synMech: 'INH:L5_PC97', weight: 0.91, delay: 0.05, label: 'pre->post97', preLoc: 0.5, hObj: NetCon[1443]},
#   {preGid: 100, sec: 'apic_59', loc: 0.25684946227808503, synMech: 'INH:L5_PC97', weight: 0.91, delay: 0.05, label: 'pre->post97', preLoc: 0.5, hObj: NetCon[1444]},
#   {preGid: 100, sec: 'dend_63', loc: 0.9972352792259073, synMech: 'INH:L5_PC97', weight: 0.91, delay: 0.05, label: 'pre->post97', preLoc: 0.5, hObj: NetCon[1445]},
#   {preGid: 100, sec: 'dend_35', loc: 0.6414868508444067, synMech: 'INH:L5_PC97', weight: 0.91, delay: 0.05, label: 'pre->post97', preLoc: 0.5, hObj: NetCon[1446]},
#   {preGid: 100, sec: 'apic_1', loc: 0.12170052466182239, synMech: 'INH:L5_PC97', weight: 0.91, delay: 0.05, label: 'pre->post97', preLoc: 0.5, hObj: NetCon[1447]},
#   {preGid: 100, sec: 'apic_62', loc: 0.7941334014992857, synMech: 'INH:L5_PC97', weight: 0.91, delay: 0.05, label: 'pre->post97', preLoc: 0.5, hObj: NetCon[1448]},
#   {preGid: 100, sec: 'apic_38', loc: 0.016702051183462047, synMech: 'INH:L5_PC97', weight: 0.91, delay: 0.05, label: 'pre->post97', preLoc: 0.5, hObj: NetCon[1449]},
#   {preGid: 100, sec: 'dend_49', loc: 0.19996495147912152, synMech: 'INH:L5_PC97', weight: 0.91, delay: 0.05, label: 'pre->post97', preLoc: 0.5, hObj: NetCon[1450]},
#   {preGid: 100, sec: 'dend_31', loc: 0.22279455596164416, synMech: 'INH:L5_PC97', weight: 0.91, delay: 0.05, label: 'pre->post97', preLoc: 0.5, hObj: NetCon[1451]},
#   {preGid: 100, sec: 'apic_26', loc: 0.595328262048547, synMech: 'INH:L5_PC97', weight: 0.91, delay: 0.05, label: 'pre->post97', preLoc: 0.5, hObj: NetCon[1452]},
#   {preGid: 100, sec: 'dend_13', loc: 0.837665954987846, synMech: 'INH:L5_PC97', weight: 0.91, delay: 0.05, label: 'pre->post97', preLoc: 0.5, hObj: NetCon[1453]},
#   {preGid: 100, sec: 'apic_56', loc: 0.8323179468574222, synMech: 'INH:L5_PC97', weight: 0.91, delay: 0.05, label: 'pre->post97', preLoc: 0.5, hObj: NetCon[1454]}],
#  [{preGid: 100, sec: 'apic_11', loc: 0.8996112361140601, synMech: 'INH:L5_PC98', weight: 0.91, delay: 0.05, label: 'pre->post98', preLoc: 0.5, hObj: NetCon[1455]},
#   {preGid: 100, sec: 'dend_5', loc: 0.303737512246298, synMech: 'INH:L5_PC98', weight: 0.91, delay: 0.05, label: 'pre->post98', preLoc: 0.5, hObj: NetCon[1456]},
#   {preGid: 100, sec: 'apic_24', loc: 0.18872074382227338, synMech: 'INH:L5_PC98', weight: 0.91, delay: 0.05, label: 'pre->post98', preLoc: 0.5, hObj: NetCon[1457]},
#   {preGid: 100, sec: 'apic_27', loc: 0.9363063404413506, synMech: 'INH:L5_PC98', weight: 0.91, delay: 0.05, label: 'pre->post98', preLoc: 0.5, hObj: NetCon[1458]},
#   {preGid: 100, sec: 'dend_39', loc: 0.012219674912775766, synMech: 'INH:L5_PC98', weight: 0.91, delay: 0.05, label: 'pre->post98', preLoc: 0.5, hObj: NetCon[1459]},
#   {preGid: 100, sec: 'dend_62', loc: 0.030120316167206257, synMech: 'INH:L5_PC98', weight: 0.91, delay: 0.05, label: 'pre->post98', preLoc: 0.5, hObj: NetCon[1460]},
#   {preGid: 100, sec: 'dend_47', loc: 0.9066272337065922, synMech: 'INH:L5_PC98', weight: 0.91, delay: 0.05, label: 'pre->post98', preLoc: 0.5, hObj: NetCon[1461]},
#   {preGid: 100, sec: 'apic_53', loc: 0.7781192881575192, synMech: 'INH:L5_PC98', weight: 0.91, delay: 0.05, label: 'pre->post98', preLoc: 0.5, hObj: NetCon[1462]},
#   {preGid: 100, sec: 'apic_21', loc: 0.13811424033412975, synMech: 'INH:L5_PC98', weight: 0.91, delay: 0.05, label: 'pre->post98', preLoc: 0.5, hObj: NetCon[1463]},
#   {preGid: 100, sec: 'apic_19', loc: 0.9346821806224092, synMech: 'INH:L5_PC98', weight: 0.91, delay: 0.05, label: 'pre->post98', preLoc: 0.5, hObj: NetCon[1464]},
#   {preGid: 100, sec: 'apic_35', loc: 0.3846294391710499, synMech: 'INH:L5_PC98', weight: 0.91, delay: 0.05, label: 'pre->post98', preLoc: 0.5, hObj: NetCon[1465]},
#   {preGid: 100, sec: 'dend_11', loc: 0.40365201528656725, synMech: 'INH:L5_PC98', weight: 0.91, delay: 0.05, label: 'pre->post98', preLoc: 0.5, hObj: NetCon[1466]},
#   {preGid: 100, sec: 'apic_63', loc: 0.7957233135022936, synMech: 'INH:L5_PC98', weight: 0.91, delay: 0.05, label: 'pre->post98', preLoc: 0.5, hObj: NetCon[1467]},
#   {preGid: 100, sec: 'apic_7', loc: 0.8228376325486662, synMech: 'INH:L5_PC98', weight: 0.91, delay: 0.05, label: 'pre->post98', preLoc: 0.5, hObj: NetCon[1468]},
#   {preGid: 100, sec: 'dend_27', loc: 0.09001695548304135, synMech: 'INH:L5_PC98', weight: 0.91, delay: 0.05, label: 'pre->post98', preLoc: 0.5, hObj: NetCon[1469]}],
#  [{preGid: 100, sec: 'dend_48', loc: 0.9316814918453961, synMech: 'INH:L5_PC99', weight: 0.91, delay: 0.05, label: 'pre->post99', preLoc: 0.5, hObj: NetCon[1470]},
#   {preGid: 100, sec: 'dend_51', loc: 0.8539061305360116, synMech: 'INH:L5_PC99', weight: 0.91, delay: 0.05, label: 'pre->post99', preLoc: 0.5, hObj: NetCon[1471]},
#   {preGid: 100, sec: 'apic_18', loc: 0.9377829600033251, synMech: 'INH:L5_PC99', weight: 0.91, delay: 0.05, label: 'pre->post99', preLoc: 0.5, hObj: NetCon[1472]},
#   {preGid: 100, sec: 'dend_36', loc: 0.19115388108119316, synMech: 'INH:L5_PC99', weight: 0.91, delay: 0.05, label: 'pre->post99', preLoc: 0.5, hObj: NetCon[1473]},
#   {preGid: 100, sec: 'apic_8', loc: 0.48691568094296817, synMech: 'INH:L5_PC99', weight: 0.91, delay: 0.05, label: 'pre->post99', preLoc: 0.5, hObj: NetCon[1474]},
#   {preGid: 100, sec: 'apic_58', loc: 0.9037081863067801, synMech: 'INH:L5_PC99', weight: 0.91, delay: 0.05, label: 'pre->post99', preLoc: 0.5, hObj: NetCon[1475]},
#   {preGid: 100, sec: 'apic_37', loc: 0.4217853666342339, synMech: 'INH:L5_PC99', weight: 0.91, delay: 0.05, label: 'pre->post99', preLoc: 0.5, hObj: NetCon[1476]},
#   {preGid: 100, sec: 'dend_30', loc: 0.7299027772227582, synMech: 'INH:L5_PC99', weight: 0.91, delay: 0.05, label: 'pre->post99', preLoc: 0.5, hObj: NetCon[1477]},
#   {preGid: 100, sec: 'apic_21', loc: 0.49978045498462753, synMech: 'INH:L5_PC99', weight: 0.91, delay: 0.05, label: 'pre->post99', preLoc: 0.5, hObj: NetCon[1478]},
#   {preGid: 100, sec: 'apic_45', loc: 0.39982498962814095, synMech: 'INH:L5_PC99', weight: 0.91, delay: 0.05, label: 'pre->post99', preLoc: 0.5, hObj: NetCon[1479]},
#   {preGid: 100, sec: 'apic_27', loc: 0.6235560910775312, synMech: 'INH:L5_PC99', weight: 0.91, delay: 0.05, label: 'pre->post99', preLoc: 0.5, hObj: NetCon[1480]},
#   {preGid: 100, sec: 'dend_33', loc: 0.09422878585457062, synMech: 'INH:L5_PC99', weight: 0.91, delay: 0.05, label: 'pre->post99', preLoc: 0.5, hObj: NetCon[1481]},
#   {preGid: 100, sec: 'apic_63', loc: 0.5974683301789828, synMech: 'INH:L5_PC99', weight: 0.91, delay: 0.05, label: 'pre->post99', preLoc: 0.5, hObj: NetCon[1482]},
#   {preGid: 100, sec: 'dend_27', loc: 0.795372935297602, synMech: 'INH:L5_PC99', weight: 0.91, delay: 0.05, label: 'pre->post99', preLoc: 0.5, hObj: NetCon[1483]},
#   {preGid: 100, sec: 'apic_49', loc: 0.8365574986735698, synMech: 'INH:L5_PC99', weight: 0.91, delay: 0.05, label: 'pre->post99', preLoc: 0.5, hObj: NetCon[1484]}],
#  [{preGid: 100, sec: 'dend_62', loc: 0.1757419324226809, synMech: 'INH:L5_PC100', weight: 0.91, delay: 0.05, label: 'pre->post100', preLoc: 0.5, hObj: NetCon[1485]},
#   {preGid: 100, sec: 'apic_66', loc: 0.20186563859363163, synMech: 'INH:L5_PC100', weight: 0.91, delay: 0.05, label: 'pre->post100', preLoc: 0.5, hObj: NetCon[1486]},
#   {preGid: 100, sec: 'apic_54', loc: 0.0546853406555174, synMech: 'INH:L5_PC100', weight: 0.91, delay: 0.05, label: 'pre->post100', preLoc: 0.5, hObj: NetCon[1487]},
#   {preGid: 100, sec: 'dend_27', loc: 0.4701021715199052, synMech: 'INH:L5_PC100', weight: 0.91, delay: 0.05, label: 'pre->post100', preLoc: 0.5, hObj: NetCon[1488]},
#   {preGid: 100, sec: 'apic_12', loc: 0.1930722326383233, synMech: 'INH:L5_PC100', weight: 0.91, delay: 0.05, label: 'pre->post100', preLoc: 0.5, hObj: NetCon[1489]},
#   {preGid: 100, sec: 'apic_64', loc: 0.7813510517046275, synMech: 'INH:L5_PC100', weight: 0.91, delay: 0.05, label: 'pre->post100', preLoc: 0.5, hObj: NetCon[1490]},
#   {preGid: 100, sec: 'apic_49', loc: 0.07860489221322123, synMech: 'INH:L5_PC100', weight: 0.91, delay: 0.05, label: 'pre->post100', preLoc: 0.5, hObj: NetCon[1491]},
#   {preGid: 100, sec: 'apic_62', loc: 0.3533489164413527, synMech: 'INH:L5_PC100', weight: 0.91, delay: 0.05, label: 'pre->post100', preLoc: 0.5, hObj: NetCon[1492]},
#   {preGid: 100, sec: 'apic_1', loc: 0.12567691812004933, synMech: 'INH:L5_PC100', weight: 0.91, delay: 0.05, label: 'pre->post100', preLoc: 0.5, hObj: NetCon[1493]},
#   {preGid: 100, sec: 'dend_48', loc: 0.9735859925894196, synMech: 'INH:L5_PC100', weight: 0.91, delay: 0.05, label: 'pre->post100', preLoc: 0.5, hObj: NetCon[1494]},
#   {preGid: 100, sec: 'apic_9', loc: 0.7409467662537356, synMech: 'INH:L5_PC100', weight: 0.91, delay: 0.05, label: 'pre->post100', preLoc: 0.5, hObj: NetCon[1495]},
#   {preGid: 100, sec: 'apic_50', loc: 0.3008154264253905, synMech: 'INH:L5_PC100', weight: 0.91, delay: 0.05, label: 'pre->post100', preLoc: 0.5, hObj: NetCon[1496]},
#   {preGid: 100, sec: 'dend_41', loc: 0.44920562345680176, synMech: 'INH:L5_PC100', weight: 0.91, delay: 0.05, label: 'pre->post100', preLoc: 0.5, hObj: NetCon[1497]},
#   {preGid: 100, sec: 'dend_39', loc: 0.7825046673218182, synMech: 'INH:L5_PC100', weight: 0.91, delay: 0.05, label: 'pre->post100', preLoc: 0.5, hObj: NetCon[1498]},
#   {preGid: 100, sec: 'dend_22', loc: 0.2823451435229345, synMech: 'INH:L5_PC100', weight: 0.91, delay: 0.05, label: 'pre->post100', preLoc: 0.5, hObj: NetCon[1499]}],
#  []]

# %%
sim.net.addStims() 							# add network stimulation
sim.setupRecording()              			# setup variables to record for each cell (spikes, V traces, etc)
# Out:
#   Number of stims on node 0: 0
#   Done; cell stims creation time = 0.00 s.
# Recording 100 traces of 1 types on node 0
# {spkt: Vector[104791], spkid: Vector[104792], V_soma: {cell_0: Vector[104793], cell_1: Vector[104794], cell_2: Vector[104795], cell_3: Vector[104796], cell_4: Vector[104797], cell_5: Vector[104798], cell_6: Vector[104799], cell_7: Vector[104800], cell_8: Vector[104801], cell_9: Vector[104802], cell_10: Vector[104803], cell_11: Vector[104804], cell_12: Vector[104805], cell_13: Vector[104806], cell_14: Vector[104807], cell_15: Vector[104808], cell_16: Vector[104809], cell_17: Vector[104810], cell_18: Vector[104811], cell_19: Vector[104812], cell_20: Vector[104813], cell_21: Vector[104814], cell_22: Vector[104815], cell_23: Vector[104816], cell_24: Vector[104817], cell_25: Vector[104818], cell_26: Vector[104819], cell_27: Vector[104820], cell_28: Vector[104821], cell_29: Vector[104822], cell_30: Vector[104823], cell_31: Vector[104824], cell_32: Vector[104825], cell_33: Vector[104826], cell_34: Vector[104827], cell_35: Vector[104828], cell_36: Vector[104829], cell_37: Vector[104830], cell_38: Vector[104831], cell_39: Vector[104832], cell_40: Vector[104833], cell_41: Vector[104834], cell_42: Vector[104835], cell_43: Vector[104836], cell_44: Vector[104837], cell_45: Vector[104838], cell_46: Vector[104839], cell_47: Vector[104840], cell_48: Vector[104841], cell_49: Vector[104842], cell_50: Vector[104843], cell_51: Vector[104844], cell_52: Vector[104845], cell_53: Vector[104846], cell_54: Vector[104847], cell_55: Vector[104848], cell_56: Vector[104849], cell_57: Vector[104850], cell_58: Vector[104851], cell_59: Vector[104852], cell_60: Vector[104853], cell_61: Vector[104854], cell_62: Vector[104855], cell_63: Vector[104856], cell_64: Vector[104857], cell_65: Vector[104858], cell_66: Vector[104859], cell_67: Vector[104860], cell_68: Vector[104861], cell_69: Vector[104862], cell_70: Vector[104863], cell_71: Vector[104864], cell_72: Vector[104865], cell_73: Vector[104866], cell_74: Vector[104867], cell_75: Vector[104868], cell_76: Vector[104869], cell_77: Vector[104870], cell_78: Vector[104871], cell_79: Vector[104872], cell_80: Vector[104873], cell_81: Vector[104874], cell_82: Vector[104875], cell_83: Vector[104876], cell_84: Vector[104877], cell_85: Vector[104878], cell_86: Vector[104879], cell_87: Vector[104880], cell_88: Vector[104881], cell_89: Vector[104882], cell_90: Vector[104883], cell_91: Vector[104884], cell_92: Vector[104885], cell_93: Vector[104886], cell_94: Vector[104887], cell_95: Vector[104888], cell_96: Vector[104889], cell_97: Vector[104890], cell_98: Vector[104891], cell_99: Vector[104892]}, t: Vector[104893], _repr_mimebundle_: {}}

# %%
sim.runSim()                      			# run Neuron simulation
# Out:
# 0.0s
#
# Running simulation using NEURON for 4000.0 ms...
# 0.1s
# 0.2s
# 0.3s
# 0.4s
# 0.5s
# 0.6s
# 0.7s
# 0.8s
# 0.9s
# 1.0s
# 1.1s
# 1.2s
# 1.3s
# 1.4s
# 1.5s
# 1.6s
# 1.7s
# 1.8s
# 1.9s
# 2.0s
# 2.1s
# 2.2s
# 2.3s
# 2.4s
# 2.5s
# 2.6s
# 2.7s
# 2.8s
# 2.9s
# 3.0s
# 3.1s
# 3.2s
# 3.3s
# 3.4s
# 3.5s
# 3.6s
# 3.7s
# 3.8s
# 3.9s
# 4.0s
#   Done; run time = 9453.38 s; real-time ratio: 0.00.

# %%
sim.gatherData()                  			# gather spiking data and cell info from each node
sim.saveData()                    			# save params, cell info and sim output to file (pickle,mat,txt,etc)#
sim.analysis.plotData()         			# plot spike raster etc
# Out:
# Gathering data...
#   Done; gather time = 0.19 s.
#
# Analyzing...
#   Cells: 101
#   Connections: 100 (0.99 per cell)
#   Synaptic contacts: 1500 (14.85 per cell)
#   Spikes: 11 (0.03 Hz)
#   Simulated time: 4.0 s; 1 workers
#   Run time: 9453.38 s
# Warning: data won't be saved. No output format specified (consider sim.cfg.savePickle, sim.cfg.saveJson etc.)
# Plotting recorded cell traces ... trace
#   Done; plotting time = 0.80 s
#
# Total time = 9462.83 s

# %%
# sim.analysis.plotRaster(figSize=(10, 3))

# %%
alltraces = []
gmax1 = []

# spkTimes = [500,2500,2550,2600,2650,2700,2750,2800,2850,2900,3400]


Traces2 = sim.analysis.plotTraces(oneFigPer='trace', overlay=1, timeRange=[2400,3900],axis=False,legend=False,scaleBarLoc=1,figSize=(10, 3),fontSize=6)
for number in range(100):
    if np.max(Traces2[1]['tracesData'][number]['cell_'+str(number)+'_V_soma'])-np.min(Traces2[1]['tracesData'][number]['cell_'+str(number)+'_V_soma']) > 0.01:
        alltraces.append(Traces2[1]['tracesData'][number]['cell_'+str(number)+'_V_soma'])
        gmax1.append(np.max(Traces2[1]['tracesData'][number]['cell_'+str(number)+'_V_soma'])-np.min(Traces2[1]['tracesData'][number]['cell_'+str(number)+'_V_soma']))
#         print(number,np.max(Traces2[1]['tracesData'][number]['cell_'+str(number)+'_V_soma'])-np.min(Traces2[1]['tracesData'][number]['cell_'+str(number)+'_V_soma']))


# Traces2 = sim.analysis.plotTraces(oneFigPer='trace', overlay=1, timeRange=[3300,3900],axis=False,legend=False,scaleBarLoc=1,figSize=(10, 3),fontSize=6)
# for number in range(20):
#     if np.max(Traces2[1]['tracesData'][number]['cell_'+str(number)+'_V_soma'])-np.min(Traces2[1]['tracesData'][number]['cell_'+str(number)+'_V_soma']) > 0.01:
#         alltraces.append(Traces2[1]['tracesData'][number]['cell_'+str(number)+'_V_soma'])
#         gmax1.append(np.max(Traces2[1]['tracesData'][number]['cell_'+str(number)+'_V_soma'])-np.min(Traces2[1]['tracesData'][number]['cell_'+str(number)+'_V_soma']))
# #         print(number,np.max(Traces2[1]['tracesData'][number]['cell_'+str(number)+'_V_soma'])-np.min(Traces2[1]['tracesData'][number]['cell_'+str(number)+'_V_soma']))


# print('L23_PC:L23_PC in silico PSP amplitude (mV; mean ± SD) = %.3f±%.3f' % (np.mean(gmax1),np.std(gmax1)))
print('INH:L5_PC in silico PSP amplitude (mV; mean ± SD) = %.3f±%.3f' % (np.mean(gmax1),np.std(gmax1)))
# Out:
# Plotting recorded cell traces ... trace
# INH:L5_PC in silico PSP amplitude (mV; mean ± SD) = 0.096±0.082

# %%
figSize = (16,9)
fig = plt.figure(figsize=figSize)  # Open a new figure
clr = ["black", "blue","green","gray", "red","black", "blue","green","gray", "red","black", "blue","green","gray", "red","black", "blue","green","gray", "red"]
number=0
for i in range(20):
    for number2 in range(i,100,20):
        plt.plot(Traces2[1]['tracesData'][number]['t'][1:],Traces2[1]['tracesData'][number]['cell_'+str(number)+'_V_soma']-Traces2[1]['tracesData'][number]['cell_'+str(number)+'_V_soma'][999]-0.5*i, label= sim.net.allCells[number]['tags']['pop'] + '_' + sim.net.allCells[number]['conns'][0]['sec'], linewidth=1.0, color=clr[i])
        number+=1
        
plt.legend(loc='upper right', bbox_to_anchor=(1.25, 1.0), fontsize=8)
# plt.xlim(2400,4150)
plt.ylim(-10.25,1.0)
plt.xlabel('Time (ms)', fontsize=16)
plt.ylabel('EPSP (mV)', fontsize=16)
# plt.xticks(range(2400,3900,200), range(0,1500,200), fontsize=14);
plt.yticks([0,-1], fontsize=14);

# %%
figSize = (8,5)
fig = plt.figure(figsize=figSize)  # Open a new figure
for number in range(np.shape(alltraces)[0]):
    plt.plot(alltraces[number]-alltraces[number][0],color = 'lightgray',linewidth=2.0)

plt.title('Vrev -70 mV and gsyn = 100p  ->  %.2f ± %.2f mV' % (np.mean(gmax1),np.std(gmax1)), fontsize=14)
plt.plot(np.mean(alltraces, axis=0)-np.mean(alltraces, axis=0)[0],color = 'black', linewidth=4.0)
# plt.legend(loc='upper right', bbox_to_anchor=(0.95, 1.0))
plt.xlim(500,12000)
plt.ylim(0.5,-0.75)
plt.xlabel('Time (ms)', fontsize=16)
plt.ylabel('PSP (mV)', fontsize=16)
plt.xticks(range(1000,12000,2000), range(0,1100,200), fontsize=14);
plt.yticks([0,-0.5], fontsize=14); 

plt.savefig('../info/syn_gmax_INH_L5PC_type5_gabaaVrev-70mV.png', facecolor = 'white' , dpi=300)

# %%
# (0.8355167606552806, 25)

# %%
np.mean(gmax1), np.size(gmax1)
# Out:
# (0.09629220488340252, 100)

# %% [markdown]
# <!-- Connection type	s-type	in vitro PSP amplitude (mV; mean ± SD)	in silico PSP amplitude (mV; mean ± SD)	Input data sources
# L5TTPC-L5MC	E1	0.28 ± 0.3	0.28 ± 0.18	Silberberg & Markram, 2007
# L5MC-L5TTPC	I2	0.5 ± 0.3	0.57 ± 0.5	Silberberg & Markram, 2007
# L4SS-L23PC	E2	0.7 ± 0.6	0.7 ± 0.9	Feldmeyer et al. 2002
# L5STPC-L5STPC	E2	0.9 ± 0.7	0.91 ± 0.8	Le Bé et al. 2007
# L5UTPC-L5UTPC	E2	0.9 ± 0.7	0.91 ± 0.8	Le Bé et al. 2007
# L23PC-L23PC	E2	1 ± 0.7	1 ± 0.3	Feldmeyer et al. 2006
# L23LBC-L23PC	I2	1.2 ± 1.1	1.2 ± 1.02	Blatow et al. 2003
# L23NBC-L23PC	I2	1.2 ± 1.1	1.2 ± 1.02	Blatow et al. 2003
# L5TTPC-L5TTPC	E2	1.3 ± 1.1	1.2 ± 0.43	Markram et al. 1997
# L4SS-L4SS	E2	1.6 ± 1.0	1.9 ± 1.5	Feldmeyer et al. 1999
# L4SP-L4SP	E2	1.6 ± 1.0	1.9 ± 1.5	Feldmeyer et al. 1999
# L4PC-L4PC	E2	1.6 ± 1.0	1.9 ± 1.5	Feldmeyer et al. 1999
# L5TTPC-L5SBC	E2	2.1 ± 1.0	1.96 ± 0.67	Angulo et al. 1999 -->
# ![image.png](attachment:image.png)

# %%
Connectiontype = ['L5TTPC_L5MC_E1', 'L5MC_L5TTPC_I2', 'L4SS_L23PC_E2', 'L5STPC_L5STPC_E2', 'L5UTPC_L5UTPC_E2', 'L23PC_L23PC_E2', 
                  'L23LBC_L23PC_I2', 'L23NBC_L23PC_I2', 'L5TTPC_L5TTPC_E2', 'L4SS_L4SS_E2', 'L4SP_L4SP_E2', 'L4PC_L4PC_E2', 'L5TTPC_L5SBC_E2']

# %%
table13c = [0.28, 0.3, 0.28, 0.18, 0.50, 0.3, 0.57, 0.50, 0.70, 0.6, 0.70, 0.90, 0.90, 0.7, 0.91, 0.80, 0.90, 0.7, 0.91, 0.80, 
            1.00, 0.7, 1.00, 0.30, 1.20, 1.1, 1.20, 1.02, 1.20, 1.1, 1.20, 1.02, 1.30, 1.1, 1.20, 0.43, 1.60, 1.0, 1.90, 1.50, 
            1.60, 1.0, 1.90, 1.50, 1.60, 1.0, 1.90, 1.50, 2.10, 1.0, 1.96, 0.67]

# %%
x = []
sx = []
y = []
sy = []

for ii in range(13):
    print(Connectiontype[ii],table13c[4*ii],table13c[4*ii+1],table13c[4*ii+2],table13c[4*ii+3])
    x.append(table13c[4*ii])
    sx.append(table13c[4*ii+1])
    y.append(table13c[4*ii+2])
    sy.append(table13c[4*ii+3])
# Out:
# L5TTPC_L5MC_E1 0.28 0.3 0.28 0.18
# L5MC_L5TTPC_I2 0.5 0.3 0.57 0.5
# L4SS_L23PC_E2 0.7 0.6 0.7 0.9
# L5STPC_L5STPC_E2 0.9 0.7 0.91 0.8
# L5UTPC_L5UTPC_E2 0.9 0.7 0.91 0.8
# L23PC_L23PC_E2 1.0 0.7 1.0 0.3
# L23LBC_L23PC_I2 1.2 1.1 1.2 1.02
# L23NBC_L23PC_I2 1.2 1.1 1.2 1.02
# L5TTPC_L5TTPC_E2 1.3 1.1 1.2 0.43
# L4SS_L4SS_E2 1.6 1.0 1.9 1.5
# L4SP_L4SP_E2 1.6 1.0 1.9 1.5
# L4PC_L4PC_E2 1.6 1.0 1.9 1.5
# L5TTPC_L5SBC_E2 2.1 1.0 1.96 0.67

# %%
import matplotlib.pyplot as plt

# a = [1, 3, 5, 7]
# b = [11, -2, 4, 19]
# plt.scatter(a, b)


# c = [1, 3, 2, 1]
# d = [1, 3, 2, 1]

# you can use color ="r" for red or skip to default as blue
# plt.errorbar(x, y, xerr=sx, yerr=sy, fmt="o", color="r")
plt.scatter(x, y)

plt.show()
