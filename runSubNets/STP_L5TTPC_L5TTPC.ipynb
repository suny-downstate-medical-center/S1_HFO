# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# # Input-output properties cells

# %%
import numpy as np
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
rootFolder = '/home/fernando/Dropbox/SUNY/2022/S1_netpyne/sim/'
# rootFolder = os.getcwd()
os.chdir(rootFolder)
print(rootFolder)
folder = os.listdir('cell_data/')
folder = sorted(folder)

savedata = 1 # Save Netpyne and BBP soma_voltage
# Out:
# /home/fernando/Dropbox/SUNY/2022/S1_netpyne/sim/

# %%
# !nrnivmodl mod

# %%
def loadTemplateName(cellnumber):     
    f = open(outFolder+'/template.hoc', 'r')
    for line in f.readlines():
        if 'begintemplate' in line:
            templatename = str(line)     
    templatename=templatename[:-1]        
    templatename=templatename[14:]
    return templatename

# %% [markdown]
# ## Netpyne

# %%
from netpyne import specs, sim   

# Network parameters
netParams = specs.NetParams()  # object of class NetParams to store the network parameters

# %%
# %matplotlib inline

# %%
## cfg  
cfg = specs.SimConfig()					            # object of class SimConfig to store simulation configuration
cfg.duration = 4000.0 						            # Duration of the simulation, in ms
cfg.dt = 0.05								                # Internal integration timestep to use
cfg.verbose = False							                # Show detailed messages 
cfg.recordTraces = {'V_soma':{'sec':'soma','loc':0.5,'var':'v'}}  # Dict with traces to record
cfg.recordStep = 0.1 			
cfg.printRunTime = 0.1 # in sec			

cfg.seeds = {'conn': 1, 'stim': 1, 'loc': 1} 
cfg.hParams = {'celsius': 34, 'v_init': -71.0}  
cfg.verbose = False
cfg.createNEURONObj = True
cfg.createPyStruct = True  
#------------------------------------------------------------------------------
# Saving
#------------------------------------------------------------------------------
cfg.filename = 'model_output'  			# Set file output name
cfg.savePickle = False         	## Save pkl file
cfg.saveJson = False	           	## Save json file
cfg.saveDataInclude = ['simData'] ## 'simData' , 'simConfig', 'netParams'
cfg.backupCfgFile = None 		##  
cfg.gatherOnlySimData = False	##  
cfg.saveCellSecs = False			
cfg.saveCellConns = True	

cfg.analysis['plotTraces'] = {'include': [i for i in range(50)], 'oneFigPer': 'trace', 'overlay': True, 'timeRange': [0,4000], 'saveFig': False, 'showFig': True, 'figSize':(12,4)} # Plot recorded traces for this list of cells
# cfg.analysis['plotShape'] = {'includePre': [0],'includePre': [0], 'saveFig': True, 'showFig': True, 'figSize':(12,12)}

# %%
# for i,metype in enumerate(folder):
#     print(i,metype)
folder[760:770]
# Out:
# ['L5_TTPC1_cADpyr232_1',
#  'L5_TTPC1_cADpyr232_2',
#  'L5_TTPC1_cADpyr232_3',
#  'L5_TTPC1_cADpyr232_4',
#  'L5_TTPC1_cADpyr232_5',
#  'L5_TTPC2_cADpyr232_1',
#  'L5_TTPC2_cADpyr232_2',
#  'L5_TTPC2_cADpyr232_3',
#  'L5_TTPC2_cADpyr232_4',
#  'L5_TTPC2_cADpyr232_5']

# %%
#------------------------------------------------------------------------------
# Cell parameters
#------------------------------------------------------------------------------
#StochKv_deterministic.mod
for cellnumber in range(760,770):
    cellName = folder[cellnumber]
    outFolder = rootFolder+'/cell_data/'+folder[cellnumber]
    cellTemplateName = loadTemplateName(cellnumber)
    cellRule = netParams.importCellParams(label=cellName, somaAtOrigin=False,
        conds={'cellType': cellName, 'cellModel': 'HH_full'},
        fileName='cellwrapper.py',
        cellName='loadCell',
        cellInstance = True,
        cellArgs={'cellName': cellName, 'cellTemplateName': cellTemplateName})
# Out:
# NEURON: morphology_0fb1ca4724 : a template cannot be redefined
#  in morphology.hoc near line 34
#  begintemplate morphology_0fb1ca4724
#                                    ^
#         xopen("morphology.hoc")
#       execute1("{xopen("mo...")
#     load_file("morphology.hoc")
#   xopen("template.hoc")
# NEURON: cADpyr232_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate cADpyr232_biophys
#                                ^
#         xopen("biophysics.hoc")
#       execute1("{xopen("bi...")
#     load_file("biophysics.hoc")
#   xopen("template.hoc")
# NEURON: synapses_0fb1ca4724 : a template cannot be redefined
#  in synapses.hoc near line 31
#  begintemplate synapses_0fb1ca4724
#                                  ^
#         xopen("synapses.hoc")
#       execute1("{xopen("sy...")
#     load_file("synapses/s...")
#   xopen("template.hoc")
# 	0
# 	0
# 	0
# cADpyr232_L5_TTPC1_0fb1ca4724[0]
# NEURON: cADpyr232_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate cADpyr232_biophys
#                                ^
#         xopen("biophysics.hoc")
# 	1
# 	1
# 	1
# cADpyr232_L5_TTPC1_fc944c2cf3[0]
# NEURON: cADpyr232_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate cADpyr232_biophys
#                                ^
#         xopen("biophysics.hoc")
# 	1
# 	1
# 	1
# cADpyr232_L5_TTPC1_da1088139b[0]
# NEURON: cADpyr232_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate cADpyr232_biophys
#                                ^
#         xopen("biophysics.hoc")
# 	1
# 	1
# 	1
# cADpyr232_L5_TTPC1_ded64abc4d[0]
# NEURON: cADpyr232_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate cADpyr232_biophys
#                                ^
#         xopen("biophysics.hoc")
# 	1
# 	1
# 	1
# cADpyr232_L5_TTPC1_b6836fcf6f[0]
# NEURON: cADpyr232_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate cADpyr232_biophys
#                                ^
#         xopen("biophysics.hoc")
# 	1
# 	1
# 	1
# cADpyr232_L5_TTPC2_8052133265[0]
# NEURON: cADpyr232_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate cADpyr232_biophys
#                                ^
#         xopen("biophysics.hoc")
# 	1
# 	1
# 	1
# cADpyr232_L5_TTPC2_a28017c6c7[0]
# NEURON: cADpyr232_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate cADpyr232_biophys
#                                ^
#         xopen("biophysics.hoc")
# 	1
# 	1
# 	1
# cADpyr232_L5_TTPC2_a467781f53[0]
# NEURON: cADpyr232_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate cADpyr232_biophys
#                                ^
#         xopen("biophysics.hoc")
# 	1
# 	1
# 	1
# cADpyr232_L5_TTPC2_c46a93702c[0]
# NEURON: cADpyr232_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate cADpyr232_biophys
#                                ^
#         xopen("biophysics.hoc")
# 	1
# 	1
# 	1
# cADpyr232_L5_TTPC2_8bab918b58[0]

# %%
for cellnumber in range(760,770):
    # ---------------------------------------------------------------------------------------------------- #
    cellName = folder[cellnumber]
    outFolder = rootFolder+'/cell_data/'+folder[cellnumber]
    cellTemplateName = loadTemplateName(cellnumber)
    
    # ---------------------------------------------------------------------------------------------------- #
    netParams.renameCellParamsSec(label=cellName, oldSec='soma_0', newSec='soma')
    
    for secname2 in netParams.cellParams[cellName]['secLists'].keys():
        if 'soma_0' in netParams.cellParams[cellName]['secLists'][secname2]:
            print(cellName,secname2,netParams.cellParams[cellName]['secLists'][secname2][0])
            netParams.cellParams[cellName]['secLists'][secname2][0] = 'soma'
    # ---------------------------------------------------------------------------------------------------- #
    
    nonSpiny = ['axon_0', 'axon_1']
    netParams.cellParams[cellName]['secLists']['spiny'] = [sec for sec in netParams.cellParams[cellName]['secLists']['all'] if sec not in nonSpiny]
    nonSpinyEE = ['axon_0', 'axon_1', 'soma']
    netParams.cellParams[cellName]['secLists']['spinyEE'] = [sec for sec in netParams.cellParams[cellName]['secLists']['all'] if sec not in nonSpinyEE]    
    
    # ---------------------------------------------------------------------------------------------------- #
    for ii in range(5):
        netParams.popParams[cellName + '_' + str(ii)] = {'cellType': cellName, 'numCells': 1, 'cellModel': 'HH_full'}
# Out:
# L5_TTPC1_cADpyr232_1 all soma_0
# L5_TTPC1_cADpyr232_1 somatic soma_0
# L5_TTPC1_cADpyr232_2 all soma_0
# L5_TTPC1_cADpyr232_2 somatic soma_0
# L5_TTPC1_cADpyr232_3 all soma_0
# L5_TTPC1_cADpyr232_3 somatic soma_0
# L5_TTPC1_cADpyr232_4 all soma_0
# L5_TTPC1_cADpyr232_4 somatic soma_0
# L5_TTPC1_cADpyr232_5 all soma_0
# L5_TTPC1_cADpyr232_5 somatic soma_0
# L5_TTPC2_cADpyr232_1 all soma_0
# L5_TTPC2_cADpyr232_1 somatic soma_0
# L5_TTPC2_cADpyr232_2 all soma_0
# L5_TTPC2_cADpyr232_2 somatic soma_0
# L5_TTPC2_cADpyr232_3 all soma_0
# L5_TTPC2_cADpyr232_3 somatic soma_0
# L5_TTPC2_cADpyr232_4 all soma_0
# L5_TTPC2_cADpyr232_4 somatic soma_0
# L5_TTPC2_cADpyr232_5 all soma_0
# L5_TTPC2_cADpyr232_5 somatic soma_0

# %%
for cellnumber in range(760,770):
    cellName = folder[cellnumber]
    print(netParams.cellParams[cellName]['secLists']['basal'][-1])
# Out:
# dend_112
# dend_112
# dend_112
# dend_112
# dend_82
# dend_79
# dend_95
# dend_95
# dend_95
# dend_95

# %%
# create custom list of spike times
# spkTimes = [2000,2500,3000,3500,4000,4500]
spkTimes = [500,2500,2550,2600,2650,2700,2750,2800,2850,2900,3400]

netParams.popParams['presyn'] = {'cellModel': 'VecStim', 'numCells': 1, 'spkTimes': spkTimes}  # VecStim with spike times

# %%
netParams.cellParams.keys()
# Out:
# odict_keys(['L5_TTPC1_cADpyr232_1', 'L5_TTPC1_cADpyr232_2', 'L5_TTPC1_cADpyr232_3', 'L5_TTPC1_cADpyr232_4', 'L5_TTPC1_cADpyr232_5', 'L5_TTPC2_cADpyr232_1', 'L5_TTPC2_cADpyr232_2', 'L5_TTPC2_cADpyr232_3', 'L5_TTPC2_cADpyr232_4', 'L5_TTPC2_cADpyr232_5'])

# %%
list(netParams.popParams.keys())[0:-1]
# Out:
# ['L5_TTPC1_cADpyr232_1_0',
#  'L5_TTPC1_cADpyr232_1_1',
#  'L5_TTPC1_cADpyr232_1_2',
#  'L5_TTPC1_cADpyr232_1_3',
#  'L5_TTPC1_cADpyr232_1_4',
#  'L5_TTPC1_cADpyr232_2_0',
#  'L5_TTPC1_cADpyr232_2_1',
#  'L5_TTPC1_cADpyr232_2_2',
#  'L5_TTPC1_cADpyr232_2_3',
#  'L5_TTPC1_cADpyr232_2_4',
#  'L5_TTPC1_cADpyr232_3_0',
#  'L5_TTPC1_cADpyr232_3_1',
#  'L5_TTPC1_cADpyr232_3_2',
#  'L5_TTPC1_cADpyr232_3_3',
#  'L5_TTPC1_cADpyr232_3_4',
#  'L5_TTPC1_cADpyr232_4_0',
#  'L5_TTPC1_cADpyr232_4_1',
#  'L5_TTPC1_cADpyr232_4_2',
#  'L5_TTPC1_cADpyr232_4_3',
#  'L5_TTPC1_cADpyr232_4_4',
#  'L5_TTPC1_cADpyr232_5_0',
#  'L5_TTPC1_cADpyr232_5_1',
#  'L5_TTPC1_cADpyr232_5_2',
#  'L5_TTPC1_cADpyr232_5_3',
#  'L5_TTPC1_cADpyr232_5_4',
#  'L5_TTPC2_cADpyr232_1_0',
#  'L5_TTPC2_cADpyr232_1_1',
#  'L5_TTPC2_cADpyr232_1_2',
#  'L5_TTPC2_cADpyr232_1_3',
#  'L5_TTPC2_cADpyr232_1_4',
#  'L5_TTPC2_cADpyr232_2_0',
#  'L5_TTPC2_cADpyr232_2_1',
#  'L5_TTPC2_cADpyr232_2_2',
#  'L5_TTPC2_cADpyr232_2_3',
#  'L5_TTPC2_cADpyr232_2_4',
#  'L5_TTPC2_cADpyr232_3_0',
#  'L5_TTPC2_cADpyr232_3_1',
#  'L5_TTPC2_cADpyr232_3_2',
#  'L5_TTPC2_cADpyr232_3_3',
#  'L5_TTPC2_cADpyr232_3_4',
#  'L5_TTPC2_cADpyr232_4_0',
#  'L5_TTPC2_cADpyr232_4_1',
#  'L5_TTPC2_cADpyr232_4_2',
#  'L5_TTPC2_cADpyr232_4_3',
#  'L5_TTPC2_cADpyr232_4_4',
#  'L5_TTPC2_cADpyr232_5_0',
#  'L5_TTPC2_cADpyr232_5_1',
#  'L5_TTPC2_cADpyr232_5_2',
#  'L5_TTPC2_cADpyr232_5_3',
#  'L5_TTPC2_cADpyr232_5_4']

# %%
import scipy.stats as stats

#E2 -> syn 119 E2 EE 0.68±0.46 1.74±0.18 0.46±0.260 671±17 17±5 L23_PC:L23_PC

# lower, upper = 0.44, 0.48
# mu, sigma = 0.46, 0.26
# X = stats.truncnorm(
#     (lower - mu) / sigma, (upper - mu) / sigma, loc=mu, scale=sigma)

lower, upper = 0.48, 0.52
mu, sigma = 0.50, 0.02
X = stats.truncnorm(
    (lower - mu) / sigma, (upper - mu) / sigma, loc=mu, scale=sigma)

Use = X.rvs(50)

# for ii in range(20):
#     netParams.synMechParams['L23_PC:L23_PC_'+str(ii+1)] = {'mod': 'ProbAMPANMDA_EMS',
#                                           'Dep': 671,
#                                           'Fac': 17,
#                                           'Use': 0.46/4.0,
#                                           'tau_r_AMPA': 0.2,
#                                           'tau_d_AMPA': 1.74,
#                                           'NMDA_ratio': 0.8,
#                                           'tau_r_NMDA': 0.29,
#                                           'tau_d_NMDA': 43.0} 
    
#E2 -> syn 123 E2 EE 1.50±1.05 1.74±0.18 0.50±0.020 671±17 17±5 L5_TTPC:L5_TTPC


for ii in range(50):
    netParams.synMechParams['L5_TTPC:L5_TTPC'+str(ii+1)] = {'mod': 'DetAMPANMDA',
                                          'Dep': 671,
                                          'Fac': 17,
                                          'Use': 0.50, # Use[ii], #0.50/1.0,
                                          'tau_r_AMPA': 0.2,
                                          'tau_d_AMPA': 1.74,
                                          'NMDA_ratio': 0.8,
                                          'tau_r_NMDA': 0.29,
                                          'tau_d_NMDA': 43.0}

# %%
import random

# lower, upper = 0.2243, 1.1426
# mu, sigma = 0.68, 0.46
# X = stats.truncnorm(
#     (lower - mu) / sigma, (upper - mu) / sigma, loc=mu, scale=sigma)

lower, upper = 0.52, 2.52
mu, sigma = 1.50, 1.05
X = stats.truncnorm(
    (lower - mu) / sigma, (upper - mu) / sigma, loc=mu, scale=sigma)


weight = X.rvs(50)

## Cell connectivity rules
for ii in range(50):
    
    listsecs = random.sample(netParams.cellParams[cellName]['secLists']['spinyEE'], len(netParams.cellParams[cellName]['secLists']['spinyEE']))
    
#     netParams.connParams['pre->post'+str(ii+1)] = { 
#             'preConds': {'pop': 'presyn'},
#             'postConds': {'pop': list(netParams.popParams.keys())[ii]},
#             'sec': listsecs,                  # target postsyn section
#             'synMech': 'L23_PC:L23_PC_'+str(ii+1),              # target synaptic mechanism
#             'weight': 0.68, # 'max(0.33*0.68, normal(0.68,0.46))',                 # synaptic weight 
#             'synsPerConn': 3, # 'int(max(0.667*3.0, normal(3.0, 1.4)))',
#             'delay': 0.05}   
    
    netParams.connParams['pre->post'+str(ii+1)] = { 
            'preConds': {'pop': 'presyn'},
            'postConds': {'pop': list(netParams.popParams.keys())[ii]},
            'sec': listsecs,                  # target postsyn section
            'synMech': 'L5_TTPC:L5_TTPC'+str(ii+1),              # target synaptic mechanism
            'weight': 1.5, # weight[ii], # # synaptic weight 
            'synsPerConn': 7, 
            'delay': 0.05}

# %%
sim.initialize(
    simConfig = cfg, 	
    netParams = netParams)  				# create network object and set cfg and net params
sim.net.createPops()               			# instantiate network populations
sim.net.createCells()              			# instantiate network cells based on defined populations
sim.net.connectCells()            			# create connections between cells based on params
# Out:
# Start time:  2023-04-18 11:18:43.617234
#
# Creating network of 51 cell populations on 1 hosts...
#   Number of cells on node 0: 51
#   Done; cell creation time = 2.92 s.
# Making connections...
#   Number of connections on node 0: 50
#   Number of synaptic contacts on node 0: 350
#   Done; cell connection time = 0.04 s.
# [[{preGid: 50, sec: 'apic_78', loc: 0.4577659479508816, synMech: 'L5_TTPC:L5_TTPC1', weight: 1.5, delay: 0.05, label: 'pre->post1', preLoc: 0.5, hObj: NetCon[0]},
#   {preGid: 50, sec: 'dend_59', loc: 0.7019151012827519, synMech: 'L5_TTPC:L5_TTPC1', weight: 1.5, delay: 0.05, label: 'pre->post1', preLoc: 0.5, hObj: NetCon[1]},
#   {preGid: 50, sec: 'apic_39', loc: 0.5021595514007392, synMech: 'L5_TTPC:L5_TTPC1', weight: 1.5, delay: 0.05, label: 'pre->post1', preLoc: 0.5, hObj: NetCon[2]},
#   {preGid: 50, sec: 'dend_41', loc: 0.4161693318273312, synMech: 'L5_TTPC:L5_TTPC1', weight: 1.5, delay: 0.05, label: 'pre->post1', preLoc: 0.5, hObj: NetCon[3]},
#   {preGid: 50, sec: 'dend_14', loc: 0.24852246781236262, synMech: 'L5_TTPC:L5_TTPC1', weight: 1.5, delay: 0.05, label: 'pre->post1', preLoc: 0.5, hObj: NetCon[4]},
#   {preGid: 50, sec: 'dend_72', loc: 0.43664318522551393, synMech: 'L5_TTPC:L5_TTPC1', weight: 1.5, delay: 0.05, label: 'pre->post1', preLoc: 0.5, hObj: NetCon[5]},
#   {preGid: 50, sec: 'apic_92', loc: 0.9460072909720301, synMech: 'L5_TTPC:L5_TTPC1', weight: 1.5, delay: 0.05, label: 'pre->post1', preLoc: 0.5, hObj: NetCon[6]}],
#  [{preGid: 50, sec: 'dend_67', loc: 0.19092731222741238, synMech: 'L5_TTPC:L5_TTPC2', weight: 1.5, delay: 0.05, label: 'pre->post2', preLoc: 0.5, hObj: NetCon[7]},
#   {preGid: 50, sec: 'dend_8', loc: 0.7575286120236864, synMech: 'L5_TTPC:L5_TTPC2', weight: 1.5, delay: 0.05, label: 'pre->post2', preLoc: 0.5, hObj: NetCon[8]},
#   {preGid: 50, sec: 'apic_23', loc: 0.15978259211133425, synMech: 'L5_TTPC:L5_TTPC2', weight: 1.5, delay: 0.05, label: 'pre->post2', preLoc: 0.5, hObj: NetCon[9]},
#   {preGid: 50, sec: 'dend_6', loc: 0.33465470305497835, synMech: 'L5_TTPC:L5_TTPC2', weight: 1.5, delay: 0.05, label: 'pre->post2', preLoc: 0.5, hObj: NetCon[10]},
#   {preGid: 50, sec: 'dend_53', loc: 0.7653769005367768, synMech: 'L5_TTPC:L5_TTPC2', weight: 1.5, delay: 0.05, label: 'pre->post2', preLoc: 0.5, hObj: NetCon[11]},
#   {preGid: 50, sec: 'dend_15', loc: 0.2801327629739888, synMech: 'L5_TTPC:L5_TTPC2', weight: 1.5, delay: 0.05, label: 'pre->post2', preLoc: 0.5, hObj: NetCon[12]},
#   {preGid: 50, sec: 'apic_79', loc: 0.6803110495444675, synMech: 'L5_TTPC:L5_TTPC2', weight: 1.5, delay: 0.05, label: 'pre->post2', preLoc: 0.5, hObj: NetCon[13]}],
#  [{preGid: 50, sec: 'dend_67', loc: 0.4930203041028457, synMech: 'L5_TTPC:L5_TTPC3', weight: 1.5, delay: 0.05, label: 'pre->post3', preLoc: 0.5, hObj: NetCon[14]},
#   {preGid: 50, sec: 'dend_45', loc: 0.7005846875579556, synMech: 'L5_TTPC:L5_TTPC3', weight: 1.5, delay: 0.05, label: 'pre->post3', preLoc: 0.5, hObj: NetCon[15]},
#   {preGid: 50, sec: 'dend_87', loc: 0.9471190025714928, synMech: 'L5_TTPC:L5_TTPC3', weight: 1.5, delay: 0.05, label: 'pre->post3', preLoc: 0.5, hObj: NetCon[16]},
#   {preGid: 50, sec: 'dend_22', loc: 0.9251019050455249, synMech: 'L5_TTPC:L5_TTPC3', weight: 1.5, delay: 0.05, label: 'pre->post3', preLoc: 0.5, hObj: NetCon[17]},
#   {preGid: 50, sec: 'dend_49', loc: 0.4076862946899146, synMech: 'L5_TTPC:L5_TTPC3', weight: 1.5, delay: 0.05, label: 'pre->post3', preLoc: 0.5, hObj: NetCon[18]},
#   {preGid: 50, sec: 'dend_86', loc: 0.8042378604202117, synMech: 'L5_TTPC:L5_TTPC3', weight: 1.5, delay: 0.05, label: 'pre->post3', preLoc: 0.5, hObj: NetCon[19]},
#   {preGid: 50, sec: 'dend_55', loc: 0.4459466286468758, synMech: 'L5_TTPC:L5_TTPC3', weight: 1.5, delay: 0.05, label: 'pre->post3', preLoc: 0.5, hObj: NetCon[20]}],
#  [{preGid: 50, sec: 'apic_76', loc: 0.19331683581312573, synMech: 'L5_TTPC:L5_TTPC4', weight: 1.5, delay: 0.05, label: 'pre->post4', preLoc: 0.5, hObj: NetCon[21]},
#   {preGid: 50, sec: 'dend_45', loc: 0.2582250562122121, synMech: 'L5_TTPC:L5_TTPC4', weight: 1.5, delay: 0.05, label: 'pre->post4', preLoc: 0.5, hObj: NetCon[22]},
#   {preGid: 50, sec: 'dend_9', loc: 0.9848222648993901, synMech: 'L5_TTPC:L5_TTPC4', weight: 1.5, delay: 0.05, label: 'pre->post4', preLoc: 0.5, hObj: NetCon[23]},
#   {preGid: 50, sec: 'apic_45', loc: 0.7627253340920335, synMech: 'L5_TTPC:L5_TTPC4', weight: 1.5, delay: 0.05, label: 'pre->post4', preLoc: 0.5, hObj: NetCon[24]},
#   {preGid: 50, sec: 'dend_67', loc: 0.8470266334644797, synMech: 'L5_TTPC:L5_TTPC4', weight: 1.5, delay: 0.05, label: 'pre->post4', preLoc: 0.5, hObj: NetCon[25]},
#   {preGid: 50, sec: 'dend_86', loc: 0.5417415703275547, synMech: 'L5_TTPC:L5_TTPC4', weight: 1.5, delay: 0.05, label: 'pre->post4', preLoc: 0.5, hObj: NetCon[26]},
#   {preGid: 50, sec: 'apic_79', loc: 0.8845176644940446, synMech: 'L5_TTPC:L5_TTPC4', weight: 1.5, delay: 0.05, label: 'pre->post4', preLoc: 0.5, hObj: NetCon[27]}],
#  [{preGid: 50, sec: 'apic_71', loc: 0.48189719026791344, synMech: 'L5_TTPC:L5_TTPC5', weight: 1.5, delay: 0.05, label: 'pre->post5', preLoc: 0.5, hObj: NetCon[28]},
#   {preGid: 50, sec: 'apic_2', loc: 0.23887517974611022, synMech: 'L5_TTPC:L5_TTPC5', weight: 1.5, delay: 0.05, label: 'pre->post5', preLoc: 0.5, hObj: NetCon[29]},
#   {preGid: 50, sec: 'dend_31', loc: 0.4361374430934511, synMech: 'L5_TTPC:L5_TTPC5', weight: 1.5, delay: 0.05, label: 'pre->post5', preLoc: 0.5, hObj: NetCon[30]},
#   {preGid: 50, sec: 'apic_23', loc: 0.5654892000405248, synMech: 'L5_TTPC:L5_TTPC5', weight: 1.5, delay: 0.05, label: 'pre->post5', preLoc: 0.5, hObj: NetCon[31]},
#   {preGid: 50, sec: 'dend_55', loc: 0.2254856210178377, synMech: 'L5_TTPC:L5_TTPC5', weight: 1.5, delay: 0.05, label: 'pre->post5', preLoc: 0.5, hObj: NetCon[32]},
#   {preGid: 50, sec: 'dend_53', loc: 0.8100348050945374, synMech: 'L5_TTPC:L5_TTPC5', weight: 1.5, delay: 0.05, label: 'pre->post5', preLoc: 0.5, hObj: NetCon[33]},
#   {preGid: 50, sec: 'dend_72', loc: 0.09077758044054396, synMech: 'L5_TTPC:L5_TTPC5', weight: 1.5, delay: 0.05, label: 'pre->post5', preLoc: 0.5, hObj: NetCon[34]}],
#  [{preGid: 50, sec: 'dend_36', loc: 0.4622194461470009, synMech: 'L5_TTPC:L5_TTPC6', weight: 1.5, delay: 0.05, label: 'pre->post6', preLoc: 0.5, hObj: NetCon[35]},
#   {preGid: 50, sec: 'apic_65', loc: 0.7021821628914622, synMech: 'L5_TTPC:L5_TTPC6', weight: 1.5, delay: 0.05, label: 'pre->post6', preLoc: 0.5, hObj: NetCon[36]},
#   {preGid: 50, sec: 'dend_31', loc: 0.3563958017100069, synMech: 'L5_TTPC:L5_TTPC6', weight: 1.5, delay: 0.05, label: 'pre->post6', preLoc: 0.5, hObj: NetCon[37]},
#   {preGid: 50, sec: 'apic_15', loc: 0.7222099265654502, synMech: 'L5_TTPC:L5_TTPC6', weight: 1.5, delay: 0.05, label: 'pre->post6', preLoc: 0.5, hObj: NetCon[38]},
#   {preGid: 50, sec: 'apic_25', loc: 0.9333338566569531, synMech: 'L5_TTPC:L5_TTPC6', weight: 1.5, delay: 0.05, label: 'pre->post6', preLoc: 0.5, hObj: NetCon[39]},
#   {preGid: 50, sec: 'apic_73', loc: 0.8557970208915835, synMech: 'L5_TTPC:L5_TTPC6', weight: 1.5, delay: 0.05, label: 'pre->post6', preLoc: 0.5, hObj: NetCon[40]},
#   {preGid: 50, sec: 'dend_47', loc: 0.8590771626510899, synMech: 'L5_TTPC:L5_TTPC6', weight: 1.5, delay: 0.05, label: 'pre->post6', preLoc: 0.5, hObj: NetCon[41]}],
#  [{preGid: 50, sec: 'apic_43', loc: 0.8141309762595789, synMech: 'L5_TTPC:L5_TTPC7', weight: 1.5, delay: 0.05, label: 'pre->post7', preLoc: 0.5, hObj: NetCon[42]},
#   {preGid: 50, sec: 'apic_28', loc: 0.32611543771400453, synMech: 'L5_TTPC:L5_TTPC7', weight: 1.5, delay: 0.05, label: 'pre->post7', preLoc: 0.5, hObj: NetCon[43]},
#   {preGid: 50, sec: 'dend_72', loc: 0.16802815803499158, synMech: 'L5_TTPC:L5_TTPC7', weight: 1.5, delay: 0.05, label: 'pre->post7', preLoc: 0.5, hObj: NetCon[44]},
#   {preGid: 50, sec: 'dend_86', loc: 0.7503922667893282, synMech: 'L5_TTPC:L5_TTPC7', weight: 1.5, delay: 0.05, label: 'pre->post7', preLoc: 0.5, hObj: NetCon[45]},
#   {preGid: 50, sec: 'dend_17', loc: 0.3797196795348018, synMech: 'L5_TTPC:L5_TTPC7', weight: 1.5, delay: 0.05, label: 'pre->post7', preLoc: 0.5, hObj: NetCon[46]},
#   {preGid: 50, sec: 'dend_2', loc: 0.5199011697231042, synMech: 'L5_TTPC:L5_TTPC7', weight: 1.5, delay: 0.05, label: 'pre->post7', preLoc: 0.5, hObj: NetCon[47]},
#   {preGid: 50, sec: 'apic_87', loc: 0.37256449480223824, synMech: 'L5_TTPC:L5_TTPC7', weight: 1.5, delay: 0.05, label: 'pre->post7', preLoc: 0.5, hObj: NetCon[48]}],
#  [{preGid: 50, sec: 'dend_56', loc: 0.6311686860411252, synMech: 'L5_TTPC:L5_TTPC8', weight: 1.5, delay: 0.05, label: 'pre->post8', preLoc: 0.5, hObj: NetCon[49]},
#   {preGid: 50, sec: 'apic_82', loc: 0.8469104927007759, synMech: 'L5_TTPC:L5_TTPC8', weight: 1.5, delay: 0.05, label: 'pre->post8', preLoc: 0.5, hObj: NetCon[50]},
#   {preGid: 50, sec: 'apic_92', loc: 0.4850418539379978, synMech: 'L5_TTPC:L5_TTPC8', weight: 1.5, delay: 0.05, label: 'pre->post8', preLoc: 0.5, hObj: NetCon[51]},
#   {preGid: 50, sec: 'apic_78', loc: 0.609753072382237, synMech: 'L5_TTPC:L5_TTPC8', weight: 1.5, delay: 0.05, label: 'pre->post8', preLoc: 0.5, hObj: NetCon[52]},
#   {preGid: 50, sec: 'apic_79', loc: 0.32927129902948976, synMech: 'L5_TTPC:L5_TTPC8', weight: 1.5, delay: 0.05, label: 'pre->post8', preLoc: 0.5, hObj: NetCon[53]},
#   {preGid: 50, sec: 'dend_22', loc: 0.6471399690545091, synMech: 'L5_TTPC:L5_TTPC8', weight: 1.5, delay: 0.05, label: 'pre->post8', preLoc: 0.5, hObj: NetCon[54]},
#   {preGid: 50, sec: 'apic_49', loc: 0.0899392931206213, synMech: 'L5_TTPC:L5_TTPC8', weight: 1.5, delay: 0.05, label: 'pre->post8', preLoc: 0.5, hObj: NetCon[55]}],
#  [{preGid: 50, sec: 'dend_30', loc: 0.9221894010842898, synMech: 'L5_TTPC:L5_TTPC9', weight: 1.5, delay: 0.05, label: 'pre->post9', preLoc: 0.5, hObj: NetCon[56]},
#   {preGid: 50, sec: 'apic_30', loc: 0.04604978165196191, synMech: 'L5_TTPC:L5_TTPC9', weight: 1.5, delay: 0.05, label: 'pre->post9', preLoc: 0.5, hObj: NetCon[57]},
#   {preGid: 50, sec: 'dend_81', loc: 0.9787387548789169, synMech: 'L5_TTPC:L5_TTPC9', weight: 1.5, delay: 0.05, label: 'pre->post9', preLoc: 0.5, hObj: NetCon[58]},
#   {preGid: 50, sec: 'dend_95', loc: 0.4061151386737081, synMech: 'L5_TTPC:L5_TTPC9', weight: 1.5, delay: 0.05, label: 'pre->post9', preLoc: 0.5, hObj: NetCon[59]},
#   {preGid: 50, sec: 'apic_25', loc: 0.6688973666842906, synMech: 'L5_TTPC:L5_TTPC9', weight: 1.5, delay: 0.05, label: 'pre->post9', preLoc: 0.5, hObj: NetCon[60]},
#   {preGid: 50, sec: 'dend_22', loc: 0.6500635489479948, synMech: 'L5_TTPC:L5_TTPC9', weight: 1.5, delay: 0.05, label: 'pre->post9', preLoc: 0.5, hObj: NetCon[61]},
#   {preGid: 50, sec: 'apic_2', loc: 0.06706735416193504, synMech: 'L5_TTPC:L5_TTPC9', weight: 1.5, delay: 0.05, label: 'pre->post9', preLoc: 0.5, hObj: NetCon[62]}],
#  [{preGid: 50, sec: 'dend_62', loc: 0.719252281045436, synMech: 'L5_TTPC:L5_TTPC10', weight: 1.5, delay: 0.05, label: 'pre->post10', preLoc: 0.5, hObj: NetCon[63]},
#   {preGid: 50, sec: 'dend_18', loc: 0.08334179200751898, synMech: 'L5_TTPC:L5_TTPC10', weight: 1.5, delay: 0.05, label: 'pre->post10', preLoc: 0.5, hObj: NetCon[64]},
#   {preGid: 50, sec: 'apic_28', loc: 0.21493745044658766, synMech: 'L5_TTPC:L5_TTPC10', weight: 1.5, delay: 0.05, label: 'pre->post10', preLoc: 0.5, hObj: NetCon[65]},
#   {preGid: 50, sec: 'apic_82', loc: 0.02241732073909298, synMech: 'L5_TTPC:L5_TTPC10', weight: 1.5, delay: 0.05, label: 'pre->post10', preLoc: 0.5, hObj: NetCon[66]},
#   {preGid: 50, sec: 'dend_9', loc: 0.9491644682970601, synMech: 'L5_TTPC:L5_TTPC10', weight: 1.5, delay: 0.05, label: 'pre->post10', preLoc: 0.5, hObj: NetCon[67]},
#   {preGid: 50, sec: 'apic_29', loc: 0.8767470436905668, synMech: 'L5_TTPC:L5_TTPC10', weight: 1.5, delay: 0.05, label: 'pre->post10', preLoc: 0.5, hObj: NetCon[68]},
#   {preGid: 50, sec: 'dend_27', loc: 0.1488042005161823, synMech: 'L5_TTPC:L5_TTPC10', weight: 1.5, delay: 0.05, label: 'pre->post10', preLoc: 0.5, hObj: NetCon[69]}],
#  [{preGid: 50, sec: 'dend_81', loc: 0.8152810711425229, synMech: 'L5_TTPC:L5_TTPC11', weight: 1.5, delay: 0.05, label: 'pre->post11', preLoc: 0.5, hObj: NetCon[70]},
#   {preGid: 50, sec: 'dend_30', loc: 0.2996303205561495, synMech: 'L5_TTPC:L5_TTPC11', weight: 1.5, delay: 0.05, label: 'pre->post11', preLoc: 0.5, hObj: NetCon[71]},
#   {preGid: 50, sec: 'dend_76', loc: 0.1962322582403238, synMech: 'L5_TTPC:L5_TTPC11', weight: 1.5, delay: 0.05, label: 'pre->post11', preLoc: 0.5, hObj: NetCon[72]},
#   {preGid: 50, sec: 'apic_81', loc: 0.8162970462982191, synMech: 'L5_TTPC:L5_TTPC11', weight: 1.5, delay: 0.05, label: 'pre->post11', preLoc: 0.5, hObj: NetCon[73]},
#   {preGid: 50, sec: 'dend_50', loc: 0.44240042762894743, synMech: 'L5_TTPC:L5_TTPC11', weight: 1.5, delay: 0.05, label: 'pre->post11', preLoc: 0.5, hObj: NetCon[74]},
#   {preGid: 50, sec: 'apic_37', loc: 0.3381186914244417, synMech: 'L5_TTPC:L5_TTPC11', weight: 1.5, delay: 0.05, label: 'pre->post11', preLoc: 0.5, hObj: NetCon[75]},
#   {preGid: 50, sec: 'dend_16', loc: 0.395510928972885, synMech: 'L5_TTPC:L5_TTPC11', weight: 1.5, delay: 0.05, label: 'pre->post11', preLoc: 0.5, hObj: NetCon[76]}],
#  [{preGid: 50, sec: 'dend_59', loc: 0.5525055683676339, synMech: 'L5_TTPC:L5_TTPC12', weight: 1.5, delay: 0.05, label: 'pre->post12', preLoc: 0.5, hObj: NetCon[77]},
#   {preGid: 50, sec: 'dend_47', loc: 0.11641710274504033, synMech: 'L5_TTPC:L5_TTPC12', weight: 1.5, delay: 0.05, label: 'pre->post12', preLoc: 0.5, hObj: NetCon[78]},
#   {preGid: 50, sec: 'dend_55', loc: 0.9226509963577931, synMech: 'L5_TTPC:L5_TTPC12', weight: 1.5, delay: 0.05, label: 'pre->post12', preLoc: 0.5, hObj: NetCon[79]},
#   {preGid: 50, sec: 'dend_72', loc: 0.5920295951147941, synMech: 'L5_TTPC:L5_TTPC12', weight: 1.5, delay: 0.05, label: 'pre->post12', preLoc: 0.5, hObj: NetCon[80]},
#   {preGid: 50, sec: 'apic_12', loc: 0.2442632513477401, synMech: 'L5_TTPC:L5_TTPC12', weight: 1.5, delay: 0.05, label: 'pre->post12', preLoc: 0.5, hObj: NetCon[81]},
#   {preGid: 50, sec: 'dend_78', loc: 0.19044017876077937, synMech: 'L5_TTPC:L5_TTPC12', weight: 1.5, delay: 0.05, label: 'pre->post12', preLoc: 0.5, hObj: NetCon[82]},
#   {preGid: 50, sec: 'apic_76', loc: 0.8678158110791797, synMech: 'L5_TTPC:L5_TTPC12', weight: 1.5, delay: 0.05, label: 'pre->post12', preLoc: 0.5, hObj: NetCon[83]}],
#  [{preGid: 50, sec: 'dend_14', loc: 0.5182663620566915, synMech: 'L5_TTPC:L5_TTPC13', weight: 1.5, delay: 0.05, label: 'pre->post13', preLoc: 0.5, hObj: NetCon[84]},
#   {preGid: 50, sec: 'dend_18', loc: 0.018348907899799562, synMech: 'L5_TTPC:L5_TTPC13', weight: 1.5, delay: 0.05, label: 'pre->post13', preLoc: 0.5, hObj: NetCon[85]},
#   {preGid: 50, sec: 'dend_55', loc: 0.9581153217507441, synMech: 'L5_TTPC:L5_TTPC13', weight: 1.5, delay: 0.05, label: 'pre->post13', preLoc: 0.5, hObj: NetCon[86]},
#   {preGid: 50, sec: 'dend_49', loc: 0.117554266139993, synMech: 'L5_TTPC:L5_TTPC13', weight: 1.5, delay: 0.05, label: 'pre->post13', preLoc: 0.5, hObj: NetCon[87]},
#   {preGid: 50, sec: 'apic_87', loc: 0.5174070696465126, synMech: 'L5_TTPC:L5_TTPC13', weight: 1.5, delay: 0.05, label: 'pre->post13', preLoc: 0.5, hObj: NetCon[88]},
#   {preGid: 50, sec: 'apic_53', loc: 0.29338656992411183, synMech: 'L5_TTPC:L5_TTPC13', weight: 1.5, delay: 0.05, label: 'pre->post13', preLoc: 0.5, hObj: NetCon[89]},
#   {preGid: 50, sec: 'apic_46', loc: 0.4929881901175997, synMech: 'L5_TTPC:L5_TTPC13', weight: 1.5, delay: 0.05, label: 'pre->post13', preLoc: 0.5, hObj: NetCon[90]}],
#  [{preGid: 50, sec: 'apic_22', loc: 0.0301241542991354, synMech: 'L5_TTPC:L5_TTPC14', weight: 1.5, delay: 0.05, label: 'pre->post14', preLoc: 0.5, hObj: NetCon[91]},
#   {preGid: 50, sec: 'apic_92', loc: 0.7666711260263546, synMech: 'L5_TTPC:L5_TTPC14', weight: 1.5, delay: 0.05, label: 'pre->post14', preLoc: 0.5, hObj: NetCon[92]},
#   {preGid: 50, sec: 'dend_29', loc: 0.9292755820463627, synMech: 'L5_TTPC:L5_TTPC14', weight: 1.5, delay: 0.05, label: 'pre->post14', preLoc: 0.5, hObj: NetCon[93]},
#   {preGid: 50, sec: 'dend_0', loc: 0.32775559509707486, synMech: 'L5_TTPC:L5_TTPC14', weight: 1.5, delay: 0.05, label: 'pre->post14', preLoc: 0.5, hObj: NetCon[94]},
#   {preGid: 50, sec: 'dend_9', loc: 0.1333211482878412, synMech: 'L5_TTPC:L5_TTPC14', weight: 1.5, delay: 0.05, label: 'pre->post14', preLoc: 0.5, hObj: NetCon[95]},
#   {preGid: 50, sec: 'dend_86', loc: 0.12018788817921544, synMech: 'L5_TTPC:L5_TTPC14', weight: 1.5, delay: 0.05, label: 'pre->post14', preLoc: 0.5, hObj: NetCon[96]},
#   {preGid: 50, sec: 'apic_66', loc: 0.4608732502379012, synMech: 'L5_TTPC:L5_TTPC14', weight: 1.5, delay: 0.05, label: 'pre->post14', preLoc: 0.5, hObj: NetCon[97]}],
#  [{preGid: 50, sec: 'apic_86', loc: 0.3097722671409507, synMech: 'L5_TTPC:L5_TTPC15', weight: 1.5, delay: 0.05, label: 'pre->post15', preLoc: 0.5, hObj: NetCon[98]},
#   {preGid: 50, sec: 'dend_53', loc: 0.47538793259211437, synMech: 'L5_TTPC:L5_TTPC15', weight: 1.5, delay: 0.05, label: 'pre->post15', preLoc: 0.5, hObj: NetCon[99]},
#   {preGid: 50, sec: 'apic_68', loc: 0.8075440261215339, synMech: 'L5_TTPC:L5_TTPC15', weight: 1.5, delay: 0.05, label: 'pre->post15', preLoc: 0.5, hObj: NetCon[100]},
#   {preGid: 50, sec: 'dend_0', loc: 0.6693379358833974, synMech: 'L5_TTPC:L5_TTPC15', weight: 1.5, delay: 0.05, label: 'pre->post15', preLoc: 0.5, hObj: NetCon[101]},
#   {preGid: 50, sec: 'dend_41', loc: 0.2892290382437404, synMech: 'L5_TTPC:L5_TTPC15', weight: 1.5, delay: 0.05, label: 'pre->post15', preLoc: 0.5, hObj: NetCon[102]},
#   {preGid: 50, sec: 'dend_56', loc: 0.2162268280440932, synMech: 'L5_TTPC:L5_TTPC15', weight: 1.5, delay: 0.05, label: 'pre->post15', preLoc: 0.5, hObj: NetCon[103]},
#   {preGid: 50, sec: 'dend_81', loc: 0.7400676267410562, synMech: 'L5_TTPC:L5_TTPC15', weight: 1.5, delay: 0.05, label: 'pre->post15', preLoc: 0.5, hObj: NetCon[104]}],
#  [{preGid: 50, sec: 'apic_76', loc: 0.11707007900890719, synMech: 'L5_TTPC:L5_TTPC16', weight: 1.5, delay: 0.05, label: 'pre->post16', preLoc: 0.5, hObj: NetCon[105]},
#   {preGid: 50, sec: 'apic_25', loc: 0.2752488326610157, synMech: 'L5_TTPC:L5_TTPC16', weight: 1.5, delay: 0.05, label: 'pre->post16', preLoc: 0.5, hObj: NetCon[106]},
#   {preGid: 50, sec: 'apic_58', loc: 0.20630540763514837, synMech: 'L5_TTPC:L5_TTPC16', weight: 1.5, delay: 0.05, label: 'pre->post16', preLoc: 0.5, hObj: NetCon[107]},
#   {preGid: 50, sec: 'dend_31', loc: 0.6245928997932211, synMech: 'L5_TTPC:L5_TTPC16', weight: 1.5, delay: 0.05, label: 'pre->post16', preLoc: 0.5, hObj: NetCon[108]},
#   {preGid: 50, sec: 'dend_15', loc: 0.2766772215634029, synMech: 'L5_TTPC:L5_TTPC16', weight: 1.5, delay: 0.05, label: 'pre->post16', preLoc: 0.5, hObj: NetCon[109]},
#   {preGid: 50, sec: 'apic_66', loc: 0.29142095859843214, synMech: 'L5_TTPC:L5_TTPC16', weight: 1.5, delay: 0.05, label: 'pre->post16', preLoc: 0.5, hObj: NetCon[110]},
#   {preGid: 50, sec: 'apic_75', loc: 0.1320070242645684, synMech: 'L5_TTPC:L5_TTPC16', weight: 1.5, delay: 0.05, label: 'pre->post16', preLoc: 0.5, hObj: NetCon[111]}],
#  [{preGid: 50, sec: 'dend_59', loc: 0.006103050291564461, synMech: 'L5_TTPC:L5_TTPC17', weight: 1.5, delay: 0.05, label: 'pre->post17', preLoc: 0.5, hObj: NetCon[112]},
#   {preGid: 50, sec: 'apic_39', loc: 0.35905854991766495, synMech: 'L5_TTPC:L5_TTPC17', weight: 1.5, delay: 0.05, label: 'pre->post17', preLoc: 0.5, hObj: NetCon[113]},
#   {preGid: 50, sec: 'dend_60', loc: 0.6013945470613291, synMech: 'L5_TTPC:L5_TTPC17', weight: 1.5, delay: 0.05, label: 'pre->post17', preLoc: 0.5, hObj: NetCon[114]},
#   {preGid: 50, sec: 'apic_73', loc: 0.7969204531323103, synMech: 'L5_TTPC:L5_TTPC17', weight: 1.5, delay: 0.05, label: 'pre->post17', preLoc: 0.5, hObj: NetCon[115]},
#   {preGid: 50, sec: 'dend_56', loc: 0.0947631410267046, synMech: 'L5_TTPC:L5_TTPC17', weight: 1.5, delay: 0.05, label: 'pre->post17', preLoc: 0.5, hObj: NetCon[116]},
#   {preGid: 50, sec: 'dend_53', loc: 0.9938066442456981, synMech: 'L5_TTPC:L5_TTPC17', weight: 1.5, delay: 0.05, label: 'pre->post17', preLoc: 0.5, hObj: NetCon[117]},
#   {preGid: 50, sec: 'dend_57', loc: 0.08669247724586249, synMech: 'L5_TTPC:L5_TTPC17', weight: 1.5, delay: 0.05, label: 'pre->post17', preLoc: 0.5, hObj: NetCon[118]}],
#  [{preGid: 50, sec: 'dend_71', loc: 0.6509005531570842, synMech: 'L5_TTPC:L5_TTPC18', weight: 1.5, delay: 0.05, label: 'pre->post18', preLoc: 0.5, hObj: NetCon[119]},
#   {preGid: 50, sec: 'dend_47', loc: 0.01605377401667822, synMech: 'L5_TTPC:L5_TTPC18', weight: 1.5, delay: 0.05, label: 'pre->post18', preLoc: 0.5, hObj: NetCon[120]},
#   {preGid: 50, sec: 'dend_6', loc: 0.09385033730648953, synMech: 'L5_TTPC:L5_TTPC18', weight: 1.5, delay: 0.05, label: 'pre->post18', preLoc: 0.5, hObj: NetCon[121]},
#   {preGid: 50, sec: 'apic_76', loc: 0.13723689079287826, synMech: 'L5_TTPC:L5_TTPC18', weight: 1.5, delay: 0.05, label: 'pre->post18', preLoc: 0.5, hObj: NetCon[122]},
#   {preGid: 50, sec: 'apic_73', loc: 0.6207085227680225, synMech: 'L5_TTPC:L5_TTPC18', weight: 1.5, delay: 0.05, label: 'pre->post18', preLoc: 0.5, hObj: NetCon[123]},
#   {preGid: 50, sec: 'dend_75', loc: 0.6458013710040611, synMech: 'L5_TTPC:L5_TTPC18', weight: 1.5, delay: 0.05, label: 'pre->post18', preLoc: 0.5, hObj: NetCon[124]},
#   {preGid: 50, sec: 'dend_37', loc: 0.8836914357706471, synMech: 'L5_TTPC:L5_TTPC18', weight: 1.5, delay: 0.05, label: 'pre->post18', preLoc: 0.5, hObj: NetCon[125]}],
#  [{preGid: 50, sec: 'dend_55', loc: 0.8627350570394, synMech: 'L5_TTPC:L5_TTPC19', weight: 1.5, delay: 0.05, label: 'pre->post19', preLoc: 0.5, hObj: NetCon[126]},
#   {preGid: 50, sec: 'apic_49', loc: 0.9425860689592807, synMech: 'L5_TTPC:L5_TTPC19', weight: 1.5, delay: 0.05, label: 'pre->post19', preLoc: 0.5, hObj: NetCon[127]},
#   {preGid: 50, sec: 'apic_68', loc: 0.16665300638628053, synMech: 'L5_TTPC:L5_TTPC19', weight: 1.5, delay: 0.05, label: 'pre->post19', preLoc: 0.5, hObj: NetCon[128]},
#   {preGid: 50, sec: 'dend_37', loc: 0.4294002300640776, synMech: 'L5_TTPC:L5_TTPC19', weight: 1.5, delay: 0.05, label: 'pre->post19', preLoc: 0.5, hObj: NetCon[129]},
#   {preGid: 50, sec: 'apic_62', loc: 0.027636519058872086, synMech: 'L5_TTPC:L5_TTPC19', weight: 1.5, delay: 0.05, label: 'pre->post19', preLoc: 0.5, hObj: NetCon[130]},
#   {preGid: 50, sec: 'dend_26', loc: 0.6935475616918313, synMech: 'L5_TTPC:L5_TTPC19', weight: 1.5, delay: 0.05, label: 'pre->post19', preLoc: 0.5, hObj: NetCon[131]},
#   {preGid: 50, sec: 'dend_31', loc: 0.013680525527643699, synMech: 'L5_TTPC:L5_TTPC19', weight: 1.5, delay: 0.05, label: 'pre->post19', preLoc: 0.5, hObj: NetCon[132]}],
#  [{preGid: 50, sec: 'dend_11', loc: 0.09382045618530382, synMech: 'L5_TTPC:L5_TTPC20', weight: 1.5, delay: 0.05, label: 'pre->post20', preLoc: 0.5, hObj: NetCon[133]},
#   {preGid: 50, sec: 'dend_64', loc: 0.6922041208360359, synMech: 'L5_TTPC:L5_TTPC20', weight: 1.5, delay: 0.05, label: 'pre->post20', preLoc: 0.5, hObj: NetCon[134]},
#   {preGid: 50, sec: 'apic_12', loc: 0.977511025644353, synMech: 'L5_TTPC:L5_TTPC20', weight: 1.5, delay: 0.05, label: 'pre->post20', preLoc: 0.5, hObj: NetCon[135]},
#   {preGid: 50, sec: 'apic_71', loc: 0.7721629680536677, synMech: 'L5_TTPC:L5_TTPC20', weight: 1.5, delay: 0.05, label: 'pre->post20', preLoc: 0.5, hObj: NetCon[136]},
#   {preGid: 50, sec: 'dend_47', loc: 0.4882077536908278, synMech: 'L5_TTPC:L5_TTPC20', weight: 1.5, delay: 0.05, label: 'pre->post20', preLoc: 0.5, hObj: NetCon[137]},
#   {preGid: 50, sec: 'dend_72', loc: 0.7983047163703224, synMech: 'L5_TTPC:L5_TTPC20', weight: 1.5, delay: 0.05, label: 'pre->post20', preLoc: 0.5, hObj: NetCon[138]},
#   {preGid: 50, sec: 'apic_76', loc: 0.8508716753915281, synMech: 'L5_TTPC:L5_TTPC20', weight: 1.5, delay: 0.05, label: 'pre->post20', preLoc: 0.5, hObj: NetCon[139]}],
#  [{preGid: 50, sec: 'dend_37', loc: 0.9116615024109322, synMech: 'L5_TTPC:L5_TTPC21', weight: 1.5, delay: 0.05, label: 'pre->post21', preLoc: 0.5, hObj: NetCon[140]},
#   {preGid: 50, sec: 'dend_48', loc: 0.5329020549648856, synMech: 'L5_TTPC:L5_TTPC21', weight: 1.5, delay: 0.05, label: 'pre->post21', preLoc: 0.5, hObj: NetCon[141]},
#   {preGid: 50, sec: 'dend_47', loc: 0.5356991798619267, synMech: 'L5_TTPC:L5_TTPC21', weight: 1.5, delay: 0.05, label: 'pre->post21', preLoc: 0.5, hObj: NetCon[142]},
#   {preGid: 50, sec: 'apic_73', loc: 0.8849109238565344, synMech: 'L5_TTPC:L5_TTPC21', weight: 1.5, delay: 0.05, label: 'pre->post21', preLoc: 0.5, hObj: NetCon[143]},
#   {preGid: 50, sec: 'apic_66', loc: 0.04954792947072388, synMech: 'L5_TTPC:L5_TTPC21', weight: 1.5, delay: 0.05, label: 'pre->post21', preLoc: 0.5, hObj: NetCon[144]},
#   {preGid: 50, sec: 'dend_43', loc: 0.2869207801304874, synMech: 'L5_TTPC:L5_TTPC21', weight: 1.5, delay: 0.05, label: 'pre->post21', preLoc: 0.5, hObj: NetCon[145]},
#   {preGid: 50, sec: 'dend_68', loc: 0.9478868155560546, synMech: 'L5_TTPC:L5_TTPC21', weight: 1.5, delay: 0.05, label: 'pre->post21', preLoc: 0.5, hObj: NetCon[146]}],
#  [{preGid: 50, sec: 'dend_65', loc: 0.8814904949510621, synMech: 'L5_TTPC:L5_TTPC22', weight: 1.5, delay: 0.05, label: 'pre->post22', preLoc: 0.5, hObj: NetCon[147]},
#   {preGid: 50, sec: 'dend_0', loc: 0.4091173018781259, synMech: 'L5_TTPC:L5_TTPC22', weight: 1.5, delay: 0.05, label: 'pre->post22', preLoc: 0.5, hObj: NetCon[148]},
#   {preGid: 50, sec: 'dend_75', loc: 0.2615609453602425, synMech: 'L5_TTPC:L5_TTPC22', weight: 1.5, delay: 0.05, label: 'pre->post22', preLoc: 0.5, hObj: NetCon[149]},
#   {preGid: 50, sec: 'dend_34', loc: 0.9357611821744943, synMech: 'L5_TTPC:L5_TTPC22', weight: 1.5, delay: 0.05, label: 'pre->post22', preLoc: 0.5, hObj: NetCon[150]},
#   {preGid: 50, sec: 'apic_33', loc: 0.5297158628217875, synMech: 'L5_TTPC:L5_TTPC22', weight: 1.5, delay: 0.05, label: 'pre->post22', preLoc: 0.5, hObj: NetCon[151]},
#   {preGid: 50, sec: 'dend_81', loc: 0.012278475169971227, synMech: 'L5_TTPC:L5_TTPC22', weight: 1.5, delay: 0.05, label: 'pre->post22', preLoc: 0.5, hObj: NetCon[152]},
#   {preGid: 50, sec: 'apic_19', loc: 0.4417077794346493, synMech: 'L5_TTPC:L5_TTPC22', weight: 1.5, delay: 0.05, label: 'pre->post22', preLoc: 0.5, hObj: NetCon[153]}],
#  [{preGid: 50, sec: 'apic_7', loc: 0.6789570619732412, synMech: 'L5_TTPC:L5_TTPC23', weight: 1.5, delay: 0.05, label: 'pre->post23', preLoc: 0.5, hObj: NetCon[154]},
#   {preGid: 50, sec: 'dend_53', loc: 0.87350583468738, synMech: 'L5_TTPC:L5_TTPC23', weight: 1.5, delay: 0.05, label: 'pre->post23', preLoc: 0.5, hObj: NetCon[155]},
#   {preGid: 50, sec: 'dend_61', loc: 0.19546498797698897, synMech: 'L5_TTPC:L5_TTPC23', weight: 1.5, delay: 0.05, label: 'pre->post23', preLoc: 0.5, hObj: NetCon[156]},
#   {preGid: 50, sec: 'apic_86', loc: 0.16601329889879113, synMech: 'L5_TTPC:L5_TTPC23', weight: 1.5, delay: 0.05, label: 'pre->post23', preLoc: 0.5, hObj: NetCon[157]},
#   {preGid: 50, sec: 'dend_65', loc: 0.6174249864144543, synMech: 'L5_TTPC:L5_TTPC23', weight: 1.5, delay: 0.05, label: 'pre->post23', preLoc: 0.5, hObj: NetCon[158]},
#   {preGid: 50, sec: 'apic_47', loc: 0.27560026789329845, synMech: 'L5_TTPC:L5_TTPC23', weight: 1.5, delay: 0.05, label: 'pre->post23', preLoc: 0.5, hObj: NetCon[159]},
#   {preGid: 50, sec: 'apic_16', loc: 0.4050098587024699, synMech: 'L5_TTPC:L5_TTPC23', weight: 1.5, delay: 0.05, label: 'pre->post23', preLoc: 0.5, hObj: NetCon[160]}],
#  [{preGid: 50, sec: 'dend_5', loc: 0.3028402844941679, synMech: 'L5_TTPC:L5_TTPC24', weight: 1.5, delay: 0.05, label: 'pre->post24', preLoc: 0.5, hObj: NetCon[161]},
#   {preGid: 50, sec: 'dend_81', loc: 0.4293706307732922, synMech: 'L5_TTPC:L5_TTPC24', weight: 1.5, delay: 0.05, label: 'pre->post24', preLoc: 0.5, hObj: NetCon[162]},
#   {preGid: 50, sec: 'apic_73', loc: 0.5665802591135355, synMech: 'L5_TTPC:L5_TTPC24', weight: 1.5, delay: 0.05, label: 'pre->post24', preLoc: 0.5, hObj: NetCon[163]},
#   {preGid: 50, sec: 'dend_54', loc: 0.6850615882811418, synMech: 'L5_TTPC:L5_TTPC24', weight: 1.5, delay: 0.05, label: 'pre->post24', preLoc: 0.5, hObj: NetCon[164]},
#   {preGid: 50, sec: 'dend_43', loc: 0.49584193006021815, synMech: 'L5_TTPC:L5_TTPC24', weight: 1.5, delay: 0.05, label: 'pre->post24', preLoc: 0.5, hObj: NetCon[165]},
#   {preGid: 50, sec: 'apic_38', loc: 0.3905003104080999, synMech: 'L5_TTPC:L5_TTPC24', weight: 1.5, delay: 0.05, label: 'pre->post24', preLoc: 0.5, hObj: NetCon[166]},
#   {preGid: 50, sec: 'dend_20', loc: 0.9446277620150944, synMech: 'L5_TTPC:L5_TTPC24', weight: 1.5, delay: 0.05, label: 'pre->post24', preLoc: 0.5, hObj: NetCon[167]}],
#  [{preGid: 50, sec: 'apic_26', loc: 0.5180666540881386, synMech: 'L5_TTPC:L5_TTPC25', weight: 1.5, delay: 0.05, label: 'pre->post25', preLoc: 0.5, hObj: NetCon[168]},
#   {preGid: 50, sec: 'dend_66', loc: 0.8893178782889861, synMech: 'L5_TTPC:L5_TTPC25', weight: 1.5, delay: 0.05, label: 'pre->post25', preLoc: 0.5, hObj: NetCon[169]},
#   {preGid: 50, sec: 'dend_82', loc: 0.41498589740591385, synMech: 'L5_TTPC:L5_TTPC25', weight: 1.5, delay: 0.05, label: 'pre->post25', preLoc: 0.5, hObj: NetCon[170]},
#   {preGid: 50, sec: 'apic_14', loc: 0.9116175409094901, synMech: 'L5_TTPC:L5_TTPC25', weight: 1.5, delay: 0.05, label: 'pre->post25', preLoc: 0.5, hObj: NetCon[171]},
#   {preGid: 50, sec: 'dend_20', loc: 0.2411398600168235, synMech: 'L5_TTPC:L5_TTPC25', weight: 1.5, delay: 0.05, label: 'pre->post25', preLoc: 0.5, hObj: NetCon[172]},
#   {preGid: 50, sec: 'apic_61', loc: 0.04721923753059576, synMech: 'L5_TTPC:L5_TTPC25', weight: 1.5, delay: 0.05, label: 'pre->post25', preLoc: 0.5, hObj: NetCon[173]},
#   {preGid: 50, sec: 'dend_31', loc: 0.4431637068622495, synMech: 'L5_TTPC:L5_TTPC25', weight: 1.5, delay: 0.05, label: 'pre->post25', preLoc: 0.5, hObj: NetCon[174]}],
#  [{preGid: 50, sec: 'dend_61', loc: 0.5466666423746843, synMech: 'L5_TTPC:L5_TTPC26', weight: 1.5, delay: 0.05, label: 'pre->post26', preLoc: 0.5, hObj: NetCon[175]},
#   {preGid: 50, sec: 'apic_91', loc: 0.21497118659867942, synMech: 'L5_TTPC:L5_TTPC26', weight: 1.5, delay: 0.05, label: 'pre->post26', preLoc: 0.5, hObj: NetCon[176]},
#   {preGid: 50, sec: 'dend_16', loc: 0.2997950097353183, synMech: 'L5_TTPC:L5_TTPC26', weight: 1.5, delay: 0.05, label: 'pre->post26', preLoc: 0.5, hObj: NetCon[177]},
#   {preGid: 50, sec: 'dend_55', loc: 0.18211732525477728, synMech: 'L5_TTPC:L5_TTPC26', weight: 1.5, delay: 0.05, label: 'pre->post26', preLoc: 0.5, hObj: NetCon[178]},
#   {preGid: 50, sec: 'dend_72', loc: 0.3578184574828448, synMech: 'L5_TTPC:L5_TTPC26', weight: 1.5, delay: 0.05, label: 'pre->post26', preLoc: 0.5, hObj: NetCon[179]},
#   {preGid: 50, sec: 'apic_45', loc: 0.06432592199308403, synMech: 'L5_TTPC:L5_TTPC26', weight: 1.5, delay: 0.05, label: 'pre->post26', preLoc: 0.5, hObj: NetCon[180]},
#   {preGid: 50, sec: 'apic_52', loc: 0.8359964509063462, synMech: 'L5_TTPC:L5_TTPC26', weight: 1.5, delay: 0.05, label: 'pre->post26', preLoc: 0.5, hObj: NetCon[181]}],
#  [{preGid: 50, sec: 'dend_22', loc: 0.16824968066131435, synMech: 'L5_TTPC:L5_TTPC27', weight: 1.5, delay: 0.05, label: 'pre->post27', preLoc: 0.5, hObj: NetCon[182]},
#   {preGid: 50, sec: 'dend_62', loc: 0.4574119622409685, synMech: 'L5_TTPC:L5_TTPC27', weight: 1.5, delay: 0.05, label: 'pre->post27', preLoc: 0.5, hObj: NetCon[183]},
#   {preGid: 50, sec: 'dend_73', loc: 0.9423058814644366, synMech: 'L5_TTPC:L5_TTPC27', weight: 1.5, delay: 0.05, label: 'pre->post27', preLoc: 0.5, hObj: NetCon[184]},
#   {preGid: 50, sec: 'apic_33', loc: 0.9409728336682291, synMech: 'L5_TTPC:L5_TTPC27', weight: 1.5, delay: 0.05, label: 'pre->post27', preLoc: 0.5, hObj: NetCon[185]},
#   {preGid: 50, sec: 'dend_72', loc: 0.6899355817565537, synMech: 'L5_TTPC:L5_TTPC27', weight: 1.5, delay: 0.05, label: 'pre->post27', preLoc: 0.5, hObj: NetCon[186]},
#   {preGid: 50, sec: 'apic_46', loc: 0.28649888640837917, synMech: 'L5_TTPC:L5_TTPC27', weight: 1.5, delay: 0.05, label: 'pre->post27', preLoc: 0.5, hObj: NetCon[187]},
#   {preGid: 50, sec: 'dend_59', loc: 0.7995853399808732, synMech: 'L5_TTPC:L5_TTPC27', weight: 1.5, delay: 0.05, label: 'pre->post27', preLoc: 0.5, hObj: NetCon[188]}],
#  [{preGid: 50, sec: 'apic_39', loc: 0.9079198705306953, synMech: 'L5_TTPC:L5_TTPC28', weight: 1.5, delay: 0.05, label: 'pre->post28', preLoc: 0.5, hObj: NetCon[189]},
#   {preGid: 50, sec: 'apic_52', loc: 0.14784259225463173, synMech: 'L5_TTPC:L5_TTPC28', weight: 1.5, delay: 0.05, label: 'pre->post28', preLoc: 0.5, hObj: NetCon[190]},
#   {preGid: 50, sec: 'dend_11', loc: 0.9305470423927769, synMech: 'L5_TTPC:L5_TTPC28', weight: 1.5, delay: 0.05, label: 'pre->post28', preLoc: 0.5, hObj: NetCon[191]},
#   {preGid: 50, sec: 'apic_66', loc: 0.28502952932011855, synMech: 'L5_TTPC:L5_TTPC28', weight: 1.5, delay: 0.05, label: 'pre->post28', preLoc: 0.5, hObj: NetCon[192]},
#   {preGid: 50, sec: 'dend_79', loc: 0.8021257678219422, synMech: 'L5_TTPC:L5_TTPC28', weight: 1.5, delay: 0.05, label: 'pre->post28', preLoc: 0.5, hObj: NetCon[193]},
#   {preGid: 50, sec: 'dend_31', loc: 0.11736776565235031, synMech: 'L5_TTPC:L5_TTPC28', weight: 1.5, delay: 0.05, label: 'pre->post28', preLoc: 0.5, hObj: NetCon[194]},
#   {preGid: 50, sec: 'apic_89', loc: 0.26712893903658846, synMech: 'L5_TTPC:L5_TTPC28', weight: 1.5, delay: 0.05, label: 'pre->post28', preLoc: 0.5, hObj: NetCon[195]}],
#  [{preGid: 50, sec: 'apic_36', loc: 0.13742924467634793, synMech: 'L5_TTPC:L5_TTPC29', weight: 1.5, delay: 0.05, label: 'pre->post29', preLoc: 0.5, hObj: NetCon[196]},
#   {preGid: 50, sec: 'dend_57', loc: 0.5345560242308319, synMech: 'L5_TTPC:L5_TTPC29', weight: 1.5, delay: 0.05, label: 'pre->post29', preLoc: 0.5, hObj: NetCon[197]},
#   {preGid: 50, sec: 'apic_89', loc: 0.4894974146870016, synMech: 'L5_TTPC:L5_TTPC29', weight: 1.5, delay: 0.05, label: 'pre->post29', preLoc: 0.5, hObj: NetCon[198]},
#   {preGid: 50, sec: 'dend_30', loc: 0.5781792488356458, synMech: 'L5_TTPC:L5_TTPC29', weight: 1.5, delay: 0.05, label: 'pre->post29', preLoc: 0.5, hObj: NetCon[199]},
#   {preGid: 50, sec: 'dend_77', loc: 0.6351757957803362, synMech: 'L5_TTPC:L5_TTPC29', weight: 1.5, delay: 0.05, label: 'pre->post29', preLoc: 0.5, hObj: NetCon[200]},
#   {preGid: 50, sec: 'apic_20', loc: 0.6278587771799717, synMech: 'L5_TTPC:L5_TTPC29', weight: 1.5, delay: 0.05, label: 'pre->post29', preLoc: 0.5, hObj: NetCon[201]},
#   {preGid: 50, sec: 'apic_54', loc: 0.581356599183069, synMech: 'L5_TTPC:L5_TTPC29', weight: 1.5, delay: 0.05, label: 'pre->post29', preLoc: 0.5, hObj: NetCon[202]}],
#  [{preGid: 50, sec: 'dend_13', loc: 0.3709863795326706, synMech: 'L5_TTPC:L5_TTPC30', weight: 1.5, delay: 0.05, label: 'pre->post30', preLoc: 0.5, hObj: NetCon[203]},
#   {preGid: 50, sec: 'apic_39', loc: 0.7218851887933959, synMech: 'L5_TTPC:L5_TTPC30', weight: 1.5, delay: 0.05, label: 'pre->post30', preLoc: 0.5, hObj: NetCon[204]},
#   {preGid: 50, sec: 'apic_29', loc: 0.48312915841934834, synMech: 'L5_TTPC:L5_TTPC30', weight: 1.5, delay: 0.05, label: 'pre->post30', preLoc: 0.5, hObj: NetCon[205]},
#   {preGid: 50, sec: 'dend_29', loc: 0.23284100749148637, synMech: 'L5_TTPC:L5_TTPC30', weight: 1.5, delay: 0.05, label: 'pre->post30', preLoc: 0.5, hObj: NetCon[206]},
#   {preGid: 50, sec: 'apic_75', loc: 0.7885767721897958, synMech: 'L5_TTPC:L5_TTPC30', weight: 1.5, delay: 0.05, label: 'pre->post30', preLoc: 0.5, hObj: NetCon[207]},
#   {preGid: 50, sec: 'apic_89', loc: 0.6735629096369362, synMech: 'L5_TTPC:L5_TTPC30', weight: 1.5, delay: 0.05, label: 'pre->post30', preLoc: 0.5, hObj: NetCon[208]},
#   {preGid: 50, sec: 'apic_36', loc: 0.49325497151049197, synMech: 'L5_TTPC:L5_TTPC30', weight: 1.5, delay: 0.05, label: 'pre->post30', preLoc: 0.5, hObj: NetCon[209]}],
#  [{preGid: 50, sec: 'apic_33', loc: 0.8070099106483554, synMech: 'L5_TTPC:L5_TTPC31', weight: 1.5, delay: 0.05, label: 'pre->post31', preLoc: 0.5, hObj: NetCon[210]},
#   {preGid: 50, sec: 'dend_21', loc: 0.6407809211751407, synMech: 'L5_TTPC:L5_TTPC31', weight: 1.5, delay: 0.05, label: 'pre->post31', preLoc: 0.5, hObj: NetCon[211]},
#   {preGid: 50, sec: 'dend_85', loc: 0.8067261781130813, synMech: 'L5_TTPC:L5_TTPC31', weight: 1.5, delay: 0.05, label: 'pre->post31', preLoc: 0.5, hObj: NetCon[212]},
#   {preGid: 50, sec: 'dend_9', loc: 0.6337760067190796, synMech: 'L5_TTPC:L5_TTPC31', weight: 1.5, delay: 0.05, label: 'pre->post31', preLoc: 0.5, hObj: NetCon[213]},
#   {preGid: 50, sec: 'apic_27', loc: 0.6258988103120698, synMech: 'L5_TTPC:L5_TTPC31', weight: 1.5, delay: 0.05, label: 'pre->post31', preLoc: 0.5, hObj: NetCon[214]},
#   {preGid: 50, sec: 'apic_92', loc: 0.02973672749786646, synMech: 'L5_TTPC:L5_TTPC31', weight: 1.5, delay: 0.05, label: 'pre->post31', preLoc: 0.5, hObj: NetCon[215]},
#   {preGid: 50, sec: 'dend_8', loc: 0.17070362765943684, synMech: 'L5_TTPC:L5_TTPC31', weight: 1.5, delay: 0.05, label: 'pre->post31', preLoc: 0.5, hObj: NetCon[216]}],
#  [{preGid: 50, sec: 'dend_63', loc: 0.7891327420670362, synMech: 'L5_TTPC:L5_TTPC32', weight: 1.5, delay: 0.05, label: 'pre->post32', preLoc: 0.5, hObj: NetCon[217]},
#   {preGid: 50, sec: 'apic_86', loc: 0.5126103723701545, synMech: 'L5_TTPC:L5_TTPC32', weight: 1.5, delay: 0.05, label: 'pre->post32', preLoc: 0.5, hObj: NetCon[218]},
#   {preGid: 50, sec: 'dend_9', loc: 0.7587484642523424, synMech: 'L5_TTPC:L5_TTPC32', weight: 1.5, delay: 0.05, label: 'pre->post32', preLoc: 0.5, hObj: NetCon[219]},
#   {preGid: 50, sec: 'dend_2', loc: 0.15279921634560817, synMech: 'L5_TTPC:L5_TTPC32', weight: 1.5, delay: 0.05, label: 'pre->post32', preLoc: 0.5, hObj: NetCon[220]},
#   {preGid: 50, sec: 'dend_51', loc: 0.2067531553666148, synMech: 'L5_TTPC:L5_TTPC32', weight: 1.5, delay: 0.05, label: 'pre->post32', preLoc: 0.5, hObj: NetCon[221]},
#   {preGid: 50, sec: 'apic_32', loc: 0.2564277093957041, synMech: 'L5_TTPC:L5_TTPC32', weight: 1.5, delay: 0.05, label: 'pre->post32', preLoc: 0.5, hObj: NetCon[222]},
#   {preGid: 50, sec: 'dend_18', loc: 0.3041270541148205, synMech: 'L5_TTPC:L5_TTPC32', weight: 1.5, delay: 0.05, label: 'pre->post32', preLoc: 0.5, hObj: NetCon[223]}],
#  [{preGid: 50, sec: 'apic_78', loc: 0.388213808065648, synMech: 'L5_TTPC:L5_TTPC33', weight: 1.5, delay: 0.05, label: 'pre->post33', preLoc: 0.5, hObj: NetCon[224]},
#   {preGid: 50, sec: 'apic_66', loc: 0.6574730777034102, synMech: 'L5_TTPC:L5_TTPC33', weight: 1.5, delay: 0.05, label: 'pre->post33', preLoc: 0.5, hObj: NetCon[225]},
#   {preGid: 50, sec: 'apic_80', loc: 0.12495089959281501, synMech: 'L5_TTPC:L5_TTPC33', weight: 1.5, delay: 0.05, label: 'pre->post33', preLoc: 0.5, hObj: NetCon[226]},
#   {preGid: 50, sec: 'apic_50', loc: 0.011852623030943976, synMech: 'L5_TTPC:L5_TTPC33', weight: 1.5, delay: 0.05, label: 'pre->post33', preLoc: 0.5, hObj: NetCon[227]},
#   {preGid: 50, sec: 'dend_28', loc: 0.03141045602838602, synMech: 'L5_TTPC:L5_TTPC33', weight: 1.5, delay: 0.05, label: 'pre->post33', preLoc: 0.5, hObj: NetCon[228]},
#   {preGid: 50, sec: 'dend_69', loc: 0.6323265689846175, synMech: 'L5_TTPC:L5_TTPC33', weight: 1.5, delay: 0.05, label: 'pre->post33', preLoc: 0.5, hObj: NetCon[229]},
#   {preGid: 50, sec: 'dend_85', loc: 0.6729982140526762, synMech: 'L5_TTPC:L5_TTPC33', weight: 1.5, delay: 0.05, label: 'pre->post33', preLoc: 0.5, hObj: NetCon[230]}],
#  [{preGid: 50, sec: 'dend_93', loc: 0.11086730727096433, synMech: 'L5_TTPC:L5_TTPC34', weight: 1.5, delay: 0.05, label: 'pre->post34', preLoc: 0.5, hObj: NetCon[231]},
#   {preGid: 50, sec: 'dend_77', loc: 0.6909315365959731, synMech: 'L5_TTPC:L5_TTPC34', weight: 1.5, delay: 0.05, label: 'pre->post34', preLoc: 0.5, hObj: NetCon[232]},
#   {preGid: 50, sec: 'apic_16', loc: 0.5447008709992157, synMech: 'L5_TTPC:L5_TTPC34', weight: 1.5, delay: 0.05, label: 'pre->post34', preLoc: 0.5, hObj: NetCon[233]},
#   {preGid: 50, sec: 'dend_59', loc: 0.660140043860886, synMech: 'L5_TTPC:L5_TTPC34', weight: 1.5, delay: 0.05, label: 'pre->post34', preLoc: 0.5, hObj: NetCon[234]},
#   {preGid: 50, sec: 'dend_46', loc: 0.675974934333807, synMech: 'L5_TTPC:L5_TTPC34', weight: 1.5, delay: 0.05, label: 'pre->post34', preLoc: 0.5, hObj: NetCon[235]},
#   {preGid: 50, sec: 'apic_15', loc: 0.10836088507066008, synMech: 'L5_TTPC:L5_TTPC34', weight: 1.5, delay: 0.05, label: 'pre->post34', preLoc: 0.5, hObj: NetCon[236]},
#   {preGid: 50, sec: 'dend_39', loc: 0.7249287224875912, synMech: 'L5_TTPC:L5_TTPC34', weight: 1.5, delay: 0.05, label: 'pre->post34', preLoc: 0.5, hObj: NetCon[237]}],
#  [{preGid: 50, sec: 'apic_64', loc: 0.45016435576820873, synMech: 'L5_TTPC:L5_TTPC35', weight: 1.5, delay: 0.05, label: 'pre->post35', preLoc: 0.5, hObj: NetCon[238]},
#   {preGid: 50, sec: 'apic_53', loc: 0.1947520207476504, synMech: 'L5_TTPC:L5_TTPC35', weight: 1.5, delay: 0.05, label: 'pre->post35', preLoc: 0.5, hObj: NetCon[239]},
#   {preGid: 50, sec: 'dend_85', loc: 0.7878044728011622, synMech: 'L5_TTPC:L5_TTPC35', weight: 1.5, delay: 0.05, label: 'pre->post35', preLoc: 0.5, hObj: NetCon[240]},
#   {preGid: 50, sec: 'apic_29', loc: 0.10700791724040333, synMech: 'L5_TTPC:L5_TTPC35', weight: 1.5, delay: 0.05, label: 'pre->post35', preLoc: 0.5, hObj: NetCon[241]},
#   {preGid: 50, sec: 'apic_81', loc: 0.2768216992759398, synMech: 'L5_TTPC:L5_TTPC35', weight: 1.5, delay: 0.05, label: 'pre->post35', preLoc: 0.5, hObj: NetCon[242]},
#   {preGid: 50, sec: 'dend_88', loc: 0.36573226526102326, synMech: 'L5_TTPC:L5_TTPC35', weight: 1.5, delay: 0.05, label: 'pre->post35', preLoc: 0.5, hObj: NetCon[243]},
#   {preGid: 50, sec: 'apic_71', loc: 0.5572871615022118, synMech: 'L5_TTPC:L5_TTPC35', weight: 1.5, delay: 0.05, label: 'pre->post35', preLoc: 0.5, hObj: NetCon[244]}],
#  [{preGid: 50, sec: 'dend_20', loc: 0.83255335095916, synMech: 'L5_TTPC:L5_TTPC36', weight: 1.5, delay: 0.05, label: 'pre->post36', preLoc: 0.5, hObj: NetCon[245]},
#   {preGid: 50, sec: 'apic_59', loc: 0.76341659911427, synMech: 'L5_TTPC:L5_TTPC36', weight: 1.5, delay: 0.05, label: 'pre->post36', preLoc: 0.5, hObj: NetCon[246]},
#   {preGid: 50, sec: 'apic_28', loc: 0.743515554487178, synMech: 'L5_TTPC:L5_TTPC36', weight: 1.5, delay: 0.05, label: 'pre->post36', preLoc: 0.5, hObj: NetCon[247]},
#   {preGid: 50, sec: 'dend_69', loc: 0.8468219519611939, synMech: 'L5_TTPC:L5_TTPC36', weight: 1.5, delay: 0.05, label: 'pre->post36', preLoc: 0.5, hObj: NetCon[248]},
#   {preGid: 50, sec: 'apic_45', loc: 0.33625929305113283, synMech: 'L5_TTPC:L5_TTPC36', weight: 1.5, delay: 0.05, label: 'pre->post36', preLoc: 0.5, hObj: NetCon[249]},
#   {preGid: 50, sec: 'dend_51', loc: 0.004039311201473341, synMech: 'L5_TTPC:L5_TTPC36', weight: 1.5, delay: 0.05, label: 'pre->post36', preLoc: 0.5, hObj: NetCon[250]},
#   {preGid: 50, sec: 'apic_81', loc: 0.44291922809324413, synMech: 'L5_TTPC:L5_TTPC36', weight: 1.5, delay: 0.05, label: 'pre->post36', preLoc: 0.5, hObj: NetCon[251]}],
#  [{preGid: 50, sec: 'dend_41', loc: 0.7355286469550638, synMech: 'L5_TTPC:L5_TTPC37', weight: 1.5, delay: 0.05, label: 'pre->post37', preLoc: 0.5, hObj: NetCon[252]},
#   {preGid: 50, sec: 'dend_68', loc: 0.34035128198905096, synMech: 'L5_TTPC:L5_TTPC37', weight: 1.5, delay: 0.05, label: 'pre->post37', preLoc: 0.5, hObj: NetCon[253]},
#   {preGid: 50, sec: 'apic_80', loc: 0.9790883102460054, synMech: 'L5_TTPC:L5_TTPC37', weight: 1.5, delay: 0.05, label: 'pre->post37', preLoc: 0.5, hObj: NetCon[254]},
#   {preGid: 50, sec: 'apic_72', loc: 0.06370453509946107, synMech: 'L5_TTPC:L5_TTPC37', weight: 1.5, delay: 0.05, label: 'pre->post37', preLoc: 0.5, hObj: NetCon[255]},
#   {preGid: 50, sec: 'apic_76', loc: 0.782210172102024, synMech: 'L5_TTPC:L5_TTPC37', weight: 1.5, delay: 0.05, label: 'pre->post37', preLoc: 0.5, hObj: NetCon[256]},
#   {preGid: 50, sec: 'dend_42', loc: 0.657511088489988, synMech: 'L5_TTPC:L5_TTPC37', weight: 1.5, delay: 0.05, label: 'pre->post37', preLoc: 0.5, hObj: NetCon[257]},
#   {preGid: 50, sec: 'apic_12', loc: 0.5153371386291339, synMech: 'L5_TTPC:L5_TTPC37', weight: 1.5, delay: 0.05, label: 'pre->post37', preLoc: 0.5, hObj: NetCon[258]}],
#  [{preGid: 50, sec: 'apic_37', loc: 0.8668871270170521, synMech: 'L5_TTPC:L5_TTPC38', weight: 1.5, delay: 0.05, label: 'pre->post38', preLoc: 0.5, hObj: NetCon[259]},
#   {preGid: 50, sec: 'apic_76', loc: 0.15382865098485302, synMech: 'L5_TTPC:L5_TTPC38', weight: 1.5, delay: 0.05, label: 'pre->post38', preLoc: 0.5, hObj: NetCon[260]},
#   {preGid: 50, sec: 'apic_73', loc: 0.19902679169364365, synMech: 'L5_TTPC:L5_TTPC38', weight: 1.5, delay: 0.05, label: 'pre->post38', preLoc: 0.5, hObj: NetCon[261]},
#   {preGid: 50, sec: 'apic_88', loc: 0.6339558700634669, synMech: 'L5_TTPC:L5_TTPC38', weight: 1.5, delay: 0.05, label: 'pre->post38', preLoc: 0.5, hObj: NetCon[262]},
#   {preGid: 50, sec: 'dend_82', loc: 0.22428881695289, synMech: 'L5_TTPC:L5_TTPC38', weight: 1.5, delay: 0.05, label: 'pre->post38', preLoc: 0.5, hObj: NetCon[263]},
#   {preGid: 50, sec: 'dend_14', loc: 0.7034406831310079, synMech: 'L5_TTPC:L5_TTPC38', weight: 1.5, delay: 0.05, label: 'pre->post38', preLoc: 0.5, hObj: NetCon[264]},
#   {preGid: 50, sec: 'apic_49', loc: 0.6926646055088347, synMech: 'L5_TTPC:L5_TTPC38', weight: 1.5, delay: 0.05, label: 'pre->post38', preLoc: 0.5, hObj: NetCon[265]}],
#  [{preGid: 50, sec: 'dend_67', loc: 0.08430009365657794, synMech: 'L5_TTPC:L5_TTPC39', weight: 1.5, delay: 0.05, label: 'pre->post39', preLoc: 0.5, hObj: NetCon[266]},
#   {preGid: 50, sec: 'dend_32', loc: 0.31309849288104724, synMech: 'L5_TTPC:L5_TTPC39', weight: 1.5, delay: 0.05, label: 'pre->post39', preLoc: 0.5, hObj: NetCon[267]},
#   {preGid: 50, sec: 'dend_42', loc: 0.600754050604087, synMech: 'L5_TTPC:L5_TTPC39', weight: 1.5, delay: 0.05, label: 'pre->post39', preLoc: 0.5, hObj: NetCon[268]},
#   {preGid: 50, sec: 'apic_80', loc: 0.0643587523155216, synMech: 'L5_TTPC:L5_TTPC39', weight: 1.5, delay: 0.05, label: 'pre->post39', preLoc: 0.5, hObj: NetCon[269]},
#   {preGid: 50, sec: 'apic_91', loc: 0.904197937230155, synMech: 'L5_TTPC:L5_TTPC39', weight: 1.5, delay: 0.05, label: 'pre->post39', preLoc: 0.5, hObj: NetCon[270]},
#   {preGid: 50, sec: 'apic_36', loc: 0.3208863748224535, synMech: 'L5_TTPC:L5_TTPC39', weight: 1.5, delay: 0.05, label: 'pre->post39', preLoc: 0.5, hObj: NetCon[271]},
#   {preGid: 50, sec: 'dend_59', loc: 0.10760360840406465, synMech: 'L5_TTPC:L5_TTPC39', weight: 1.5, delay: 0.05, label: 'pre->post39', preLoc: 0.5, hObj: NetCon[272]}],
#  [{preGid: 50, sec: 'apic_71', loc: 0.7131679909756572, synMech: 'L5_TTPC:L5_TTPC40', weight: 1.5, delay: 0.05, label: 'pre->post40', preLoc: 0.5, hObj: NetCon[273]},
#   {preGid: 50, sec: 'dend_37', loc: 0.17643672411133038, synMech: 'L5_TTPC:L5_TTPC40', weight: 1.5, delay: 0.05, label: 'pre->post40', preLoc: 0.5, hObj: NetCon[274]},
#   {preGid: 50, sec: 'apic_27', loc: 0.6002850350332473, synMech: 'L5_TTPC:L5_TTPC40', weight: 1.5, delay: 0.05, label: 'pre->post40', preLoc: 0.5, hObj: NetCon[275]},
#   {preGid: 50, sec: 'dend_76', loc: 0.979141334998314, synMech: 'L5_TTPC:L5_TTPC40', weight: 1.5, delay: 0.05, label: 'pre->post40', preLoc: 0.5, hObj: NetCon[276]},
#   {preGid: 50, sec: 'dend_20', loc: 0.8406849362085916, synMech: 'L5_TTPC:L5_TTPC40', weight: 1.5, delay: 0.05, label: 'pre->post40', preLoc: 0.5, hObj: NetCon[277]},
#   {preGid: 50, sec: 'dend_29', loc: 0.25336370903270555, synMech: 'L5_TTPC:L5_TTPC40', weight: 1.5, delay: 0.05, label: 'pre->post40', preLoc: 0.5, hObj: NetCon[278]},
#   {preGid: 50, sec: 'dend_77', loc: 0.10075829194036107, synMech: 'L5_TTPC:L5_TTPC40', weight: 1.5, delay: 0.05, label: 'pre->post40', preLoc: 0.5, hObj: NetCon[279]}],
#  [{preGid: 50, sec: 'apic_37', loc: 0.6002074277410647, synMech: 'L5_TTPC:L5_TTPC41', weight: 1.5, delay: 0.05, label: 'pre->post41', preLoc: 0.5, hObj: NetCon[280]},
#   {preGid: 50, sec: 'dend_68', loc: 0.4770961015725286, synMech: 'L5_TTPC:L5_TTPC41', weight: 1.5, delay: 0.05, label: 'pre->post41', preLoc: 0.5, hObj: NetCon[281]},
#   {preGid: 50, sec: 'dend_40', loc: 0.7370762751974912, synMech: 'L5_TTPC:L5_TTPC41', weight: 1.5, delay: 0.05, label: 'pre->post41', preLoc: 0.5, hObj: NetCon[282]},
#   {preGid: 50, sec: 'apic_30', loc: 0.23970704565751863, synMech: 'L5_TTPC:L5_TTPC41', weight: 1.5, delay: 0.05, label: 'pre->post41', preLoc: 0.5, hObj: NetCon[283]},
#   {preGid: 50, sec: 'apic_80', loc: 0.6996483321445515, synMech: 'L5_TTPC:L5_TTPC41', weight: 1.5, delay: 0.05, label: 'pre->post41', preLoc: 0.5, hObj: NetCon[284]},
#   {preGid: 50, sec: 'apic_50', loc: 0.8874626750538415, synMech: 'L5_TTPC:L5_TTPC41', weight: 1.5, delay: 0.05, label: 'pre->post41', preLoc: 0.5, hObj: NetCon[285]},
#   {preGid: 50, sec: 'apic_53', loc: 0.2819643069333102, synMech: 'L5_TTPC:L5_TTPC41', weight: 1.5, delay: 0.05, label: 'pre->post41', preLoc: 0.5, hObj: NetCon[286]}],
#  [{preGid: 50, sec: 'dend_85', loc: 0.6785779894009322, synMech: 'L5_TTPC:L5_TTPC42', weight: 1.5, delay: 0.05, label: 'pre->post42', preLoc: 0.5, hObj: NetCon[287]},
#   {preGid: 50, sec: 'apic_22', loc: 0.8963851370834439, synMech: 'L5_TTPC:L5_TTPC42', weight: 1.5, delay: 0.05, label: 'pre->post42', preLoc: 0.5, hObj: NetCon[288]},
#   {preGid: 50, sec: 'apic_85', loc: 0.7704928513181131, synMech: 'L5_TTPC:L5_TTPC42', weight: 1.5, delay: 0.05, label: 'pre->post42', preLoc: 0.5, hObj: NetCon[289]},
#   {preGid: 50, sec: 'dend_51', loc: 0.3884073943125783, synMech: 'L5_TTPC:L5_TTPC42', weight: 1.5, delay: 0.05, label: 'pre->post42', preLoc: 0.5, hObj: NetCon[290]},
#   {preGid: 50, sec: 'dend_93', loc: 0.9543799965520384, synMech: 'L5_TTPC:L5_TTPC42', weight: 1.5, delay: 0.05, label: 'pre->post42', preLoc: 0.5, hObj: NetCon[291]},
#   {preGid: 50, sec: 'dend_32', loc: 0.0028640906472606562, synMech: 'L5_TTPC:L5_TTPC42', weight: 1.5, delay: 0.05, label: 'pre->post42', preLoc: 0.5, hObj: NetCon[292]},
#   {preGid: 50, sec: 'dend_5', loc: 0.9737402635951287, synMech: 'L5_TTPC:L5_TTPC42', weight: 1.5, delay: 0.05, label: 'pre->post42', preLoc: 0.5, hObj: NetCon[293]}],
#  [{preGid: 50, sec: 'dend_66', loc: 0.5884911434342096, synMech: 'L5_TTPC:L5_TTPC43', weight: 1.5, delay: 0.05, label: 'pre->post43', preLoc: 0.5, hObj: NetCon[294]},
#   {preGid: 50, sec: 'dend_55', loc: 0.6207367081113454, synMech: 'L5_TTPC:L5_TTPC43', weight: 1.5, delay: 0.05, label: 'pre->post43', preLoc: 0.5, hObj: NetCon[295]},
#   {preGid: 50, sec: 'dend_62', loc: 0.8826306044940216, synMech: 'L5_TTPC:L5_TTPC43', weight: 1.5, delay: 0.05, label: 'pre->post43', preLoc: 0.5, hObj: NetCon[296]},
#   {preGid: 50, sec: 'apic_50', loc: 0.21598028961225094, synMech: 'L5_TTPC:L5_TTPC43', weight: 1.5, delay: 0.05, label: 'pre->post43', preLoc: 0.5, hObj: NetCon[297]},
#   {preGid: 50, sec: 'apic_76', loc: 0.4273267589761469, synMech: 'L5_TTPC:L5_TTPC43', weight: 1.5, delay: 0.05, label: 'pre->post43', preLoc: 0.5, hObj: NetCon[298]},
#   {preGid: 50, sec: 'apic_92', loc: 0.6315409380651548, synMech: 'L5_TTPC:L5_TTPC43', weight: 1.5, delay: 0.05, label: 'pre->post43', preLoc: 0.5, hObj: NetCon[299]},
#   {preGid: 50, sec: 'apic_84', loc: 0.4156869853505156, synMech: 'L5_TTPC:L5_TTPC43', weight: 1.5, delay: 0.05, label: 'pre->post43', preLoc: 0.5, hObj: NetCon[300]}],
#  [{preGid: 50, sec: 'apic_44', loc: 0.35370145210794673, synMech: 'L5_TTPC:L5_TTPC44', weight: 1.5, delay: 0.05, label: 'pre->post44', preLoc: 0.5, hObj: NetCon[301]},
#   {preGid: 50, sec: 'apic_19', loc: 0.01656896835395965, synMech: 'L5_TTPC:L5_TTPC44', weight: 1.5, delay: 0.05, label: 'pre->post44', preLoc: 0.5, hObj: NetCon[302]},
#   {preGid: 50, sec: 'dend_17', loc: 0.42121082058516385, synMech: 'L5_TTPC:L5_TTPC44', weight: 1.5, delay: 0.05, label: 'pre->post44', preLoc: 0.5, hObj: NetCon[303]},
#   {preGid: 50, sec: 'apic_27', loc: 0.02919796729192002, synMech: 'L5_TTPC:L5_TTPC44', weight: 1.5, delay: 0.05, label: 'pre->post44', preLoc: 0.5, hObj: NetCon[304]},
#   {preGid: 50, sec: 'dend_21', loc: 0.6287140902225078, synMech: 'L5_TTPC:L5_TTPC44', weight: 1.5, delay: 0.05, label: 'pre->post44', preLoc: 0.5, hObj: NetCon[305]},
#   {preGid: 50, sec: 'dend_31', loc: 0.5596951569078442, synMech: 'L5_TTPC:L5_TTPC44', weight: 1.5, delay: 0.05, label: 'pre->post44', preLoc: 0.5, hObj: NetCon[306]},
#   {preGid: 50, sec: 'apic_53', loc: 0.2936436418299755, synMech: 'L5_TTPC:L5_TTPC44', weight: 1.5, delay: 0.05, label: 'pre->post44', preLoc: 0.5, hObj: NetCon[307]}],
#  [{preGid: 50, sec: 'apic_82', loc: 0.8120161717143343, synMech: 'L5_TTPC:L5_TTPC45', weight: 1.5, delay: 0.05, label: 'pre->post45', preLoc: 0.5, hObj: NetCon[308]},
#   {preGid: 50, sec: 'apic_35', loc: 0.27412195730071454, synMech: 'L5_TTPC:L5_TTPC45', weight: 1.5, delay: 0.05, label: 'pre->post45', preLoc: 0.5, hObj: NetCon[309]},
#   {preGid: 50, sec: 'apic_12', loc: 0.05510229504146069, synMech: 'L5_TTPC:L5_TTPC45', weight: 1.5, delay: 0.05, label: 'pre->post45', preLoc: 0.5, hObj: NetCon[310]},
#   {preGid: 50, sec: 'dend_88', loc: 0.9348874776795639, synMech: 'L5_TTPC:L5_TTPC45', weight: 1.5, delay: 0.05, label: 'pre->post45', preLoc: 0.5, hObj: NetCon[311]},
#   {preGid: 50, sec: 'dend_63', loc: 0.29130083852955674, synMech: 'L5_TTPC:L5_TTPC45', weight: 1.5, delay: 0.05, label: 'pre->post45', preLoc: 0.5, hObj: NetCon[312]},
#   {preGid: 50, sec: 'dend_23', loc: 0.3915435335700158, synMech: 'L5_TTPC:L5_TTPC45', weight: 1.5, delay: 0.05, label: 'pre->post45', preLoc: 0.5, hObj: NetCon[313]},
#   {preGid: 50, sec: 'apic_84', loc: 0.6668610081750691, synMech: 'L5_TTPC:L5_TTPC45', weight: 1.5, delay: 0.05, label: 'pre->post45', preLoc: 0.5, hObj: NetCon[314]}],
#  [{preGid: 50, sec: 'apic_64', loc: 0.1623736090658404, synMech: 'L5_TTPC:L5_TTPC46', weight: 1.5, delay: 0.05, label: 'pre->post46', preLoc: 0.5, hObj: NetCon[315]},
#   {preGid: 50, sec: 'dend_22', loc: 0.27064941904853285, synMech: 'L5_TTPC:L5_TTPC46', weight: 1.5, delay: 0.05, label: 'pre->post46', preLoc: 0.5, hObj: NetCon[316]},
#   {preGid: 50, sec: 'apic_59', loc: 0.3049324362873624, synMech: 'L5_TTPC:L5_TTPC46', weight: 1.5, delay: 0.05, label: 'pre->post46', preLoc: 0.5, hObj: NetCon[317]},
#   {preGid: 50, sec: 'dend_81', loc: 0.45548254305648866, synMech: 'L5_TTPC:L5_TTPC46', weight: 1.5, delay: 0.05, label: 'pre->post46', preLoc: 0.5, hObj: NetCon[318]},
#   {preGid: 50, sec: 'apic_35', loc: 0.039647008606891396, synMech: 'L5_TTPC:L5_TTPC46', weight: 1.5, delay: 0.05, label: 'pre->post46', preLoc: 0.5, hObj: NetCon[319]},
#   {preGid: 50, sec: 'apic_41', loc: 0.5101544024522047, synMech: 'L5_TTPC:L5_TTPC46', weight: 1.5, delay: 0.05, label: 'pre->post46', preLoc: 0.5, hObj: NetCon[320]},
#   {preGid: 50, sec: 'dend_54', loc: 0.5301225025317591, synMech: 'L5_TTPC:L5_TTPC46', weight: 1.5, delay: 0.05, label: 'pre->post46', preLoc: 0.5, hObj: NetCon[321]}],
#  [{preGid: 50, sec: 'apic_36', loc: 0.8880236210453515, synMech: 'L5_TTPC:L5_TTPC47', weight: 1.5, delay: 0.05, label: 'pre->post47', preLoc: 0.5, hObj: NetCon[322]},
#   {preGid: 50, sec: 'dend_8', loc: 0.9637544054104977, synMech: 'L5_TTPC:L5_TTPC47', weight: 1.5, delay: 0.05, label: 'pre->post47', preLoc: 0.5, hObj: NetCon[323]},
#   {preGid: 50, sec: 'dend_51', loc: 0.13449608084090525, synMech: 'L5_TTPC:L5_TTPC47', weight: 1.5, delay: 0.05, label: 'pre->post47', preLoc: 0.5, hObj: NetCon[324]},
#   {preGid: 50, sec: 'apic_88', loc: 0.8349735933221571, synMech: 'L5_TTPC:L5_TTPC47', weight: 1.5, delay: 0.05, label: 'pre->post47', preLoc: 0.5, hObj: NetCon[325]},
#   {preGid: 50, sec: 'dend_28', loc: 0.13819736190891269, synMech: 'L5_TTPC:L5_TTPC47', weight: 1.5, delay: 0.05, label: 'pre->post47', preLoc: 0.5, hObj: NetCon[326]},
#   {preGid: 50, sec: 'dend_26', loc: 0.6607545725727155, synMech: 'L5_TTPC:L5_TTPC47', weight: 1.5, delay: 0.05, label: 'pre->post47', preLoc: 0.5, hObj: NetCon[327]},
#   {preGid: 50, sec: 'dend_88', loc: 0.17904578715503142, synMech: 'L5_TTPC:L5_TTPC47', weight: 1.5, delay: 0.05, label: 'pre->post47', preLoc: 0.5, hObj: NetCon[328]}],
#  [{preGid: 50, sec: 'dend_40', loc: 0.3026556108055628, synMech: 'L5_TTPC:L5_TTPC48', weight: 1.5, delay: 0.05, label: 'pre->post48', preLoc: 0.5, hObj: NetCon[329]},
#   {preGid: 50, sec: 'dend_31', loc: 0.18447303087567818, synMech: 'L5_TTPC:L5_TTPC48', weight: 1.5, delay: 0.05, label: 'pre->post48', preLoc: 0.5, hObj: NetCon[330]},
#   {preGid: 50, sec: 'apic_60', loc: 0.9785055174871277, synMech: 'L5_TTPC:L5_TTPC48', weight: 1.5, delay: 0.05, label: 'pre->post48', preLoc: 0.5, hObj: NetCon[331]},
#   {preGid: 50, sec: 'apic_36', loc: 0.7666291114184685, synMech: 'L5_TTPC:L5_TTPC48', weight: 1.5, delay: 0.05, label: 'pre->post48', preLoc: 0.5, hObj: NetCon[332]},
#   {preGid: 50, sec: 'dend_81', loc: 0.6629679731487736, synMech: 'L5_TTPC:L5_TTPC48', weight: 1.5, delay: 0.05, label: 'pre->post48', preLoc: 0.5, hObj: NetCon[333]},
#   {preGid: 50, sec: 'apic_28', loc: 0.2737071901481968, synMech: 'L5_TTPC:L5_TTPC48', weight: 1.5, delay: 0.05, label: 'pre->post48', preLoc: 0.5, hObj: NetCon[334]},
#   {preGid: 50, sec: 'dend_17', loc: 0.01754177733945167, synMech: 'L5_TTPC:L5_TTPC48', weight: 1.5, delay: 0.05, label: 'pre->post48', preLoc: 0.5, hObj: NetCon[335]}],
#  [{preGid: 50, sec: 'dend_22', loc: 0.1900143711071079, synMech: 'L5_TTPC:L5_TTPC49', weight: 1.5, delay: 0.05, label: 'pre->post49', preLoc: 0.5, hObj: NetCon[336]},
#   {preGid: 50, sec: 'dend_8', loc: 0.4330328984586316, synMech: 'L5_TTPC:L5_TTPC49', weight: 1.5, delay: 0.05, label: 'pre->post49', preLoc: 0.5, hObj: NetCon[337]},
#   {preGid: 50, sec: 'apic_35', loc: 0.6580043108735194, synMech: 'L5_TTPC:L5_TTPC49', weight: 1.5, delay: 0.05, label: 'pre->post49', preLoc: 0.5, hObj: NetCon[338]},
#   {preGid: 50, sec: 'dend_76', loc: 0.7192184712880477, synMech: 'L5_TTPC:L5_TTPC49', weight: 1.5, delay: 0.05, label: 'pre->post49', preLoc: 0.5, hObj: NetCon[339]},
#   {preGid: 50, sec: 'apic_56', loc: 0.22377727615200804, synMech: 'L5_TTPC:L5_TTPC49', weight: 1.5, delay: 0.05, label: 'pre->post49', preLoc: 0.5, hObj: NetCon[340]},
#   {preGid: 50, sec: 'dend_5', loc: 0.0478542470084782, synMech: 'L5_TTPC:L5_TTPC49', weight: 1.5, delay: 0.05, label: 'pre->post49', preLoc: 0.5, hObj: NetCon[341]},
#   {preGid: 50, sec: 'dend_48', loc: 0.9654400536492465, synMech: 'L5_TTPC:L5_TTPC49', weight: 1.5, delay: 0.05, label: 'pre->post49', preLoc: 0.5, hObj: NetCon[342]}],
#  [{preGid: 50, sec: 'apic_74', loc: 0.3550586536014275, synMech: 'L5_TTPC:L5_TTPC50', weight: 1.5, delay: 0.05, label: 'pre->post50', preLoc: 0.5, hObj: NetCon[343]},
#   {preGid: 50, sec: 'apic_28', loc: 0.7444683188199833, synMech: 'L5_TTPC:L5_TTPC50', weight: 1.5, delay: 0.05, label: 'pre->post50', preLoc: 0.5, hObj: NetCon[344]},
#   {preGid: 50, sec: 'dend_87', loc: 0.010184397789649966, synMech: 'L5_TTPC:L5_TTPC50', weight: 1.5, delay: 0.05, label: 'pre->post50', preLoc: 0.5, hObj: NetCon[345]},
#   {preGid: 50, sec: 'apic_12', loc: 0.8294164716918879, synMech: 'L5_TTPC:L5_TTPC50', weight: 1.5, delay: 0.05, label: 'pre->post50', preLoc: 0.5, hObj: NetCon[346]},
#   {preGid: 50, sec: 'dend_23', loc: 0.17377840993687288, synMech: 'L5_TTPC:L5_TTPC50', weight: 1.5, delay: 0.05, label: 'pre->post50', preLoc: 0.5, hObj: NetCon[347]},
#   {preGid: 50, sec: 'dend_42', loc: 0.4169328290812032, synMech: 'L5_TTPC:L5_TTPC50', weight: 1.5, delay: 0.05, label: 'pre->post50', preLoc: 0.5, hObj: NetCon[348]},
#   {preGid: 50, sec: 'apic_49', loc: 0.25106154501331546, synMech: 'L5_TTPC:L5_TTPC50', weight: 1.5, delay: 0.05, label: 'pre->post50', preLoc: 0.5, hObj: NetCon[349]}],
#  []]

# %%
sim.net.addStims() 							# add network stimulation
sim.setupRecording()              			# setup variables to record for each cell (spikes, V traces, etc)
# Out:
#   Number of stims on node 0: 0
#   Done; cell stims creation time = 0.00 s.
# Recording 50 traces of 1 types on node 0
# {spkt: Vector[66774], spkid: Vector[66775], V_soma: {cell_0: Vector[66776], cell_1: Vector[66777], cell_2: Vector[66778], cell_3: Vector[66779], cell_4: Vector[66780], cell_5: Vector[66781], cell_6: Vector[66782], cell_7: Vector[66783], cell_8: Vector[66784], cell_9: Vector[66785], cell_10: Vector[66786], cell_11: Vector[66787], cell_12: Vector[66788], cell_13: Vector[66789], cell_14: Vector[66790], cell_15: Vector[66791], cell_16: Vector[66792], cell_17: Vector[66793], cell_18: Vector[66794], cell_19: Vector[66795], cell_20: Vector[66796], cell_21: Vector[66797], cell_22: Vector[66798], cell_23: Vector[66799], cell_24: Vector[66800], cell_25: Vector[66801], cell_26: Vector[66802], cell_27: Vector[66803], cell_28: Vector[66804], cell_29: Vector[66805], cell_30: Vector[66806], cell_31: Vector[66807], cell_32: Vector[66808], cell_33: Vector[66809], cell_34: Vector[66810], cell_35: Vector[66811], cell_36: Vector[66812], cell_37: Vector[66813], cell_38: Vector[66814], cell_39: Vector[66815], cell_40: Vector[66816], cell_41: Vector[66817], cell_42: Vector[66818], cell_43: Vector[66819], cell_44: Vector[66820], cell_45: Vector[66821], cell_46: Vector[66822], cell_47: Vector[66823], cell_48: Vector[66824], cell_49: Vector[66825]}, t: Vector[66826], _repr_mimebundle_: {}}

# %%
sim.runSim()                      			# run Neuron simulation
# Out:
# 0.0s
#
# Running simulation using NEURON for 4000.0 ms...
# 0.1s
# 0.2s
# 0.3s
# 0.4s
# 0.5s
# 0.6s
# 0.7s
# 0.8s
# 0.9s
# 1.0s
# 1.1s
# 1.2s
# 1.3s
# 1.4s
# 1.5s
# 1.6s
# 1.7s
# 1.8s
# 1.9s
# 2.0s
# 2.1s
# 2.2s
# 2.3s
# 2.4s
# 2.5s
# 2.6s
# 2.7s
# 2.8s
# 2.9s
# 3.0s
# 3.1s
# 3.2s
# 3.3s
# 3.4s
# 3.5s
# 3.6s
# 3.7s
# 3.8s
# 3.9s
# 4.0s
#   Done; run time = 3206.48 s; real-time ratio: 0.00.

# %%
sim.gatherData()                  			# gather spiking data and cell info from each node
sim.saveData()                    			# save params, cell info and sim output to file (pickle,mat,txt,etc)#
sim.analysis.plotData()         			# plot spike raster etc
# Out:
# Gathering data...
#   Done; gather time = 0.10 s.
#
# Analyzing...
#   Cells: 51
#   Connections: 50 (0.98 per cell)
#   Synaptic contacts: 350 (6.86 per cell)
#   Spikes: 11 (0.05 Hz)
#   Simulated time: 4.0 s; 1 workers
#   Run time: 3206.48 s
# Warning: data won't be saved. No output format specified (consider sim.cfg.savePickle, sim.cfg.saveJson etc.)
# Plotting recorded cell traces ... trace
#   Done; plotting time = 0.44 s
#
# Total time = 3210.05 s

# %%
# sim.analysis.plotRaster(figSize=(10, 3))

# %%
alltraces = []
gmax1 = []

# spkTimes = [500,2500,2550,2600,2650,2700,2750,2800,2850,2900,3400]


Traces2 = sim.analysis.plotTraces(oneFigPer='trace', overlay=1, timeRange=[2400,3900],axis=False,legend=False,scaleBarLoc=1,figSize=(10, 3),fontSize=6)
for number in range(50):
    if np.max(Traces2[1]['tracesData'][number]['cell_'+str(number)+'_V_soma'])-np.min(Traces2[1]['tracesData'][number]['cell_'+str(number)+'_V_soma']) > 0.01:
        alltraces.append(Traces2[1]['tracesData'][number]['cell_'+str(number)+'_V_soma'])
        gmax1.append(np.max(Traces2[1]['tracesData'][number]['cell_'+str(number)+'_V_soma'])-np.min(Traces2[1]['tracesData'][number]['cell_'+str(number)+'_V_soma']))
#         print(number,np.max(Traces2[1]['tracesData'][number]['cell_'+str(number)+'_V_soma'])-np.min(Traces2[1]['tracesData'][number]['cell_'+str(number)+'_V_soma']))


# Traces2 = sim.analysis.plotTraces(oneFigPer='trace', overlay=1, timeRange=[3300,3900],axis=False,legend=False,scaleBarLoc=1,figSize=(10, 3),fontSize=6)
# for number in range(20):
#     if np.max(Traces2[1]['tracesData'][number]['cell_'+str(number)+'_V_soma'])-np.min(Traces2[1]['tracesData'][number]['cell_'+str(number)+'_V_soma']) > 0.01:
#         alltraces.append(Traces2[1]['tracesData'][number]['cell_'+str(number)+'_V_soma'])
#         gmax1.append(np.max(Traces2[1]['tracesData'][number]['cell_'+str(number)+'_V_soma'])-np.min(Traces2[1]['tracesData'][number]['cell_'+str(number)+'_V_soma']))
# #         print(number,np.max(Traces2[1]['tracesData'][number]['cell_'+str(number)+'_V_soma'])-np.min(Traces2[1]['tracesData'][number]['cell_'+str(number)+'_V_soma']))


# print('L23_PC:L23_PC in silico PSP amplitude (mV; mean ± SD) = %.3f±%.3f' % (np.mean(gmax1),np.std(gmax1)))
print('L5_TTPC:L5_TTPC in silico PSP amplitude (mV; mean ± SD) = %.3f±%.3f' % (np.mean(gmax1),np.std(gmax1)))
# Out:
# Plotting recorded cell traces ... trace
# L5_TTPC:L5_TTPC in silico PSP amplitude (mV; mean ± SD) = 0.926±0.178

# %%
figSize = (16,9)
fig = plt.figure(figsize=figSize)  # Open a new figure
clr = ["black", "blue","green","gray", "red","black", "blue","green","gray", "red"]
number=0
for i in range(10):
    for number2 in range(i,50,10):
        plt.plot(Traces2[1]['tracesData'][number]['t'][1:],Traces2[1]['tracesData'][number]['cell_'+str(number)+'_V_soma']-Traces2[1]['tracesData'][number]['cell_'+str(number)+'_V_soma'][999]-1.0*i, label= sim.net.allCells[number]['tags']['pop'] + '_' + sim.net.allCells[number]['conns'][0]['sec'], linewidth=1.0, color=clr[i])
        number+=1
        
plt.legend(loc='upper right', bbox_to_anchor=(1.25, 1.0), fontsize=8)
# plt.xlim(2400,4150)
plt.ylim(-9.25,2.0)
plt.xlabel('Time (ms)', fontsize=16)
plt.ylabel('EPSP (mV)', fontsize=16)
# plt.xticks(range(2400,3900,200), range(0,1500,200), fontsize=14);
plt.yticks([0,1], fontsize=14);

# %%
figSize = (8,5)
fig = plt.figure(figsize=figSize)  # Open a new figure
for number in range(np.shape(alltraces)[0]):
    plt.plot(alltraces[number]-alltraces[number][0],color = 'lightgray',linewidth=2.0)

plt.title('Vrev -80 mV and gsyn = 100p  ->  %.2f ± %.2f mV' % (np.mean(gmax1),np.std(gmax1)), fontsize=14)
plt.plot(np.mean(alltraces, axis=0)-np.mean(alltraces, axis=0)[0],color = 'black', linewidth=4.0)
# plt.legend(loc='upper right', bbox_to_anchor=(0.95, 1.0))
plt.xlim(500,12000)
plt.ylim(-0.25,1.5)
plt.xlabel('Time (ms)', fontsize=16)
plt.ylabel('PSP (mV)', fontsize=16)
plt.xticks(range(1000,12000,2000), range(0,1100,200), fontsize=14);
plt.yticks([0,1,2], fontsize=14); 

plt.savefig('../info/syn_gmax_L5TTPC_L5TTPC.png', facecolor = 'white' , dpi=300)

# %%
# (0.8355167606552806, 25)

# %%
np.mean(gmax1), np.size(gmax1)
# Out:
# (0.9256953124220527, 50)

# %% [markdown]
# <!-- Connection type	s-type	in vitro PSP amplitude (mV; mean ± SD)	in silico PSP amplitude (mV; mean ± SD)	Input data sources
# L5TTPC-L5MC	E1	0.28 ± 0.3	0.28 ± 0.18	Silberberg & Markram, 2007
# L5MC-L5TTPC	I2	0.5 ± 0.3	0.57 ± 0.5	Silberberg & Markram, 2007
# L4SS-L23PC	E2	0.7 ± 0.6	0.7 ± 0.9	Feldmeyer et al. 2002
# L5STPC-L5STPC	E2	0.9 ± 0.7	0.91 ± 0.8	Le Bé et al. 2007
# L5UTPC-L5UTPC	E2	0.9 ± 0.7	0.91 ± 0.8	Le Bé et al. 2007
# L23PC-L23PC	E2	1 ± 0.7	1 ± 0.3	Feldmeyer et al. 2006
# L23LBC-L23PC	I2	1.2 ± 1.1	1.2 ± 1.02	Blatow et al. 2003
# L23NBC-L23PC	I2	1.2 ± 1.1	1.2 ± 1.02	Blatow et al. 2003
# L5TTPC-L5TTPC	E2	1.3 ± 1.1	1.2 ± 0.43	Markram et al. 1997
# L4SS-L4SS	E2	1.6 ± 1.0	1.9 ± 1.5	Feldmeyer et al. 1999
# L4SP-L4SP	E2	1.6 ± 1.0	1.9 ± 1.5	Feldmeyer et al. 1999
# L4PC-L4PC	E2	1.6 ± 1.0	1.9 ± 1.5	Feldmeyer et al. 1999
# L5TTPC-L5SBC	E2	2.1 ± 1.0	1.96 ± 0.67	Angulo et al. 1999 -->
# ![image.png](attachment:image.png)

# %%
Connectiontype = ['L5TTPC_L5MC_E1', 'L5MC_L5TTPC_I2', 'L4SS_L23PC_E2', 'L5STPC_L5STPC_E2', 'L5UTPC_L5UTPC_E2', 'L23PC_L23PC_E2', 
                  'L23LBC_L23PC_I2', 'L23NBC_L23PC_I2', 'L5TTPC_L5TTPC_E2', 'L4SS_L4SS_E2', 'L4SP_L4SP_E2', 'L4PC_L4PC_E2', 'L5TTPC_L5SBC_E2']

# %%
table13c = [0.28, 0.3, 0.28, 0.18, 0.50, 0.3, 0.57, 0.50, 0.70, 0.6, 0.70, 0.90, 0.90, 0.7, 0.91, 0.80, 0.90, 0.7, 0.91, 0.80, 
            1.00, 0.7, 1.00, 0.30, 1.20, 1.1, 1.20, 1.02, 1.20, 1.1, 1.20, 1.02, 1.30, 1.1, 1.20, 0.43, 1.60, 1.0, 1.90, 1.50, 
            1.60, 1.0, 1.90, 1.50, 1.60, 1.0, 1.90, 1.50, 2.10, 1.0, 1.96, 0.67]

# %%
x = []
sx = []
y = []
sy = []

for ii in range(13):
    print(Connectiontype[ii],table13c[4*ii],table13c[4*ii+1],table13c[4*ii+2],table13c[4*ii+3])
    x.append(table13c[4*ii])
    sx.append(table13c[4*ii+1])
    y.append(table13c[4*ii+2])
    sy.append(table13c[4*ii+3])

# %%
import matplotlib.pyplot as plt

# a = [1, 3, 5, 7]
# b = [11, -2, 4, 19]
# plt.scatter(a, b)


# c = [1, 3, 2, 1]
# d = [1, 3, 2, 1]

# you can use color ="r" for red or skip to default as blue
# plt.errorbar(x, y, xerr=sx, yerr=sy, fmt="o", color="r")
plt.scatter(x, y)

plt.show()
