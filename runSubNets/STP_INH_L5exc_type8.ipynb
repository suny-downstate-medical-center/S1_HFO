# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# # Input-output properties cells

# %%
import numpy as np
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
rootFolder = '/home/fernando/Dropbox/SUNY/2022/S1_netpyne/sim/'
# rootFolder = os.getcwd()
os.chdir(rootFolder)
print(rootFolder)
folder = os.listdir('cell_data/')
folder = sorted(folder)

savedata = 1 # Save Netpyne and BBP soma_voltage
# Out:
# /home/fernando/Dropbox/SUNY/2022/S1_netpyne/sim/

# %%
# !nrnivmodl mod

# %%
def loadTemplateName(cellnumber):     
    f = open(outFolder+'/template.hoc', 'r')
    for line in f.readlines():
        if 'begintemplate' in line:
            templatename = str(line)     
    templatename=templatename[:-1]        
    templatename=templatename[14:]
    return templatename

# %% [markdown]
# ## Netpyne

# %%
from netpyne import specs, sim   

# Network parameters
netParams = specs.NetParams()  # object of class NetParams to store the network parameters

# %%
# %matplotlib inline

# %%
## cfg  
cfg = specs.SimConfig()					            # object of class SimConfig to store simulation configuration
cfg.duration = 4000.0 						            # Duration of the simulation, in ms
cfg.dt = 0.05								                # Internal integration timestep to use
cfg.verbose = False							                # Show detailed messages 
cfg.recordTraces = {'V_soma':{'sec':'soma','loc':0.5,'var':'v'}}  # Dict with traces to record
cfg.recordStep = 0.1 			
cfg.printRunTime = 0.1 # in sec			

cfg.seeds = {'conn': 1, 'stim': 1, 'loc': 1} 
cfg.hParams = {'celsius': 34, 'v_init': -71.0}  
cfg.verbose = False
cfg.createNEURONObj = True
cfg.createPyStruct = True  
#------------------------------------------------------------------------------
# Saving
#------------------------------------------------------------------------------
cfg.filename = 'model_output'  			# Set file output name
cfg.savePickle = False         	## Save pkl file
cfg.saveJson = False	           	## Save json file
cfg.saveDataInclude = ['simData'] ## 'simData' , 'simConfig', 'netParams'
cfg.backupCfgFile = None 		##  
cfg.gatherOnlySimData = False	##  
cfg.saveCellSecs = False			
cfg.saveCellConns = True	

cfg.analysis['plotTraces'] = {'include': [i for i in range(100)], 'oneFigPer': 'trace', 'overlay': True, 'timeRange': [0,4000], 'saveFig': False, 'showFig': True, 'figSize':(12,4)} # Plot recorded traces for this list of cells
# cfg.analysis['plotShape'] = {'includePre': [0],'includePre': [0], 'saveFig': True, 'showFig': True, 'figSize':(12,12)}

# %%
# for i,metype in enumerate(folder):
#     print(i,metype)
folder[755:775]
# Out:
# ['L5_STPC_cADpyr232_1',
#  'L5_STPC_cADpyr232_2',
#  'L5_STPC_cADpyr232_3',
#  'L5_STPC_cADpyr232_4',
#  'L5_STPC_cADpyr232_5',
#  'L5_TTPC1_cADpyr232_1',
#  'L5_TTPC1_cADpyr232_2',
#  'L5_TTPC1_cADpyr232_3',
#  'L5_TTPC1_cADpyr232_4',
#  'L5_TTPC1_cADpyr232_5',
#  'L5_TTPC2_cADpyr232_1',
#  'L5_TTPC2_cADpyr232_2',
#  'L5_TTPC2_cADpyr232_3',
#  'L5_TTPC2_cADpyr232_4',
#  'L5_TTPC2_cADpyr232_5',
#  'L5_UTPC_cADpyr232_1',
#  'L5_UTPC_cADpyr232_2',
#  'L5_UTPC_cADpyr232_3',
#  'L5_UTPC_cADpyr232_4',
#  'L5_UTPC_cADpyr232_5']

# %%
#------------------------------------------------------------------------------
# Cell parameters
#------------------------------------------------------------------------------
#StochKv_deterministic.mod
for cellnumber in range(755,775):
    cellName = folder[cellnumber]
    outFolder = rootFolder+'/cell_data/'+folder[cellnumber]
    cellTemplateName = loadTemplateName(cellnumber)
    cellRule = netParams.importCellParams(label=cellName, somaAtOrigin=False,
        conds={'cellType': cellName, 'cellModel': 'HH_full'},
        fileName='cellwrapper.py',
        cellName='loadCell',
        cellInstance = True,
        cellArgs={'cellName': cellName, 'cellTemplateName': cellTemplateName})
# Out:
# NEURON: morphology_d16b0be14e : a template cannot be redefined
#  in morphology.hoc near line 34
#  begintemplate morphology_d16b0be14e
#                                    ^
#         xopen("morphology.hoc")
#       execute1("{xopen("mo...")
#     load_file("morphology.hoc")
#   xopen("template.hoc")
# NEURON: cADpyr232_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate cADpyr232_biophys
#                                ^
#         xopen("biophysics.hoc")
#       execute1("{xopen("bi...")
#     load_file("biophysics.hoc")
#   xopen("template.hoc")
# NEURON: synapses_d16b0be14e : a template cannot be redefined
#  in synapses.hoc near line 31
#  begintemplate synapses_d16b0be14e
#                                  ^
#         xopen("synapses.hoc")
#       execute1("{xopen("sy...")
#     load_file("synapses/s...")
#   xopen("template.hoc")
# 	0
# 	0
# 	0
# cADpyr232_L5_STPC_d16b0be14e[0]
# NEURON: cADpyr232_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate cADpyr232_biophys
#                                ^
#         xopen("biophysics.hoc")
# 	1
# 	1
# 	1
# cADpyr232_L5_STPC_d63221b7a8[0]
# NEURON: cADpyr232_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate cADpyr232_biophys
#                                ^
#         xopen("biophysics.hoc")
# 	1
# 	1
# 	1
# cADpyr232_L5_STPC_a78c3cbca8[0]
# NEURON: cADpyr232_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate cADpyr232_biophys
#                                ^
#         xopen("biophysics.hoc")
# 	1
# 	1
# 	1
# cADpyr232_L5_STPC_4ec7a36770[0]
# NEURON: cADpyr232_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate cADpyr232_biophys
#                                ^
#         xopen("biophysics.hoc")
# 	1
# 	1
# 	1
# cADpyr232_L5_STPC_6d41d50fcb[0]
# NEURON: cADpyr232_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate cADpyr232_biophys
#                                ^
#         xopen("biophysics.hoc")
# 	1
# 	1
# 	1
# cADpyr232_L5_TTPC1_0fb1ca4724[0]
# NEURON: cADpyr232_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate cADpyr232_biophys
#                                ^
#         xopen("biophysics.hoc")
# 	1
# 	1
# 	1
# cADpyr232_L5_TTPC1_fc944c2cf3[0]
# NEURON: cADpyr232_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate cADpyr232_biophys
#                                ^
#         xopen("biophysics.hoc")
# 	1
# 	1
# 	1
# cADpyr232_L5_TTPC1_da1088139b[0]
# NEURON: cADpyr232_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate cADpyr232_biophys
#                                ^
#         xopen("biophysics.hoc")
# 	1
# 	1
# 	1
# cADpyr232_L5_TTPC1_ded64abc4d[0]
# NEURON: cADpyr232_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate cADpyr232_biophys
#                                ^
#         xopen("biophysics.hoc")
# 	1
# 	1
# 	1
# cADpyr232_L5_TTPC1_b6836fcf6f[0]
# NEURON: cADpyr232_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate cADpyr232_biophys
#                                ^
#         xopen("biophysics.hoc")
# 	1
# 	1
# 	1
# cADpyr232_L5_TTPC2_8052133265[0]
# NEURON: cADpyr232_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate cADpyr232_biophys
#                                ^
#         xopen("biophysics.hoc")
# 	1
# 	1
# 	1
# cADpyr232_L5_TTPC2_a28017c6c7[0]
# NEURON: cADpyr232_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate cADpyr232_biophys
#                                ^
#         xopen("biophysics.hoc")
# 	1
# 	1
# 	1
# cADpyr232_L5_TTPC2_a467781f53[0]
# NEURON: cADpyr232_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate cADpyr232_biophys
#                                ^
#         xopen("biophysics.hoc")
# 	1
# 	1
# 	1
# cADpyr232_L5_TTPC2_c46a93702c[0]
# NEURON: cADpyr232_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate cADpyr232_biophys
#                                ^
#         xopen("biophysics.hoc")
# 	1
# 	1
# 	1
# cADpyr232_L5_TTPC2_8bab918b58[0]
# NEURON: cADpyr232_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate cADpyr232_biophys
#                                ^
#         xopen("biophysics.hoc")
# 	1
# 	1
# 	1
# cADpyr232_L5_UTPC_5e3840b51e[0]
# NEURON: cADpyr232_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate cADpyr232_biophys
#                                ^
#         xopen("biophysics.hoc")
# 	1
# 	1
# 	1
# cADpyr232_L5_UTPC_34f655e7f8[0]
# NEURON: cADpyr232_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate cADpyr232_biophys
#                                ^
#         xopen("biophysics.hoc")
# 	1
# 	1
# 	1
# cADpyr232_L5_UTPC_d736225429[0]
# NEURON: cADpyr232_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate cADpyr232_biophys
#                                ^
#         xopen("biophysics.hoc")
# 	1
# 	1
# 	1
# cADpyr232_L5_UTPC_da1143b075[0]
# NEURON: cADpyr232_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate cADpyr232_biophys
#                                ^
#         xopen("biophysics.hoc")
# 	1
# 	1
# 	1
# cADpyr232_L5_UTPC_79412a7e72[0]

# %%
for cellnumber in range(755,775):
    # ---------------------------------------------------------------------------------------------------- #
    cellName = folder[cellnumber]
    outFolder = rootFolder+'/cell_data/'+folder[cellnumber]
    cellTemplateName = loadTemplateName(cellnumber)
    
    # ---------------------------------------------------------------------------------------------------- #
    netParams.renameCellParamsSec(label=cellName, oldSec='soma_0', newSec='soma')
    
    for secname2 in netParams.cellParams[cellName]['secLists'].keys():
        if 'soma_0' in netParams.cellParams[cellName]['secLists'][secname2]:
            print(cellName,secname2,netParams.cellParams[cellName]['secLists'][secname2][0])
            netParams.cellParams[cellName]['secLists'][secname2][0] = 'soma'
    # ---------------------------------------------------------------------------------------------------- #
    
    nonSpiny = ['axon_0', 'axon_1']
    netParams.cellParams[cellName]['secLists']['spiny'] = [sec for sec in netParams.cellParams[cellName]['secLists']['all'] if sec not in nonSpiny]
    nonSpinyEE = ['axon_0', 'axon_1', 'soma']
    netParams.cellParams[cellName]['secLists']['spinyEE'] = [sec for sec in netParams.cellParams[cellName]['secLists']['all'] if sec not in nonSpinyEE]    
    
    # ---------------------------------------------------------------------------------------------------- #
    for ii in range(5):
        netParams.popParams[cellName + '_' + str(ii)] = {'cellType': cellName, 'numCells': 1, 'cellModel': 'HH_full'}
# Out:
# L5_STPC_cADpyr232_1 all soma_0
# L5_STPC_cADpyr232_1 somatic soma_0
# L5_STPC_cADpyr232_2 all soma_0
# L5_STPC_cADpyr232_2 somatic soma_0
# L5_STPC_cADpyr232_3 all soma_0
# L5_STPC_cADpyr232_3 somatic soma_0
# L5_STPC_cADpyr232_4 all soma_0
# L5_STPC_cADpyr232_4 somatic soma_0
# L5_STPC_cADpyr232_5 all soma_0
# L5_STPC_cADpyr232_5 somatic soma_0
# L5_TTPC1_cADpyr232_1 all soma_0
# L5_TTPC1_cADpyr232_1 somatic soma_0
# L5_TTPC1_cADpyr232_2 all soma_0
# L5_TTPC1_cADpyr232_2 somatic soma_0
# L5_TTPC1_cADpyr232_3 all soma_0
# L5_TTPC1_cADpyr232_3 somatic soma_0
# L5_TTPC1_cADpyr232_4 all soma_0
# L5_TTPC1_cADpyr232_4 somatic soma_0
# L5_TTPC1_cADpyr232_5 all soma_0
# L5_TTPC1_cADpyr232_5 somatic soma_0
# L5_TTPC2_cADpyr232_1 all soma_0
# L5_TTPC2_cADpyr232_1 somatic soma_0
# L5_TTPC2_cADpyr232_2 all soma_0
# L5_TTPC2_cADpyr232_2 somatic soma_0
# L5_TTPC2_cADpyr232_3 all soma_0
# L5_TTPC2_cADpyr232_3 somatic soma_0
# L5_TTPC2_cADpyr232_4 all soma_0
# L5_TTPC2_cADpyr232_4 somatic soma_0
# L5_TTPC2_cADpyr232_5 all soma_0
# L5_TTPC2_cADpyr232_5 somatic soma_0
# L5_UTPC_cADpyr232_1 all soma_0
# L5_UTPC_cADpyr232_1 somatic soma_0
# L5_UTPC_cADpyr232_2 all soma_0
# L5_UTPC_cADpyr232_2 somatic soma_0
# L5_UTPC_cADpyr232_3 all soma_0
# L5_UTPC_cADpyr232_3 somatic soma_0
# L5_UTPC_cADpyr232_4 all soma_0
# L5_UTPC_cADpyr232_4 somatic soma_0
# L5_UTPC_cADpyr232_5 all soma_0
# L5_UTPC_cADpyr232_5 somatic soma_0

# %%
for cellnumber in range(755,775):
    cellName = folder[cellnumber]
    print(netParams.cellParams[cellName]['secLists']['basal'][-1])
# Out:
# dend_41
# dend_45
# dend_59
# dend_45
# dend_59
# dend_112
# dend_112
# dend_112
# dend_112
# dend_82
# dend_79
# dend_95
# dend_95
# dend_95
# dend_95
# dend_42
# dend_42
# dend_42
# dend_60
# dend_63

# %%
# create custom list of spike times
# spkTimes = [2000,2500,3000,3500,4000,4500]
spkTimes = [500,2500,2550,2600,2650,2700,2750,2800,2850,2900,3400]

netParams.popParams['presyn'] = {'cellModel': 'VecStim', 'numCells': 1, 'spkTimes': spkTimes}  # VecStim with spike times

# %%
netParams.cellParams.keys()
# Out:
# odict_keys(['L5_STPC_cADpyr232_1', 'L5_STPC_cADpyr232_2', 'L5_STPC_cADpyr232_3', 'L5_STPC_cADpyr232_4', 'L5_STPC_cADpyr232_5', 'L5_TTPC1_cADpyr232_1', 'L5_TTPC1_cADpyr232_2', 'L5_TTPC1_cADpyr232_3', 'L5_TTPC1_cADpyr232_4', 'L5_TTPC1_cADpyr232_5', 'L5_TTPC2_cADpyr232_1', 'L5_TTPC2_cADpyr232_2', 'L5_TTPC2_cADpyr232_3', 'L5_TTPC2_cADpyr232_4', 'L5_TTPC2_cADpyr232_5', 'L5_UTPC_cADpyr232_1', 'L5_UTPC_cADpyr232_2', 'L5_UTPC_cADpyr232_3', 'L5_UTPC_cADpyr232_4', 'L5_UTPC_cADpyr232_5'])

# %%
list(netParams.popParams.keys())[0:-1]
# Out:
# ['L5_STPC_cADpyr232_1_0',
#  'L5_STPC_cADpyr232_1_1',
#  'L5_STPC_cADpyr232_1_2',
#  'L5_STPC_cADpyr232_1_3',
#  'L5_STPC_cADpyr232_1_4',
#  'L5_STPC_cADpyr232_2_0',
#  'L5_STPC_cADpyr232_2_1',
#  'L5_STPC_cADpyr232_2_2',
#  'L5_STPC_cADpyr232_2_3',
#  'L5_STPC_cADpyr232_2_4',
#  'L5_STPC_cADpyr232_3_0',
#  'L5_STPC_cADpyr232_3_1',
#  'L5_STPC_cADpyr232_3_2',
#  'L5_STPC_cADpyr232_3_3',
#  'L5_STPC_cADpyr232_3_4',
#  'L5_STPC_cADpyr232_4_0',
#  'L5_STPC_cADpyr232_4_1',
#  'L5_STPC_cADpyr232_4_2',
#  'L5_STPC_cADpyr232_4_3',
#  'L5_STPC_cADpyr232_4_4',
#  'L5_STPC_cADpyr232_5_0',
#  'L5_STPC_cADpyr232_5_1',
#  'L5_STPC_cADpyr232_5_2',
#  'L5_STPC_cADpyr232_5_3',
#  'L5_STPC_cADpyr232_5_4',
#  'L5_TTPC1_cADpyr232_1_0',
#  'L5_TTPC1_cADpyr232_1_1',
#  'L5_TTPC1_cADpyr232_1_2',
#  'L5_TTPC1_cADpyr232_1_3',
#  'L5_TTPC1_cADpyr232_1_4',
#  'L5_TTPC1_cADpyr232_2_0',
#  'L5_TTPC1_cADpyr232_2_1',
#  'L5_TTPC1_cADpyr232_2_2',
#  'L5_TTPC1_cADpyr232_2_3',
#  'L5_TTPC1_cADpyr232_2_4',
#  'L5_TTPC1_cADpyr232_3_0',
#  'L5_TTPC1_cADpyr232_3_1',
#  'L5_TTPC1_cADpyr232_3_2',
#  'L5_TTPC1_cADpyr232_3_3',
#  'L5_TTPC1_cADpyr232_3_4',
#  'L5_TTPC1_cADpyr232_4_0',
#  'L5_TTPC1_cADpyr232_4_1',
#  'L5_TTPC1_cADpyr232_4_2',
#  'L5_TTPC1_cADpyr232_4_3',
#  'L5_TTPC1_cADpyr232_4_4',
#  'L5_TTPC1_cADpyr232_5_0',
#  'L5_TTPC1_cADpyr232_5_1',
#  'L5_TTPC1_cADpyr232_5_2',
#  'L5_TTPC1_cADpyr232_5_3',
#  'L5_TTPC1_cADpyr232_5_4',
#  'L5_TTPC2_cADpyr232_1_0',
#  'L5_TTPC2_cADpyr232_1_1',
#  'L5_TTPC2_cADpyr232_1_2',
#  'L5_TTPC2_cADpyr232_1_3',
#  'L5_TTPC2_cADpyr232_1_4',
#  'L5_TTPC2_cADpyr232_2_0',
#  'L5_TTPC2_cADpyr232_2_1',
#  'L5_TTPC2_cADpyr232_2_2',
#  'L5_TTPC2_cADpyr232_2_3',
#  'L5_TTPC2_cADpyr232_2_4',
#  'L5_TTPC2_cADpyr232_3_0',
#  'L5_TTPC2_cADpyr232_3_1',
#  'L5_TTPC2_cADpyr232_3_2',
#  'L5_TTPC2_cADpyr232_3_3',
#  'L5_TTPC2_cADpyr232_3_4',
#  'L5_TTPC2_cADpyr232_4_0',
#  'L5_TTPC2_cADpyr232_4_1',
#  'L5_TTPC2_cADpyr232_4_2',
#  'L5_TTPC2_cADpyr232_4_3',
#  'L5_TTPC2_cADpyr232_4_4',
#  'L5_TTPC2_cADpyr232_5_0',
#  'L5_TTPC2_cADpyr232_5_1',
#  'L5_TTPC2_cADpyr232_5_2',
#  'L5_TTPC2_cADpyr232_5_3',
#  'L5_TTPC2_cADpyr232_5_4',
#  'L5_UTPC_cADpyr232_1_0',
#  'L5_UTPC_cADpyr232_1_1',
#  'L5_UTPC_cADpyr232_1_2',
#  'L5_UTPC_cADpyr232_1_3',
#  'L5_UTPC_cADpyr232_1_4',
#  'L5_UTPC_cADpyr232_2_0',
#  'L5_UTPC_cADpyr232_2_1',
#  'L5_UTPC_cADpyr232_2_2',
#  'L5_UTPC_cADpyr232_2_3',
#  'L5_UTPC_cADpyr232_2_4',
#  'L5_UTPC_cADpyr232_3_0',
#  'L5_UTPC_cADpyr232_3_1',
#  'L5_UTPC_cADpyr232_3_2',
#  'L5_UTPC_cADpyr232_3_3',
#  'L5_UTPC_cADpyr232_3_4',
#  'L5_UTPC_cADpyr232_4_0',
#  'L5_UTPC_cADpyr232_4_1',
#  'L5_UTPC_cADpyr232_4_2',
#  'L5_UTPC_cADpyr232_4_3',
#  'L5_UTPC_cADpyr232_4_4',
#  'L5_UTPC_cADpyr232_5_0',
#  'L5_UTPC_cADpyr232_5_1',
#  'L5_UTPC_cADpyr232_5_2',
#  'L5_UTPC_cADpyr232_5_3',
#  'L5_UTPC_cADpyr232_5_4']

# %%
# import scipy.stats as stats
# lower, upper = 0.48, 0.52
# mu, sigma = 0.50, 0.02
# X = stats.truncnorm(
#     (lower - mu) / sigma, (upper - mu) / sigma, loc=mu, scale=sigma)
# Use = X.rvs(100)

# --------------------------------------------------------------------------------------#
#BBP	gsyn	decay	       use	     dep	 fac	types	rules
#8	0.75±0.32	8.30±2.20	0.25±0.130	706±405	21±9	I2-IE	BTC-DBC-BP:Excitatory

for ii in range(100):
    netParams.synMechParams['INH:L5_PC'+str(ii+1)] = {'mod': 'DetGABAAB',
                                         'Use': 0.25,
                                         'Dep': 706.0,
                                         'Fac': 21.0,
                                         'tau_d_GABAA': 8.30,
                                         'tau_r_GABAA': 0.2,   #rng.lognormal(0.2, 0.1) in synapses.hoc  
                                         'tau_d_GABAB': 260.9,
                                         'tau_r_GABAB': 3.5,
                                         'e_GABAA': -80.0, #= -80   (mV) : GABAA reversal potential    
                                            }

# %%
import random

# lower, upper = 0.5, 1.0
# mu, sigma = 0.75, 0.32
# X = stats.truncnorm(
#     (lower - mu) / sigma, (upper - mu) / sigma, loc=mu, scale=sigma)

# weight = X.rvs(100)

## Cell connectivity rules
for ii in range(100):
    
    listsecs = random.sample(netParams.cellParams[cellName]['secLists']['spiny'], len(netParams.cellParams[cellName]['secLists']['spiny']))

    netParams.connParams['pre->post'+str(ii+1)] = { 
            'preConds': {'pop': 'presyn'},
            'postConds': {'pop': list(netParams.popParams.keys())[ii]},
            'sec': listsecs,                  # target postsyn section
            'synMech': 'INH:L5_PC'+str(ii+1),              # target synaptic mechanism
            'weight': 0.75, # weight[ii], # # synaptic weight 
            'synsPerConn': 15, 
            'delay': 0.05}

# %%
sim.initialize(
    simConfig = cfg, 	
    netParams = netParams)  				# create network object and set cfg and net params
sim.net.createPops()               			# instantiate network populations
sim.net.createCells()              			# instantiate network cells based on defined populations
sim.net.connectCells()            			# create connections between cells based on params
# Out:
# Start time:  2023-04-18 15:28:08.178032
#
# Creating network of 101 cell populations on 1 hosts...
#   Number of cells on node 0: 101
#   Done; cell creation time = 5.21 s.
# Making connections...
#   Number of connections on node 0: 100
#   Number of synaptic contacts on node 0: 1500
#   Done; cell connection time = 0.11 s.
# [[{preGid: 100, sec: 'apic_6', loc: 0.5598062624286517, synMech: 'INH:L5_PC1', weight: 0.75, delay: 0.05, label: 'pre->post1', preLoc: 0.5, hObj: NetCon[0]},
#   {preGid: 100, sec: 'dend_40', loc: 0.7836997678957877, synMech: 'INH:L5_PC1', weight: 0.75, delay: 0.05, label: 'pre->post1', preLoc: 0.5, hObj: NetCon[1]},
#   {preGid: 100, sec: 'apic_12', loc: 0.6481988992463417, synMech: 'INH:L5_PC1', weight: 0.75, delay: 0.05, label: 'pre->post1', preLoc: 0.5, hObj: NetCon[2]},
#   {preGid: 100, sec: 'dend_2', loc: 0.7330268289993874, synMech: 'INH:L5_PC1', weight: 0.75, delay: 0.05, label: 'pre->post1', preLoc: 0.5, hObj: NetCon[3]},
#   {preGid: 100, sec: 'dend_41', loc: 0.46274756829692876, synMech: 'INH:L5_PC1', weight: 0.75, delay: 0.05, label: 'pre->post1', preLoc: 0.5, hObj: NetCon[4]},
#   {preGid: 100, sec: 'dend_37', loc: 0.40545111940047573, synMech: 'INH:L5_PC1', weight: 0.75, delay: 0.05, label: 'pre->post1', preLoc: 0.5, hObj: NetCon[5]},
#   {preGid: 100, sec: 'dend_20', loc: 0.9582360708266328, synMech: 'INH:L5_PC1', weight: 0.75, delay: 0.05, label: 'pre->post1', preLoc: 0.5, hObj: NetCon[6]},
#   {preGid: 100, sec: 'apic_7', loc: 0.0787982733078868, synMech: 'INH:L5_PC1', weight: 0.75, delay: 0.05, label: 'pre->post1', preLoc: 0.5, hObj: NetCon[7]},
#   {preGid: 100, sec: 'apic_34', loc: 0.9903721736327742, synMech: 'INH:L5_PC1', weight: 0.75, delay: 0.05, label: 'pre->post1', preLoc: 0.5, hObj: NetCon[8]},
#   {preGid: 100, sec: 'apic_50', loc: 0.5913662076552035, synMech: 'INH:L5_PC1', weight: 0.75, delay: 0.05, label: 'pre->post1', preLoc: 0.5, hObj: NetCon[9]},
#   {preGid: 100, sec: 'dend_22', loc: 0.6581759408833702, synMech: 'INH:L5_PC1', weight: 0.75, delay: 0.05, label: 'pre->post1', preLoc: 0.5, hObj: NetCon[10]},
#   {preGid: 100, sec: 'dend_14', loc: 0.9422202855713073, synMech: 'INH:L5_PC1', weight: 0.75, delay: 0.05, label: 'pre->post1', preLoc: 0.5, hObj: NetCon[11]},
#   {preGid: 100, sec: 'apic_59', loc: 0.6216336319148971, synMech: 'INH:L5_PC1', weight: 0.75, delay: 0.05, label: 'pre->post1', preLoc: 0.5, hObj: NetCon[12]},
#   {preGid: 100, sec: 'apic_35', loc: 0.06672621706704293, synMech: 'INH:L5_PC1', weight: 0.75, delay: 0.05, label: 'pre->post1', preLoc: 0.5, hObj: NetCon[13]},
#   {preGid: 100, sec: 'apic_22', loc: 0.3993935629091685, synMech: 'INH:L5_PC1', weight: 0.75, delay: 0.05, label: 'pre->post1', preLoc: 0.5, hObj: NetCon[14]}],
#  [{preGid: 100, sec: 'dend_2', loc: 0.8426915865279507, synMech: 'INH:L5_PC2', weight: 0.75, delay: 0.05, label: 'pre->post2', preLoc: 0.5, hObj: NetCon[15]},
#   {preGid: 100, sec: 'apic_49', loc: 0.9329259090157868, synMech: 'INH:L5_PC2', weight: 0.75, delay: 0.05, label: 'pre->post2', preLoc: 0.5, hObj: NetCon[16]},
#   {preGid: 100, sec: 'apic_19', loc: 0.8808941273402057, synMech: 'INH:L5_PC2', weight: 0.75, delay: 0.05, label: 'pre->post2', preLoc: 0.5, hObj: NetCon[17]},
#   {preGid: 100, sec: 'dend_18', loc: 0.6301364917801484, synMech: 'INH:L5_PC2', weight: 0.75, delay: 0.05, label: 'pre->post2', preLoc: 0.5, hObj: NetCon[18]},
#   {preGid: 100, sec: 'dend_35', loc: 0.46299676446034993, synMech: 'INH:L5_PC2', weight: 0.75, delay: 0.05, label: 'pre->post2', preLoc: 0.5, hObj: NetCon[19]},
#   {preGid: 100, sec: 'dend_20', loc: 0.6703788986612088, synMech: 'INH:L5_PC2', weight: 0.75, delay: 0.05, label: 'pre->post2', preLoc: 0.5, hObj: NetCon[20]},
#   {preGid: 100, sec: 'apic_16', loc: 0.6659713221753515, synMech: 'INH:L5_PC2', weight: 0.75, delay: 0.05, label: 'pre->post2', preLoc: 0.5, hObj: NetCon[21]},
#   {preGid: 100, sec: 'apic_21', loc: 0.2689067482978947, synMech: 'INH:L5_PC2', weight: 0.75, delay: 0.05, label: 'pre->post2', preLoc: 0.5, hObj: NetCon[22]},
#   {preGid: 100, sec: 'dend_10', loc: 0.28349344274927357, synMech: 'INH:L5_PC2', weight: 0.75, delay: 0.05, label: 'pre->post2', preLoc: 0.5, hObj: NetCon[23]},
#   {preGid: 100, sec: 'apic_59', loc: 0.34541362964233896, synMech: 'INH:L5_PC2', weight: 0.75, delay: 0.05, label: 'pre->post2', preLoc: 0.5, hObj: NetCon[24]},
#   {preGid: 100, sec: 'apic_30', loc: 0.11275853817057567, synMech: 'INH:L5_PC2', weight: 0.75, delay: 0.05, label: 'pre->post2', preLoc: 0.5, hObj: NetCon[25]},
#   {preGid: 100, sec: 'dend_16', loc: 0.08611952625261042, synMech: 'INH:L5_PC2', weight: 0.75, delay: 0.05, label: 'pre->post2', preLoc: 0.5, hObj: NetCon[26]},
#   {preGid: 100, sec: 'dend_22', loc: 0.8370068704779817, synMech: 'INH:L5_PC2', weight: 0.75, delay: 0.05, label: 'pre->post2', preLoc: 0.5, hObj: NetCon[27]},
#   {preGid: 100, sec: 'dend_21', loc: 0.046779641759615395, synMech: 'INH:L5_PC2', weight: 0.75, delay: 0.05, label: 'pre->post2', preLoc: 0.5, hObj: NetCon[28]},
#   {preGid: 100, sec: 'apic_6', loc: 0.40049602158938685, synMech: 'INH:L5_PC2', weight: 0.75, delay: 0.05, label: 'pre->post2', preLoc: 0.5, hObj: NetCon[29]}],
#  [{preGid: 100, sec: 'apic_66', loc: 0.21043691449815582, synMech: 'INH:L5_PC3', weight: 0.75, delay: 0.05, label: 'pre->post3', preLoc: 0.5, hObj: NetCon[30]},
#   {preGid: 100, sec: 'dend_16', loc: 0.5203370876099721, synMech: 'INH:L5_PC3', weight: 0.75, delay: 0.05, label: 'pre->post3', preLoc: 0.5, hObj: NetCon[31]},
#   {preGid: 100, sec: 'apic_60', loc: 0.8974463422514282, synMech: 'INH:L5_PC3', weight: 0.75, delay: 0.05, label: 'pre->post3', preLoc: 0.5, hObj: NetCon[32]},
#   {preGid: 100, sec: 'apic_40', loc: 0.478627892165395, synMech: 'INH:L5_PC3', weight: 0.75, delay: 0.05, label: 'pre->post3', preLoc: 0.5, hObj: NetCon[33]},
#   {preGid: 100, sec: 'dend_2', loc: 0.6056512535910903, synMech: 'INH:L5_PC3', weight: 0.75, delay: 0.05, label: 'pre->post3', preLoc: 0.5, hObj: NetCon[34]},
#   {preGid: 100, sec: 'apic_47', loc: 0.3521122008474988, synMech: 'INH:L5_PC3', weight: 0.75, delay: 0.05, label: 'pre->post3', preLoc: 0.5, hObj: NetCon[35]},
#   {preGid: 100, sec: 'dend_25', loc: 0.368973530730776, synMech: 'INH:L5_PC3', weight: 0.75, delay: 0.05, label: 'pre->post3', preLoc: 0.5, hObj: NetCon[36]},
#   {preGid: 100, sec: 'apic_18', loc: 0.9274049593370581, synMech: 'INH:L5_PC3', weight: 0.75, delay: 0.05, label: 'pre->post3', preLoc: 0.5, hObj: NetCon[37]},
#   {preGid: 100, sec: 'apic_49', loc: 0.23445772622486477, synMech: 'INH:L5_PC3', weight: 0.75, delay: 0.05, label: 'pre->post3', preLoc: 0.5, hObj: NetCon[38]},
#   {preGid: 100, sec: 'apic_50', loc: 0.9394979205938043, synMech: 'INH:L5_PC3', weight: 0.75, delay: 0.05, label: 'pre->post3', preLoc: 0.5, hObj: NetCon[39]},
#   {preGid: 100, sec: 'dend_20', loc: 0.42380327432956394, synMech: 'INH:L5_PC3', weight: 0.75, delay: 0.05, label: 'pre->post3', preLoc: 0.5, hObj: NetCon[40]},
#   {preGid: 100, sec: 'apic_45', loc: 0.7751812746171871, synMech: 'INH:L5_PC3', weight: 0.75, delay: 0.05, label: 'pre->post3', preLoc: 0.5, hObj: NetCon[41]},
#   {preGid: 100, sec: 'apic_22', loc: 0.6077802976788264, synMech: 'INH:L5_PC3', weight: 0.75, delay: 0.05, label: 'pre->post3', preLoc: 0.5, hObj: NetCon[42]},
#   {preGid: 100, sec: 'apic_59', loc: 0.6868157184032935, synMech: 'INH:L5_PC3', weight: 0.75, delay: 0.05, label: 'pre->post3', preLoc: 0.5, hObj: NetCon[43]},
#   {preGid: 100, sec: 'dend_40', loc: 0.12888296499624713, synMech: 'INH:L5_PC3', weight: 0.75, delay: 0.05, label: 'pre->post3', preLoc: 0.5, hObj: NetCon[44]}],
#  [{preGid: 100, sec: 'apic_21', loc: 0.7989202486026854, synMech: 'INH:L5_PC4', weight: 0.75, delay: 0.05, label: 'pre->post4', preLoc: 0.5, hObj: NetCon[45]},
#   {preGid: 100, sec: 'apic_41', loc: 0.2874533002408403, synMech: 'INH:L5_PC4', weight: 0.75, delay: 0.05, label: 'pre->post4', preLoc: 0.5, hObj: NetCon[46]},
#   {preGid: 100, sec: 'dend_1', loc: 0.46043269382643315, synMech: 'INH:L5_PC4', weight: 0.75, delay: 0.05, label: 'pre->post4', preLoc: 0.5, hObj: NetCon[47]},
#   {preGid: 100, sec: 'apic_54', loc: 0.9221060153194821, synMech: 'INH:L5_PC4', weight: 0.75, delay: 0.05, label: 'pre->post4', preLoc: 0.5, hObj: NetCon[48]},
#   {preGid: 100, sec: 'apic_20', loc: 0.9593641977820583, synMech: 'INH:L5_PC4', weight: 0.75, delay: 0.05, label: 'pre->post4', preLoc: 0.5, hObj: NetCon[49]},
#   {preGid: 100, sec: 'dend_35', loc: 0.1349480905792613, synMech: 'INH:L5_PC4', weight: 0.75, delay: 0.05, label: 'pre->post4', preLoc: 0.5, hObj: NetCon[50]},
#   {preGid: 100, sec: 'dend_20', loc: 0.956532044596601, synMech: 'INH:L5_PC4', weight: 0.75, delay: 0.05, label: 'pre->post4', preLoc: 0.5, hObj: NetCon[51]},
#   {preGid: 100, sec: 'apic_29', loc: 0.6751730907154097, synMech: 'INH:L5_PC4', weight: 0.75, delay: 0.05, label: 'pre->post4', preLoc: 0.5, hObj: NetCon[52]},
#   {preGid: 100, sec: 'dend_16', loc: 0.6276541405285404, synMech: 'INH:L5_PC4', weight: 0.75, delay: 0.05, label: 'pre->post4', preLoc: 0.5, hObj: NetCon[53]},
#   {preGid: 100, sec: 'apic_28', loc: 0.11648336229272847, synMech: 'INH:L5_PC4', weight: 0.75, delay: 0.05, label: 'pre->post4', preLoc: 0.5, hObj: NetCon[54]},
#   {preGid: 100, sec: 'dend_10', loc: 0.18596302843061557, synMech: 'INH:L5_PC4', weight: 0.75, delay: 0.05, label: 'pre->post4', preLoc: 0.5, hObj: NetCon[55]},
#   {preGid: 100, sec: 'apic_18', loc: 0.04157983502815333, synMech: 'INH:L5_PC4', weight: 0.75, delay: 0.05, label: 'pre->post4', preLoc: 0.5, hObj: NetCon[56]},
#   {preGid: 100, sec: 'dend_40', loc: 0.8003231378360696, synMech: 'INH:L5_PC4', weight: 0.75, delay: 0.05, label: 'pre->post4', preLoc: 0.5, hObj: NetCon[57]},
#   {preGid: 100, sec: 'apic_48', loc: 0.11025348663463405, synMech: 'INH:L5_PC4', weight: 0.75, delay: 0.05, label: 'pre->post4', preLoc: 0.5, hObj: NetCon[58]},
#   {preGid: 100, sec: 'apic_64', loc: 0.6457261884798821, synMech: 'INH:L5_PC4', weight: 0.75, delay: 0.05, label: 'pre->post4', preLoc: 0.5, hObj: NetCon[59]}],
#  [{preGid: 100, sec: 'apic_64', loc: 0.6944184925274459, synMech: 'INH:L5_PC5', weight: 0.75, delay: 0.05, label: 'pre->post5', preLoc: 0.5, hObj: NetCon[60]},
#   {preGid: 100, sec: 'apic_12', loc: 0.674774822766365, synMech: 'INH:L5_PC5', weight: 0.75, delay: 0.05, label: 'pre->post5', preLoc: 0.5, hObj: NetCon[61]},
#   {preGid: 100, sec: 'apic_49', loc: 0.3507307403720318, synMech: 'INH:L5_PC5', weight: 0.75, delay: 0.05, label: 'pre->post5', preLoc: 0.5, hObj: NetCon[62]},
#   {preGid: 100, sec: 'dend_14', loc: 0.326207344171926, synMech: 'INH:L5_PC5', weight: 0.75, delay: 0.05, label: 'pre->post5', preLoc: 0.5, hObj: NetCon[63]},
#   {preGid: 100, sec: 'apic_29', loc: 0.8762489481276853, synMech: 'INH:L5_PC5', weight: 0.75, delay: 0.05, label: 'pre->post5', preLoc: 0.5, hObj: NetCon[64]},
#   {preGid: 100, sec: 'apic_60', loc: 0.09728818502972503, synMech: 'INH:L5_PC5', weight: 0.75, delay: 0.05, label: 'pre->post5', preLoc: 0.5, hObj: NetCon[65]},
#   {preGid: 100, sec: 'apic_20', loc: 0.9843066251170519, synMech: 'INH:L5_PC5', weight: 0.75, delay: 0.05, label: 'pre->post5', preLoc: 0.5, hObj: NetCon[66]},
#   {preGid: 100, sec: 'dend_16', loc: 0.721712180789787, synMech: 'INH:L5_PC5', weight: 0.75, delay: 0.05, label: 'pre->post5', preLoc: 0.5, hObj: NetCon[67]},
#   {preGid: 100, sec: 'apic_18', loc: 0.8893384763124301, synMech: 'INH:L5_PC5', weight: 0.75, delay: 0.05, label: 'pre->post5', preLoc: 0.5, hObj: NetCon[68]},
#   {preGid: 100, sec: 'dend_40', loc: 0.09096288043873328, synMech: 'INH:L5_PC5', weight: 0.75, delay: 0.05, label: 'pre->post5', preLoc: 0.5, hObj: NetCon[69]},
#   {preGid: 100, sec: 'dend_4', loc: 0.16712010342459663, synMech: 'INH:L5_PC5', weight: 0.75, delay: 0.05, label: 'pre->post5', preLoc: 0.5, hObj: NetCon[70]},
#   {preGid: 100, sec: 'dend_25', loc: 0.5920274787803507, synMech: 'INH:L5_PC5', weight: 0.75, delay: 0.05, label: 'pre->post5', preLoc: 0.5, hObj: NetCon[71]},
#   {preGid: 100, sec: 'apic_0', loc: 0.8689917975462791, synMech: 'INH:L5_PC5', weight: 0.75, delay: 0.05, label: 'pre->post5', preLoc: 0.5, hObj: NetCon[72]},
#   {preGid: 100, sec: 'dend_12', loc: 0.31524753486100765, synMech: 'INH:L5_PC5', weight: 0.75, delay: 0.05, label: 'pre->post5', preLoc: 0.5, hObj: NetCon[73]},
#   {preGid: 100, sec: 'apic_59', loc: 0.17814782045746866, synMech: 'INH:L5_PC5', weight: 0.75, delay: 0.05, label: 'pre->post5', preLoc: 0.5, hObj: NetCon[74]}],
#  [{preGid: 100, sec: 'apic_31', loc: 0.7735410686012766, synMech: 'INH:L5_PC6', weight: 0.75, delay: 0.05, label: 'pre->post6', preLoc: 0.5, hObj: NetCon[75]},
#   {preGid: 100, sec: 'apic_52', loc: 0.9800408455996948, synMech: 'INH:L5_PC6', weight: 0.75, delay: 0.05, label: 'pre->post6', preLoc: 0.5, hObj: NetCon[76]},
#   {preGid: 100, sec: 'apic_17', loc: 0.9738167736256199, synMech: 'INH:L5_PC6', weight: 0.75, delay: 0.05, label: 'pre->post6', preLoc: 0.5, hObj: NetCon[77]},
#   {preGid: 100, sec: 'dend_43', loc: 0.849858698292284, synMech: 'INH:L5_PC6', weight: 0.75, delay: 0.05, label: 'pre->post6', preLoc: 0.5, hObj: NetCon[78]},
#   {preGid: 100, sec: 'dend_2', loc: 0.583550959957319, synMech: 'INH:L5_PC6', weight: 0.75, delay: 0.05, label: 'pre->post6', preLoc: 0.5, hObj: NetCon[79]},
#   {preGid: 100, sec: 'dend_16', loc: 0.3736101869384696, synMech: 'INH:L5_PC6', weight: 0.75, delay: 0.05, label: 'pre->post6', preLoc: 0.5, hObj: NetCon[80]},
#   {preGid: 100, sec: 'apic_18', loc: 0.6869746848026657, synMech: 'INH:L5_PC6', weight: 0.75, delay: 0.05, label: 'pre->post6', preLoc: 0.5, hObj: NetCon[81]},
#   {preGid: 100, sec: 'apic_4', loc: 0.35813666594285953, synMech: 'INH:L5_PC6', weight: 0.75, delay: 0.05, label: 'pre->post6', preLoc: 0.5, hObj: NetCon[82]},
#   {preGid: 100, sec: 'dend_8', loc: 0.9995337835314501, synMech: 'INH:L5_PC6', weight: 0.75, delay: 0.05, label: 'pre->post6', preLoc: 0.5, hObj: NetCon[83]},
#   {preGid: 100, sec: 'dend_11', loc: 0.0020506094691105253, synMech: 'INH:L5_PC6', weight: 0.75, delay: 0.05, label: 'pre->post6', preLoc: 0.5, hObj: NetCon[84]},
#   {preGid: 100, sec: 'dend_12', loc: 0.9998515691850594, synMech: 'INH:L5_PC6', weight: 0.75, delay: 0.05, label: 'pre->post6', preLoc: 0.5, hObj: NetCon[85]},
#   {preGid: 100, sec: 'dend_38', loc: 0.36776725516556624, synMech: 'INH:L5_PC6', weight: 0.75, delay: 0.05, label: 'pre->post6', preLoc: 0.5, hObj: NetCon[86]},
#   {preGid: 100, sec: 'apic_41', loc: 0.5921161926365098, synMech: 'INH:L5_PC6', weight: 0.75, delay: 0.05, label: 'pre->post6', preLoc: 0.5, hObj: NetCon[87]},
#   {preGid: 100, sec: 'dend_44', loc: 0.811180776870664, synMech: 'INH:L5_PC6', weight: 0.75, delay: 0.05, label: 'pre->post6', preLoc: 0.5, hObj: NetCon[88]},
#   {preGid: 100, sec: 'apic_30', loc: 0.21901850604151918, synMech: 'INH:L5_PC6', weight: 0.75, delay: 0.05, label: 'pre->post6', preLoc: 0.5, hObj: NetCon[89]}],
#  [{preGid: 100, sec: 'dend_24', loc: 0.016237283718918555, synMech: 'INH:L5_PC7', weight: 0.75, delay: 0.05, label: 'pre->post7', preLoc: 0.5, hObj: NetCon[90]},
#   {preGid: 100, sec: 'dend_19', loc: 0.6224041682650686, synMech: 'INH:L5_PC7', weight: 0.75, delay: 0.05, label: 'pre->post7', preLoc: 0.5, hObj: NetCon[91]},
#   {preGid: 100, sec: 'apic_9', loc: 0.08352613170394185, synMech: 'INH:L5_PC7', weight: 0.75, delay: 0.05, label: 'pre->post7', preLoc: 0.5, hObj: NetCon[92]},
#   {preGid: 100, sec: 'apic_13', loc: 0.36247587350377736, synMech: 'INH:L5_PC7', weight: 0.75, delay: 0.05, label: 'pre->post7', preLoc: 0.5, hObj: NetCon[93]},
#   {preGid: 100, sec: 'dend_16', loc: 0.5078958266827497, synMech: 'INH:L5_PC7', weight: 0.75, delay: 0.05, label: 'pre->post7', preLoc: 0.5, hObj: NetCon[94]},
#   {preGid: 100, sec: 'apic_49', loc: 0.5267826156329893, synMech: 'INH:L5_PC7', weight: 0.75, delay: 0.05, label: 'pre->post7', preLoc: 0.5, hObj: NetCon[95]},
#   {preGid: 100, sec: 'apic_27', loc: 0.11838367972718145, synMech: 'INH:L5_PC7', weight: 0.75, delay: 0.05, label: 'pre->post7', preLoc: 0.5, hObj: NetCon[96]},
#   {preGid: 100, sec: 'apic_40', loc: 0.4799032393599952, synMech: 'INH:L5_PC7', weight: 0.75, delay: 0.05, label: 'pre->post7', preLoc: 0.5, hObj: NetCon[97]},
#   {preGid: 100, sec: 'dend_43', loc: 0.8611586312760388, synMech: 'INH:L5_PC7', weight: 0.75, delay: 0.05, label: 'pre->post7', preLoc: 0.5, hObj: NetCon[98]},
#   {preGid: 100, sec: 'apic_19', loc: 0.47742175923033603, synMech: 'INH:L5_PC7', weight: 0.75, delay: 0.05, label: 'pre->post7', preLoc: 0.5, hObj: NetCon[99]},
#   {preGid: 100, sec: 'apic_45', loc: 0.7676389250193095, synMech: 'INH:L5_PC7', weight: 0.75, delay: 0.05, label: 'pre->post7', preLoc: 0.5, hObj: NetCon[100]},
#   {preGid: 100, sec: 'dend_41', loc: 0.1733770482731634, synMech: 'INH:L5_PC7', weight: 0.75, delay: 0.05, label: 'pre->post7', preLoc: 0.5, hObj: NetCon[101]},
#   {preGid: 100, sec: 'apic_44', loc: 0.3190204316967882, synMech: 'INH:L5_PC7', weight: 0.75, delay: 0.05, label: 'pre->post7', preLoc: 0.5, hObj: NetCon[102]},
#   {preGid: 100, sec: 'dend_30', loc: 0.6710267327935785, synMech: 'INH:L5_PC7', weight: 0.75, delay: 0.05, label: 'pre->post7', preLoc: 0.5, hObj: NetCon[103]},
#   {preGid: 100, sec: 'dend_26', loc: 0.4114204005232488, synMech: 'INH:L5_PC7', weight: 0.75, delay: 0.05, label: 'pre->post7', preLoc: 0.5, hObj: NetCon[104]}],
#  [{preGid: 100, sec: 'apic_39', loc: 0.08912607811352243, synMech: 'INH:L5_PC8', weight: 0.75, delay: 0.05, label: 'pre->post8', preLoc: 0.5, hObj: NetCon[105]},
#   {preGid: 100, sec: 'dend_38', loc: 0.4827804813068408, synMech: 'INH:L5_PC8', weight: 0.75, delay: 0.05, label: 'pre->post8', preLoc: 0.5, hObj: NetCon[106]},
#   {preGid: 100, sec: 'dend_1', loc: 0.3747575458216165, synMech: 'INH:L5_PC8', weight: 0.75, delay: 0.05, label: 'pre->post8', preLoc: 0.5, hObj: NetCon[107]},
#   {preGid: 100, sec: 'dend_36', loc: 0.3181571219896719, synMech: 'INH:L5_PC8', weight: 0.75, delay: 0.05, label: 'pre->post8', preLoc: 0.5, hObj: NetCon[108]},
#   {preGid: 100, sec: 'apic_53', loc: 0.029910205449566636, synMech: 'INH:L5_PC8', weight: 0.75, delay: 0.05, label: 'pre->post8', preLoc: 0.5, hObj: NetCon[109]},
#   {preGid: 100, sec: 'apic_7', loc: 0.3177238853854646, synMech: 'INH:L5_PC8', weight: 0.75, delay: 0.05, label: 'pre->post8', preLoc: 0.5, hObj: NetCon[110]},
#   {preGid: 100, sec: 'dend_45', loc: 0.7810568027208495, synMech: 'INH:L5_PC8', weight: 0.75, delay: 0.05, label: 'pre->post8', preLoc: 0.5, hObj: NetCon[111]},
#   {preGid: 100, sec: 'apic_31', loc: 0.17796287196138433, synMech: 'INH:L5_PC8', weight: 0.75, delay: 0.05, label: 'pre->post8', preLoc: 0.5, hObj: NetCon[112]},
#   {preGid: 100, sec: 'dend_26', loc: 0.41765248377122854, synMech: 'INH:L5_PC8', weight: 0.75, delay: 0.05, label: 'pre->post8', preLoc: 0.5, hObj: NetCon[113]},
#   {preGid: 100, sec: 'dend_13', loc: 0.7561181798330395, synMech: 'INH:L5_PC8', weight: 0.75, delay: 0.05, label: 'pre->post8', preLoc: 0.5, hObj: NetCon[114]},
#   {preGid: 100, sec: 'dend_34', loc: 0.06275539696074149, synMech: 'INH:L5_PC8', weight: 0.75, delay: 0.05, label: 'pre->post8', preLoc: 0.5, hObj: NetCon[115]},
#   {preGid: 100, sec: 'apic_11', loc: 0.19401501508519364, synMech: 'INH:L5_PC8', weight: 0.75, delay: 0.05, label: 'pre->post8', preLoc: 0.5, hObj: NetCon[116]},
#   {preGid: 100, sec: 'dend_32', loc: 0.3794239436053232, synMech: 'INH:L5_PC8', weight: 0.75, delay: 0.05, label: 'pre->post8', preLoc: 0.5, hObj: NetCon[117]},
#   {preGid: 100, sec: 'dend_23', loc: 0.541358202816672, synMech: 'INH:L5_PC8', weight: 0.75, delay: 0.05, label: 'pre->post8', preLoc: 0.5, hObj: NetCon[118]},
#   {preGid: 100, sec: 'apic_27', loc: 0.9846571309511821, synMech: 'INH:L5_PC8', weight: 0.75, delay: 0.05, label: 'pre->post8', preLoc: 0.5, hObj: NetCon[119]}],
#  [{preGid: 100, sec: 'apic_1', loc: 0.8891836700098292, synMech: 'INH:L5_PC9', weight: 0.75, delay: 0.05, label: 'pre->post9', preLoc: 0.5, hObj: NetCon[120]},
#   {preGid: 100, sec: 'apic_45', loc: 0.5666265623068691, synMech: 'INH:L5_PC9', weight: 0.75, delay: 0.05, label: 'pre->post9', preLoc: 0.5, hObj: NetCon[121]},
#   {preGid: 100, sec: 'apic_52', loc: 0.8118501921905625, synMech: 'INH:L5_PC9', weight: 0.75, delay: 0.05, label: 'pre->post9', preLoc: 0.5, hObj: NetCon[122]},
#   {preGid: 100, sec: 'dend_7', loc: 0.9829333630566086, synMech: 'INH:L5_PC9', weight: 0.75, delay: 0.05, label: 'pre->post9', preLoc: 0.5, hObj: NetCon[123]},
#   {preGid: 100, sec: 'dend_45', loc: 0.7362979562291653, synMech: 'INH:L5_PC9', weight: 0.75, delay: 0.05, label: 'pre->post9', preLoc: 0.5, hObj: NetCon[124]},
#   {preGid: 100, sec: 'dend_1', loc: 0.7059606343103066, synMech: 'INH:L5_PC9', weight: 0.75, delay: 0.05, label: 'pre->post9', preLoc: 0.5, hObj: NetCon[125]},
#   {preGid: 100, sec: 'apic_4', loc: 0.25612786051319586, synMech: 'INH:L5_PC9', weight: 0.75, delay: 0.05, label: 'pre->post9', preLoc: 0.5, hObj: NetCon[126]},
#   {preGid: 100, sec: 'apic_44', loc: 0.19513523220960372, synMech: 'INH:L5_PC9', weight: 0.75, delay: 0.05, label: 'pre->post9', preLoc: 0.5, hObj: NetCon[127]},
#   {preGid: 100, sec: 'apic_12', loc: 0.8351528958606068, synMech: 'INH:L5_PC9', weight: 0.75, delay: 0.05, label: 'pre->post9', preLoc: 0.5, hObj: NetCon[128]},
#   {preGid: 100, sec: 'apic_19', loc: 0.10286099284419468, synMech: 'INH:L5_PC9', weight: 0.75, delay: 0.05, label: 'pre->post9', preLoc: 0.5, hObj: NetCon[129]},
#   {preGid: 100, sec: 'apic_21', loc: 0.7734138213940163, synMech: 'INH:L5_PC9', weight: 0.75, delay: 0.05, label: 'pre->post9', preLoc: 0.5, hObj: NetCon[130]},
#   {preGid: 100, sec: 'apic_7', loc: 0.44602154650130177, synMech: 'INH:L5_PC9', weight: 0.75, delay: 0.05, label: 'pre->post9', preLoc: 0.5, hObj: NetCon[131]},
#   {preGid: 100, sec: 'dend_20', loc: 0.3446014173485188, synMech: 'INH:L5_PC9', weight: 0.75, delay: 0.05, label: 'pre->post9', preLoc: 0.5, hObj: NetCon[132]},
#   {preGid: 100, sec: 'apic_53', loc: 0.7267953472453808, synMech: 'INH:L5_PC9', weight: 0.75, delay: 0.05, label: 'pre->post9', preLoc: 0.5, hObj: NetCon[133]},
#   {preGid: 100, sec: 'apic_16', loc: 0.1729280028357187, synMech: 'INH:L5_PC9', weight: 0.75, delay: 0.05, label: 'pre->post9', preLoc: 0.5, hObj: NetCon[134]}],
#  [{preGid: 100, sec: 'dend_16', loc: 0.444551234665102, synMech: 'INH:L5_PC10', weight: 0.75, delay: 0.05, label: 'pre->post10', preLoc: 0.5, hObj: NetCon[135]},
#   {preGid: 100, sec: 'apic_42', loc: 0.9926638664798162, synMech: 'INH:L5_PC10', weight: 0.75, delay: 0.05, label: 'pre->post10', preLoc: 0.5, hObj: NetCon[136]},
#   {preGid: 100, sec: 'apic_47', loc: 0.17780530212235557, synMech: 'INH:L5_PC10', weight: 0.75, delay: 0.05, label: 'pre->post10', preLoc: 0.5, hObj: NetCon[137]},
#   {preGid: 100, sec: 'dend_14', loc: 0.9317082653303597, synMech: 'INH:L5_PC10', weight: 0.75, delay: 0.05, label: 'pre->post10', preLoc: 0.5, hObj: NetCon[138]},
#   {preGid: 100, sec: 'dend_37', loc: 0.8701057573048399, synMech: 'INH:L5_PC10', weight: 0.75, delay: 0.05, label: 'pre->post10', preLoc: 0.5, hObj: NetCon[139]},
#   {preGid: 100, sec: 'apic_16', loc: 0.3117897931442843, synMech: 'INH:L5_PC10', weight: 0.75, delay: 0.05, label: 'pre->post10', preLoc: 0.5, hObj: NetCon[140]},
#   {preGid: 100, sec: 'apic_53', loc: 0.7224916333017518, synMech: 'INH:L5_PC10', weight: 0.75, delay: 0.05, label: 'pre->post10', preLoc: 0.5, hObj: NetCon[141]},
#   {preGid: 100, sec: 'apic_40', loc: 0.5288864950779625, synMech: 'INH:L5_PC10', weight: 0.75, delay: 0.05, label: 'pre->post10', preLoc: 0.5, hObj: NetCon[142]},
#   {preGid: 100, sec: 'dend_8', loc: 0.16558408319161172, synMech: 'INH:L5_PC10', weight: 0.75, delay: 0.05, label: 'pre->post10', preLoc: 0.5, hObj: NetCon[143]},
#   {preGid: 100, sec: 'dend_23', loc: 0.8322960101709358, synMech: 'INH:L5_PC10', weight: 0.75, delay: 0.05, label: 'pre->post10', preLoc: 0.5, hObj: NetCon[144]},
#   {preGid: 100, sec: 'dend_12', loc: 0.8733740202672663, synMech: 'INH:L5_PC10', weight: 0.75, delay: 0.05, label: 'pre->post10', preLoc: 0.5, hObj: NetCon[145]},
#   {preGid: 100, sec: 'apic_21', loc: 0.16874677392762616, synMech: 'INH:L5_PC10', weight: 0.75, delay: 0.05, label: 'pre->post10', preLoc: 0.5, hObj: NetCon[146]},
#   {preGid: 100, sec: 'apic_31', loc: 0.21518744554630564, synMech: 'INH:L5_PC10', weight: 0.75, delay: 0.05, label: 'pre->post10', preLoc: 0.5, hObj: NetCon[147]},
#   {preGid: 100, sec: 'dend_0', loc: 0.9554446569980966, synMech: 'INH:L5_PC10', weight: 0.75, delay: 0.05, label: 'pre->post10', preLoc: 0.5, hObj: NetCon[148]},
#   {preGid: 100, sec: 'dend_26', loc: 0.51444056763746, synMech: 'INH:L5_PC10', weight: 0.75, delay: 0.05, label: 'pre->post10', preLoc: 0.5, hObj: NetCon[149]}],
#  [{preGid: 100, sec: 'apic_24', loc: 0.4887414318741263, synMech: 'INH:L5_PC11', weight: 0.75, delay: 0.05, label: 'pre->post11', preLoc: 0.5, hObj: NetCon[150]},
#   {preGid: 100, sec: 'apic_46', loc: 0.4440894532971743, synMech: 'INH:L5_PC11', weight: 0.75, delay: 0.05, label: 'pre->post11', preLoc: 0.5, hObj: NetCon[151]},
#   {preGid: 100, sec: 'apic_38', loc: 0.6242949117473047, synMech: 'INH:L5_PC11', weight: 0.75, delay: 0.05, label: 'pre->post11', preLoc: 0.5, hObj: NetCon[152]},
#   {preGid: 100, sec: 'apic_21', loc: 0.9779105778078856, synMech: 'INH:L5_PC11', weight: 0.75, delay: 0.05, label: 'pre->post11', preLoc: 0.5, hObj: NetCon[153]},
#   {preGid: 100, sec: 'apic_9', loc: 0.9445201586846802, synMech: 'INH:L5_PC11', weight: 0.75, delay: 0.05, label: 'pre->post11', preLoc: 0.5, hObj: NetCon[154]},
#   {preGid: 100, sec: 'dend_44', loc: 0.2031508387637312, synMech: 'INH:L5_PC11', weight: 0.75, delay: 0.05, label: 'pre->post11', preLoc: 0.5, hObj: NetCon[155]},
#   {preGid: 100, sec: 'apic_66', loc: 0.11207388991839413, synMech: 'INH:L5_PC11', weight: 0.75, delay: 0.05, label: 'pre->post11', preLoc: 0.5, hObj: NetCon[156]},
#   {preGid: 100, sec: 'dend_52', loc: 0.8129030898591764, synMech: 'INH:L5_PC11', weight: 0.75, delay: 0.05, label: 'pre->post11', preLoc: 0.5, hObj: NetCon[157]},
#   {preGid: 100, sec: 'apic_39', loc: 0.9930348813112236, synMech: 'INH:L5_PC11', weight: 0.75, delay: 0.05, label: 'pre->post11', preLoc: 0.5, hObj: NetCon[158]},
#   {preGid: 100, sec: 'apic_1', loc: 0.0916678423158098, synMech: 'INH:L5_PC11', weight: 0.75, delay: 0.05, label: 'pre->post11', preLoc: 0.5, hObj: NetCon[159]},
#   {preGid: 100, sec: 'dend_48', loc: 0.9177726347341517, synMech: 'INH:L5_PC11', weight: 0.75, delay: 0.05, label: 'pre->post11', preLoc: 0.5, hObj: NetCon[160]},
#   {preGid: 100, sec: 'dend_18', loc: 0.5982514319607628, synMech: 'INH:L5_PC11', weight: 0.75, delay: 0.05, label: 'pre->post11', preLoc: 0.5, hObj: NetCon[161]},
#   {preGid: 100, sec: 'dend_45', loc: 0.3212632770235166, synMech: 'INH:L5_PC11', weight: 0.75, delay: 0.05, label: 'pre->post11', preLoc: 0.5, hObj: NetCon[162]},
#   {preGid: 100, sec: 'apic_22', loc: 0.8494470929104786, synMech: 'INH:L5_PC11', weight: 0.75, delay: 0.05, label: 'pre->post11', preLoc: 0.5, hObj: NetCon[163]},
#   {preGid: 100, sec: 'dend_30', loc: 0.6393442355396879, synMech: 'INH:L5_PC11', weight: 0.75, delay: 0.05, label: 'pre->post11', preLoc: 0.5, hObj: NetCon[164]}],
#  [{preGid: 100, sec: 'dend_26', loc: 0.0820485510805208, synMech: 'INH:L5_PC12', weight: 0.75, delay: 0.05, label: 'pre->post12', preLoc: 0.5, hObj: NetCon[165]},
#   {preGid: 100, sec: 'apic_28', loc: 0.8736346740390173, synMech: 'INH:L5_PC12', weight: 0.75, delay: 0.05, label: 'pre->post12', preLoc: 0.5, hObj: NetCon[166]},
#   {preGid: 100, sec: 'apic_39', loc: 0.6978375126498083, synMech: 'INH:L5_PC12', weight: 0.75, delay: 0.05, label: 'pre->post12', preLoc: 0.5, hObj: NetCon[167]},
#   {preGid: 100, sec: 'apic_3', loc: 0.7727111500420762, synMech: 'INH:L5_PC12', weight: 0.75, delay: 0.05, label: 'pre->post12', preLoc: 0.5, hObj: NetCon[168]},
#   {preGid: 100, sec: 'apic_45', loc: 0.7903890678975042, synMech: 'INH:L5_PC12', weight: 0.75, delay: 0.05, label: 'pre->post12', preLoc: 0.5, hObj: NetCon[169]},
#   {preGid: 100, sec: 'dend_13', loc: 0.43011465013483297, synMech: 'INH:L5_PC12', weight: 0.75, delay: 0.05, label: 'pre->post12', preLoc: 0.5, hObj: NetCon[170]},
#   {preGid: 100, sec: 'apic_65', loc: 0.4074759128843164, synMech: 'INH:L5_PC12', weight: 0.75, delay: 0.05, label: 'pre->post12', preLoc: 0.5, hObj: NetCon[171]},
#   {preGid: 100, sec: 'apic_33', loc: 0.9937212201087922, synMech: 'INH:L5_PC12', weight: 0.75, delay: 0.05, label: 'pre->post12', preLoc: 0.5, hObj: NetCon[172]},
#   {preGid: 100, sec: 'dend_5', loc: 0.362164237541969, synMech: 'INH:L5_PC12', weight: 0.75, delay: 0.05, label: 'pre->post12', preLoc: 0.5, hObj: NetCon[173]},
#   {preGid: 100, sec: 'dend_7', loc: 0.5407063207190231, synMech: 'INH:L5_PC12', weight: 0.75, delay: 0.05, label: 'pre->post12', preLoc: 0.5, hObj: NetCon[174]},
#   {preGid: 100, sec: 'apic_34', loc: 0.7685526188236871, synMech: 'INH:L5_PC12', weight: 0.75, delay: 0.05, label: 'pre->post12', preLoc: 0.5, hObj: NetCon[175]},
#   {preGid: 100, sec: 'apic_15', loc: 0.5356670055620466, synMech: 'INH:L5_PC12', weight: 0.75, delay: 0.05, label: 'pre->post12', preLoc: 0.5, hObj: NetCon[176]},
#   {preGid: 100, sec: 'dend_12', loc: 0.7294218518796981, synMech: 'INH:L5_PC12', weight: 0.75, delay: 0.05, label: 'pre->post12', preLoc: 0.5, hObj: NetCon[177]},
#   {preGid: 100, sec: 'dend_42', loc: 0.7016430715492431, synMech: 'INH:L5_PC12', weight: 0.75, delay: 0.05, label: 'pre->post12', preLoc: 0.5, hObj: NetCon[178]},
#   {preGid: 100, sec: 'apic_63', loc: 0.6146805369855282, synMech: 'INH:L5_PC12', weight: 0.75, delay: 0.05, label: 'pre->post12', preLoc: 0.5, hObj: NetCon[179]}],
#  [{preGid: 100, sec: 'dend_18', loc: 0.6471741436674714, synMech: 'INH:L5_PC13', weight: 0.75, delay: 0.05, label: 'pre->post13', preLoc: 0.5, hObj: NetCon[180]},
#   {preGid: 100, sec: 'dend_45', loc: 0.41894616390209866, synMech: 'INH:L5_PC13', weight: 0.75, delay: 0.05, label: 'pre->post13', preLoc: 0.5, hObj: NetCon[181]},
#   {preGid: 100, sec: 'dend_34', loc: 0.15666228802923685, synMech: 'INH:L5_PC13', weight: 0.75, delay: 0.05, label: 'pre->post13', preLoc: 0.5, hObj: NetCon[182]},
#   {preGid: 100, sec: 'apic_63', loc: 0.9967777720712363, synMech: 'INH:L5_PC13', weight: 0.75, delay: 0.05, label: 'pre->post13', preLoc: 0.5, hObj: NetCon[183]},
#   {preGid: 100, sec: 'dend_52', loc: 0.01801055975671605, synMech: 'INH:L5_PC13', weight: 0.75, delay: 0.05, label: 'pre->post13', preLoc: 0.5, hObj: NetCon[184]},
#   {preGid: 100, sec: 'apic_66', loc: 0.1945495431699635, synMech: 'INH:L5_PC13', weight: 0.75, delay: 0.05, label: 'pre->post13', preLoc: 0.5, hObj: NetCon[185]},
#   {preGid: 100, sec: 'dend_36', loc: 0.7630657253711275, synMech: 'INH:L5_PC13', weight: 0.75, delay: 0.05, label: 'pre->post13', preLoc: 0.5, hObj: NetCon[186]},
#   {preGid: 100, sec: 'dend_11', loc: 0.17208264766049802, synMech: 'INH:L5_PC13', weight: 0.75, delay: 0.05, label: 'pre->post13', preLoc: 0.5, hObj: NetCon[187]},
#   {preGid: 100, sec: 'dend_7', loc: 0.4567710467839947, synMech: 'INH:L5_PC13', weight: 0.75, delay: 0.05, label: 'pre->post13', preLoc: 0.5, hObj: NetCon[188]},
#   {preGid: 100, sec: 'dend_17', loc: 0.5044782489711733, synMech: 'INH:L5_PC13', weight: 0.75, delay: 0.05, label: 'pre->post13', preLoc: 0.5, hObj: NetCon[189]},
#   {preGid: 100, sec: 'apic_54', loc: 0.3109284144138457, synMech: 'INH:L5_PC13', weight: 0.75, delay: 0.05, label: 'pre->post13', preLoc: 0.5, hObj: NetCon[190]},
#   {preGid: 100, sec: 'apic_36', loc: 0.5601692940222993, synMech: 'INH:L5_PC13', weight: 0.75, delay: 0.05, label: 'pre->post13', preLoc: 0.5, hObj: NetCon[191]},
#   {preGid: 100, sec: 'apic_22', loc: 0.8583337865002806, synMech: 'INH:L5_PC13', weight: 0.75, delay: 0.05, label: 'pre->post13', preLoc: 0.5, hObj: NetCon[192]},
#   {preGid: 100, sec: 'apic_49', loc: 0.5661164734482815, synMech: 'INH:L5_PC13', weight: 0.75, delay: 0.05, label: 'pre->post13', preLoc: 0.5, hObj: NetCon[193]},
#   {preGid: 100, sec: 'dend_33', loc: 0.2130059940927771, synMech: 'INH:L5_PC13', weight: 0.75, delay: 0.05, label: 'pre->post13', preLoc: 0.5, hObj: NetCon[194]}],
#  [{preGid: 100, sec: 'apic_27', loc: 0.37112090750305304, synMech: 'INH:L5_PC14', weight: 0.75, delay: 0.05, label: 'pre->post14', preLoc: 0.5, hObj: NetCon[195]},
#   {preGid: 100, sec: 'dend_10', loc: 0.3820738208096002, synMech: 'INH:L5_PC14', weight: 0.75, delay: 0.05, label: 'pre->post14', preLoc: 0.5, hObj: NetCon[196]},
#   {preGid: 100, sec: 'apic_49', loc: 0.9519586811842691, synMech: 'INH:L5_PC14', weight: 0.75, delay: 0.05, label: 'pre->post14', preLoc: 0.5, hObj: NetCon[197]},
#   {preGid: 100, sec: 'dend_45', loc: 0.05727385250090992, synMech: 'INH:L5_PC14', weight: 0.75, delay: 0.05, label: 'pre->post14', preLoc: 0.5, hObj: NetCon[198]},
#   {preGid: 100, sec: 'dend_23', loc: 0.20230367531193227, synMech: 'INH:L5_PC14', weight: 0.75, delay: 0.05, label: 'pre->post14', preLoc: 0.5, hObj: NetCon[199]},
#   {preGid: 100, sec: 'dend_44', loc: 0.9314768976009028, synMech: 'INH:L5_PC14', weight: 0.75, delay: 0.05, label: 'pre->post14', preLoc: 0.5, hObj: NetCon[200]},
#   {preGid: 100, sec: 'apic_61', loc: 0.4604945660599476, synMech: 'INH:L5_PC14', weight: 0.75, delay: 0.05, label: 'pre->post14', preLoc: 0.5, hObj: NetCon[201]},
#   {preGid: 100, sec: 'dend_51', loc: 0.06897330734992642, synMech: 'INH:L5_PC14', weight: 0.75, delay: 0.05, label: 'pre->post14', preLoc: 0.5, hObj: NetCon[202]},
#   {preGid: 100, sec: 'dend_33', loc: 0.7980271779651461, synMech: 'INH:L5_PC14', weight: 0.75, delay: 0.05, label: 'pre->post14', preLoc: 0.5, hObj: NetCon[203]},
#   {preGid: 100, sec: 'dend_52', loc: 0.9141263487802734, synMech: 'INH:L5_PC14', weight: 0.75, delay: 0.05, label: 'pre->post14', preLoc: 0.5, hObj: NetCon[204]},
#   {preGid: 100, sec: 'apic_18', loc: 0.12471035450122808, synMech: 'INH:L5_PC14', weight: 0.75, delay: 0.05, label: 'pre->post14', preLoc: 0.5, hObj: NetCon[205]},
#   {preGid: 100, sec: 'apic_40', loc: 0.04673629537575428, synMech: 'INH:L5_PC14', weight: 0.75, delay: 0.05, label: 'pre->post14', preLoc: 0.5, hObj: NetCon[206]},
#   {preGid: 100, sec: 'apic_48', loc: 0.697935278923314, synMech: 'INH:L5_PC14', weight: 0.75, delay: 0.05, label: 'pre->post14', preLoc: 0.5, hObj: NetCon[207]},
#   {preGid: 100, sec: 'apic_19', loc: 0.47300283993526193, synMech: 'INH:L5_PC14', weight: 0.75, delay: 0.05, label: 'pre->post14', preLoc: 0.5, hObj: NetCon[208]},
#   {preGid: 100, sec: 'dend_14', loc: 0.7806136407134411, synMech: 'INH:L5_PC14', weight: 0.75, delay: 0.05, label: 'pre->post14', preLoc: 0.5, hObj: NetCon[209]}],
#  [{preGid: 100, sec: 'apic_9', loc: 0.9555580882105054, synMech: 'INH:L5_PC15', weight: 0.75, delay: 0.05, label: 'pre->post15', preLoc: 0.5, hObj: NetCon[210]},
#   {preGid: 100, sec: 'apic_63', loc: 0.5101495266559022, synMech: 'INH:L5_PC15', weight: 0.75, delay: 0.05, label: 'pre->post15', preLoc: 0.5, hObj: NetCon[211]},
#   {preGid: 100, sec: 'apic_28', loc: 0.9352894520171742, synMech: 'INH:L5_PC15', weight: 0.75, delay: 0.05, label: 'pre->post15', preLoc: 0.5, hObj: NetCon[212]},
#   {preGid: 100, sec: 'apic_65', loc: 0.42156154440274224, synMech: 'INH:L5_PC15', weight: 0.75, delay: 0.05, label: 'pre->post15', preLoc: 0.5, hObj: NetCon[213]},
#   {preGid: 100, sec: 'apic_53', loc: 0.13774735755721398, synMech: 'INH:L5_PC15', weight: 0.75, delay: 0.05, label: 'pre->post15', preLoc: 0.5, hObj: NetCon[214]},
#   {preGid: 100, sec: 'apic_52', loc: 0.2929601711401149, synMech: 'INH:L5_PC15', weight: 0.75, delay: 0.05, label: 'pre->post15', preLoc: 0.5, hObj: NetCon[215]},
#   {preGid: 100, sec: 'apic_39', loc: 0.25428160361790175, synMech: 'INH:L5_PC15', weight: 0.75, delay: 0.05, label: 'pre->post15', preLoc: 0.5, hObj: NetCon[216]},
#   {preGid: 100, sec: 'dend_45', loc: 0.8776544130275322, synMech: 'INH:L5_PC15', weight: 0.75, delay: 0.05, label: 'pre->post15', preLoc: 0.5, hObj: NetCon[217]},
#   {preGid: 100, sec: 'dend_9', loc: 0.3999794287433823, synMech: 'INH:L5_PC15', weight: 0.75, delay: 0.05, label: 'pre->post15', preLoc: 0.5, hObj: NetCon[218]},
#   {preGid: 100, sec: 'apic_44', loc: 0.33393690376455426, synMech: 'INH:L5_PC15', weight: 0.75, delay: 0.05, label: 'pre->post15', preLoc: 0.5, hObj: NetCon[219]},
#   {preGid: 100, sec: 'apic_22', loc: 0.9173507180335788, synMech: 'INH:L5_PC15', weight: 0.75, delay: 0.05, label: 'pre->post15', preLoc: 0.5, hObj: NetCon[220]},
#   {preGid: 100, sec: 'apic_32', loc: 0.5505416702554564, synMech: 'INH:L5_PC15', weight: 0.75, delay: 0.05, label: 'pre->post15', preLoc: 0.5, hObj: NetCon[221]},
#   {preGid: 100, sec: 'dend_35', loc: 0.7339019516551302, synMech: 'INH:L5_PC15', weight: 0.75, delay: 0.05, label: 'pre->post15', preLoc: 0.5, hObj: NetCon[222]},
#   {preGid: 100, sec: 'apic_41', loc: 0.06308514743965124, synMech: 'INH:L5_PC15', weight: 0.75, delay: 0.05, label: 'pre->post15', preLoc: 0.5, hObj: NetCon[223]},
#   {preGid: 100, sec: 'dend_43', loc: 0.7488089918625261, synMech: 'INH:L5_PC15', weight: 0.75, delay: 0.05, label: 'pre->post15', preLoc: 0.5, hObj: NetCon[224]}],
#  [{preGid: 100, sec: 'apic_42', loc: 0.9256552991696445, synMech: 'INH:L5_PC16', weight: 0.75, delay: 0.05, label: 'pre->post16', preLoc: 0.5, hObj: NetCon[225]},
#   {preGid: 100, sec: 'apic_25', loc: 0.8430505003798864, synMech: 'INH:L5_PC16', weight: 0.75, delay: 0.05, label: 'pre->post16', preLoc: 0.5, hObj: NetCon[226]},
#   {preGid: 100, sec: 'apic_34', loc: 0.8613440289771523, synMech: 'INH:L5_PC16', weight: 0.75, delay: 0.05, label: 'pre->post16', preLoc: 0.5, hObj: NetCon[227]},
#   {preGid: 100, sec: 'apic_12', loc: 0.44993789748168095, synMech: 'INH:L5_PC16', weight: 0.75, delay: 0.05, label: 'pre->post16', preLoc: 0.5, hObj: NetCon[228]},
#   {preGid: 100, sec: 'dend_34', loc: 0.3634015592089567, synMech: 'INH:L5_PC16', weight: 0.75, delay: 0.05, label: 'pre->post16', preLoc: 0.5, hObj: NetCon[229]},
#   {preGid: 100, sec: 'apic_16', loc: 0.9139687344493401, synMech: 'INH:L5_PC16', weight: 0.75, delay: 0.05, label: 'pre->post16', preLoc: 0.5, hObj: NetCon[230]},
#   {preGid: 100, sec: 'apic_37', loc: 0.7957587105473818, synMech: 'INH:L5_PC16', weight: 0.75, delay: 0.05, label: 'pre->post16', preLoc: 0.5, hObj: NetCon[231]},
#   {preGid: 100, sec: 'apic_7', loc: 0.39403566086509456, synMech: 'INH:L5_PC16', weight: 0.75, delay: 0.05, label: 'pre->post16', preLoc: 0.5, hObj: NetCon[232]},
#   {preGid: 100, sec: 'dend_41', loc: 0.5712037052280076, synMech: 'INH:L5_PC16', weight: 0.75, delay: 0.05, label: 'pre->post16', preLoc: 0.5, hObj: NetCon[233]},
#   {preGid: 100, sec: 'dend_3', loc: 0.018481752405206928, synMech: 'INH:L5_PC16', weight: 0.75, delay: 0.05, label: 'pre->post16', preLoc: 0.5, hObj: NetCon[234]},
#   {preGid: 100, sec: 'dend_36', loc: 0.3141314449544572, synMech: 'INH:L5_PC16', weight: 0.75, delay: 0.05, label: 'pre->post16', preLoc: 0.5, hObj: NetCon[235]},
#   {preGid: 100, sec: 'apic_36', loc: 0.9528201404719588, synMech: 'INH:L5_PC16', weight: 0.75, delay: 0.05, label: 'pre->post16', preLoc: 0.5, hObj: NetCon[236]},
#   {preGid: 100, sec: 'dend_9', loc: 0.8172370654598525, synMech: 'INH:L5_PC16', weight: 0.75, delay: 0.05, label: 'pre->post16', preLoc: 0.5, hObj: NetCon[237]},
#   {preGid: 100, sec: 'apic_49', loc: 0.20963361782365367, synMech: 'INH:L5_PC16', weight: 0.75, delay: 0.05, label: 'pre->post16', preLoc: 0.5, hObj: NetCon[238]},
#   {preGid: 100, sec: 'dend_19', loc: 0.20196548712821508, synMech: 'INH:L5_PC16', weight: 0.75, delay: 0.05, label: 'pre->post16', preLoc: 0.5, hObj: NetCon[239]}],
#  [{preGid: 100, sec: 'apic_12', loc: 0.05176358690831768, synMech: 'INH:L5_PC17', weight: 0.75, delay: 0.05, label: 'pre->post17', preLoc: 0.5, hObj: NetCon[240]},
#   {preGid: 100, sec: 'apic_9', loc: 0.8518483645313372, synMech: 'INH:L5_PC17', weight: 0.75, delay: 0.05, label: 'pre->post17', preLoc: 0.5, hObj: NetCon[241]},
#   {preGid: 100, sec: 'dend_7', loc: 0.11625822705348918, synMech: 'INH:L5_PC17', weight: 0.75, delay: 0.05, label: 'pre->post17', preLoc: 0.5, hObj: NetCon[242]},
#   {preGid: 100, sec: 'apic_1', loc: 0.21398221626366745, synMech: 'INH:L5_PC17', weight: 0.75, delay: 0.05, label: 'pre->post17', preLoc: 0.5, hObj: NetCon[243]},
#   {preGid: 100, sec: 'dend_2', loc: 0.03010737153092398, synMech: 'INH:L5_PC17', weight: 0.75, delay: 0.05, label: 'pre->post17', preLoc: 0.5, hObj: NetCon[244]},
#   {preGid: 100, sec: 'dend_37', loc: 0.4713644817849877, synMech: 'INH:L5_PC17', weight: 0.75, delay: 0.05, label: 'pre->post17', preLoc: 0.5, hObj: NetCon[245]},
#   {preGid: 100, sec: 'dend_19', loc: 0.9399395811899739, synMech: 'INH:L5_PC17', weight: 0.75, delay: 0.05, label: 'pre->post17', preLoc: 0.5, hObj: NetCon[246]},
#   {preGid: 100, sec: 'dend_1', loc: 0.39755617696576506, synMech: 'INH:L5_PC17', weight: 0.75, delay: 0.05, label: 'pre->post17', preLoc: 0.5, hObj: NetCon[247]},
#   {preGid: 100, sec: 'apic_7', loc: 0.5038505176028395, synMech: 'INH:L5_PC17', weight: 0.75, delay: 0.05, label: 'pre->post17', preLoc: 0.5, hObj: NetCon[248]},
#   {preGid: 100, sec: 'dend_26', loc: 0.1688819187668226, synMech: 'INH:L5_PC17', weight: 0.75, delay: 0.05, label: 'pre->post17', preLoc: 0.5, hObj: NetCon[249]},
#   {preGid: 100, sec: 'dend_36', loc: 0.19313360528178403, synMech: 'INH:L5_PC17', weight: 0.75, delay: 0.05, label: 'pre->post17', preLoc: 0.5, hObj: NetCon[250]},
#   {preGid: 100, sec: 'dend_38', loc: 0.6480246433543626, synMech: 'INH:L5_PC17', weight: 0.75, delay: 0.05, label: 'pre->post17', preLoc: 0.5, hObj: NetCon[251]},
#   {preGid: 100, sec: 'dend_13', loc: 0.7679667034483316, synMech: 'INH:L5_PC17', weight: 0.75, delay: 0.05, label: 'pre->post17', preLoc: 0.5, hObj: NetCon[252]},
#   {preGid: 100, sec: 'dend_34', loc: 0.13549406634456748, synMech: 'INH:L5_PC17', weight: 0.75, delay: 0.05, label: 'pre->post17', preLoc: 0.5, hObj: NetCon[253]},
#   {preGid: 100, sec: 'apic_15', loc: 0.31093404365687943, synMech: 'INH:L5_PC17', weight: 0.75, delay: 0.05, label: 'pre->post17', preLoc: 0.5, hObj: NetCon[254]}],
#  [{preGid: 100, sec: 'dend_10', loc: 0.4924917423019131, synMech: 'INH:L5_PC18', weight: 0.75, delay: 0.05, label: 'pre->post18', preLoc: 0.5, hObj: NetCon[255]},
#   {preGid: 100, sec: 'dend_37', loc: 0.6827477663043049, synMech: 'INH:L5_PC18', weight: 0.75, delay: 0.05, label: 'pre->post18', preLoc: 0.5, hObj: NetCon[256]},
#   {preGid: 100, sec: 'dend_2', loc: 0.39979680872781326, synMech: 'INH:L5_PC18', weight: 0.75, delay: 0.05, label: 'pre->post18', preLoc: 0.5, hObj: NetCon[257]},
#   {preGid: 100, sec: 'apic_40', loc: 0.3015102411712253, synMech: 'INH:L5_PC18', weight: 0.75, delay: 0.05, label: 'pre->post18', preLoc: 0.5, hObj: NetCon[258]},
#   {preGid: 100, sec: 'apic_36', loc: 0.032959048848374896, synMech: 'INH:L5_PC18', weight: 0.75, delay: 0.05, label: 'pre->post18', preLoc: 0.5, hObj: NetCon[259]},
#   {preGid: 100, sec: 'apic_13', loc: 0.3656773968749853, synMech: 'INH:L5_PC18', weight: 0.75, delay: 0.05, label: 'pre->post18', preLoc: 0.5, hObj: NetCon[260]},
#   {preGid: 100, sec: 'dend_22', loc: 0.19421500752931295, synMech: 'INH:L5_PC18', weight: 0.75, delay: 0.05, label: 'pre->post18', preLoc: 0.5, hObj: NetCon[261]},
#   {preGid: 100, sec: 'apic_39', loc: 0.49711301800885116, synMech: 'INH:L5_PC18', weight: 0.75, delay: 0.05, label: 'pre->post18', preLoc: 0.5, hObj: NetCon[262]},
#   {preGid: 100, sec: 'dend_32', loc: 0.7144342384229923, synMech: 'INH:L5_PC18', weight: 0.75, delay: 0.05, label: 'pre->post18', preLoc: 0.5, hObj: NetCon[263]},
#   {preGid: 100, sec: 'apic_19', loc: 0.745147807115035, synMech: 'INH:L5_PC18', weight: 0.75, delay: 0.05, label: 'pre->post18', preLoc: 0.5, hObj: NetCon[264]},
#   {preGid: 100, sec: 'apic_52', loc: 0.18549556606799203, synMech: 'INH:L5_PC18', weight: 0.75, delay: 0.05, label: 'pre->post18', preLoc: 0.5, hObj: NetCon[265]},
#   {preGid: 100, sec: 'apic_21', loc: 0.43334140372738833, synMech: 'INH:L5_PC18', weight: 0.75, delay: 0.05, label: 'pre->post18', preLoc: 0.5, hObj: NetCon[266]},
#   {preGid: 100, sec: 'dend_20', loc: 0.7535556352701658, synMech: 'INH:L5_PC18', weight: 0.75, delay: 0.05, label: 'pre->post18', preLoc: 0.5, hObj: NetCon[267]},
#   {preGid: 100, sec: 'dend_41', loc: 0.8455278435668875, synMech: 'INH:L5_PC18', weight: 0.75, delay: 0.05, label: 'pre->post18', preLoc: 0.5, hObj: NetCon[268]},
#   {preGid: 100, sec: 'dend_26', loc: 0.22601254047215494, synMech: 'INH:L5_PC18', weight: 0.75, delay: 0.05, label: 'pre->post18', preLoc: 0.5, hObj: NetCon[269]}],
#  [{preGid: 100, sec: 'apic_45', loc: 0.5946410550673844, synMech: 'INH:L5_PC19', weight: 0.75, delay: 0.05, label: 'pre->post19', preLoc: 0.5, hObj: NetCon[270]},
#   {preGid: 100, sec: 'apic_49', loc: 0.1522878137082883, synMech: 'INH:L5_PC19', weight: 0.75, delay: 0.05, label: 'pre->post19', preLoc: 0.5, hObj: NetCon[271]},
#   {preGid: 100, sec: 'dend_32', loc: 0.44343173634382227, synMech: 'INH:L5_PC19', weight: 0.75, delay: 0.05, label: 'pre->post19', preLoc: 0.5, hObj: NetCon[272]},
#   {preGid: 100, sec: 'dend_16', loc: 0.4108149264169422, synMech: 'INH:L5_PC19', weight: 0.75, delay: 0.05, label: 'pre->post19', preLoc: 0.5, hObj: NetCon[273]},
#   {preGid: 100, sec: 'dend_22', loc: 0.8917953867949752, synMech: 'INH:L5_PC19', weight: 0.75, delay: 0.05, label: 'pre->post19', preLoc: 0.5, hObj: NetCon[274]},
#   {preGid: 100, sec: 'apic_52', loc: 0.023852671848297126, synMech: 'INH:L5_PC19', weight: 0.75, delay: 0.05, label: 'pre->post19', preLoc: 0.5, hObj: NetCon[275]},
#   {preGid: 100, sec: 'apic_20', loc: 0.5531351306633568, synMech: 'INH:L5_PC19', weight: 0.75, delay: 0.05, label: 'pre->post19', preLoc: 0.5, hObj: NetCon[276]},
#   {preGid: 100, sec: 'apic_13', loc: 0.4925401259182452, synMech: 'INH:L5_PC19', weight: 0.75, delay: 0.05, label: 'pre->post19', preLoc: 0.5, hObj: NetCon[277]},
#   {preGid: 100, sec: 'apic_53', loc: 0.6118318196749183, synMech: 'INH:L5_PC19', weight: 0.75, delay: 0.05, label: 'pre->post19', preLoc: 0.5, hObj: NetCon[278]},
#   {preGid: 100, sec: 'apic_4', loc: 0.3507672317755688, synMech: 'INH:L5_PC19', weight: 0.75, delay: 0.05, label: 'pre->post19', preLoc: 0.5, hObj: NetCon[279]},
#   {preGid: 100, sec: 'dend_30', loc: 0.7985993175378335, synMech: 'INH:L5_PC19', weight: 0.75, delay: 0.05, label: 'pre->post19', preLoc: 0.5, hObj: NetCon[280]},
#   {preGid: 100, sec: 'dend_8', loc: 0.16392271180228962, synMech: 'INH:L5_PC19', weight: 0.75, delay: 0.05, label: 'pre->post19', preLoc: 0.5, hObj: NetCon[281]},
#   {preGid: 100, sec: 'apic_5', loc: 0.3350081660211805, synMech: 'INH:L5_PC19', weight: 0.75, delay: 0.05, label: 'pre->post19', preLoc: 0.5, hObj: NetCon[282]},
#   {preGid: 100, sec: 'apic_16', loc: 0.3567082199690157, synMech: 'INH:L5_PC19', weight: 0.75, delay: 0.05, label: 'pre->post19', preLoc: 0.5, hObj: NetCon[283]},
#   {preGid: 100, sec: 'dend_37', loc: 0.17489564483762823, synMech: 'INH:L5_PC19', weight: 0.75, delay: 0.05, label: 'pre->post19', preLoc: 0.5, hObj: NetCon[284]}],
#  [{preGid: 100, sec: 'apic_38', loc: 0.34227338431653975, synMech: 'INH:L5_PC20', weight: 0.75, delay: 0.05, label: 'pre->post20', preLoc: 0.5, hObj: NetCon[285]},
#   {preGid: 100, sec: 'apic_45', loc: 0.17602693445265502, synMech: 'INH:L5_PC20', weight: 0.75, delay: 0.05, label: 'pre->post20', preLoc: 0.5, hObj: NetCon[286]},
#   {preGid: 100, sec: 'dend_30', loc: 0.3806257469305704, synMech: 'INH:L5_PC20', weight: 0.75, delay: 0.05, label: 'pre->post20', preLoc: 0.5, hObj: NetCon[287]},
#   {preGid: 100, sec: 'apic_1', loc: 0.6549616266512842, synMech: 'INH:L5_PC20', weight: 0.75, delay: 0.05, label: 'pre->post20', preLoc: 0.5, hObj: NetCon[288]},
#   {preGid: 100, sec: 'apic_25', loc: 0.08733954827490756, synMech: 'INH:L5_PC20', weight: 0.75, delay: 0.05, label: 'pre->post20', preLoc: 0.5, hObj: NetCon[289]},
#   {preGid: 100, sec: 'apic_36', loc: 0.20669860177781935, synMech: 'INH:L5_PC20', weight: 0.75, delay: 0.05, label: 'pre->post20', preLoc: 0.5, hObj: NetCon[290]},
#   {preGid: 100, sec: 'dend_6', loc: 0.7020079102700315, synMech: 'INH:L5_PC20', weight: 0.75, delay: 0.05, label: 'pre->post20', preLoc: 0.5, hObj: NetCon[291]},
#   {preGid: 100, sec: 'dend_24', loc: 0.6150847159930719, synMech: 'INH:L5_PC20', weight: 0.75, delay: 0.05, label: 'pre->post20', preLoc: 0.5, hObj: NetCon[292]},
#   {preGid: 100, sec: 'dend_17', loc: 0.1769253163546991, synMech: 'INH:L5_PC20', weight: 0.75, delay: 0.05, label: 'pre->post20', preLoc: 0.5, hObj: NetCon[293]},
# ...
#   {preGid: 100, sec: 'dend_46', loc: 0.20732889225191636, synMech: 'INH:L5_PC94', weight: 0.75, delay: 0.05, label: 'pre->post94', preLoc: 0.5, hObj: NetCon[1403]},
#   {preGid: 100, sec: 'apic_29', loc: 0.8669862804235946, synMech: 'INH:L5_PC94', weight: 0.75, delay: 0.05, label: 'pre->post94', preLoc: 0.5, hObj: NetCon[1404]},
#   {preGid: 100, sec: 'dend_35', loc: 0.0002797077952511998, synMech: 'INH:L5_PC94', weight: 0.75, delay: 0.05, label: 'pre->post94', preLoc: 0.5, hObj: NetCon[1405]},
#   {preGid: 100, sec: 'apic_25', loc: 0.1894023018997216, synMech: 'INH:L5_PC94', weight: 0.75, delay: 0.05, label: 'pre->post94', preLoc: 0.5, hObj: NetCon[1406]},
#   {preGid: 100, sec: 'dend_30', loc: 0.14934915983045655, synMech: 'INH:L5_PC94', weight: 0.75, delay: 0.05, label: 'pre->post94', preLoc: 0.5, hObj: NetCon[1407]},
#   {preGid: 100, sec: 'dend_57', loc: 0.3551892217188183, synMech: 'INH:L5_PC94', weight: 0.75, delay: 0.05, label: 'pre->post94', preLoc: 0.5, hObj: NetCon[1408]},
#   {preGid: 100, sec: 'apic_28', loc: 0.6294463298371674, synMech: 'INH:L5_PC94', weight: 0.75, delay: 0.05, label: 'pre->post94', preLoc: 0.5, hObj: NetCon[1409]}],
#  [{preGid: 100, sec: 'dend_11', loc: 0.8187021841472096, synMech: 'INH:L5_PC95', weight: 0.75, delay: 0.05, label: 'pre->post95', preLoc: 0.5, hObj: NetCon[1410]},
#   {preGid: 100, sec: 'dend_57', loc: 0.9453343820342535, synMech: 'INH:L5_PC95', weight: 0.75, delay: 0.05, label: 'pre->post95', preLoc: 0.5, hObj: NetCon[1411]},
#   {preGid: 100, sec: 'apic_58', loc: 0.29698072102259904, synMech: 'INH:L5_PC95', weight: 0.75, delay: 0.05, label: 'pre->post95', preLoc: 0.5, hObj: NetCon[1412]},
#   {preGid: 100, sec: 'apic_26', loc: 0.44168999452208524, synMech: 'INH:L5_PC95', weight: 0.75, delay: 0.05, label: 'pre->post95', preLoc: 0.5, hObj: NetCon[1413]},
#   {preGid: 100, sec: 'apic_23', loc: 0.8290442288636712, synMech: 'INH:L5_PC95', weight: 0.75, delay: 0.05, label: 'pre->post95', preLoc: 0.5, hObj: NetCon[1414]},
#   {preGid: 100, sec: 'apic_54', loc: 0.9750662639209524, synMech: 'INH:L5_PC95', weight: 0.75, delay: 0.05, label: 'pre->post95', preLoc: 0.5, hObj: NetCon[1415]},
#   {preGid: 100, sec: 'dend_55', loc: 0.9110465152246268, synMech: 'INH:L5_PC95', weight: 0.75, delay: 0.05, label: 'pre->post95', preLoc: 0.5, hObj: NetCon[1416]},
#   {preGid: 100, sec: 'apic_17', loc: 0.9870455525395075, synMech: 'INH:L5_PC95', weight: 0.75, delay: 0.05, label: 'pre->post95', preLoc: 0.5, hObj: NetCon[1417]},
#   {preGid: 100, sec: 'dend_33', loc: 0.6960309083569308, synMech: 'INH:L5_PC95', weight: 0.75, delay: 0.05, label: 'pre->post95', preLoc: 0.5, hObj: NetCon[1418]},
#   {preGid: 100, sec: 'apic_21', loc: 0.48060586596904575, synMech: 'INH:L5_PC95', weight: 0.75, delay: 0.05, label: 'pre->post95', preLoc: 0.5, hObj: NetCon[1419]},
#   {preGid: 100, sec: 'dend_58', loc: 0.7949855789883904, synMech: 'INH:L5_PC95', weight: 0.75, delay: 0.05, label: 'pre->post95', preLoc: 0.5, hObj: NetCon[1420]},
#   {preGid: 100, sec: 'apic_25', loc: 0.13188008436212043, synMech: 'INH:L5_PC95', weight: 0.75, delay: 0.05, label: 'pre->post95', preLoc: 0.5, hObj: NetCon[1421]},
#   {preGid: 100, sec: 'apic_60', loc: 0.9273925659749431, synMech: 'INH:L5_PC95', weight: 0.75, delay: 0.05, label: 'pre->post95', preLoc: 0.5, hObj: NetCon[1422]},
#   {preGid: 100, sec: 'dend_43', loc: 0.3326889774228041, synMech: 'INH:L5_PC95', weight: 0.75, delay: 0.05, label: 'pre->post95', preLoc: 0.5, hObj: NetCon[1423]},
#   {preGid: 100, sec: 'apic_32', loc: 0.6158959395398355, synMech: 'INH:L5_PC95', weight: 0.75, delay: 0.05, label: 'pre->post95', preLoc: 0.5, hObj: NetCon[1424]}],
#  [{preGid: 100, sec: 'apic_26', loc: 0.22659397229355274, synMech: 'INH:L5_PC96', weight: 0.75, delay: 0.05, label: 'pre->post96', preLoc: 0.5, hObj: NetCon[1425]},
#   {preGid: 100, sec: 'dend_45', loc: 0.8125773075430555, synMech: 'INH:L5_PC96', weight: 0.75, delay: 0.05, label: 'pre->post96', preLoc: 0.5, hObj: NetCon[1426]},
#   {preGid: 100, sec: 'apic_35', loc: 0.7941898716915486, synMech: 'INH:L5_PC96', weight: 0.75, delay: 0.05, label: 'pre->post96', preLoc: 0.5, hObj: NetCon[1427]},
#   {preGid: 100, sec: 'apic_16', loc: 0.22187737316831216, synMech: 'INH:L5_PC96', weight: 0.75, delay: 0.05, label: 'pre->post96', preLoc: 0.5, hObj: NetCon[1428]},
#   {preGid: 100, sec: 'dend_63', loc: 0.7650040222305522, synMech: 'INH:L5_PC96', weight: 0.75, delay: 0.05, label: 'pre->post96', preLoc: 0.5, hObj: NetCon[1429]},
#   {preGid: 100, sec: 'dend_47', loc: 0.9867743273820194, synMech: 'INH:L5_PC96', weight: 0.75, delay: 0.05, label: 'pre->post96', preLoc: 0.5, hObj: NetCon[1430]},
#   {preGid: 100, sec: 'apic_46', loc: 0.16811909759991622, synMech: 'INH:L5_PC96', weight: 0.75, delay: 0.05, label: 'pre->post96', preLoc: 0.5, hObj: NetCon[1431]},
#   {preGid: 100, sec: 'dend_39', loc: 0.1215103190224919, synMech: 'INH:L5_PC96', weight: 0.75, delay: 0.05, label: 'pre->post96', preLoc: 0.5, hObj: NetCon[1432]},
#   {preGid: 100, sec: 'apic_17', loc: 0.2998848214903966, synMech: 'INH:L5_PC96', weight: 0.75, delay: 0.05, label: 'pre->post96', preLoc: 0.5, hObj: NetCon[1433]},
#   {preGid: 100, sec: 'dend_20', loc: 0.24134803223790308, synMech: 'INH:L5_PC96', weight: 0.75, delay: 0.05, label: 'pre->post96', preLoc: 0.5, hObj: NetCon[1434]},
#   {preGid: 100, sec: 'dend_35', loc: 0.24995095421356772, synMech: 'INH:L5_PC96', weight: 0.75, delay: 0.05, label: 'pre->post96', preLoc: 0.5, hObj: NetCon[1435]},
#   {preGid: 100, sec: 'dend_25', loc: 0.9991819455623288, synMech: 'INH:L5_PC96', weight: 0.75, delay: 0.05, label: 'pre->post96', preLoc: 0.5, hObj: NetCon[1436]},
#   {preGid: 100, sec: 'dend_46', loc: 0.01245110738480213, synMech: 'INH:L5_PC96', weight: 0.75, delay: 0.05, label: 'pre->post96', preLoc: 0.5, hObj: NetCon[1437]},
#   {preGid: 100, sec: 'apic_50', loc: 0.25015973423793464, synMech: 'INH:L5_PC96', weight: 0.75, delay: 0.05, label: 'pre->post96', preLoc: 0.5, hObj: NetCon[1438]},
#   {preGid: 100, sec: 'apic_62', loc: 0.41171692677119526, synMech: 'INH:L5_PC96', weight: 0.75, delay: 0.05, label: 'pre->post96', preLoc: 0.5, hObj: NetCon[1439]}],
#  [{preGid: 100, sec: 'dend_17', loc: 0.4500989641178351, synMech: 'INH:L5_PC97', weight: 0.75, delay: 0.05, label: 'pre->post97', preLoc: 0.5, hObj: NetCon[1440]},
#   {preGid: 100, sec: 'apic_21', loc: 0.5318472817735633, synMech: 'INH:L5_PC97', weight: 0.75, delay: 0.05, label: 'pre->post97', preLoc: 0.5, hObj: NetCon[1441]},
#   {preGid: 100, sec: 'dend_39', loc: 0.4160066027361449, synMech: 'INH:L5_PC97', weight: 0.75, delay: 0.05, label: 'pre->post97', preLoc: 0.5, hObj: NetCon[1442]},
#   {preGid: 100, sec: 'apic_20', loc: 0.04610879694032111, synMech: 'INH:L5_PC97', weight: 0.75, delay: 0.05, label: 'pre->post97', preLoc: 0.5, hObj: NetCon[1443]},
#   {preGid: 100, sec: 'apic_35', loc: 0.7730671180659546, synMech: 'INH:L5_PC97', weight: 0.75, delay: 0.05, label: 'pre->post97', preLoc: 0.5, hObj: NetCon[1444]},
#   {preGid: 100, sec: 'dend_26', loc: 0.7037505093483264, synMech: 'INH:L5_PC97', weight: 0.75, delay: 0.05, label: 'pre->post97', preLoc: 0.5, hObj: NetCon[1445]},
#   {preGid: 100, sec: 'apic_1', loc: 0.7602284888181862, synMech: 'INH:L5_PC97', weight: 0.75, delay: 0.05, label: 'pre->post97', preLoc: 0.5, hObj: NetCon[1446]},
#   {preGid: 100, sec: 'dend_16', loc: 0.8495360801018087, synMech: 'INH:L5_PC97', weight: 0.75, delay: 0.05, label: 'pre->post97', preLoc: 0.5, hObj: NetCon[1447]},
#   {preGid: 100, sec: 'apic_66', loc: 0.9990955637756153, synMech: 'INH:L5_PC97', weight: 0.75, delay: 0.05, label: 'pre->post97', preLoc: 0.5, hObj: NetCon[1448]},
#   {preGid: 100, sec: 'apic_63', loc: 0.3583870839419953, synMech: 'INH:L5_PC97', weight: 0.75, delay: 0.05, label: 'pre->post97', preLoc: 0.5, hObj: NetCon[1449]},
#   {preGid: 100, sec: 'dend_61', loc: 0.9545907048930287, synMech: 'INH:L5_PC97', weight: 0.75, delay: 0.05, label: 'pre->post97', preLoc: 0.5, hObj: NetCon[1450]},
#   {preGid: 100, sec: 'dend_63', loc: 0.12871524852686095, synMech: 'INH:L5_PC97', weight: 0.75, delay: 0.05, label: 'pre->post97', preLoc: 0.5, hObj: NetCon[1451]},
#   {preGid: 100, sec: 'dend_51', loc: 0.5791332169981174, synMech: 'INH:L5_PC97', weight: 0.75, delay: 0.05, label: 'pre->post97', preLoc: 0.5, hObj: NetCon[1452]},
#   {preGid: 100, sec: 'dend_62', loc: 0.1772301523089771, synMech: 'INH:L5_PC97', weight: 0.75, delay: 0.05, label: 'pre->post97', preLoc: 0.5, hObj: NetCon[1453]},
#   {preGid: 100, sec: 'dend_35', loc: 0.8885458726412899, synMech: 'INH:L5_PC97', weight: 0.75, delay: 0.05, label: 'pre->post97', preLoc: 0.5, hObj: NetCon[1454]}],
#  [{preGid: 100, sec: 'apic_61', loc: 0.7115594238527074, synMech: 'INH:L5_PC98', weight: 0.75, delay: 0.05, label: 'pre->post98', preLoc: 0.5, hObj: NetCon[1455]},
#   {preGid: 100, sec: 'apic_16', loc: 0.9633827441069132, synMech: 'INH:L5_PC98', weight: 0.75, delay: 0.05, label: 'pre->post98', preLoc: 0.5, hObj: NetCon[1456]},
#   {preGid: 100, sec: 'apic_64', loc: 0.8805661489517728, synMech: 'INH:L5_PC98', weight: 0.75, delay: 0.05, label: 'pre->post98', preLoc: 0.5, hObj: NetCon[1457]},
#   {preGid: 100, sec: 'dend_15', loc: 0.8406321063088906, synMech: 'INH:L5_PC98', weight: 0.75, delay: 0.05, label: 'pre->post98', preLoc: 0.5, hObj: NetCon[1458]},
#   {preGid: 100, sec: 'apic_45', loc: 0.5089483256030938, synMech: 'INH:L5_PC98', weight: 0.75, delay: 0.05, label: 'pre->post98', preLoc: 0.5, hObj: NetCon[1459]},
#   {preGid: 100, sec: 'apic_31', loc: 0.7119753057667391, synMech: 'INH:L5_PC98', weight: 0.75, delay: 0.05, label: 'pre->post98', preLoc: 0.5, hObj: NetCon[1460]},
#   {preGid: 100, sec: 'dend_45', loc: 0.007973269501894347, synMech: 'INH:L5_PC98', weight: 0.75, delay: 0.05, label: 'pre->post98', preLoc: 0.5, hObj: NetCon[1461]},
#   {preGid: 100, sec: 'apic_25', loc: 0.39784443968401983, synMech: 'INH:L5_PC98', weight: 0.75, delay: 0.05, label: 'pre->post98', preLoc: 0.5, hObj: NetCon[1462]},
#   {preGid: 100, sec: 'apic_24', loc: 0.15441390483237946, synMech: 'INH:L5_PC98', weight: 0.75, delay: 0.05, label: 'pre->post98', preLoc: 0.5, hObj: NetCon[1463]},
#   {preGid: 100, sec: 'apic_9', loc: 0.6003629118357182, synMech: 'INH:L5_PC98', weight: 0.75, delay: 0.05, label: 'pre->post98', preLoc: 0.5, hObj: NetCon[1464]},
#   {preGid: 100, sec: 'dend_22', loc: 0.2911160722658913, synMech: 'INH:L5_PC98', weight: 0.75, delay: 0.05, label: 'pre->post98', preLoc: 0.5, hObj: NetCon[1465]},
#   {preGid: 100, sec: 'apic_32', loc: 0.225983380991791, synMech: 'INH:L5_PC98', weight: 0.75, delay: 0.05, label: 'pre->post98', preLoc: 0.5, hObj: NetCon[1466]},
#   {preGid: 100, sec: 'dend_54', loc: 0.5118827666770366, synMech: 'INH:L5_PC98', weight: 0.75, delay: 0.05, label: 'pre->post98', preLoc: 0.5, hObj: NetCon[1467]},
#   {preGid: 100, sec: 'apic_58', loc: 0.5988360477908813, synMech: 'INH:L5_PC98', weight: 0.75, delay: 0.05, label: 'pre->post98', preLoc: 0.5, hObj: NetCon[1468]},
#   {preGid: 100, sec: 'dend_61', loc: 0.18909253201011517, synMech: 'INH:L5_PC98', weight: 0.75, delay: 0.05, label: 'pre->post98', preLoc: 0.5, hObj: NetCon[1469]}],
#  [{preGid: 100, sec: 'dend_18', loc: 0.5304496708097332, synMech: 'INH:L5_PC99', weight: 0.75, delay: 0.05, label: 'pre->post99', preLoc: 0.5, hObj: NetCon[1470]},
#   {preGid: 100, sec: 'apic_24', loc: 0.6979749353212903, synMech: 'INH:L5_PC99', weight: 0.75, delay: 0.05, label: 'pre->post99', preLoc: 0.5, hObj: NetCon[1471]},
#   {preGid: 100, sec: 'apic_61', loc: 0.44484701801680904, synMech: 'INH:L5_PC99', weight: 0.75, delay: 0.05, label: 'pre->post99', preLoc: 0.5, hObj: NetCon[1472]},
#   {preGid: 100, sec: 'dend_33', loc: 0.6752900183803258, synMech: 'INH:L5_PC99', weight: 0.75, delay: 0.05, label: 'pre->post99', preLoc: 0.5, hObj: NetCon[1473]},
#   {preGid: 100, sec: 'apic_63', loc: 0.1142625742994477, synMech: 'INH:L5_PC99', weight: 0.75, delay: 0.05, label: 'pre->post99', preLoc: 0.5, hObj: NetCon[1474]},
#   {preGid: 100, sec: 'apic_13', loc: 0.11319463339149838, synMech: 'INH:L5_PC99', weight: 0.75, delay: 0.05, label: 'pre->post99', preLoc: 0.5, hObj: NetCon[1475]},
#   {preGid: 100, sec: 'dend_42', loc: 0.9718772634587824, synMech: 'INH:L5_PC99', weight: 0.75, delay: 0.05, label: 'pre->post99', preLoc: 0.5, hObj: NetCon[1476]},
#   {preGid: 100, sec: 'dend_59', loc: 0.09105984470684923, synMech: 'INH:L5_PC99', weight: 0.75, delay: 0.05, label: 'pre->post99', preLoc: 0.5, hObj: NetCon[1477]},
#   {preGid: 100, sec: 'dend_46', loc: 0.021436101767400018, synMech: 'INH:L5_PC99', weight: 0.75, delay: 0.05, label: 'pre->post99', preLoc: 0.5, hObj: NetCon[1478]},
#   {preGid: 100, sec: 'apic_54', loc: 0.4880905151200247, synMech: 'INH:L5_PC99', weight: 0.75, delay: 0.05, label: 'pre->post99', preLoc: 0.5, hObj: NetCon[1479]},
#   {preGid: 100, sec: 'dend_3', loc: 0.8774847782752994, synMech: 'INH:L5_PC99', weight: 0.75, delay: 0.05, label: 'pre->post99', preLoc: 0.5, hObj: NetCon[1480]},
#   {preGid: 100, sec: 'apic_52', loc: 0.7130754572449173, synMech: 'INH:L5_PC99', weight: 0.75, delay: 0.05, label: 'pre->post99', preLoc: 0.5, hObj: NetCon[1481]},
#   {preGid: 100, sec: 'dend_63', loc: 0.2120534431829475, synMech: 'INH:L5_PC99', weight: 0.75, delay: 0.05, label: 'pre->post99', preLoc: 0.5, hObj: NetCon[1482]},
#   {preGid: 100, sec: 'apic_62', loc: 0.8366207827004456, synMech: 'INH:L5_PC99', weight: 0.75, delay: 0.05, label: 'pre->post99', preLoc: 0.5, hObj: NetCon[1483]},
#   {preGid: 100, sec: 'apic_37', loc: 0.3751047060423464, synMech: 'INH:L5_PC99', weight: 0.75, delay: 0.05, label: 'pre->post99', preLoc: 0.5, hObj: NetCon[1484]}],
#  [{preGid: 100, sec: 'apic_35', loc: 0.931101021759354, synMech: 'INH:L5_PC100', weight: 0.75, delay: 0.05, label: 'pre->post100', preLoc: 0.5, hObj: NetCon[1485]},
#   {preGid: 100, sec: 'apic_61', loc: 0.7522068827226581, synMech: 'INH:L5_PC100', weight: 0.75, delay: 0.05, label: 'pre->post100', preLoc: 0.5, hObj: NetCon[1486]},
#   {preGid: 100, sec: 'dend_13', loc: 0.3921364191442313, synMech: 'INH:L5_PC100', weight: 0.75, delay: 0.05, label: 'pre->post100', preLoc: 0.5, hObj: NetCon[1487]},
#   {preGid: 100, sec: 'dend_27', loc: 0.8680845931624748, synMech: 'INH:L5_PC100', weight: 0.75, delay: 0.05, label: 'pre->post100', preLoc: 0.5, hObj: NetCon[1488]},
#   {preGid: 100, sec: 'dend_11', loc: 0.45103901044117123, synMech: 'INH:L5_PC100', weight: 0.75, delay: 0.05, label: 'pre->post100', preLoc: 0.5, hObj: NetCon[1489]},
#   {preGid: 100, sec: 'dend_52', loc: 0.33727780740656854, synMech: 'INH:L5_PC100', weight: 0.75, delay: 0.05, label: 'pre->post100', preLoc: 0.5, hObj: NetCon[1490]},
#   {preGid: 100, sec: 'apic_43', loc: 0.11703413950047001, synMech: 'INH:L5_PC100', weight: 0.75, delay: 0.05, label: 'pre->post100', preLoc: 0.5, hObj: NetCon[1491]},
#   {preGid: 100, sec: 'dend_51', loc: 0.674413062268879, synMech: 'INH:L5_PC100', weight: 0.75, delay: 0.05, label: 'pre->post100', preLoc: 0.5, hObj: NetCon[1492]},
#   {preGid: 100, sec: 'apic_10', loc: 0.42785663913754657, synMech: 'INH:L5_PC100', weight: 0.75, delay: 0.05, label: 'pre->post100', preLoc: 0.5, hObj: NetCon[1493]},
#   {preGid: 100, sec: 'apic_59', loc: 0.1597792412651571, synMech: 'INH:L5_PC100', weight: 0.75, delay: 0.05, label: 'pre->post100', preLoc: 0.5, hObj: NetCon[1494]},
#   {preGid: 100, sec: 'apic_53', loc: 0.033251395265172554, synMech: 'INH:L5_PC100', weight: 0.75, delay: 0.05, label: 'pre->post100', preLoc: 0.5, hObj: NetCon[1495]},
#   {preGid: 100, sec: 'apic_63', loc: 0.6264997331078883, synMech: 'INH:L5_PC100', weight: 0.75, delay: 0.05, label: 'pre->post100', preLoc: 0.5, hObj: NetCon[1496]},
#   {preGid: 100, sec: 'dend_36', loc: 0.952355047822836, synMech: 'INH:L5_PC100', weight: 0.75, delay: 0.05, label: 'pre->post100', preLoc: 0.5, hObj: NetCon[1497]},
#   {preGid: 100, sec: 'dend_39', loc: 0.2497550580753991, synMech: 'INH:L5_PC100', weight: 0.75, delay: 0.05, label: 'pre->post100', preLoc: 0.5, hObj: NetCon[1498]},
#   {preGid: 100, sec: 'apic_39', loc: 0.10484218244019868, synMech: 'INH:L5_PC100', weight: 0.75, delay: 0.05, label: 'pre->post100', preLoc: 0.5, hObj: NetCon[1499]}],
#  []]

# %%
sim.net.addStims() 							# add network stimulation
sim.setupRecording()              			# setup variables to record for each cell (spikes, V traces, etc)
# Out:
#   Number of stims on node 0: 0
#   Done; cell stims creation time = 0.00 s.
# Recording 100 traces of 1 types on node 0
# {spkt: Vector[104791], spkid: Vector[104792], V_soma: {cell_0: Vector[104793], cell_1: Vector[104794], cell_2: Vector[104795], cell_3: Vector[104796], cell_4: Vector[104797], cell_5: Vector[104798], cell_6: Vector[104799], cell_7: Vector[104800], cell_8: Vector[104801], cell_9: Vector[104802], cell_10: Vector[104803], cell_11: Vector[104804], cell_12: Vector[104805], cell_13: Vector[104806], cell_14: Vector[104807], cell_15: Vector[104808], cell_16: Vector[104809], cell_17: Vector[104810], cell_18: Vector[104811], cell_19: Vector[104812], cell_20: Vector[104813], cell_21: Vector[104814], cell_22: Vector[104815], cell_23: Vector[104816], cell_24: Vector[104817], cell_25: Vector[104818], cell_26: Vector[104819], cell_27: Vector[104820], cell_28: Vector[104821], cell_29: Vector[104822], cell_30: Vector[104823], cell_31: Vector[104824], cell_32: Vector[104825], cell_33: Vector[104826], cell_34: Vector[104827], cell_35: Vector[104828], cell_36: Vector[104829], cell_37: Vector[104830], cell_38: Vector[104831], cell_39: Vector[104832], cell_40: Vector[104833], cell_41: Vector[104834], cell_42: Vector[104835], cell_43: Vector[104836], cell_44: Vector[104837], cell_45: Vector[104838], cell_46: Vector[104839], cell_47: Vector[104840], cell_48: Vector[104841], cell_49: Vector[104842], cell_50: Vector[104843], cell_51: Vector[104844], cell_52: Vector[104845], cell_53: Vector[104846], cell_54: Vector[104847], cell_55: Vector[104848], cell_56: Vector[104849], cell_57: Vector[104850], cell_58: Vector[104851], cell_59: Vector[104852], cell_60: Vector[104853], cell_61: Vector[104854], cell_62: Vector[104855], cell_63: Vector[104856], cell_64: Vector[104857], cell_65: Vector[104858], cell_66: Vector[104859], cell_67: Vector[104860], cell_68: Vector[104861], cell_69: Vector[104862], cell_70: Vector[104863], cell_71: Vector[104864], cell_72: Vector[104865], cell_73: Vector[104866], cell_74: Vector[104867], cell_75: Vector[104868], cell_76: Vector[104869], cell_77: Vector[104870], cell_78: Vector[104871], cell_79: Vector[104872], cell_80: Vector[104873], cell_81: Vector[104874], cell_82: Vector[104875], cell_83: Vector[104876], cell_84: Vector[104877], cell_85: Vector[104878], cell_86: Vector[104879], cell_87: Vector[104880], cell_88: Vector[104881], cell_89: Vector[104882], cell_90: Vector[104883], cell_91: Vector[104884], cell_92: Vector[104885], cell_93: Vector[104886], cell_94: Vector[104887], cell_95: Vector[104888], cell_96: Vector[104889], cell_97: Vector[104890], cell_98: Vector[104891], cell_99: Vector[104892]}, t: Vector[104893], _repr_mimebundle_: {}}

# %%
sim.runSim()                      			# run Neuron simulation
# Out:
# 0.0s
#
# Running simulation using NEURON for 4000.0 ms...
# 0.1s
# 0.2s
# 0.3s
# 0.4s
# 0.5s
# 0.6s
# 0.7s
# 0.8s
# 0.9s
# 1.0s
# 1.1s
# 1.2s
# 1.3s
# 1.4s
# 1.5s
# 1.6s
# 1.7s
# 1.8s
# 1.9s
# 2.0s
# 2.1s
# 2.2s
# 2.3s
# 2.4s
# 2.5s
# 2.6s
# 2.7s
# 2.8s
# 2.9s
# 3.0s
# 3.1s
# 3.2s
# 3.3s
# 3.4s
# 3.5s
# 3.6s
# 3.7s
# 3.8s
# 3.9s
# 4.0s
#   Done; run time = 5794.58 s; real-time ratio: 0.00.

# %%
sim.gatherData()                  			# gather spiking data and cell info from each node
sim.saveData()                    			# save params, cell info and sim output to file (pickle,mat,txt,etc)#
sim.analysis.plotData()         			# plot spike raster etc
# Out:
# Gathering data...
#   Done; gather time = 0.19 s.
#
# Analyzing...
#   Cells: 101
#   Connections: 100 (0.99 per cell)
#   Synaptic contacts: 1500 (14.85 per cell)
#   Spikes: 11 (0.03 Hz)
#   Simulated time: 4.0 s; 1 workers
#   Run time: 5794.58 s
# Warning: data won't be saved. No output format specified (consider sim.cfg.savePickle, sim.cfg.saveJson etc.)
# Plotting recorded cell traces ... trace
#   Done; plotting time = 0.76 s
#
# Total time = 5800.98 s

# %%
# sim.analysis.plotRaster(figSize=(10, 3))

# %%
alltraces = []
gmax1 = []

# spkTimes = [500,2500,2550,2600,2650,2700,2750,2800,2850,2900,3400]


Traces2 = sim.analysis.plotTraces(oneFigPer='trace', overlay=1, timeRange=[2400,3900],axis=False,legend=False,scaleBarLoc=1,figSize=(10, 3),fontSize=6)
for number in range(100):
    if np.max(Traces2[1]['tracesData'][number]['cell_'+str(number)+'_V_soma'])-np.min(Traces2[1]['tracesData'][number]['cell_'+str(number)+'_V_soma']) > 0.01:
        alltraces.append(Traces2[1]['tracesData'][number]['cell_'+str(number)+'_V_soma'])
        gmax1.append(np.max(Traces2[1]['tracesData'][number]['cell_'+str(number)+'_V_soma'])-np.min(Traces2[1]['tracesData'][number]['cell_'+str(number)+'_V_soma']))
#         print(number,np.max(Traces2[1]['tracesData'][number]['cell_'+str(number)+'_V_soma'])-np.min(Traces2[1]['tracesData'][number]['cell_'+str(number)+'_V_soma']))


# Traces2 = sim.analysis.plotTraces(oneFigPer='trace', overlay=1, timeRange=[3300,3900],axis=False,legend=False,scaleBarLoc=1,figSize=(10, 3),fontSize=6)
# for number in range(20):
#     if np.max(Traces2[1]['tracesData'][number]['cell_'+str(number)+'_V_soma'])-np.min(Traces2[1]['tracesData'][number]['cell_'+str(number)+'_V_soma']) > 0.01:
#         alltraces.append(Traces2[1]['tracesData'][number]['cell_'+str(number)+'_V_soma'])
#         gmax1.append(np.max(Traces2[1]['tracesData'][number]['cell_'+str(number)+'_V_soma'])-np.min(Traces2[1]['tracesData'][number]['cell_'+str(number)+'_V_soma']))
# #         print(number,np.max(Traces2[1]['tracesData'][number]['cell_'+str(number)+'_V_soma'])-np.min(Traces2[1]['tracesData'][number]['cell_'+str(number)+'_V_soma']))


# print('L23_PC:L23_PC in silico PSP amplitude (mV; mean ± SD) = %.3f±%.3f' % (np.mean(gmax1),np.std(gmax1)))
print('INH:L5_PC in silico PSP amplitude (mV; mean ± SD) = %.3f±%.3f' % (np.mean(gmax1),np.std(gmax1)))
# Out:
# Plotting recorded cell traces ... trace
# INH:L5_PC in silico PSP amplitude (mV; mean ± SD) = 0.329±0.150

# %%
figSize = (16,9)
fig = plt.figure(figsize=figSize)  # Open a new figure
clr = ["black", "blue","green","gray", "red","black", "blue","green","gray", "red","black", "blue","green","gray", "red","black", "blue","green","gray", "red"]
number=0
for i in range(20):
    for number2 in range(i,100,20):
        plt.plot(Traces2[1]['tracesData'][number]['t'][1:],Traces2[1]['tracesData'][number]['cell_'+str(number)+'_V_soma']-Traces2[1]['tracesData'][number]['cell_'+str(number)+'_V_soma'][999]-0.5*i, label= sim.net.allCells[number]['tags']['pop'] + '_' + sim.net.allCells[number]['conns'][0]['sec'], linewidth=1.0, color=clr[i])
        number+=1
        
plt.legend(loc='upper right', bbox_to_anchor=(1.25, 1.0), fontsize=8)
# plt.xlim(2400,4150)
plt.ylim(-10.25,1.0)
plt.xlabel('Time (ms)', fontsize=16)
plt.ylabel('EPSP (mV)', fontsize=16)
# plt.xticks(range(2400,3900,200), range(0,1500,200), fontsize=14);
plt.yticks([0,-1], fontsize=14);

# %%
figSize = (8,5)
fig = plt.figure(figsize=figSize)  # Open a new figure
for number in range(np.shape(alltraces)[0]):
    plt.plot(alltraces[number]-alltraces[number][0],color = 'lightgray',linewidth=2.0)

plt.title('Vrev -80 mV and gsyn = 100p  ->  %.2f ± %.2f mV' % (np.mean(gmax1),np.std(gmax1)), fontsize=14)
plt.plot(np.mean(alltraces, axis=0)-np.mean(alltraces, axis=0)[0],color = 'black', linewidth=4.0)
# plt.legend(loc='upper right', bbox_to_anchor=(0.95, 1.0))
plt.xlim(500,12000)
plt.ylim(0.25,-1.0)
plt.xlabel('Time (ms)', fontsize=16)
plt.ylabel('PSP (mV)', fontsize=16)
plt.xticks(range(1000,12000,2000), range(0,1100,200), fontsize=14);
plt.yticks([0,-1], fontsize=14); 

plt.savefig('../info/syn_gmax_INH_L5PC_type8.png', facecolor = 'white' , dpi=300)

# %%
# (0.8355167606552806, 25)

# %%
np.mean(gmax1), np.size(gmax1)
# Out:
# (0.3293689637378232, 100)

# %% [markdown]
# <!-- Connection type	s-type	in vitro PSP amplitude (mV; mean ± SD)	in silico PSP amplitude (mV; mean ± SD)	Input data sources
# L5TTPC-L5MC	E1	0.28 ± 0.3	0.28 ± 0.18	Silberberg & Markram, 2007
# L5MC-L5TTPC	I2	0.5 ± 0.3	0.57 ± 0.5	Silberberg & Markram, 2007
# L4SS-L23PC	E2	0.7 ± 0.6	0.7 ± 0.9	Feldmeyer et al. 2002
# L5STPC-L5STPC	E2	0.9 ± 0.7	0.91 ± 0.8	Le Bé et al. 2007
# L5UTPC-L5UTPC	E2	0.9 ± 0.7	0.91 ± 0.8	Le Bé et al. 2007
# L23PC-L23PC	E2	1 ± 0.7	1 ± 0.3	Feldmeyer et al. 2006
# L23LBC-L23PC	I2	1.2 ± 1.1	1.2 ± 1.02	Blatow et al. 2003
# L23NBC-L23PC	I2	1.2 ± 1.1	1.2 ± 1.02	Blatow et al. 2003
# L5TTPC-L5TTPC	E2	1.3 ± 1.1	1.2 ± 0.43	Markram et al. 1997
# L4SS-L4SS	E2	1.6 ± 1.0	1.9 ± 1.5	Feldmeyer et al. 1999
# L4SP-L4SP	E2	1.6 ± 1.0	1.9 ± 1.5	Feldmeyer et al. 1999
# L4PC-L4PC	E2	1.6 ± 1.0	1.9 ± 1.5	Feldmeyer et al. 1999
# L5TTPC-L5SBC	E2	2.1 ± 1.0	1.96 ± 0.67	Angulo et al. 1999 -->
# ![image.png](attachment:image.png)

# %%
Connectiontype = ['L5TTPC_L5MC_E1', 'L5MC_L5TTPC_I2', 'L4SS_L23PC_E2', 'L5STPC_L5STPC_E2', 'L5UTPC_L5UTPC_E2', 'L23PC_L23PC_E2', 
                  'L23LBC_L23PC_I2', 'L23NBC_L23PC_I2', 'L5TTPC_L5TTPC_E2', 'L4SS_L4SS_E2', 'L4SP_L4SP_E2', 'L4PC_L4PC_E2', 'L5TTPC_L5SBC_E2']

# %%
table13c = [0.28, 0.3, 0.28, 0.18, 0.50, 0.3, 0.57, 0.50, 0.70, 0.6, 0.70, 0.90, 0.90, 0.7, 0.91, 0.80, 0.90, 0.7, 0.91, 0.80, 
            1.00, 0.7, 1.00, 0.30, 1.20, 1.1, 1.20, 1.02, 1.20, 1.1, 1.20, 1.02, 1.30, 1.1, 1.20, 0.43, 1.60, 1.0, 1.90, 1.50, 
            1.60, 1.0, 1.90, 1.50, 1.60, 1.0, 1.90, 1.50, 2.10, 1.0, 1.96, 0.67]

# %%
x = []
sx = []
y = []
sy = []

for ii in range(13):
    print(Connectiontype[ii],table13c[4*ii],table13c[4*ii+1],table13c[4*ii+2],table13c[4*ii+3])
    x.append(table13c[4*ii])
    sx.append(table13c[4*ii+1])
    y.append(table13c[4*ii+2])
    sy.append(table13c[4*ii+3])
# Out:
# L5TTPC_L5MC_E1 0.28 0.3 0.28 0.18
# L5MC_L5TTPC_I2 0.5 0.3 0.57 0.5
# L4SS_L23PC_E2 0.7 0.6 0.7 0.9
# L5STPC_L5STPC_E2 0.9 0.7 0.91 0.8
# L5UTPC_L5UTPC_E2 0.9 0.7 0.91 0.8
# L23PC_L23PC_E2 1.0 0.7 1.0 0.3
# L23LBC_L23PC_I2 1.2 1.1 1.2 1.02
# L23NBC_L23PC_I2 1.2 1.1 1.2 1.02
# L5TTPC_L5TTPC_E2 1.3 1.1 1.2 0.43
# L4SS_L4SS_E2 1.6 1.0 1.9 1.5
# L4SP_L4SP_E2 1.6 1.0 1.9 1.5
# L4PC_L4PC_E2 1.6 1.0 1.9 1.5
# L5TTPC_L5SBC_E2 2.1 1.0 1.96 0.67

# %%
import matplotlib.pyplot as plt

# a = [1, 3, 5, 7]
# b = [11, -2, 4, 19]
# plt.scatter(a, b)


# c = [1, 3, 2, 1]
# d = [1, 3, 2, 1]

# you can use color ="r" for red or skip to default as blue
# plt.errorbar(x, y, xerr=sx, yerr=sy, fmt="o", color="r")
plt.scatter(x, y)

plt.show()
